# %%
import sys
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from scipy import ndimage
from keras.optimizers import Adadelta,Adam
from keras.callbacks import TensorBoard, CSVLogger, ModelCheckpoint
# from lipnet.lipreading.generators import BasicGenerator
# from lipnet.lipreading.callbacks import Statistics, Visualize
# from lipnet.lipreading.curriculums import Curriculum
# from lipnet.core.decoders import Decoder
# from lipnet.lipreading.helpers import labels_to_text
# from lipnet.utils.spell import Spell
from lipnet.model2 import LipNet
import numpy as np
import datetime
import cv2
import skvideo.io
import dlib
from scipy.misc import imresize
# from lipnet.lipreading.aligns import Align
import imageio
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
import random
import tensorflow as tf
import keras.backend as K
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

FACE_PREDICTOR_PATH  = os.path.join('common','predictors','shape_predictor_68_face_landmarks.dat')
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(FACE_PREDICTOR_PATH)

frames_count = 30
words_folder = 'training/unseen_speakers/datasets/lipread_mp4'
words = os.listdir(words_folder)
words = ['Building','Absolutely','Winds'
,'Figures'
,'Years'
# ,'Series'
# ,'Given'
# ,'Questions'
# ,'Phone'
# ,'Justice'
# ,'Human'
# ,'Powers'
# ,'Former'
# ,'Should'
# ,'Guilty'
,'Having'
,'Their'
,'Often'
,'Facing'
,'Every'] #words[:2]
words = [s.upper() for s in words]
max_len = 12 #np.max([len(word) for word in words])
used_words = {''}
print(words)
def datagen(data_partition = 'train', batch_size = 16):
    while True:
        counter = 0
        word_idx = np.random.randint(len(words))
        used_words.add(words[word_idx])
        train_folder = 'training/unseen_speakers/datasets/lipread_mp4/{0}/{1}/'.format(words[word_idx],data_partition)
    #         print(train_folder)
        files = os.listdir(train_folder)
        paths = list(set([x.split('.')[0] for x in files]))
        
        X_data = []#np.zeros((batch_size,))
        Y_data = []
        input_length = []
        label_length = []
        source_str = []
        while counter<batch_size:
#             print(counter)
            idx = np.random.randint(len(paths))
            path = os.path.join(train_folder,paths[idx]+'.mp4')
    #         src_str_path = os.path.join(train_folder,paths[idx]+'.txt')
    #         with open(src_str_path) as f:
    #             l = f.readlines()
    #             print(l)

            vid = imageio.get_reader(path,  'ffmpeg')
            frames = []
            end = 0
            for i in range(frames_count):
                end = i
                frames.append(vid.get_data(i))

            ###
#             print('vedio frame shape:',np.shape(frames), data_partition, paths[idx])
            frames = get_frames_mouth(detector,predictor, frames, paths[idx])
            
            # for completely turned faces dlib cant identify the lip hence cannot crop
            # this check ensures only vid croppings which are 50x100x3 are added in batch
#             print('mouth frame shape:',np.shape(frames), data_partition, paths[idx])

            if 'numpy.ndarray' in str(type(frames)) \
                    and len(np.shape(frames))==4 \
                    and np.shape(frames)[1] == 100 \
                    and np.shape(frames)[2] == 50:
            
                X_data.append(frames)


                ####
                Y_data.append([ord(c) - 65 for c in words[word_idx]]+[-1]*(max_len-len(words[word_idx])))
                input_length.append(frames_count)
                label_length.append(len(words[word_idx]))
                source_str.append(words[word_idx])
                counter+=1
            else:
                continue
        
        X_data = np.array(X_data).astype(np.float32) / 255 
        Y_data = np.array(Y_data)
        input_length = np.array(input_length)
        label_length = np.array(label_length)
        source_str = np.array(source_str)
        
        inputs = {'the_input': X_data,
                  'the_labels': Y_data,
                  'input_length': input_length,
                  'label_length': label_length,
                  'source_str': source_str  # used for visualization only
                  }
        outputs = {'ctc': np.zeros([batch_size])}
        
#         print('the_input:', inputs['the_input'].shape)
#         print('the_labels:', inputs['the_labels'].shape)
#         print('input_length:', inputs['input_length'].shape)
#         print('label_length:', inputs['label_length'].shape)
#         print('source_str:', inputs['source_str'].shape)
#         print('batch_frames_shape',X_data.shape, data_partition)
        yield (inputs, outputs)
# Out:
# ['BUILDING', 'ABSOLUTELY', 'WINDS', 'FIGURES', 'YEARS', 'HAVING', 'THEIR', 'OFTEN', 'FACING', 'EVERY']

# %%
def get_frames_mouth(detector, predictor, frames, word):
    try:
        MOUTH_WIDTH = 100
        MOUTH_HEIGHT = 50
        HORIZONTAL_PAD = 0.19
        normalize_ratio = None
        mouth_frames = []
        for frame in frames:
            dets = detector(frame, 1)
            shape = None
            for k, d in enumerate(dets):
                shape = predictor(frame, d)
                i = -1
            if shape is None: # Detector doesn't detect face, just return as is
                return frames
            mouth_points = []
            for part in shape.parts():
                i += 1
                if i < 48: # Only take mouth region
                    continue
                mouth_points.append((part.x,part.y))
            np_mouth_points = np.array(mouth_points)

            mouth_centroid = np.mean(np_mouth_points[:, -2:], axis=0)

            if normalize_ratio is None:
                mouth_left = np.min(np_mouth_points[:, :-1]) * (1.0 - HORIZONTAL_PAD)
                mouth_right = np.max(np_mouth_points[:, :-1]) * (1.0 + HORIZONTAL_PAD)

                normalize_ratio = MOUTH_WIDTH / float(mouth_right - mouth_left)

            new_img_shape = (int(frame.shape[0] * normalize_ratio), int(frame.shape[1] * normalize_ratio))
            resized_img = imresize(frame, new_img_shape)

            mouth_centroid_norm = mouth_centroid * normalize_ratio

            mouth_l = int(mouth_centroid_norm[0] - MOUTH_WIDTH / 2)
            mouth_r = int(mouth_centroid_norm[0] + MOUTH_WIDTH / 2)
            mouth_t = int(mouth_centroid_norm[1] - MOUTH_HEIGHT / 2)
            mouth_b = int(mouth_centroid_norm[1] + MOUTH_HEIGHT / 2)

            mouth_crop_image = resized_img[mouth_t:mouth_b, mouth_l:mouth_r]
            
            mouth_frames.append(ndimage.rotate(mouth_crop_image, 90))
    #     print('shape mouth frames:',np.shape(mouth_frames))
        return np.array(mouth_frames)
    except Exception as e:
        print(e)
        print(word)
        return []

# %%
# global lip_gen

run_name = datetime.datetime.now().strftime('%Y:%m:%d_%H:%M:%S')
run_name, start_epoch, stop_epoch, img_c, img_w, img_h, frames_n, absolute_max_string_len, minibatch_size = \
    run_name, 0, 1000, 3, 100, 50, 30, 12, 2



CURRENT_PATH = os.getcwd()+'/training/unseen_speakers'
DATASET_DIR  = os.path.join(CURRENT_PATH, 'datasets')
OUTPUT_DIR   = os.path.join(CURRENT_PATH, 'results')
LOG_DIR      = os.path.join(CURRENT_PATH, 'logs')
# if not os.path.exists('training/unseen_speakers/results/'+run_name):
#     os.makedirs('training/unseen_speakers/results/'+run_name)
if not os.path.exists('training/unseen_speakers/logs/'+run_name):
    os.makedirs('training/unseen_speakers/logs/'+run_name)

PREDICT_GREEDY      = False
PREDICT_BEAM_WIDTH  = 200
PREDICT_DICTIONARY  = os.path.join(CURRENT_PATH,'..','..','common','dictionaries','lfw.txt')
FACE_PREDICTOR_PATH  = os.path.join(CURRENT_PATH,'..','..','common','predictors','shape_predictor_68_face_landmarks.dat')

# def curriculum_rules(epoch):
#     return { 'sentence_length': -1, 'flip_probability': 0.5, 'jitter_probability': 0.05 }


# # def train(run_name, start_epoch, stop_epoch, img_c, img_w, img_h, frames_n, absolute_max_string_len, minibatch_size):
# curriculum = Curriculum(curriculum_rules)
# lip_gen = BasicGenerator(dataset_path=DATASET_DIR, #vtype = "face", face_predictor_path = FACE_PREDICTOR_PATH,
#                             minibatch_size=minibatch_size,
#                             img_c=img_c, img_w=img_w, img_h=img_h, frames_n=frames_n,
#                             absolute_max_string_len=absolute_max_string_len,
#                             curriculum=curriculum, start_epoch=start_epoch).build()
# lip_gen_train = datagen(data_partition='train', batch_size=5)
# lip_gen_val = datagen(data_partition='val', batch_size=5)

lipnet = LipNet(img_c=img_c, img_w=img_w, img_h=img_h, frames_n=frames_n,
                        absolute_max_string_len=absolute_max_string_len, output_size=27)
# lipnet.summary()
# adadelta = Adadelta(lr=0.0001, decay=1e-08, epsilon=1e-08)

adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=1e-08)

# the loss calc occurs elsewhere, so use a dummy lambda func for the loss
lipnet.model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=adam, metrics=['accuracy'])


# spell = Spell(path=PREDICT_DICTIONARY)
# decoder = Decoder(greedy=PREDICT_GREEDY, beam_width=PREDICT_BEAM_WIDTH,
#                   postprocessors=[labels_to_text, spell.sentence])

# define callbacks
# statistics  = Statistics(lipnet, lip_gen.next_val(), decoder, 256, output_dir=os.path.join(OUTPUT_DIR, run_name))
# visualize   = Visualize(os.path.join(OUTPUT_DIR, run_name), lipnet, lip_gen.next_val(), decoder, num_display_sentences=minibatch_size)
tensorboard = TensorBoard(log_dir=os.path.join(LOG_DIR, 'twenty-'+run_name))
# csv_logger  = CSVLogger(os.path.join(LOG_DIR, "{}-{}.csv".format('training',run_name)), separator=',', append=True)
checkpoint  = ModelCheckpoint(save_best_only=True,
                              filepath='training/unseen_speakers/results/weights_lfw-ten.hdf5'
                              , monitor='val_loss'
                              , verbose=1
                              , mode='min'
                              , period=1)
    
    # x = next(lip_gen.next_val())
    # for i in x:
    #     print('$$$$$----------', type(i))
# Out:
# y_pred (?, 30, 27)

# %%
# run_name = datetime.datetime.now().strftime('%Y:%m:%d:%H:%M:%S')
# train(run_name, 0, 1000, 3, 100, 50, 75, 32, 2)

# %%
# os.getcwd()+'training/unseen_speakers'

# %%
# g=lip_gen.next_train()
# inputs, outputs = next(g)

# %%
# inputs

# %%
# len('place green at t six now')

# %%
# len([ 15.,  11.,   0.,   2.,   4.,  26.,   6.,  17.,   4.,   4.,  13.,
#           26.,   0.,  19.,  26.,  19.,  26.,  18.,   8.,  23.,  26.,  13.,
#           14.,  22.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.])

# %%
# outputs

# %%
# load weight if necessary

start_epoch = 17084
if start_epoch > 0:
    weight_file = os.path.join(OUTPUT_DIR, 'weights_lfw-ten.hdf5')
    lipnet.model.load_weights(weight_file)

lipnet.model.fit_generator(generator=datagen(data_partition='train', batch_size=4),
                    steps_per_epoch=1
                    , epochs=50000,
                    #steps_per_epoch=lip_gen.default_training_steps, epochs=stop_epoch,
                    validation_data=datagen(data_partition='val', batch_size=4)
                    , validation_steps=1,#validation_steps=lip_gen.default_validation_steps,
                    callbacks=[checkpoint,tensorboard],                         
                    initial_epoch=start_epoch, 
                    verbose=1)
                    #max_q_size=5,
                    #workers=2,
                    #pickle_safe=True)
# Out:
# Epoch 17085/50000
# 1/1 [==============================] - 15s 15s/step - loss: 4.1436 - acc: 0.0000e+00 - val_loss: 17.8083 - val_acc: 0.0000e+00
#
# Epoch 17085: val_loss improved from inf to 17.80834, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17086/50000
# 1/1 [==============================] - 7s 7s/step - loss: 12.7777 - acc: 0.0000e+00 - val_loss: 12.8267 - val_acc: 0.0000e+00
#
# Epoch 17086: val_loss improved from 17.80834 to 12.82666, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17087/50000
# 1/1 [==============================] - 10s 10s/step - loss: 11.3588 - acc: 0.0000e+00 - val_loss: 12.2712 - val_acc: 0.0000e+00
#
# Epoch 17087: val_loss improved from 12.82666 to 12.27119, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17088/50000
# 1/1 [==============================] - 10s 10s/step - loss: 13.6864 - acc: 0.0000e+00 - val_loss: 9.7022 - val_acc: 0.0000e+00
#
# Epoch 17088: val_loss improved from 12.27119 to 9.70217, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17089/50000
# 1/1 [==============================] - 10s 10s/step - loss: 10.5199 - acc: 0.0000e+00 - val_loss: 15.8912 - val_acc: 0.0000e+00
#
# Epoch 17089: val_loss did not improve from 9.70217
# Epoch 17090/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.1403 - acc: 0.0000e+00 - val_loss: 11.3370 - val_acc: 0.0000e+00
#
# Epoch 17090: val_loss did not improve from 9.70217
# Epoch 17091/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.5213 - acc: 0.0000e+00 - val_loss: 21.1810 - val_acc: 0.0000e+00
#
# Epoch 17091: val_loss did not improve from 9.70217
# Epoch 17092/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.7999 - acc: 0.0000e+00 - val_loss: 9.1216 - val_acc: 0.0000e+00
#
# Epoch 17092: val_loss improved from 9.70217 to 9.12156, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17093/50000
# 1/1 [==============================] - 10s 10s/step - loss: 11.4255 - acc: 0.0000e+00 - val_loss: 8.3093 - val_acc: 0.0000e+00
#
# Epoch 17093: val_loss improved from 9.12156 to 8.30929, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17094/50000
# 1/1 [==============================] - 10s 10s/step - loss: 9.3236 - acc: 0.0000e+00 - val_loss: 11.5799 - val_acc: 0.0000e+00
#
# Epoch 17094: val_loss did not improve from 8.30929
# Epoch 17095/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.5377 - acc: 0.0000e+00 - val_loss: 6.0196 - val_acc: 0.0000e+00
#
# Epoch 17095: val_loss improved from 8.30929 to 6.01961, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17096/50000
# 1/1 [==============================] - 10s 10s/step - loss: 11.3395 - acc: 0.0000e+00 - val_loss: 8.0690 - val_acc: 0.0000e+00
#
# Epoch 17096: val_loss did not improve from 6.01961
# Epoch 17097/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6540 - acc: 0.0000e+00 - val_loss: 12.5681 - val_acc: 0.0000e+00
#
# Epoch 17097: val_loss did not improve from 6.01961
# Epoch 17098/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.3294 - acc: 0.0000e+00 - val_loss: 7.6203 - val_acc: 0.0000e+00
#
# Epoch 17098: val_loss did not improve from 6.01961
# Epoch 17099/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.9876 - acc: 0.0000e+00 - val_loss: 17.9569 - val_acc: 0.0000e+00
#
# Epoch 17099: val_loss did not improve from 6.01961
# Epoch 17100/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.1594 - acc: 0.0000e+00 - val_loss: 11.5991 - val_acc: 0.0000e+00
#
# Epoch 17100: val_loss did not improve from 6.01961
# Epoch 17101/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.3119 - acc: 0.0000e+00 - val_loss: 7.4412 - val_acc: 0.0000e+00
#
# Epoch 17101: val_loss did not improve from 6.01961
# Epoch 17102/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.5765 - acc: 0.0000e+00 - val_loss: 7.3962 - val_acc: 0.0000e+00
#
# Epoch 17102: val_loss did not improve from 6.01961
# Epoch 17103/50000
# 1/1 [==============================] - 11s 11s/step - loss: 22.7965 - acc: 0.0000e+00 - val_loss: 9.3013 - val_acc: 0.0000e+00
#
# Epoch 17103: val_loss did not improve from 6.01961
# Epoch 17104/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.3030 - acc: 0.0000e+00 - val_loss: 11.0866 - val_acc: 0.0000e+00
#
# Epoch 17104: val_loss did not improve from 6.01961
# Epoch 17105/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.2420 - acc: 0.0000e+00 - val_loss: 10.4384 - val_acc: 0.0000e+00
#
# Epoch 17105: val_loss did not improve from 6.01961
# Epoch 17106/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.7633 - acc: 0.0000e+00 - val_loss: 20.2716 - val_acc: 0.0000e+00
#
# Epoch 17106: val_loss did not improve from 6.01961
# Epoch 17107/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.4976 - acc: 0.0000e+00 - val_loss: 11.8107 - val_acc: 0.0000e+00
#
# Epoch 17107: val_loss did not improve from 6.01961
# Epoch 17108/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.9199 - acc: 0.0000e+00 - val_loss: 17.5691 - val_acc: 0.0000e+00
#
# Epoch 17108: val_loss did not improve from 6.01961
# Epoch 17109/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.4901 - acc: 0.0000e+00 - val_loss: 7.9249 - val_acc: 0.0000e+00
#
# Epoch 17109: val_loss did not improve from 6.01961
# Epoch 17110/50000
# 1/1 [==============================] - 12s 12s/step - loss: 9.1359 - acc: 0.0000e+00 - val_loss: 12.2586 - val_acc: 0.0000e+00
#
# Epoch 17110: val_loss did not improve from 6.01961
# Epoch 17111/50000
# 1/1 [==============================] - 11s 11s/step - loss: 17.2404 - acc: 0.0000e+00 - val_loss: 9.7710 - val_acc: 0.0000e+00
#
# Epoch 17111: val_loss did not improve from 6.01961
# Epoch 17112/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3982 - acc: 0.0000e+00 - val_loss: 12.4499 - val_acc: 0.0000e+00
#
# Epoch 17112: val_loss did not improve from 6.01961
# Epoch 17113/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.5443 - acc: 0.0000e+00 - val_loss: 17.9056 - val_acc: 0.0000e+00
#
# Epoch 17113: val_loss did not improve from 6.01961
# Epoch 17114/50000
# 1/1 [==============================] - 13s 13s/step - loss: 11.4345 - acc: 0.0000e+00 - val_loss: 5.8997 - val_acc: 0.0000e+00
#
# Epoch 17114: val_loss improved from 6.01961 to 5.89972, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17115/50000
# 1/1 [==============================] - 10s 10s/step - loss: 16.8856 - acc: 0.0000e+00 - val_loss: 7.8974 - val_acc: 0.0000e+00
#
# Epoch 17115: val_loss did not improve from 5.89972
# Epoch 17116/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.4818 - acc: 0.0000e+00 - val_loss: 10.4910 - val_acc: 0.0000e+00
#
# Epoch 17116: val_loss did not improve from 5.89972
# Epoch 17117/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.1106 - acc: 0.0000e+00 - val_loss: 11.4707 - val_acc: 0.0000e+00
#
# Epoch 17117: val_loss did not improve from 5.89972
# Epoch 17118/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.1359 - acc: 0.0000e+00 - val_loss: 17.0807 - val_acc: 0.0000e+00
#
# Epoch 17118: val_loss did not improve from 5.89972
# Epoch 17119/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.2285 - acc: 0.0000e+00 - val_loss: 13.3749 - val_acc: 0.0000e+00
#
# Epoch 17119: val_loss did not improve from 5.89972
# Epoch 17120/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3622 - acc: 0.0000e+00 - val_loss: 19.7320 - val_acc: 0.0000e+00
#
# Epoch 17120: val_loss did not improve from 5.89972
# Epoch 17121/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.1941 - acc: 0.0000e+00 - val_loss: 11.4080 - val_acc: 0.0000e+00
#
# Epoch 17121: val_loss did not improve from 5.89972
# Epoch 17122/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.8034 - acc: 0.0000e+00 - val_loss: 11.0287 - val_acc: 0.0000e+00
#
# Epoch 17122: val_loss did not improve from 5.89972
# Epoch 17123/50000
# 1/1 [==============================] - 11s 11s/step - loss: 18.4337 - acc: 0.0000e+00 - val_loss: 11.1706 - val_acc: 0.0000e+00
# Epoch 17123: val_loss did not improve from 5.89972
# Epoch 17124/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.9745 - acc: 0.0000e+00 - val_loss: 16.1313 - val_acc: 0.0000e+00
#
# Epoch 17124: val_loss did not improve from 5.89972
# Epoch 17125/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.0904 - acc: 0.0000e+00 - val_loss: 6.7922 - val_acc: 0.0000e+00
#
# Epoch 17125: val_loss did not improve from 5.89972
# Epoch 17126/50000
# 1/1 [==============================] - 11s 11s/step - loss: 6.6897 - acc: 0.0000e+00 - val_loss: 9.4012 - val_acc: 0.0000e+00
#
# Epoch 17126: val_loss did not improve from 5.89972
# Epoch 17127/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.6141 - acc: 0.0000e+00 - val_loss: 6.2552 - val_acc: 0.0000e+00
#
# Epoch 17127: val_loss did not improve from 5.89972
# Epoch 17128/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.4304 - acc: 0.0000e+00 - val_loss: 21.7106 - val_acc: 0.0000e+00
#
# Epoch 17128: val_loss did not improve from 5.89972
# Epoch 17129/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.7348 - acc: 0.0000e+00 - val_loss: 6.8428 - val_acc: 0.0000e+00
#
# Epoch 17129: val_loss did not improve from 5.89972
# Epoch 17130/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.9777 - acc: 0.0000e+00 - val_loss: 12.8312 - val_acc: 0.0000e+00
#
# Epoch 17130: val_loss did not improve from 5.89972
# Epoch 17131/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.9043 - acc: 0.0000e+00 - val_loss: 19.5889 - val_acc: 0.0000e+00
#
# Epoch 17131: val_loss did not improve from 5.89972
# Epoch 17132/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.2560 - acc: 0.0000e+00 - val_loss: 3.8262 - val_acc: 0.0000e+00
#
# Epoch 17132: val_loss improved from 5.89972 to 3.82616, saving model to training/unseen_speakers/results/weights_lfw-ten.hdf5
# Epoch 17133/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.0340 - acc: 0.0000e+00 - val_loss: 23.2357 - val_acc: 0.0000e+00
#
# Epoch 17133: val_loss did not improve from 3.82616
# Epoch 17134/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.8933 - acc: 0.0000e+00 - val_loss: 4.8270 - val_acc: 0.0000e+00
#
# Epoch 17134: val_loss did not improve from 3.82616
# Epoch 17135/50000
# 1/1 [==============================] - 11s 11s/step - loss: 17.0430 - acc: 0.0000e+00 - val_loss: 11.3495 - val_acc: 0.0000e+00
#
# Epoch 17135: val_loss did not improve from 3.82616
# Epoch 17136/50000
# 1/1 [==============================] - 15s 15s/step - loss: 9.4110 - acc: 0.0000e+00 - val_loss: 9.2760 - val_acc: 0.0000e+00
#
# Epoch 17136: val_loss did not improve from 3.82616
# Epoch 17137/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.4290 - acc: 0.0000e+00 - val_loss: 17.6399 - val_acc: 0.0000e+00
#
# Epoch 17137: val_loss did not improve from 3.82616
# Epoch 17138/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.2026 - acc: 0.0000e+00 - val_loss: 17.3241 - val_acc: 0.0000e+00
#
# Epoch 17138: val_loss did not improve from 3.82616
# Epoch 17139/50000
# 1/1 [==============================] - 13s 13s/step - loss: 9.9705 - acc: 0.0000e+00 - val_loss: 11.8921 - val_acc: 0.0000e+00
#
# Epoch 17139: val_loss did not improve from 3.82616
# Epoch 17140/50000
# 1/1 [==============================] - 14s 14s/step - loss: 20.3165 - acc: 0.0000e+00 - val_loss: 10.1604 - val_acc: 0.0000e+00
#
# Epoch 17140: val_loss did not improve from 3.82616
# Epoch 17141/50000
# 1/1 [==============================] - 11s 11s/step - loss: 19.0608 - acc: 0.0000e+00 - val_loss: 11.9788 - val_acc: 0.0000e+00
#
# Epoch 17141: val_loss did not improve from 3.82616
# Epoch 17142/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6924 - acc: 0.0000e+00 - val_loss: 20.7142 - val_acc: 0.0000e+00
#
# Epoch 17142: val_loss did not improve from 3.82616
# Epoch 17143/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.0048 - acc: 0.0000e+00 - val_loss: 11.1515 - val_acc: 0.0000e+00
#
# Epoch 17143: val_loss did not improve from 3.82616
# Epoch 17144/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.4526 - acc: 0.0000e+00 - val_loss: 8.0206 - val_acc: 0.0000e+00
#
# Epoch 17144: val_loss did not improve from 3.82616
# Epoch 17145/50000
# 1/1 [==============================] - 10s 10s/step - loss: 11.0215 - acc: 0.0000e+00 - val_loss: 11.8145 - val_acc: 0.0000e+00
#
# Epoch 17145: val_loss did not improve from 3.82616
# Epoch 17146/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6583 - acc: 0.0000e+00 - val_loss: 10.9405 - val_acc: 0.0000e+00
#
# Epoch 17146: val_loss did not improve from 3.82616
# Epoch 17147/50000
# 1/1 [==============================] - 13s 13s/step - loss: 11.4469 - acc: 0.0000e+00 - val_loss: 10.3821 - val_acc: 0.0000e+00
#
# Epoch 17147: val_loss did not improve from 3.82616
# Epoch 17148/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.7412 - acc: 0.0000e+00 - val_loss: 8.4501 - val_acc: 0.0000e+00
#
# Epoch 17148: val_loss did not improve from 3.82616
# Epoch 17149/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.9410 - acc: 0.0000e+00 - val_loss: 10.9067 - val_acc: 0.0000e+00
#
# Epoch 17149: val_loss did not improve from 3.82616
# Epoch 17150/50000
# 1/1 [==============================] - 11s 11s/step - loss: 16.4056 - acc: 0.0000e+00 - val_loss: 12.4897 - val_acc: 0.0000e+00
#
# Epoch 17150: val_loss did not improve from 3.82616
# Epoch 17151/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6534 - acc: 0.0000e+00 - val_loss: 11.8383 - val_acc: 0.0000e+00
#
# Epoch 17151: val_loss did not improve from 3.82616
# Epoch 17152/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.3852 - acc: 0.0000e+00 - val_loss: 16.4394 - val_acc: 0.0000e+00
#
# Epoch 17152: val_loss did not improve from 3.82616
# Epoch 17153/50000
# 1/1 [==============================] - 10s 10s/step - loss: 10.3712 - acc: 0.0000e+00 - val_loss: 11.2653 - val_acc: 0.0000e+00
#
# Epoch 17153: val_loss did not improve from 3.82616
# Epoch 17154/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.4181 - acc: 0.0000e+00 - val_loss: 9.3459 - val_acc: 0.0000e+00
#
# Epoch 17154: val_loss did not improve from 3.82616
# Epoch 17155/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.0057 - acc: 0.0000e+00 - val_loss: 13.4443 - val_acc: 0.0000e+00
#
# Epoch 17155: val_loss did not improve from 3.82616
# Epoch 17156/50000
# 1/1 [==============================] - 11s 11s/step - loss: 15.1757 - acc: 0.0000e+00 - val_loss: 11.7735 - val_acc: 0.0000e+00
#
# Epoch 17156: val_loss did not improve from 3.82616
# Epoch 17157/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3360 - acc: 0.0000e+00 - val_loss: 9.9059 - val_acc: 0.0000e+00
#
# Epoch 17157: val_loss did not improve from 3.82616
# Epoch 17158/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.0743 - acc: 0.0000e+00 - val_loss: 15.8831 - val_acc: 0.0000e+00
#
# Epoch 17158: val_loss did not improve from 3.82616
# Epoch 17159/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.8502 - acc: 0.0000e+00 - val_loss: 14.7919 - val_acc: 0.0000e+00
#
# Epoch 17159: val_loss did not improve from 3.82616
# Epoch 17160/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.6206 - acc: 0.0000e+00 - val_loss: 9.5139 - val_acc: 0.0000e+00
#
# Epoch 17160: val_loss did not improve from 3.82616
# Epoch 17161/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.7854 - acc: 0.0000e+00 - val_loss: 18.0195 - val_acc: 0.0000e+00
#
# Epoch 17161: val_loss did not improve from 3.82616
# Epoch 17162/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.4952 - acc: 0.0000e+00 - val_loss: 11.4898 - val_acc: 0.0000e+00
#
# Epoch 17162: val_loss did not improve from 3.82616
# Epoch 17163/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6851 - acc: 0.0000e+00 - val_loss: 15.7477 - val_acc: 0.0000e+00
#
# Epoch 17163: val_loss did not improve from 3.82616
# Epoch 17164/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.7338 - acc: 0.0000e+00 - val_loss: 9.8514 - val_acc: 0.0000e+00
#
# Epoch 17164: val_loss did not improve from 3.82616
# Epoch 17165/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.1642 - acc: 0.0000e+00 - val_loss: 9.7866 - val_acc: 0.0000e+00
#
# Epoch 17165: val_loss did not improve from 3.82616
# Epoch 17166/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.5696 - acc: 0.0000e+00 - val_loss: 16.0988 - val_acc: 0.0000e+00
#
# Epoch 17166: val_loss did not improve from 3.82616
# Epoch 17167/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.7870 - acc: 0.0000e+00 - val_loss: 9.7858 - val_acc: 0.0000e+00
#
# Epoch 17167: val_loss did not improve from 3.82616
# Epoch 17168/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.7133 - acc: 0.0000e+00 - val_loss: 12.1816 - val_acc: 0.0000e+00
#
# Epoch 17168: val_loss did not improve from 3.82616
# Epoch 17169/50000
# 1/1 [==============================] - 13s 13s/step - loss: 9.0393 - acc: 0.0000e+00 - val_loss: 11.8703 - val_acc: 0.0000e+00
#
# Epoch 17169: val_loss did not improve from 3.82616
# Epoch 17170/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.3755 - acc: 0.0000e+00 - val_loss: 16.1948 - val_acc: 0.0000e+00
#
# Epoch 17170: val_loss did not improve from 3.82616
# Epoch 17171/50000
# 1/1 [==============================] - 11s 11s/step - loss: 6.6105 - acc: 0.0000e+00 - val_loss: 7.5545 - val_acc: 0.0000e+00
#
# Epoch 17171: val_loss did not improve from 3.82616
# Epoch 17172/50000
# 1/1 [==============================] - 11s 11s/step - loss: 16.7105 - acc: 0.0000e+00 - val_loss: 13.7169 - val_acc: 0.0000e+00
#
# Epoch 17172: val_loss did not improve from 3.82616
# Epoch 17173/50000
# 1/1 [==============================] - 13s 13s/step - loss: 16.8215 - acc: 0.0000e+00 - val_loss: 10.8498 - val_acc: 0.0000e+00
#
# Epoch 17173: val_loss did not improve from 3.82616
# Epoch 17174/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.9542 - acc: 0.0000e+00 - val_loss: 10.0359 - val_acc: 0.0000e+00
#
# Epoch 17174: val_loss did not improve from 3.82616
# Epoch 17175/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.1444 - acc: 0.0000e+00 - val_loss: 10.0131 - val_acc: 0.0000e+00
#
# Epoch 17175: val_loss did not improve from 3.82616
# Epoch 17176/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.2272 - acc: 0.0000e+00 - val_loss: 21.9095 - val_acc: 0.0000e+00
#
# Epoch 17176: val_loss did not improve from 3.82616
# Epoch 17177/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.5142 - acc: 0.0000e+00 - val_loss: 11.3707 - val_acc: 0.0000e+00
#
# Epoch 17177: val_loss did not improve from 3.82616
# Epoch 17178/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.4356 - acc: 0.0000e+00 - val_loss: 10.9535 - val_acc: 0.0000e+00
#
# Epoch 17178: val_loss did not improve from 3.82616
# Epoch 17179/50000
# 1/1 [==============================] - 11s 11s/step - loss: 20.9063 - acc: 0.0000e+00 - val_loss: 10.1972 - val_acc: 0.0000e+00
#
# Epoch 17179: val_loss did not improve from 3.82616
# Epoch 17180/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.1240 - acc: 0.0000e+00 - val_loss: 9.9319 - val_acc: 0.0000e+00
#
# Epoch 17180: val_loss did not improve from 3.82616
# Epoch 17181/50000
# 1/1 [==============================] - 11s 11s/step - loss: 4.2490 - acc: 0.0000e+00 - val_loss: 9.3791 - val_acc: 0.0000e+00
#
# Epoch 17181: val_loss did not improve from 3.82616
# Epoch 17182/50000
# 1/1 [==============================] - 11s 11s/step - loss: 15.5987 - acc: 0.0000e+00 - val_loss: 9.4885 - val_acc: 0.0000e+00
#
# Epoch 17182: val_loss did not improve from 3.82616
# Epoch 17183/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.0801 - acc: 0.0000e+00 - val_loss: 9.1612 - val_acc: 0.0000e+00
#
# Epoch 17183: val_loss did not improve from 3.82616
# Epoch 17184/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.3220 - acc: 0.0000e+00 - val_loss: 10.6614 - val_acc: 0.0000e+00
#
# Epoch 17184: val_loss did not improve from 3.82616
# Epoch 17185/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.1580 - acc: 0.0000e+00 - val_loss: 9.2985 - val_acc: 0.0000e+00
#
# Epoch 17185: val_loss did not improve from 3.82616
# Epoch 17186/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.1424 - acc: 0.0000e+00 - val_loss: 11.2017 - val_acc: 0.0000e+00
#
# Epoch 17186: val_loss did not improve from 3.82616
# Epoch 17187/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.4574 - acc: 0.0000e+00 - val_loss: 13.0526 - val_acc: 0.0000e+00
#
# Epoch 17187: val_loss did not improve from 3.82616
# Epoch 17188/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.4420 - acc: 0.0000e+00 - val_loss: 22.7271 - val_acc: 0.0000e+00
#
# Epoch 17188: val_loss did not improve from 3.82616
# Epoch 17189/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.5576 - acc: 0.0000e+00 - val_loss: 11.1787 - val_acc: 0.0000e+00
#
# Epoch 17189: val_loss did not improve from 3.82616
# Epoch 17190/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.4387 - acc: 0.0000e+00 - val_loss: 10.1810 - val_acc: 0.0000e+00
#
# Epoch 17190: val_loss did not improve from 3.82616
# Epoch 17191/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.9902 - acc: 0.0000e+00 - val_loss: 10.2581 - val_acc: 0.0000e+00
#
# Epoch 17191: val_loss did not improve from 3.82616
# Epoch 17192/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.0428 - acc: 0.0000e+00 - val_loss: 11.1222 - val_acc: 0.0000e+00
#
# Epoch 17192: val_loss did not improve from 3.82616
# Epoch 17193/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.4738 - acc: 0.0000e+00 - val_loss: 9.7440 - val_acc: 0.0000e+00
#
# Epoch 17193: val_loss did not improve from 3.82616
# Epoch 17194/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.3766 - acc: 0.0000e+00 - val_loss: 10.5375 - val_acc: 0.0000e+00
#
# Epoch 17194: val_loss did not improve from 3.82616
# Epoch 17195/50000
# 1/1 [==============================] - 11s 11s/step - loss: 17.0977 - acc: 0.0000e+00 - val_loss: 11.9010 - val_acc: 0.0000e+00
#
# Epoch 17195: val_loss did not improve from 3.82616
# Epoch 17196/50000
# 1/1 [==============================] - 13s 13s/step - loss: 18.3510 - acc: 0.0000e+00 - val_loss: 13.6910 - val_acc: 0.0000e+00
#
# Epoch 17196: val_loss did not improve from 3.82616
# Epoch 17197/50000
# 1/1 [==============================] - 11s 11s/step - loss: 16.2177 - acc: 0.0000e+00 - val_loss: 9.3011 - val_acc: 0.0000e+00
#
# Epoch 17197: val_loss did not improve from 3.82616
# Epoch 17198/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.4043 - acc: 0.0000e+00 - val_loss: 15.8584 - val_acc: 0.0000e+00
#
# Epoch 17198: val_loss did not improve from 3.82616
# Epoch 17199/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.0864 - acc: 0.0000e+00 - val_loss: 10.7603 - val_acc: 0.0000e+00
#
# Epoch 17199: val_loss did not improve from 3.82616
# Epoch 17200/50000
# could not broadcast input array from shape (100,50,3) into shape (100)
# WINDS_00042
# 1/1 [==============================] - 11s 11s/step - loss: 15.4267 - acc: 0.0000e+00 - val_loss: 21.9896 - val_acc: 0.0000e+00
#
# Epoch 17200: val_loss did not improve from 3.82616
# Epoch 17201/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3782 - acc: 0.0000e+00 - val_loss: 11.3237 - val_acc: 0.0000e+00
#
# Epoch 17201: val_loss did not improve from 3.82616
# Epoch 17202/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.5954 - acc: 0.0000e+00 - val_loss: 9.5369 - val_acc: 0.0000e+00
#
# Epoch 17202: val_loss did not improve from 3.82616
# Epoch 17203/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.8352 - acc: 0.0000e+00 - val_loss: 11.5077 - val_acc: 0.0000e+00
#
# Epoch 17203: val_loss did not improve from 3.82616
# Epoch 17204/50000
# 1/1 [==============================] - 10s 10s/step - loss: 17.8901 - acc: 0.0000e+00 - val_loss: 11.1322 - val_acc: 0.0000e+00
#
# Epoch 17204: val_loss did not improve from 3.82616
# Epoch 17205/50000
# 1/1 [==============================] - 15s 15s/step - loss: 10.5174 - acc: 0.0000e+00 - val_loss: 12.5724 - val_acc: 0.0000e+00
#
# Epoch 17205: val_loss did not improve from 3.82616
# Epoch 17206/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.2582 - acc: 0.0000e+00 - val_loss: 10.5498 - val_acc: 0.0000e+00
# Epoch 17206: val_loss did not improve from 3.82616
# Epoch 17207/50000
# 1/1 [==============================] - 11s 11s/step - loss: 5.1063 - acc: 0.0000e+00 - val_loss: 8.7068 - val_acc: 0.0000e+00
#
# Epoch 17207: val_loss did not improve from 3.82616
# Epoch 17208/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.6142 - acc: 0.0000e+00 - val_loss: 11.9729 - val_acc: 0.0000e+00
#
# Epoch 17208: val_loss did not improve from 3.82616
# Epoch 17209/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.3565 - acc: 0.0000e+00 - val_loss: 9.5675 - val_acc: 0.0000e+00
#
# Epoch 17209: val_loss did not improve from 3.82616
# Epoch 17210/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3840 - acc: 0.0000e+00 - val_loss: 12.1902 - val_acc: 0.0000e+00
#
# Epoch 17210: val_loss did not improve from 3.82616
# Epoch 17211/50000
# 1/1 [==============================] - 11s 11s/step - loss: 17.4335 - acc: 0.0000e+00 - val_loss: 9.8001 - val_acc: 0.0000e+00
#
# Epoch 17211: val_loss did not improve from 3.82616
# Epoch 17212/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.9251 - acc: 0.0000e+00 - val_loss: 9.2718 - val_acc: 0.0000e+00
#
# Epoch 17212: val_loss did not improve from 3.82616
# Epoch 17213/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6392 - acc: 0.0000e+00 - val_loss: 11.8649 - val_acc: 0.0000e+00
#
# Epoch 17213: val_loss did not improve from 3.82616
# Epoch 17214/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.7184 - acc: 0.0000e+00 - val_loss: 12.6007 - val_acc: 0.0000e+00
#
# Epoch 17214: val_loss did not improve from 3.82616
# Epoch 17215/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.0016 - acc: 0.0000e+00 - val_loss: 9.4049 - val_acc: 0.0000e+00
#
# Epoch 17215: val_loss did not improve from 3.82616
# Epoch 17216/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.2536 - acc: 0.0000e+00 - val_loss: 10.9817 - val_acc: 0.0000e+00
#
# Epoch 17216: val_loss did not improve from 3.82616
# Epoch 17217/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.2460 - acc: 0.0000e+00 - val_loss: 8.8595 - val_acc: 0.0000e+00
#
# Epoch 17217: val_loss did not improve from 3.82616
# Epoch 17218/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3386 - acc: 0.0000e+00 - val_loss: 17.4453 - val_acc: 0.0000e+00
#
# Epoch 17218: val_loss did not improve from 3.82616
# Epoch 17219/50000
# 1/1 [==============================] - 11s 11s/step - loss: 15.5098 - acc: 0.0000e+00 - val_loss: 9.0995 - val_acc: 0.0000e+00
#
# Epoch 17219: val_loss did not improve from 3.82616
# Epoch 17220/50000
# 1/1 [==============================] - 12s 12s/step - loss: 13.1617 - acc: 0.0000e+00 - val_loss: 11.5719 - val_acc: 0.0000e+00
#
# Epoch 17220: val_loss did not improve from 3.82616
# Epoch 17221/50000
# 1/1 [==============================] - 11s 11s/step - loss: 15.9241 - acc: 0.0000e+00 - val_loss: 8.8995 - val_acc: 0.0000e+00
#
# Epoch 17221: val_loss did not improve from 3.82616
# Epoch 17222/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.7320 - acc: 0.0000e+00 - val_loss: 9.3873 - val_acc: 0.0000e+00
#
# Epoch 17222: val_loss did not improve from 3.82616
# Epoch 17223/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.9059 - acc: 0.0000e+00 - val_loss: 12.5446 - val_acc: 0.0000e+00
#
# Epoch 17223: val_loss did not improve from 3.82616
# Epoch 17224/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.4331 - acc: 0.0000e+00 - val_loss: 10.1230 - val_acc: 0.0000e+00
#
# Epoch 17224: val_loss did not improve from 3.82616
# Epoch 17225/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.9782 - acc: 0.0000e+00 - val_loss: 12.0948 - val_acc: 0.0000e+00
#
# Epoch 17225: val_loss did not improve from 3.82616
# Epoch 17226/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.8440 - acc: 0.0000e+00 - val_loss: 14.5946 - val_acc: 0.0000e+00
#
# Epoch 17226: val_loss did not improve from 3.82616
# Epoch 17227/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.1823 - acc: 0.0000e+00 - val_loss: 11.9340 - val_acc: 0.0000e+00
#
# Epoch 17227: val_loss did not improve from 3.82616
# Epoch 17228/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.1275 - acc: 0.0000e+00 - val_loss: 11.2945 - val_acc: 0.0000e+00
#
# Epoch 17228: val_loss did not improve from 3.82616
# Epoch 17229/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.7801 - acc: 0.0000e+00 - val_loss: 11.8204 - val_acc: 0.0000e+00
#
# Epoch 17229: val_loss did not improve from 3.82616
# Epoch 17230/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.1791 - acc: 0.0000e+00 - val_loss: 11.5894 - val_acc: 0.0000e+00
#
# Epoch 17230: val_loss did not improve from 3.82616
# Epoch 17231/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.9701 - acc: 0.0000e+00 - val_loss: 9.1056 - val_acc: 0.0000e+00
#
# Epoch 17231: val_loss did not improve from 3.82616
# Epoch 17232/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.7289 - acc: 0.0000e+00 - val_loss: 11.4298 - val_acc: 0.0000e+00
#
# Epoch 17232: val_loss did not improve from 3.82616
# Epoch 17233/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.7218 - acc: 0.0000e+00 - val_loss: 6.2289 - val_acc: 0.0000e+00
#
# Epoch 17233: val_loss did not improve from 3.82616
# Epoch 17234/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.8389 - acc: 0.0000e+00 - val_loss: 8.7933 - val_acc: 0.0000e+00
#
# Epoch 17234: val_loss did not improve from 3.82616
# Epoch 17235/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.5821 - acc: 0.0000e+00 - val_loss: 7.7738 - val_acc: 0.0000e+00
#
# Epoch 17235: val_loss did not improve from 3.82616
# Epoch 17236/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.5611 - acc: 0.0000e+00 - val_loss: 8.3014 - val_acc: 0.0000e+00
#
# Epoch 17236: val_loss did not improve from 3.82616
# Epoch 17237/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.4700 - acc: 0.0000e+00 - val_loss: 8.7829 - val_acc: 0.0000e+00
#
# Epoch 17237: val_loss did not improve from 3.82616
# Epoch 17238/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.0465 - acc: 0.0000e+00 - val_loss: 11.5466 - val_acc: 0.0000e+00
#
# Epoch 17238: val_loss did not improve from 3.82616
# Epoch 17239/50000
# 1/1 [==============================] - 13s 13s/step - loss: 11.0642 - acc: 0.0000e+00 - val_loss: 12.8241 - val_acc: 0.0000e+00
#
# Epoch 17239: val_loss did not improve from 3.82616
# Epoch 17240/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3566 - acc: 0.0000e+00 - val_loss: 8.7650 - val_acc: 0.0000e+00
#
# Epoch 17240: val_loss did not improve from 3.82616
# Epoch 17241/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.8485 - acc: 0.0000e+00 - val_loss: 9.7035 - val_acc: 0.0000e+00
#
# Epoch 17241: val_loss did not improve from 3.82616
# Epoch 17242/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.6645 - acc: 0.0000e+00 - val_loss: 8.5165 - val_acc: 0.0000e+00
#
# Epoch 17242: val_loss did not improve from 3.82616
# Epoch 17243/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.1754 - acc: 0.0000e+00 - val_loss: 8.9674 - val_acc: 0.0000e+00
#
# Epoch 17243: val_loss did not improve from 3.82616
# Epoch 17244/50000
# 1/1 [==============================] - 13s 13s/step - loss: 12.3580 - acc: 0.0000e+00 - val_loss: 8.6762 - val_acc: 0.0000e+00
#
# Epoch 17244: val_loss did not improve from 3.82616
# Epoch 17245/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.5662 - acc: 0.0000e+00 - val_loss: 22.1243 - val_acc: 0.0000e+00
#
# Epoch 17245: val_loss did not improve from 3.82616
# Epoch 17246/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3329 - acc: 0.0000e+00 - val_loss: 11.0519 - val_acc: 0.0000e+00
#
# Epoch 17246: val_loss did not improve from 3.82616
# Epoch 17247/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.2399 - acc: 0.0000e+00 - val_loss: 11.2257 - val_acc: 0.0000e+00
#
# Epoch 17247: val_loss did not improve from 3.82616
# Epoch 17248/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.1387 - acc: 0.0000e+00 - val_loss: 13.3303 - val_acc: 0.0000e+00
# Epoch 17248: val_loss did not improve from 3.82616
# Epoch 17249/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.2100 - acc: 0.0000e+00 - val_loss: 12.0560 - val_acc: 0.0000e+00
#
# Epoch 17249: val_loss did not improve from 3.82616
# Epoch 17250/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.8496 - acc: 0.0000e+00 - val_loss: 12.0792 - val_acc: 0.0000e+00
#
# Epoch 17250: val_loss did not improve from 3.82616
# Epoch 17251/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6090 - acc: 0.0000e+00 - val_loss: 20.2990 - val_acc: 0.0000e+00
#
# Epoch 17251: val_loss did not improve from 3.82616
# Epoch 17252/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.7828 - acc: 0.0000e+00 - val_loss: 9.1299 - val_acc: 0.0000e+00
#
# Epoch 17252: val_loss did not improve from 3.82616
# Epoch 17253/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.9410 - acc: 0.0000e+00 - val_loss: 8.7317 - val_acc: 0.0000e+00
#
# Epoch 17253: val_loss did not improve from 3.82616
# Epoch 17254/50000
# 1/1 [==============================] - 11s 11s/step - loss: 19.3236 - acc: 0.0000e+00 - val_loss: 11.5954 - val_acc: 0.0000e+00
#
# Epoch 17254: val_loss did not improve from 3.82616
# Epoch 17255/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.7850 - acc: 0.0000e+00 - val_loss: 8.8159 - val_acc: 0.0000e+00
#
# Epoch 17255: val_loss did not improve from 3.82616
# Epoch 17256/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.7776 - acc: 0.0000e+00 - val_loss: 11.1884 - val_acc: 0.0000e+00
#
# Epoch 17256: val_loss did not improve from 3.82616
# Epoch 17257/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.4518 - acc: 0.0000e+00 - val_loss: 11.8521 - val_acc: 0.0000e+00
#
# Epoch 17257: val_loss did not improve from 3.82616
# Epoch 17258/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.4483 - acc: 0.0000e+00 - val_loss: 11.3415 - val_acc: 0.0000e+00
#
# Epoch 17258: val_loss did not improve from 3.82616
# Epoch 17259/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.6710 - acc: 0.0000e+00 - val_loss: 13.0562 - val_acc: 0.0000e+00
#
# Epoch 17259: val_loss did not improve from 3.82616
# Epoch 17260/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.0358 - acc: 0.0000e+00 - val_loss: 9.9906 - val_acc: 0.0000e+00
#
# Epoch 17260: val_loss did not improve from 3.82616
# Epoch 17261/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.0025 - acc: 0.0000e+00 - val_loss: 13.4076 - val_acc: 0.0000e+00
#
# Epoch 17261: val_loss did not improve from 3.82616
# Epoch 17262/50000
# 1/1 [==============================] - 11s 11s/step - loss: 20.1831 - acc: 0.0000e+00 - val_loss: 9.1860 - val_acc: 0.0000e+00
#
# Epoch 17262: val_loss did not improve from 3.82616
# Epoch 17263/50000
# 1/1 [==============================] - 12s 12s/step - loss: 9.4672 - acc: 0.0000e+00 - val_loss: 11.8311 - val_acc: 0.0000e+00
#
# Epoch 17263: val_loss did not improve from 3.82616
# Epoch 17264/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.0761 - acc: 0.0000e+00 - val_loss: 9.2339 - val_acc: 0.0000e+00
#
# Epoch 17264: val_loss did not improve from 3.82616
# Epoch 17265/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.7690 - acc: 0.0000e+00 - val_loss: 12.6589 - val_acc: 0.0000e+00
#
# Epoch 17265: val_loss did not improve from 3.82616
# Epoch 17266/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.7653 - acc: 0.0000e+00 - val_loss: 11.8690 - val_acc: 0.0000e+00
#
# Epoch 17266: val_loss did not improve from 3.82616
# Epoch 17267/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.3005 - acc: 0.0000e+00 - val_loss: 11.7406 - val_acc: 0.0000e+00
#
# Epoch 17267: val_loss did not improve from 3.82616
# Epoch 17268/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.3935 - acc: 0.0000e+00 - val_loss: 12.8490 - val_acc: 0.0000e+00
#
# Epoch 17268: val_loss did not improve from 3.82616
# Epoch 17269/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.9279 - acc: 0.0000e+00 - val_loss: 12.2925 - val_acc: 0.0000e+00
#
# Epoch 17269: val_loss did not improve from 3.82616
# Epoch 17270/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.4922 - acc: 0.0000e+00 - val_loss: 12.2736 - val_acc: 0.0000e+00
#
# Epoch 17270: val_loss did not improve from 3.82616
# Epoch 17271/50000
# 1/1 [==============================] - 13s 13s/step - loss: 13.1756 - acc: 0.0000e+00 - val_loss: 11.5829 - val_acc: 0.0000e+00
#
# Epoch 17271: val_loss did not improve from 3.82616
# Epoch 17272/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.4472 - acc: 0.0000e+00 - val_loss: 11.7571 - val_acc: 0.0000e+00
#
# Epoch 17272: val_loss did not improve from 3.82616
# Epoch 17273/50000
# 1/1 [==============================] - 11s 11s/step - loss: 6.2369 - acc: 0.0000e+00 - val_loss: 9.4077 - val_acc: 0.0000e+00
#
# Epoch 17273: val_loss did not improve from 3.82616
# Epoch 17274/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.2032 - acc: 0.0000e+00 - val_loss: 7.7860 - val_acc: 0.0000e+00
#
# Epoch 17274: val_loss did not improve from 3.82616
# Epoch 17275/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.8460 - acc: 0.0000e+00 - val_loss: 9.9337 - val_acc: 0.0000e+00
#
# Epoch 17275: val_loss did not improve from 3.82616
# Epoch 17276/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.8408 - acc: 0.0000e+00 - val_loss: 13.8583 - val_acc: 0.0000e+00
#
# Epoch 17276: val_loss did not improve from 3.82616
# Epoch 17277/50000
# 1/1 [==============================] - 11s 11s/step - loss: 19.0066 - acc: 0.0000e+00 - val_loss: 11.8075 - val_acc: 0.0000e+00
#
# Epoch 17277: val_loss did not improve from 3.82616
# Epoch 17278/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.7664 - acc: 0.0000e+00 - val_loss: 12.5295 - val_acc: 0.0000e+00
#
# Epoch 17278: val_loss did not improve from 3.82616
# Epoch 17279/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.8790 - acc: 0.0000e+00 - val_loss: 12.1147 - val_acc: 0.0000e+00
#
# Epoch 17279: val_loss did not improve from 3.82616
# Epoch 17280/50000
# 1/1 [==============================] - 14s 14s/step - loss: 11.5290 - acc: 0.0000e+00 - val_loss: 5.9579 - val_acc: 0.0000e+00
#
# Epoch 17280: val_loss did not improve from 3.82616
# Epoch 17281/50000
# 1/1 [==============================] - 10s 10s/step - loss: 11.9746 - acc: 0.0000e+00 - val_loss: 9.4231 - val_acc: 0.0000e+00
#
# Epoch 17281: val_loss did not improve from 3.82616
# Epoch 17282/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.9248 - acc: 0.0000e+00 - val_loss: 12.9828 - val_acc: 0.0000e+00
#
# Epoch 17282: val_loss did not improve from 3.82616
# Epoch 17283/50000
# 1/1 [==============================] - 13s 13s/step - loss: 9.1284 - acc: 0.0000e+00 - val_loss: 9.9810 - val_acc: 0.0000e+00
#
# Epoch 17283: val_loss did not improve from 3.82616
# Epoch 17284/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.1807 - acc: 0.0000e+00 - val_loss: 9.6314 - val_acc: 0.0000e+00
#
# Epoch 17284: val_loss did not improve from 3.82616
# Epoch 17285/50000
# 1/1 [==============================] - 13s 13s/step - loss: 11.1463 - acc: 0.0000e+00 - val_loss: 10.1019 - val_acc: 0.0000e+00
#
# Epoch 17285: val_loss did not improve from 3.82616
# Epoch 17286/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.3288 - acc: 0.0000e+00 - val_loss: 9.4418 - val_acc: 0.0000e+00
#
# Epoch 17286: val_loss did not improve from 3.82616
# Epoch 17287/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.3263 - acc: 0.0000e+00 - val_loss: 18.8224 - val_acc: 0.0000e+00
#
# Epoch 17287: val_loss did not improve from 3.82616
# Epoch 17288/50000
# 1/1 [==============================] - 10s 10s/step - loss: 9.3943 - acc: 0.0000e+00 - val_loss: 10.9474 - val_acc: 0.0000e+00
#
# Epoch 17288: val_loss did not improve from 3.82616
# Epoch 17289/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.0682 - acc: 0.0000e+00 - val_loss: 10.9618 - val_acc: 0.0000e+00
#
# Epoch 17289: val_loss did not improve from 3.82616
# Epoch 17290/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.2698 - acc: 0.0000e+00 - val_loss: 15.0085 - val_acc: 0.0000e+00
# Epoch 17290: val_loss did not improve from 3.82616
# Epoch 17291/50000
# 1/1 [==============================] - 12s 12s/step - loss: 11.4269 - acc: 0.0000e+00 - val_loss: 10.2936 - val_acc: 0.0000e+00
#
# Epoch 17291: val_loss did not improve from 3.82616
# Epoch 17292/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.4009 - acc: 0.0000e+00 - val_loss: 10.8418 - val_acc: 0.0000e+00
#
# Epoch 17292: val_loss did not improve from 3.82616
# Epoch 17293/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.9022 - acc: 0.0000e+00 - val_loss: 10.7428 - val_acc: 0.0000e+00
#
# Epoch 17293: val_loss did not improve from 3.82616
# Epoch 17294/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.9553 - acc: 0.0000e+00 - val_loss: 6.2524 - val_acc: 0.0000e+00
#
# Epoch 17294: val_loss did not improve from 3.82616
# Epoch 17295/50000
# 1/1 [==============================] - 11s 11s/step - loss: 17.1109 - acc: 0.0000e+00 - val_loss: 9.0609 - val_acc: 0.0000e+00
#
# Epoch 17295: val_loss did not improve from 3.82616
# Epoch 17296/50000
# 1/1 [==============================] - 10s 10s/step - loss: 9.8196 - acc: 0.0000e+00 - val_loss: 10.0064 - val_acc: 0.0000e+00
#
# Epoch 17296: val_loss did not improve from 3.82616
# Epoch 17297/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.3400 - acc: 0.0000e+00 - val_loss: 10.4188 - val_acc: 0.0000e+00
#
# Epoch 17297: val_loss did not improve from 3.82616
# Epoch 17298/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.8345 - acc: 0.0000e+00 - val_loss: 12.6083 - val_acc: 0.0000e+00
#
# Epoch 17298: val_loss did not improve from 3.82616
# Epoch 17299/50000
# 1/1 [==============================] - 11s 11s/step - loss: 19.5162 - acc: 0.0000e+00 - val_loss: 12.7675 - val_acc: 0.0000e+00
#
# Epoch 17299: val_loss did not improve from 3.82616
# Epoch 17300/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.7054 - acc: 0.0000e+00 - val_loss: 8.5078 - val_acc: 0.0000e+00
#
# Epoch 17300: val_loss did not improve from 3.82616
# Epoch 17301/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.3487 - acc: 0.0000e+00 - val_loss: 11.4774 - val_acc: 0.0000e+00
#
# Epoch 17301: val_loss did not improve from 3.82616
# Epoch 17302/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.4934 - acc: 0.0000e+00 - val_loss: 9.1841 - val_acc: 0.0000e+00
#
# Epoch 17302: val_loss did not improve from 3.82616
# Epoch 17303/50000
# 1/1 [==============================] - 11s 11s/step - loss: 17.1791 - acc: 0.0000e+00 - val_loss: 12.9775 - val_acc: 0.0000e+00
#
# Epoch 17303: val_loss did not improve from 3.82616
# Epoch 17304/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.5315 - acc: 0.0000e+00 - val_loss: 13.2361 - val_acc: 0.0000e+00
#
# Epoch 17304: val_loss did not improve from 3.82616
# Epoch 17305/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.7646 - acc: 0.0000e+00 - val_loss: 10.7783 - val_acc: 0.0000e+00
#
# Epoch 17305: val_loss did not improve from 3.82616
# Epoch 17306/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.5354 - acc: 0.0000e+00 - val_loss: 10.4200 - val_acc: 0.0000e+00
#
# Epoch 17306: val_loss did not improve from 3.82616
# Epoch 17307/50000
# 1/1 [==============================] - 13s 13s/step - loss: 9.8982 - acc: 0.0000e+00 - val_loss: 11.1407 - val_acc: 0.0000e+00
#
# Epoch 17307: val_loss did not improve from 3.82616
# Epoch 17308/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.3319 - acc: 0.0000e+00 - val_loss: 8.6286 - val_acc: 0.0000e+00
#
# Epoch 17308: val_loss did not improve from 3.82616
# Epoch 17309/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.6979 - acc: 0.0000e+00 - val_loss: 22.3476 - val_acc: 0.0000e+00
#
# Epoch 17309: val_loss did not improve from 3.82616
# Epoch 17310/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.8647 - acc: 0.0000e+00 - val_loss: 12.4163 - val_acc: 0.0000e+00
#
# Epoch 17310: val_loss did not improve from 3.82616
# Epoch 17311/50000
# 1/1 [==============================] - 11s 11s/step - loss: 15.4625 - acc: 0.0000e+00 - val_loss: 5.8562 - val_acc: 0.0000e+00
#
# Epoch 17311: val_loss did not improve from 3.82616
# Epoch 17312/50000
# 1/1 [==============================] - 11s 11s/step - loss: 21.2744 - acc: 0.0000e+00 - val_loss: 10.4823 - val_acc: 0.0000e+00
#
# Epoch 17312: val_loss did not improve from 3.82616
# Epoch 17313/50000
# 1/1 [==============================] - 11s 11s/step - loss: 18.5683 - acc: 0.0000e+00 - val_loss: 10.3218 - val_acc: 0.0000e+00
#
# Epoch 17313: val_loss did not improve from 3.82616
# Epoch 17314/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.3367 - acc: 0.0000e+00 - val_loss: 12.4377 - val_acc: 0.0000e+00
#
# Epoch 17314: val_loss did not improve from 3.82616
# Epoch 17315/50000
# 1/1 [==============================] - 10s 10s/step - loss: 10.5725 - acc: 0.0000e+00 - val_loss: 10.4216 - val_acc: 0.0000e+00
#
# Epoch 17315: val_loss did not improve from 3.82616
# Epoch 17316/50000
# 1/1 [==============================] - 11s 11s/step - loss: 15.4774 - acc: 0.0000e+00 - val_loss: 13.3779 - val_acc: 0.0000e+00
#
# Epoch 17316: val_loss did not improve from 3.82616
# Epoch 17317/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.8470 - acc: 0.0000e+00 - val_loss: 15.2245 - val_acc: 0.0000e+00
#
# Epoch 17317: val_loss did not improve from 3.82616
# Epoch 17318/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.8217 - acc: 0.0000e+00 - val_loss: 9.3003 - val_acc: 0.0000e+00
#
# Epoch 17318: val_loss did not improve from 3.82616
# Epoch 17319/50000
# 1/1 [==============================] - 11s 11s/step - loss: 20.6021 - acc: 0.0000e+00 - val_loss: 11.5742 - val_acc: 0.0000e+00
#
# Epoch 17319: val_loss did not improve from 3.82616
# Epoch 17320/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.5750 - acc: 0.0000e+00 - val_loss: 8.0620 - val_acc: 0.0000e+00
#
# Epoch 17320: val_loss did not improve from 3.82616
# Epoch 17321/50000
# 1/1 [==============================] - 11s 11s/step - loss: 15.7679 - acc: 0.0000e+00 - val_loss: 13.9731 - val_acc: 0.0000e+00
#
# Epoch 17321: val_loss did not improve from 3.82616
# Epoch 17322/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.4312 - acc: 0.0000e+00 - val_loss: 10.1428 - val_acc: 0.0000e+00
#
# Epoch 17322: val_loss did not improve from 3.82616
# Epoch 17323/50000
# 1/1 [==============================] - 11s 11s/step - loss: 13.5586 - acc: 0.0000e+00 - val_loss: 14.4250 - val_acc: 0.0000e+00
#
# Epoch 17323: val_loss did not improve from 3.82616
# Epoch 17324/50000
# ...
# 1/1 [==============================] - 11s 11s/step - loss: 15.2989 - acc: 0.0000e+00 - val_loss: 11.4661 - val_acc: 0.0000e+00
#
# Epoch 22169: val_loss did not improve from 1.91368
# Epoch 22170/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.2197 - acc: 0.0000e+00 - val_loss: 9.2543 - val_acc: 0.0000e+00
#
# Epoch 22170: val_loss did not improve from 1.91368
# Epoch 22171/50000
# 1/1 [==============================] - 11s 11s/step - loss: 6.7773 - acc: 0.0000e+00 - val_loss: 11.7383 - val_acc: 0.0000e+00
#
# Epoch 22171: val_loss did not improve from 1.91368
# Epoch 22172/50000
# 1/1 [==============================] - 11s 11s/step - loss: 5.7431 - acc: 0.0000e+00 - val_loss: 9.9899 - val_acc: 0.0000e+00
#
# Epoch 22172: val_loss did not improve from 1.91368
# Epoch 22173/50000
# 1/1 [==============================] - 11s 11s/step - loss: 14.0828 - acc: 0.0000e+00 - val_loss: 9.3036 - val_acc: 0.0000e+00
#
# Epoch 22173: val_loss did not improve from 1.91368
# Epoch 22174/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.2014 - acc: 0.0000e+00 - val_loss: 9.7060 - val_acc: 0.0000e+00
#
# Epoch 22174: val_loss did not improve from 1.91368
# Epoch 22175/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.7826 - acc: 0.0000e+00 - val_loss: 9.9383 - val_acc: 0.0000e+00
#
# Epoch 22175: val_loss did not improve from 1.91368
# Epoch 22176/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.3832 - acc: 0.0000e+00 - val_loss: 11.1772 - val_acc: 0.0000e+00
#
# Epoch 22176: val_loss did not improve from 1.91368
# Epoch 22177/50000
# 1/1 [==============================] - 14s 14s/step - loss: 7.6943 - acc: 0.0000e+00 - val_loss: 14.9188 - val_acc: 0.0000e+00
#
# Epoch 22177: val_loss did not improve from 1.91368
# Epoch 22178/50000
# 1/1 [==============================] - 11s 11s/step - loss: 11.7243 - acc: 0.0000e+00 - val_loss: 8.4471 - val_acc: 0.0000e+00
#
# Epoch 22178: val_loss did not improve from 1.91368
# Epoch 22179/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.4688 - acc: 0.0000e+00 - val_loss: 10.8215 - val_acc: 0.0000e+00
#
# Epoch 22179: val_loss did not improve from 1.91368
# Epoch 22180/50000
# 1/1 [==============================] - 14s 14s/step - loss: 8.0012 - acc: 0.0000e+00 - val_loss: 8.9076 - val_acc: 0.0000e+00
#
# Epoch 22180: val_loss did not improve from 1.91368
# Epoch 22181/50000
# 1/1 [==============================] - 10s 10s/step - loss: 11.9319 - acc: 0.0000e+00 - val_loss: 5.7324 - val_acc: 0.0000e+00
#
# Epoch 22181: val_loss did not improve from 1.91368
# Epoch 22182/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.6734 - acc: 0.0000e+00 - val_loss: 8.6284 - val_acc: 0.0000e+00
#
# Epoch 22182: val_loss did not improve from 1.91368
# Epoch 22183/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.5587 - acc: 0.0000e+00 - val_loss: 8.2378 - val_acc: 0.0000e+00
#
# Epoch 22183: val_loss did not improve from 1.91368
# Epoch 22184/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.5983 - acc: 0.0000e+00 - val_loss: 7.9117 - val_acc: 0.0000e+00
#
# Epoch 22184: val_loss did not improve from 1.91368
# Epoch 22185/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.5807 - acc: 0.0000e+00 - val_loss: 13.9707 - val_acc: 0.0000e+00
#
# Epoch 22185: val_loss did not improve from 1.91368
# Epoch 22186/50000
# 1/1 [==============================] - 11s 11s/step - loss: 10.7383 - acc: 0.0000e+00 - val_loss: 10.0337 - val_acc: 0.0000e+00
#
# Epoch 22186: val_loss did not improve from 1.91368
# Epoch 22187/50000
# 1/1 [==============================] - 11s 11s/step - loss: 4.9660 - acc: 0.0000e+00 - val_loss: 11.7390 - val_acc: 0.0000e+00
#
# Epoch 22187: val_loss did not improve from 1.91368
# Epoch 22188/50000
# 1/1 [==============================] - 11s 11s/step - loss: 7.9127 - acc: 0.0000e+00 - val_loss: 8.4765 - val_acc: 0.0000e+00
#
# Epoch 22188: val_loss did not improve from 1.91368
# Epoch 22189/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.9153 - acc: 0.0000e+00 - val_loss: 11.6900 - val_acc: 0.0000e+00
#
# Epoch 22189: val_loss did not improve from 1.91368
# Epoch 22190/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.4555 - acc: 0.0000e+00 - val_loss: 11.6873 - val_acc: 0.0000e+00
#
# Epoch 22190: val_loss did not improve from 1.91368
# Epoch 22191/50000
# 1/1 [==============================] - 12s 12s/step - loss: 9.2806 - acc: 0.0000e+00 - val_loss: 8.7579 - val_acc: 0.0000e+00
#
# Epoch 22191: val_loss did not improve from 1.91368
# Epoch 22192/50000
# 1/1 [==============================] - 12s 12s/step - loss: 13.5347 - acc: 0.0000e+00 - val_loss: 4.4275 - val_acc: 0.0000e+00
#
# Epoch 22192: val_loss did not improve from 1.91368
# Epoch 22193/50000
# 1/1 [==============================] - 12s 12s/step - loss: 10.6791 - acc: 0.0000e+00 - val_loss: 7.9013 - val_acc: 0.0000e+00
#
# Epoch 22193: val_loss did not improve from 1.91368
# Epoch 22194/50000
# 1/1 [==============================] - 12s 12s/step - loss: 7.6899 - acc: 0.0000e+00 - val_loss: 9.2091 - val_acc: 0.0000e+00
#
# Epoch 22194: val_loss did not improve from 1.91368
# Epoch 22195/50000
# 1/1 [==============================] - 12s 12s/step - loss: 11.8346 - acc: 0.0000e+00 - val_loss: 13.5836 - val_acc: 0.0000e+00
#
# Epoch 22195: val_loss did not improve from 1.91368
# Epoch 22196/50000
# 1/1 [==============================] - 12s 12s/step - loss: 9.8525 - acc: 0.0000e+00 - val_loss: 15.0589 - val_acc: 0.0000e+00
#
# Epoch 22196: val_loss did not improve from 1.91368
# Epoch 22197/50000
# 1/1 [==============================] - 12s 12s/step - loss: 15.9731 - acc: 0.0000e+00 - val_loss: 6.9408 - val_acc: 0.0000e+00
#
# Epoch 22197: val_loss did not improve from 1.91368
# Epoch 22198/50000
# 1/1 [==============================] - 11s 11s/step - loss: 9.3438 - acc: 0.0000e+00 - val_loss: 8.9041 - val_acc: 0.0000e+00
#
# Epoch 22198: val_loss did not improve from 1.91368
# Epoch 22199/50000
# 1/1 [==============================] - 11s 11s/step - loss: 6.9720 - acc: 0.0000e+00 - val_loss: 8.1608 - val_acc: 0.0000e+00
#
# Epoch 22199: val_loss did not improve from 1.91368
# Epoch 22200/50000
# 1/1 [==============================] - 12s 12s/step - loss: 14.0778 - acc: 0.0000e+00 - val_loss: 10.8974 - val_acc: 0.0000e+00
#
# Epoch 22200: val_loss did not improve from 1.91368
# Epoch 22201/50000
# 1/1 [==============================] - 12s 12s/step - loss: 7.7777 - acc: 0.0000e+00 - val_loss: 7.6298 - val_acc: 0.0000e+00
#
# Epoch 22201: val_loss did not improve from 1.91368
# Epoch 22202/50000
# 1/1 [==============================] - 12s 12s/step - loss: 6.8134 - acc: 0.0000e+00 - val_loss: 7.8421 - val_acc: 0.0000e+00
#
# Epoch 22202: val_loss did not improve from 1.91368
# Epoch 22203/50000
# 1/1 [==============================] - 11s 11s/step - loss: 12.4417 - acc: 0.0000e+00 - val_loss: 8.3054 - val_acc: 0.0000e+00
#
# Epoch 22203: val_loss did not improve from 1.91368
# Epoch 22204/50000
# 1/1 [==============================] - 12s 12s/step - loss: 10.5759 - acc: 0.0000e+00 - val_loss: 15.4782 - val_acc: 0.0000e+00
#
# Epoch 22204: val_loss did not improve from 1.91368
# Epoch 22205/50000
# 1/1 [==============================] - 12s 12s/step - loss: 7.5909 - acc: 0.0000e+00 - val_loss: 3.4394 - val_acc: 0.0000e+00
#
# Epoch 22205: val_loss did not improve from 1.91368
# Epoch 22206/50000
# 1/1 [==============================] - 12s 12s/step - loss: 6.7552 - acc: 0.0000e+00 - val_loss: 7.6525 - val_acc: 0.0000e+00
# Epoch 22206: val_loss did not improve from 1.91368
# Epoch 22207/50000
# 1/1 [==============================] - 12s 12s/step - loss: 12.4868 - acc: 0.0000e+00 - val_loss: 9.5237 - val_acc: 0.0000e+00
#
# Epoch 22207: val_loss did not improve from 1.91368
# Epoch 22208/50000
# 1/1 [==============================] - 12s 12s/step - loss: 7.3120 - acc: 0.0000e+00 - val_loss: 7.3236 - val_acc: 0.0000e+00
#
# Epoch 22208: val_loss did not improve from 1.91368
# Epoch 22209/50000
# 1/1 [==============================] - 12s 12s/step - loss: 13.9996 - acc: 0.0000e+00 - val_loss: 12.5109 - val_acc: 0.0000e+00
#
# Epoch 22209: val_loss did not improve from 1.91368
# Epoch 22210/50000
# 1/1 [==============================] - 14s 14s/step - loss: 8.8594 - acc: 0.0000e+00 - val_loss: 9.6364 - val_acc: 0.0000e+00
#
# Epoch 22210: val_loss did not improve from 1.91368
# Epoch 22211/50000
# 1/1 [==============================] - 12s 12s/step - loss: 3.0987 - acc: 0.0000e+00 - val_loss: 14.7090 - val_acc: 0.0000e+00
#
# Epoch 22211: val_loss did not improve from 1.91368
# Epoch 22212/50000
# 1/1 [==============================] - 12s 12s/step - loss: 12.4402 - acc: 0.0000e+00 - val_loss: 3.2033 - val_acc: 0.0000e+00
#
# Epoch 22212: val_loss did not improve from 1.91368
# Epoch 22213/50000
# 1/1 [==============================] - 11s 11s/step - loss: 8.2156 - acc: 0.0000e+00 - val_loss: 5.9567 - val_acc: 0.0000e+00
#
# Epoch 22213: val_loss did not improve from 1.91368
# Epoch 22214/50000
# 1/1 [==============================] - 12s 12s/step - loss: 10.0553 - acc: 0.0000e+00 - val_loss: 9.0130 - val_acc: 0.0000e+00
#
# Epoch 22214: val_loss did not improve from 1.91368
# Epoch 22215/50000
# 1/1 [==============================] - 12s 12s/step - loss: 10.0556 - acc: 0.0000e+00 - val_loss: 16.4546 - val_acc: 0.0000e+00
#
# Epoch 22215: val_loss did not improve from 1.91368
# Epoch 22216/50000
# 1/1 [==============================] - 12s 12s/step - loss: 8.4651 - acc: 0.0000e+00 - val_loss: 18.7226 - val_acc: 0.0000e+00
#
# Epoch 22216: val_loss did not improve from 1.91368
# Epoch 22217/50000
# 1/1 [==============================] - 12s 12s/step - loss: 7.6490 - acc: 0.0000e+00 - val_loss: 5.4679 - val_acc: 0.0000e+00
#
# Epoch 22217: val_loss did not improve from 1.91368
# Epoch 22218/50000
# 1/1 [==============================] - 12s 12s/step - loss: 8.3144 - acc: 0.0000e+00 - val_loss: 14.4710 - val_acc: 0.0000e+00
#
# Epoch 22218: val_loss did not improve from 1.91368
# Epoch 22219/50000
# 1/1 [==============================] - 20s 20s/step - loss: 9.4430 - acc: 0.0000e+00 - val_loss: 7.7142 - val_acc: 0.0000e+00
#
# Epoch 22219: val_loss did not improve from 1.91368
# Epoch 22220/50000
# 1/1 [==============================] - 12s 12s/step - loss: 10.9795 - acc: 0.0000e+00 - val_loss: 9.8434 - val_acc: 0.0000e+00
#
# Epoch 22220: val_loss did not improve from 1.91368
# Epoch 22221/50000
# 1/1 [==============================] - 12s 12s/step - loss: 7.7689 - acc: 0.0000e+00 - val_loss: 9.4088 - val_acc: 0.0000e+00
#
# Epoch 22221: val_loss did not improve from 1.91368
# Epoch 22222/50000
# 1/1 [==============================] - 12s 12s/step - loss: 7.1613 - acc: 0.0000e+00 - val_loss: 9.4350 - val_acc: 0.0000e+00
#
# Epoch 22222: val_loss did not improve from 1.91368
# Epoch 22223/50000
# 1/1 [==============================] - 12s 12s/step - loss: 11.9121 - acc: 0.0000e+00 - val_loss: 17.2012 - val_acc: 0.0000e+00
#
# Epoch 22223: val_loss did not improve from 1.91368
# Epoch 22224/50000
# 1/1 [==============================] - 12s 12s/step - loss: 5.2552 - acc: 0.0000e+00 - val_loss: 8.5319 - val_acc: 0.0000e+00
#
# Epoch 22224: val_loss did not improve from 1.91368
# Epoch 22225/50000
# 1/1 [==============================] - 12s 12s/step - loss: 10.1064 - acc: 0.0000e+00 - val_loss: 18.1178 - val_acc: 0.0000e+00
#
# Epoch 22225: val_loss did not improve from 1.91368
# Epoch 22226/50000
# 1/1 [==============================] - 12s 12s/step - loss: 6.7104 - acc: 0.0000e+00 - val_loss: 8.4203 - val_acc: 0.0000e+00
#
# Epoch 22226: val_loss did not improve from 1.91368
# Epoch 22227/50000
# 1/1 [==============================] - 14s 14s/step - loss: 11.3040 - acc: 0.0000e+00 - val_loss: 12.1217 - val_acc: 0.0000e+00
#
# Epoch 22227: val_loss did not improve from 1.91368
# Epoch 22228/50000
# --------------------------------------------------------------------
# KeyboardInterrupt                  Traceback (most recent call last)
# <ipython-input-12-21040577ca80> in <module>()
#      14                     callbacks=[checkpoint,tensorboard],
#      15                     initial_epoch=start_epoch,
# ---> 16                     verbose=1)
#      17                     #max_q_size=5,
#      18                     #workers=2,
#
# ~/.local/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     232                             val_enqueuer_gen,
#     233                             validation_steps,
# --> 234                             workers=0)
#     235                     else:
#     236                         # No need for try/except because
#
# ~/.local/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1470             workers=workers,
#    1471             use_multiprocessing=use_multiprocessing,
# -> 1472             verbose=verbose)
#    1473
#    1474     @interfaces.legacy_generator_methods_support
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_generator.py in evaluate_generator(model, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#     328
#     329         while steps_done < steps:
# --> 330             generator_output = next(output_generator)
#     331             if not hasattr(generator_output, '__len__'):
#     332                 raise ValueError('Output of generator should be a tuple '
#
# ~/.local/lib/python3.6/site-packages/keras/utils/data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# /home/anaconda3/envs/tf-gpu/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /home/anaconda3/envs/tf-gpu/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /home/anaconda3/envs/tf-gpu/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /home/anaconda3/envs/tf-gpu/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
# g=datagen(data_partition='test', batch_size=1)
# x,y = next(g)

# %%
used_words

# %%
# x['the_input'][0].shape, x['source_str'], x['the_labels']

# %%
# # im = batch_frames[1][25]
# import matplotlib.pyplot as plt
# %matplotlib inline
# # generator = datagen(min_row_number=0,max_row_number=200000, batch_size= 6)
# # X,Y = next(generator)
# X = x['the_input'][0]
# # print(X.shape, Y.shape)
# def plot_data(x,ax):
# #     x = x.reshape((size,size))
#     ax.imshow(x, cmap='gray')
# #     if y is not None:
# #         ax.scatter(y[0::2] , y[1::2] , marker='x', s=10)
# fig = plt.figure(figsize=(30,30))
# fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
# for i in range(30):
#     ax = fig.add_subplot(1, 30, i + 1, xticks=[], yticks=[])
#     plot_data(X[i], ax)

# %%
# # import io
# # import base64
# # from IPython.display import HTML

# # video = io.open('evaluation/samples/test.mp4', 'r+b').read()
# # encoded = base64.b64encode(video)
# # HTML(data='''<video alt="test" controls>
# #                 <source src="data:video/mp4;base64,{0}" type="video/mp4" />
# #              </video>'''.format(encoded.decode('ascii')))
# im = cv2.imread('training/unseen_speakers/test_pic.jpg')
# ims = get_frames_mouth(detector, predictor, [im])
# plt.imshow(ims[0][...,::-1])

# %%
# # np.max([len(word) for word in words])
# type(np.array([1,2]))

# %%
# lipnet.predict(np.array([X]))

# %%
# m = []
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append(1)
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([[1],[1],[1]])
# np.array(m).shape
t = {1,2,3,4,5}
t.add(5)
t.add(6)

# %%
t
