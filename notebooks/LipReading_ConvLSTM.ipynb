# %%
import tensorflow as tf
from keras.models import model_from_json
import os
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import imageio
from matplotlib import pyplot as plt
import warnings
import cv2
import pandas as pd
from mtcnn.mtcnn import MTCNN
import keras.backend as K
from keras.layers import Input,ConvLSTM2D,GRU, BatchNormalization, Activation, Bidirectional, Dense, Reshape, Conv2D, MaxPooling3D, UpSampling2D,Lambda, TimeDistributed,Flatten, LSTM
from keras.models import Model
from keras import backend as K
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
warnings.filterwarnings("ignore")
from keras.callbacks import TensorBoard, CSVLogger, ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

# %%
def _ctc_lambda_func(args):
    labels, y_pred, input_length, label_length = args
    y_pred = y_pred[:, :, :]
    return K.tf.keras.backend.ctc_batch_cost(labels, y_pred, input_length, label_length)


input_layer = Input(shape=(30, 100, 50,3),name='input')
labels = Input(shape=(12,),name='labels')
input_length = Input(shape=(1,),name='input_length')
label_length = Input(shape=(1,),name='label_length')

conv_lstm_1 = ConvLSTM2D(activation='relu',filters=32,return_sequences=True,kernel_size=(3,3),padding='same',recurrent_activation='relu')(input_layer)
conv_lstm_1 = BatchNormalization()(conv_lstm_1)
conv_lstm_1 = Activation(activation='relu')(conv_lstm_1)
max_pool_1 = MaxPooling3D(pool_size=(1,2,2))(conv_lstm_1)

conv_lstm_2 = ConvLSTM2D(activation='relu',filters=32,return_sequences=True,kernel_size=(3,3),padding='same',recurrent_activation='relu')(max_pool_1)
conv_lstm_2 = BatchNormalization()(conv_lstm_2)
conv_lstm_2 = Activation(activation='relu')(conv_lstm_2)
max_pool_2 = MaxPooling3D(pool_size=(1,2,2))(conv_lstm_2)

conv_lstm_3 = ConvLSTM2D(activation='relu',filters=64,return_sequences=True,kernel_size=(3,3),padding='same',recurrent_activation='relu')(max_pool_2)
conv_lstm_3 = BatchNormalization()(conv_lstm_3)
conv_lstm_3 = Activation(activation='relu')(conv_lstm_3)
max_pool_3 = MaxPooling3D(pool_size=(1,2,2))(conv_lstm_3)

conv_lstm_4 = ConvLSTM2D(activation='relu',filters=96,return_sequences=True,kernel_size=(3,3),padding='same',recurrent_activation='relu')(max_pool_3)
conv_lstm_4 = BatchNormalization()(conv_lstm_4)
conv_lstm_4 = Activation(activation='relu')(conv_lstm_4)
max_pool_4 = MaxPooling3D(pool_size=(1,2,2))(conv_lstm_4)

flat = TimeDistributed(Flatten())(max_pool_4)
bgru = LSTM(512, return_sequences=True)(flat)
bgru = LSTM(512, return_sequences=True)(bgru)

ctc_class_dense = Dense(28,name='ctc_class_dense')(bgru)
_y_pred = Activation(activation='softmax', name='ctc_softmax')(ctc_class_dense)
gru = LSTM(512, return_sequences=False)(bgru)
# dense = Dense(128)(lstm)
cls_hidden_dense=Dense(1024,name='cls_hidden_dense')(gru)

classification_output=Dense(21,activation='softmax',name='classification')(cls_hidden_dense)

# with open('LipReading_model.json') as f:
#     loadedmodel = f.read()
# lm = model_from_json(loadedmodel)
# # ctc
# _labels = lm.get_layer('the_labels').output
# _input_length = lm.get_layer('input_length').output
# _label_length = lm.get_layer('label_length').output


ctc_loss = Lambda(_ctc_lambda_func, output_shape=(1,), name='ctc')([labels,_y_pred,input_length,label_length])
model = Model(inputs=[input_layer,labels,input_length,label_length], outputs=[classification_output,ctc_loss])
# model = Model(input_layer,[classification_output,_y_pred])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 30, 100, 50,  0
# __________________________________________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)     (None, 30, 100, 50,  40448       input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 30, 100, 50,  128         conv_lst_m2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 30, 100, 50,  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 30, 50, 25, 3 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)     (None, 30, 50, 25, 3 73856       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 30, 50, 25, 3 128         conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 30, 50, 25, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 30, 25, 12, 3 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)     (None, 30, 25, 12, 6 221440      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 30, 25, 12, 6 256         conv_lst_m2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 30, 25, 12, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 30, 12, 6, 64 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_4 (ConvLSTM2D)     (None, 30, 12, 6, 96 553344      max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 30, 12, 6, 96 384         conv_lst_m2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 30, 12, 6, 96 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 30, 6, 3, 96) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 30, 1728)     0           max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 30, 512)      4589568     time_distributed_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 30, 512)      2099200     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 512)          2099200     lstm_2[0][0]
# __________________________________________________________________________________________________
# ctc_class_dense (Dense)         (None, 30, 28)       14364       lstm_2[0][0]
# __________________________________________________________________________________________________
# cls_hidden_dense (Dense)        (None, 1024)         525312      lstm_3[0][0]
# __________________________________________________________________________________________________
# labels (InputLayer)             (None, 12)           0
# __________________________________________________________________________________________________
# ctc_softmax (Activation)        (None, 30, 28)       0           ctc_class_dense[0][0]
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# classification (Dense)          (None, 21)           21525       cls_hidden_dense[0][0]
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           labels[0][0]
#                                                                  ctc_softmax[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 10,239,153
# Trainable params: 10,238,705
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %%
SVG(model_to_dot(model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
frames_count = 30
# words_folder = 'training/unseen_speakers/TARGET/datasets/lipread_mp4'
words = pd.read_csv('words_v2.csv')['words']
max_len = np.max([len(word) for word in words])

def datagen(data_partition = 'train', batch_size = 16):
    while True:
        counter = 0
        
        X_data = []#np.zeros((batch_size,))
        Y_data = []
        input_length = []
        label_length = []
        source_str = []
        word_id = []
        while counter<batch_size:
#             print(counter)
            word_idx = np.random.randint(len(words))
#             print('data part:', data_partition, ', word index', word_idx)
            
            train_folder = 'training/unseen_speakers/lrw_cropped/{0}/{1}/'.format(words[word_idx],data_partition)
        #         print(train_folder)
            files = os.listdir(train_folder)
        #         print(files)
            paths = list(set([x.split('.')[0] for x in files]))
        
            idx = np.random.randint(len(paths))
            path = os.path.join(train_folder,paths[idx])
#             print(path)
            frames = []
            for img_name in sorted(os.listdir(path)):
                img = cv2.imread(os.path.join(path,img_name))
                frames.append(img)
            frames = np.array(frames)
#             print(frames.shape, path)
            if len(frames.shape)==4:
#                 frames = np.rollaxis(frames,2, start=1)
    #             print(path)
    #             print(frames.shape)
    #             print('---------')
                if 'numpy.ndarray' in str(type(frames)) \
                        and len(np.shape(frames))==4 \
                        and np.shape(frames)[1] == 100 \
                        and np.shape(frames)[2] == 50:
#                     print(frames.shape, path)
                    if len(frames)<30:
                        diff = 30-len(frames)
            #             print(fr[-1].shape)
                        for i in range(diff):
                            frames = np.insert(arr = frames,values = frames[-1], obj=[-1], axis = 0)
                    X_data.append(frames)
                    ####
                    Y_data.append([ord(c) - 65 for c in words[word_idx]]+[-1]*(max_len-len(words[word_idx])))
                    input_length.append(frames_count)
                    label_length.append(len(words[word_idx]))
                    source_str.append(words[word_idx])
                    word_id.append(word_idx)
                    counter+=1
#                     print(counter)
                else:
                    continue
            else:
                print('error:', frames.shape, path)
                continue

        X_data = np.array(X_data).astype(np.float32) / 255 
        Y_data = np.array(Y_data)
        input_length = np.array(input_length)
        label_length = np.array(label_length)
        source_str = np.array(source_str)
        
        inputs = {'input': X_data,
                  'labels': Y_data,
                  'input_length': input_length,
                  'label_length': label_length,
                  'source_str': source_str  # used for visualization only
                  }
        ctc_outpts = np.zeros([batch_size])
        classes = to_categorical(y=word_id,num_classes=len(words))   
        
#         print('the_input:', inputs['the_input'].shape)
#         print('the_labels:', inputs['the_labels'].shape)
#         print('input_length:', inputs['input_length'].shape)
#         print('label_length:', inputs['label_length'].shape)
#         print('source_str:', inputs['source_str'].shape)
#         print('batch_frames_shape',X_data.shape, data_partition)

        yield inputs, [classes,ctc_outpts]

# %%
g_tr=datagen(data_partition='train',batch_size=16)
g_val=datagen(data_partition='val',batch_size=16)

# %%
for i in range(5):
    x,y=next(g_val)
#     display(x['input'].shape,np.argmax(y[0],axis=-1),x['labels'],x['input_length'],x['label_length'],x['source_str'])
# #     np.argmax(y[0],axis=1)
#     print('---------------')

# %%
words
# Out:
# 0       ABSOLUTELY
# 1        AFTERNOON
# 2        AGREEMENT
# 3          BETWEEN
# 4       CONFERENCE
# 5     CONSERVATIVE
# 6        EMERGENCY
# 7        EVERYBODY
# 8         EXPECTED
# 9        FINANCIAL
# 10      GOVERNMENT
# 11     IMMIGRATION
# 12     INDEPENDENT
# 13      OPPOSITION
# 14      PARLIAMENT
# 15      REFERENDUM
# 16         SEVERAL
# 17     SIGNIFICANT
# 18    TEMPERATURES
# 19      THEMSELVES
# 20     WESTMINSTER
# Name: words, dtype: object

# %%
X = x['input'][0]
print()
fig = plt.figure(figsize=(30,30))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(30):
    ax = fig.add_subplot(1, 30, i + 1, xticks=[], yticks=[])
    ax.imshow(X[i])

# %%
# tensorboard = TensorBoard(log_dir=os.path.join(LOG_DIR, 'tune-crop-'+run_name))
# csv_logger  = CSVLogger(os.path.join(LOG_DIR, "{}-{}.csv".format('training',run_name)), separator=',', append=True)
checkpoint  = ModelCheckpoint(save_best_only=True,
                              filepath='training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5'
                              , monitor='val_loss'
                              , verbose=1
                              , mode='min'
                              , period=1)
# es = EarlyStopping(patience=10000, monitor='val_loss', min_delta=0.0005, mode='auto')

# %%
# def test_loss(y_true, y_pred): 
#     return y_pred

# %%
from keras.optimizers import Adadelta,Adam, SGD
# adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=1e-08)
EPOCHS = 50000
INIT_LR = 0.005
# opt = SGD(lr=INIT_LR, decay=1e-6, momentum=0.95, nesterov=True)
opt = Adam(lr=INIT_LR, decay=1e-6, beta_1=0.9, beta_2=0.999)
# opt = Adadelta(lr=INIT_LR, decay=1e-04)

losses = {
    'ctc':lambda y_true,y_pred:y_pred,
    'classification':'categorical_crossentropy'
}
model.compile(loss=losses, optimizer=opt, metrics=['accuracy'])

# %%
# model.load_weights('training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5')
hist = model.fit_generator(g_tr
                    , steps_per_epoch=1
                    , epochs=EPOCHS
                    #steps_per_epoch=lip_gen.default_training_steps, epochs=stop_epoch,
                    , validation_data=g_val
                    , validation_steps=1
                    ,callbacks=[checkpoint]
                    ,initial_epoch=0
                    ,verbose=3)
                    #max_q_size=5,
                    #workers=2,
                    #pickle_safe=True)
# Out:
# Epoch 1/50000
#
# Epoch 00001: val_loss improved from inf to 75.98090, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 2/50000
#
# Epoch 00002: val_loss improved from 75.98090 to 38.37070, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 3/50000
#
# Epoch 00003: val_loss did not improve from 38.37070
# Epoch 4/50000
#
# Epoch 00004: val_loss did not improve from 38.37070
# Epoch 5/50000
#
# Epoch 00005: val_loss did not improve from 38.37070
# Epoch 6/50000
#
# Epoch 00006: val_loss did not improve from 38.37070
# Epoch 7/50000
#
# Epoch 00007: val_loss did not improve from 38.37070
# Epoch 8/50000
#
# Epoch 00008: val_loss improved from 38.37070 to 36.66889, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 9/50000
#
# Epoch 00009: val_loss did not improve from 36.66889
# Epoch 10/50000
#
# Epoch 00010: val_loss did not improve from 36.66889
# Epoch 11/50000
#
# Epoch 00011: val_loss improved from 36.66889 to 35.88465, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 12/50000
#
# Epoch 00012: val_loss improved from 35.88465 to 35.63330, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 13/50000
#
# Epoch 00013: val_loss improved from 35.63330 to 35.46058, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 14/50000
#
# Epoch 00014: val_loss did not improve from 35.46058
# Epoch 15/50000
#
# Epoch 00015: val_loss improved from 35.46058 to 34.73220, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 16/50000
#
# Epoch 00016: val_loss improved from 34.73220 to 33.54587, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 17/50000
#
# Epoch 00017: val_loss did not improve from 33.54587
# Epoch 18/50000
#
# Epoch 00018: val_loss did not improve from 33.54587
# Epoch 19/50000
#
# Epoch 00019: val_loss did not improve from 33.54587
# Epoch 20/50000
#
# Epoch 00020: val_loss improved from 33.54587 to 32.50863, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 21/50000
#
# Epoch 00021: val_loss did not improve from 32.50863
# Epoch 22/50000
#
# Epoch 00022: val_loss did not improve from 32.50863
# Epoch 23/50000
#
# Epoch 00023: val_loss improved from 32.50863 to 31.51127, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 24/50000
#
# Epoch 00024: val_loss did not improve from 31.51127
# Epoch 25/50000
#
# Epoch 00025: val_loss improved from 31.51127 to 30.25027, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 26/50000
#
# Epoch 00026: val_loss did not improve from 30.25027
# Epoch 27/50000
#
# Epoch 00027: val_loss improved from 30.25027 to 30.20230, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 28/50000
#
# Epoch 00028: val_loss did not improve from 30.20230
# Epoch 29/50000
#
# Epoch 00029: val_loss did not improve from 30.20230
# Epoch 30/50000
#
# Epoch 00030: val_loss did not improve from 30.20230
# Epoch 31/50000
#
# Epoch 00031: val_loss did not improve from 30.20230
# Epoch 32/50000
#
# Epoch 00032: val_loss did not improve from 30.20230
# Epoch 33/50000
#
# Epoch 00033: val_loss did not improve from 30.20230
# Epoch 34/50000
#
# Epoch 00034: val_loss did not improve from 30.20230
# Epoch 35/50000
#
# Epoch 00035: val_loss improved from 30.20230 to 30.11285, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 36/50000
#
# Epoch 00036: val_loss did not improve from 30.11285
# Epoch 37/50000
#
# Epoch 00037: val_loss improved from 30.11285 to 29.99428, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 38/50000
#
# Epoch 00038: val_loss did not improve from 29.99428
# Epoch 39/50000
#
# Epoch 00039: val_loss did not improve from 29.99428
# Epoch 40/50000
#
# Epoch 00040: val_loss did not improve from 29.99428
# Epoch 41/50000
#
# Epoch 00041: val_loss did not improve from 29.99428
# Epoch 42/50000
#
# Epoch 00042: val_loss did not improve from 29.99428
# Epoch 43/50000
#
# Epoch 00043: val_loss did not improve from 29.99428
# Epoch 44/50000
#
# Epoch 00044: val_loss did not improve from 29.99428
# Epoch 45/50000
#
# Epoch 00045: val_loss did not improve from 29.99428
# Epoch 46/50000
#
# Epoch 00046: val_loss improved from 29.99428 to 29.56298, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 47/50000
#
# Epoch 00047: val_loss did not improve from 29.56298
# Epoch 48/50000
#
# Epoch 00048: val_loss did not improve from 29.56298
# Epoch 49/50000
#
# Epoch 00049: val_loss did not improve from 29.56298
# Epoch 50/50000
#
# Epoch 00050: val_loss did not improve from 29.56298
# Epoch 51/50000
#
# Epoch 00051: val_loss did not improve from 29.56298
# Epoch 52/50000
#
# Epoch 00052: val_loss improved from 29.56298 to 29.29738, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 53/50000
#
# Epoch 00053: val_loss improved from 29.29738 to 29.07354, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 54/50000
#
# Epoch 00054: val_loss did not improve from 29.07354
# Epoch 55/50000
#
# Epoch 00055: val_loss did not improve from 29.07354
# Epoch 56/50000
#
# Epoch 00056: val_loss did not improve from 29.07354
# Epoch 57/50000
#
# Epoch 00057: val_loss did not improve from 29.07354
# Epoch 58/50000
#
# Epoch 00058: val_loss did not improve from 29.07354
# Epoch 59/50000
#
# Epoch 00059: val_loss did not improve from 29.07354
# Epoch 60/50000
#
# Epoch 00060: val_loss did not improve from 29.07354
# Epoch 61/50000
#
# Epoch 00061: val_loss improved from 29.07354 to 27.02319, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 62/50000
#
# Epoch 00062: val_loss did not improve from 27.02319
# Epoch 63/50000
#
# Epoch 00063: val_loss did not improve from 27.02319
# Epoch 64/50000
#
# Epoch 00064: val_loss did not improve from 27.02319
# Epoch 65/50000
#
# Epoch 00065: val_loss did not improve from 27.02319
# Epoch 66/50000
#
# Epoch 00066: val_loss did not improve from 27.02319
# Epoch 67/50000
#
# Epoch 00067: val_loss did not improve from 27.02319
# Epoch 68/50000
#
# Epoch 00068: val_loss did not improve from 27.02319
# Epoch 69/50000
#
# Epoch 00069: val_loss did not improve from 27.02319
# Epoch 70/50000
#
# Epoch 00070: val_loss did not improve from 27.02319
# Epoch 71/50000
#
# Epoch 00071: val_loss did not improve from 27.02319
# Epoch 72/50000
#
# Epoch 00072: val_loss did not improve from 27.02319
# Epoch 73/50000
#
# Epoch 00073: val_loss did not improve from 27.02319
# Epoch 74/50000
#
# Epoch 00074: val_loss did not improve from 27.02319
# Epoch 75/50000
#
# Epoch 00075: val_loss did not improve from 27.02319
# Epoch 76/50000
#
# Epoch 00076: val_loss did not improve from 27.02319
# Epoch 77/50000
#
# Epoch 00077: val_loss did not improve from 27.02319
# Epoch 78/50000
#
# Epoch 00078: val_loss did not improve from 27.02319
# Epoch 79/50000
#
# Epoch 00079: val_loss did not improve from 27.02319
# Epoch 80/50000
#
# Epoch 00080: val_loss did not improve from 27.02319
# Epoch 81/50000
#
# Epoch 00081: val_loss did not improve from 27.02319
# Epoch 82/50000
#
# Epoch 00082: val_loss did not improve from 27.02319
# Epoch 83/50000
#
# Epoch 00083: val_loss did not improve from 27.02319
# Epoch 84/50000
#
# Epoch 00084: val_loss did not improve from 27.02319
# Epoch 85/50000
#
# Epoch 00085: val_loss did not improve from 27.02319
# Epoch 86/50000
#
# Epoch 00086: val_loss did not improve from 27.02319
# Epoch 87/50000
#
# Epoch 00087: val_loss did not improve from 27.02319
# Epoch 88/50000
#
# Epoch 00088: val_loss did not improve from 27.02319
# Epoch 89/50000
#
# Epoch 00089: val_loss did not improve from 27.02319
# Epoch 90/50000
#
# Epoch 00090: val_loss did not improve from 27.02319
# Epoch 91/50000
#
# Epoch 00091: val_loss did not improve from 27.02319
# Epoch 92/50000
#
# Epoch 00092: val_loss did not improve from 27.02319
# Epoch 93/50000
#
# Epoch 00093: val_loss did not improve from 27.02319
# Epoch 94/50000
#
# Epoch 00094: val_loss did not improve from 27.02319
# Epoch 95/50000
#
# Epoch 00095: val_loss did not improve from 27.02319
# Epoch 96/50000
# Epoch 00096: val_loss did not improve from 27.02319
# Epoch 97/50000
#
# Epoch 00097: val_loss did not improve from 27.02319
# Epoch 98/50000
#
# Epoch 00098: val_loss did not improve from 27.02319
# Epoch 99/50000
#
# Epoch 00099: val_loss did not improve from 27.02319
# Epoch 100/50000
#
# Epoch 00100: val_loss did not improve from 27.02319
# Epoch 101/50000
#
# Epoch 00101: val_loss did not improve from 27.02319
# Epoch 102/50000
#
# Epoch 00102: val_loss did not improve from 27.02319
# Epoch 103/50000
#
# Epoch 00103: val_loss did not improve from 27.02319
# Epoch 104/50000
#
# Epoch 00104: val_loss did not improve from 27.02319
# Epoch 105/50000
#
# Epoch 00105: val_loss did not improve from 27.02319
# Epoch 106/50000
#
# Epoch 00106: val_loss did not improve from 27.02319
# Epoch 107/50000
#
# Epoch 00107: val_loss did not improve from 27.02319
# Epoch 108/50000
#
# Epoch 00108: val_loss did not improve from 27.02319
# Epoch 109/50000
#
# Epoch 00109: val_loss did not improve from 27.02319
# Epoch 110/50000
#
# Epoch 00110: val_loss did not improve from 27.02319
# Epoch 111/50000
#
# Epoch 00111: val_loss did not improve from 27.02319
# Epoch 112/50000
#
# Epoch 00112: val_loss did not improve from 27.02319
# Epoch 113/50000
#
# Epoch 00113: val_loss did not improve from 27.02319
# Epoch 114/50000
#
# Epoch 00114: val_loss did not improve from 27.02319
# Epoch 115/50000
#
# Epoch 00115: val_loss did not improve from 27.02319
# Epoch 116/50000
#
# Epoch 00116: val_loss did not improve from 27.02319
# Epoch 117/50000
#
# Epoch 00117: val_loss did not improve from 27.02319
# Epoch 118/50000
#
# Epoch 00118: val_loss did not improve from 27.02319
# Epoch 119/50000
#
# Epoch 00119: val_loss did not improve from 27.02319
# Epoch 120/50000
#
# Epoch 00120: val_loss did not improve from 27.02319
# Epoch 121/50000
#
# Epoch 00121: val_loss did not improve from 27.02319
# Epoch 122/50000
#
# Epoch 00122: val_loss did not improve from 27.02319
# Epoch 123/50000
#
# Epoch 00123: val_loss did not improve from 27.02319
# Epoch 124/50000
#
# Epoch 00124: val_loss did not improve from 27.02319
# Epoch 125/50000
#
# Epoch 00125: val_loss did not improve from 27.02319
# Epoch 126/50000
#
# Epoch 00126: val_loss did not improve from 27.02319
# Epoch 127/50000
#
# Epoch 00127: val_loss did not improve from 27.02319
# Epoch 128/50000
#
# Epoch 00128: val_loss did not improve from 27.02319
# Epoch 129/50000
#
# Epoch 00129: val_loss did not improve from 27.02319
# Epoch 130/50000
#
# Epoch 00130: val_loss did not improve from 27.02319
# Epoch 131/50000
#
# Epoch 00131: val_loss did not improve from 27.02319
# Epoch 132/50000
#
# Epoch 00132: val_loss did not improve from 27.02319
# Epoch 133/50000
#
# Epoch 00133: val_loss did not improve from 27.02319
# Epoch 134/50000
#
# Epoch 00134: val_loss did not improve from 27.02319
# Epoch 135/50000
#
# Epoch 00135: val_loss did not improve from 27.02319
# Epoch 136/50000
#
# Epoch 00136: val_loss did not improve from 27.02319
# Epoch 137/50000
#
# Epoch 00137: val_loss did not improve from 27.02319
# Epoch 138/50000
#
# Epoch 00138: val_loss did not improve from 27.02319
# Epoch 139/50000
#
# Epoch 00139: val_loss improved from 27.02319 to 26.90793, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 140/50000
#
# Epoch 00140: val_loss did not improve from 26.90793
# Epoch 141/50000
#
# Epoch 00141: val_loss did not improve from 26.90793
# Epoch 142/50000
#
# Epoch 00142: val_loss did not improve from 26.90793
# Epoch 143/50000
#
# Epoch 00143: val_loss did not improve from 26.90793
# Epoch 144/50000
#
# Epoch 00144: val_loss did not improve from 26.90793
# Epoch 145/50000
#
# Epoch 00145: val_loss did not improve from 26.90793
# Epoch 146/50000
#
# Epoch 00146: val_loss did not improve from 26.90793
# Epoch 147/50000
#
# Epoch 00147: val_loss did not improve from 26.90793
# Epoch 148/50000
#
# Epoch 00148: val_loss did not improve from 26.90793
# Epoch 149/50000
#
# Epoch 00149: val_loss did not improve from 26.90793
# Epoch 150/50000
#
# Epoch 00150: val_loss did not improve from 26.90793
# Epoch 151/50000
#
# Epoch 00151: val_loss did not improve from 26.90793
# Epoch 152/50000
#
# Epoch 00152: val_loss did not improve from 26.90793
# Epoch 153/50000
#
# Epoch 00153: val_loss did not improve from 26.90793
# Epoch 154/50000
#
# Epoch 00154: val_loss did not improve from 26.90793
# Epoch 155/50000
#
# Epoch 00155: val_loss did not improve from 26.90793
# Epoch 156/50000
#
# Epoch 00156: val_loss improved from 26.90793 to 26.27455, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 157/50000
#
# Epoch 00157: val_loss did not improve from 26.27455
# Epoch 158/50000
#
# Epoch 00158: val_loss did not improve from 26.27455
# Epoch 159/50000
#
# Epoch 00159: val_loss did not improve from 26.27455
# Epoch 160/50000
#
# Epoch 00160: val_loss did not improve from 26.27455
# Epoch 161/50000
#
# Epoch 00161: val_loss did not improve from 26.27455
# Epoch 162/50000
#
# Epoch 00162: val_loss did not improve from 26.27455
# Epoch 163/50000
#
# Epoch 00163: val_loss did not improve from 26.27455
# Epoch 164/50000
#
# Epoch 00164: val_loss did not improve from 26.27455
# Epoch 165/50000
#
# Epoch 00165: val_loss did not improve from 26.27455
# Epoch 166/50000
#
# Epoch 00166: val_loss did not improve from 26.27455
# Epoch 167/50000
#
# Epoch 00167: val_loss did not improve from 26.27455
# Epoch 168/50000
#
# Epoch 00168: val_loss did not improve from 26.27455
# Epoch 169/50000
#
# Epoch 00169: val_loss did not improve from 26.27455
# Epoch 170/50000
#
# Epoch 00170: val_loss did not improve from 26.27455
# Epoch 171/50000
#
# Epoch 00171: val_loss did not improve from 26.27455
# Epoch 172/50000
#
# Epoch 00172: val_loss did not improve from 26.27455
# Epoch 173/50000
#
# Epoch 00173: val_loss did not improve from 26.27455
# Epoch 174/50000
#
# Epoch 00174: val_loss did not improve from 26.27455
# Epoch 175/50000
#
# Epoch 00175: val_loss did not improve from 26.27455
# Epoch 176/50000
#
# Epoch 00176: val_loss did not improve from 26.27455
# Epoch 177/50000
#
# Epoch 00177: val_loss did not improve from 26.27455
# Epoch 178/50000
#
# Epoch 00178: val_loss did not improve from 26.27455
# Epoch 179/50000
#
# Epoch 00179: val_loss improved from 26.27455 to 25.72791, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 180/50000
#
# Epoch 00180: val_loss did not improve from 25.72791
# Epoch 181/50000
#
# Epoch 00181: val_loss did not improve from 25.72791
# Epoch 182/50000
#
# Epoch 00182: val_loss did not improve from 25.72791
# Epoch 183/50000
#
# Epoch 00183: val_loss did not improve from 25.72791
# Epoch 184/50000
#
# Epoch 00184: val_loss did not improve from 25.72791
# Epoch 185/50000
#
# Epoch 00185: val_loss did not improve from 25.72791
# Epoch 186/50000
#
# Epoch 00186: val_loss did not improve from 25.72791
# Epoch 187/50000
#
# Epoch 00187: val_loss did not improve from 25.72791
# Epoch 188/50000
#
# Epoch 00188: val_loss did not improve from 25.72791
# Epoch 189/50000
#
# Epoch 00189: val_loss did not improve from 25.72791
# Epoch 190/50000
#
# Epoch 00190: val_loss did not improve from 25.72791
# Epoch 191/50000
#
# Epoch 00191: val_loss did not improve from 25.72791
# Epoch 192/50000
#
# Epoch 00192: val_loss did not improve from 25.72791
# Epoch 193/50000
#
# Epoch 00193: val_loss did not improve from 25.72791
# Epoch 194/50000
#
# Epoch 00194: val_loss did not improve from 25.72791
# Epoch 195/50000
#
# Epoch 00195: val_loss did not improve from 25.72791
# Epoch 196/50000
#
# Epoch 00196: val_loss did not improve from 25.72791
# Epoch 197/50000
#
# Epoch 00197: val_loss did not improve from 25.72791
# Epoch 198/50000
#
# Epoch 00198: val_loss did not improve from 25.72791
# Epoch 199/50000
#
# Epoch 00199: val_loss did not improve from 25.72791
# Epoch 200/50000
#
# Epoch 00200: val_loss did not improve from 25.72791
# Epoch 201/50000
#
# Epoch 00201: val_loss did not improve from 25.72791
# Epoch 202/50000
#
# Epoch 00202: val_loss did not improve from 25.72791
# Epoch 203/50000
#
# Epoch 00203: val_loss did not improve from 25.72791
# Epoch 204/50000
#
# Epoch 00204: val_loss did not improve from 25.72791
# Epoch 205/50000
#
# Epoch 00205: val_loss did not improve from 25.72791
# Epoch 206/50000
#
# Epoch 00206: val_loss did not improve from 25.72791
# Epoch 207/50000
#
# Epoch 00207: val_loss did not improve from 25.72791
# Epoch 208/50000
#
# Epoch 00208: val_loss did not improve from 25.72791
# Epoch 209/50000
#
# Epoch 00209: val_loss did not improve from 25.72791
# Epoch 210/50000
#
# Epoch 00210: val_loss did not improve from 25.72791
# Epoch 211/50000
# Epoch 00211: val_loss did not improve from 25.72791
# Epoch 212/50000
#
# Epoch 00212: val_loss did not improve from 25.72791
# Epoch 213/50000
#
# Epoch 00213: val_loss did not improve from 25.72791
# Epoch 214/50000
#
# Epoch 00214: val_loss did not improve from 25.72791
# Epoch 215/50000
#
# Epoch 00215: val_loss did not improve from 25.72791
# Epoch 216/50000
#
# Epoch 00216: val_loss did not improve from 25.72791
# Epoch 217/50000
#
# Epoch 00217: val_loss did not improve from 25.72791
# Epoch 218/50000
#
# Epoch 00218: val_loss did not improve from 25.72791
# Epoch 219/50000
#
# Epoch 00219: val_loss did not improve from 25.72791
# Epoch 220/50000
#
# Epoch 00220: val_loss did not improve from 25.72791
# Epoch 221/50000
#
# Epoch 00221: val_loss did not improve from 25.72791
# Epoch 222/50000
#
# Epoch 00222: val_loss did not improve from 25.72791
# Epoch 223/50000
#
# Epoch 00223: val_loss did not improve from 25.72791
# Epoch 224/50000
#
# Epoch 00224: val_loss did not improve from 25.72791
# Epoch 225/50000
#
# Epoch 00225: val_loss improved from 25.72791 to 25.39383, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 226/50000
#
# Epoch 00226: val_loss did not improve from 25.39383
# Epoch 227/50000
#
# Epoch 00227: val_loss did not improve from 25.39383
# Epoch 228/50000
#
# Epoch 00228: val_loss did not improve from 25.39383
# Epoch 229/50000
#
# Epoch 00229: val_loss did not improve from 25.39383
# Epoch 230/50000
#
# Epoch 00230: val_loss did not improve from 25.39383
# Epoch 231/50000
#
# Epoch 00231: val_loss did not improve from 25.39383
# Epoch 232/50000
#
# Epoch 00232: val_loss did not improve from 25.39383
# Epoch 233/50000
#
# Epoch 00233: val_loss did not improve from 25.39383
# Epoch 234/50000
#
# Epoch 00234: val_loss did not improve from 25.39383
# Epoch 235/50000
#
# Epoch 00235: val_loss did not improve from 25.39383
# Epoch 236/50000
#
# Epoch 00236: val_loss did not improve from 25.39383
# Epoch 237/50000
#
# Epoch 00237: val_loss did not improve from 25.39383
# Epoch 238/50000
#
# Epoch 00238: val_loss did not improve from 25.39383
# Epoch 239/50000
#
# Epoch 00239: val_loss did not improve from 25.39383
# Epoch 240/50000
#
# Epoch 00240: val_loss improved from 25.39383 to 25.05235, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 241/50000
#
# Epoch 00241: val_loss improved from 25.05235 to 23.31071, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 242/50000
#
# Epoch 00242: val_loss did not improve from 23.31071
# Epoch 243/50000
#
# Epoch 00243: val_loss did not improve from 23.31071
# Epoch 244/50000
#
# Epoch 00244: val_loss did not improve from 23.31071
# Epoch 245/50000
#
# Epoch 00245: val_loss did not improve from 23.31071
# Epoch 246/50000
#
# Epoch 00246: val_loss did not improve from 23.31071
# Epoch 247/50000
#
# Epoch 00247: val_loss did not improve from 23.31071
# Epoch 248/50000
#
# Epoch 00248: val_loss did not improve from 23.31071
# Epoch 249/50000
#
# Epoch 00249: val_loss did not improve from 23.31071
# Epoch 250/50000
#
# Epoch 00250: val_loss did not improve from 23.31071
# Epoch 251/50000
#
# Epoch 00251: val_loss did not improve from 23.31071
# Epoch 252/50000
#
# Epoch 00252: val_loss did not improve from 23.31071
# Epoch 253/50000
#
# Epoch 00253: val_loss did not improve from 23.31071
# Epoch 254/50000
#
# Epoch 00254: val_loss did not improve from 23.31071
# Epoch 255/50000
#
# Epoch 00255: val_loss did not improve from 23.31071
# Epoch 256/50000
#
# Epoch 00256: val_loss did not improve from 23.31071
# Epoch 257/50000
#
# Epoch 00257: val_loss did not improve from 23.31071
# Epoch 258/50000
#
# Epoch 00258: val_loss did not improve from 23.31071
# Epoch 259/50000
#
# Epoch 00259: val_loss did not improve from 23.31071
# Epoch 260/50000
#
# Epoch 00260: val_loss did not improve from 23.31071
# Epoch 261/50000
#
# Epoch 00261: val_loss did not improve from 23.31071
# Epoch 262/50000
#
# Epoch 00262: val_loss did not improve from 23.31071
# Epoch 263/50000
#
# Epoch 00263: val_loss did not improve from 23.31071
# Epoch 264/50000
#
# Epoch 00264: val_loss did not improve from 23.31071
# Epoch 265/50000
#
# Epoch 00265: val_loss did not improve from 23.31071
# Epoch 266/50000
#
# Epoch 00266: val_loss did not improve from 23.31071
# Epoch 267/50000
#
# Epoch 00267: val_loss did not improve from 23.31071
# Epoch 268/50000
#
# Epoch 00268: val_loss did not improve from 23.31071
# Epoch 269/50000
#
# Epoch 00269: val_loss did not improve from 23.31071
# Epoch 270/50000
#
# Epoch 00270: val_loss did not improve from 23.31071
# Epoch 271/50000
#
# Epoch 00271: val_loss did not improve from 23.31071
# Epoch 272/50000
#
# Epoch 00272: val_loss did not improve from 23.31071
# Epoch 273/50000
#
# Epoch 00273: val_loss did not improve from 23.31071
# Epoch 274/50000
#
# Epoch 00274: val_loss did not improve from 23.31071
# Epoch 275/50000
#
# Epoch 00275: val_loss did not improve from 23.31071
# Epoch 276/50000
#
# Epoch 00276: val_loss did not improve from 23.31071
# Epoch 277/50000
#
# Epoch 00277: val_loss did not improve from 23.31071
# Epoch 278/50000
#
# Epoch 00278: val_loss did not improve from 23.31071
# Epoch 279/50000
#
# Epoch 00279: val_loss did not improve from 23.31071
# Epoch 280/50000
#
# Epoch 00280: val_loss did not improve from 23.31071
# Epoch 281/50000
#
# Epoch 00281: val_loss did not improve from 23.31071
# Epoch 282/50000
#
# Epoch 00282: val_loss did not improve from 23.31071
# Epoch 283/50000
#
# Epoch 00283: val_loss did not improve from 23.31071
# Epoch 284/50000
#
# Epoch 00284: val_loss did not improve from 23.31071
# Epoch 285/50000
#
# Epoch 00285: val_loss did not improve from 23.31071
# Epoch 286/50000
#
# Epoch 00286: val_loss did not improve from 23.31071
# Epoch 287/50000
#
# Epoch 00287: val_loss did not improve from 23.31071
# Epoch 288/50000
#
# Epoch 00288: val_loss did not improve from 23.31071
# Epoch 289/50000
#
# Epoch 00289: val_loss did not improve from 23.31071
# Epoch 290/50000
#
# Epoch 00290: val_loss did not improve from 23.31071
# Epoch 291/50000
#
# Epoch 00291: val_loss did not improve from 23.31071
# Epoch 292/50000
#
# Epoch 00292: val_loss improved from 23.31071 to 22.78037, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 293/50000
#
# Epoch 00293: val_loss did not improve from 22.78037
# Epoch 294/50000
#
# Epoch 00294: val_loss did not improve from 22.78037
# Epoch 295/50000
#
# Epoch 00295: val_loss did not improve from 22.78037
# Epoch 296/50000
#
# Epoch 00296: val_loss did not improve from 22.78037
# Epoch 297/50000
#
# Epoch 00297: val_loss did not improve from 22.78037
# Epoch 298/50000
#
# Epoch 00298: val_loss did not improve from 22.78037
# Epoch 299/50000
#
# Epoch 00299: val_loss did not improve from 22.78037
# Epoch 300/50000
#
# Epoch 00300: val_loss did not improve from 22.78037
# Epoch 301/50000
#
# Epoch 00301: val_loss did not improve from 22.78037
# Epoch 302/50000
#
# Epoch 00302: val_loss did not improve from 22.78037
# Epoch 303/50000
#
# Epoch 00303: val_loss did not improve from 22.78037
# Epoch 304/50000
#
# Epoch 00304: val_loss did not improve from 22.78037
# Epoch 305/50000
#
# Epoch 00305: val_loss did not improve from 22.78037
# Epoch 306/50000
#
# Epoch 00306: val_loss did not improve from 22.78037
# Epoch 307/50000
#
# Epoch 00307: val_loss did not improve from 22.78037
# Epoch 308/50000
#
# Epoch 00308: val_loss did not improve from 22.78037
# Epoch 309/50000
#
# Epoch 00309: val_loss did not improve from 22.78037
# Epoch 310/50000
#
# Epoch 00310: val_loss did not improve from 22.78037
# Epoch 311/50000
#
# Epoch 00311: val_loss did not improve from 22.78037
# Epoch 312/50000
#
# Epoch 00312: val_loss did not improve from 22.78037
# Epoch 313/50000
#
# Epoch 00313: val_loss did not improve from 22.78037
# Epoch 314/50000
#
# Epoch 00314: val_loss did not improve from 22.78037
# Epoch 315/50000
#
# Epoch 00315: val_loss did not improve from 22.78037
# Epoch 316/50000
#
# Epoch 00316: val_loss did not improve from 22.78037
# Epoch 317/50000
#
# Epoch 00317: val_loss did not improve from 22.78037
# Epoch 318/50000
#
# Epoch 00318: val_loss did not improve from 22.78037
# Epoch 319/50000
#
# Epoch 00319: val_loss did not improve from 22.78037
# Epoch 320/50000
#
# Epoch 00320: val_loss did not improve from 22.78037
# Epoch 321/50000
#
# Epoch 00321: val_loss did not improve from 22.78037
# Epoch 322/50000
#
# Epoch 00322: val_loss did not improve from 22.78037
# Epoch 323/50000
#
# Epoch 00323: val_loss did not improve from 22.78037
# Epoch 324/50000
#
# Epoch 00324: val_loss did not improve from 22.78037
# Epoch 325/50000
# Epoch 00325: val_loss did not improve from 22.78037
# Epoch 326/50000
#
# Epoch 00326: val_loss did not improve from 22.78037
# Epoch 327/50000
#
# Epoch 00327: val_loss did not improve from 22.78037
# Epoch 328/50000
#
# Epoch 00328: val_loss did not improve from 22.78037
# Epoch 329/50000
#
# Epoch 00329: val_loss did not improve from 22.78037
# Epoch 330/50000
#
# Epoch 00330: val_loss did not improve from 22.78037
# Epoch 331/50000
#
# Epoch 00331: val_loss did not improve from 22.78037
# Epoch 332/50000
#
# Epoch 00332: val_loss did not improve from 22.78037
# Epoch 333/50000
#
# Epoch 00333: val_loss did not improve from 22.78037
# Epoch 334/50000
#
# Epoch 00334: val_loss did not improve from 22.78037
# Epoch 335/50000
#
# Epoch 00335: val_loss did not improve from 22.78037
# Epoch 336/50000
#
# Epoch 00336: val_loss did not improve from 22.78037
# Epoch 337/50000
#
# Epoch 00337: val_loss did not improve from 22.78037
# Epoch 338/50000
#
# Epoch 00338: val_loss did not improve from 22.78037
# Epoch 339/50000
#
# Epoch 00339: val_loss did not improve from 22.78037
# Epoch 340/50000
#
# Epoch 00340: val_loss did not improve from 22.78037
# Epoch 341/50000
#
# Epoch 00341: val_loss did not improve from 22.78037
# Epoch 342/50000
#
# Epoch 00342: val_loss did not improve from 22.78037
# Epoch 343/50000
#
# Epoch 00343: val_loss did not improve from 22.78037
# Epoch 344/50000
#
# Epoch 00344: val_loss did not improve from 22.78037
# Epoch 345/50000
#
# Epoch 00345: val_loss did not improve from 22.78037
# Epoch 346/50000
#
# Epoch 00346: val_loss did not improve from 22.78037
# Epoch 347/50000
#
# Epoch 00347: val_loss did not improve from 22.78037
# Epoch 348/50000
#
# Epoch 00348: val_loss did not improve from 22.78037
# Epoch 349/50000
#
# Epoch 00349: val_loss did not improve from 22.78037
# Epoch 350/50000
#
# Epoch 00350: val_loss did not improve from 22.78037
# Epoch 351/50000
#
# Epoch 00351: val_loss did not improve from 22.78037
# Epoch 352/50000
#
# Epoch 00352: val_loss did not improve from 22.78037
# Epoch 353/50000
#
# Epoch 00353: val_loss improved from 22.78037 to 22.10679, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 354/50000
#
# Epoch 00354: val_loss did not improve from 22.10679
# Epoch 355/50000
#
# Epoch 00355: val_loss did not improve from 22.10679
# Epoch 356/50000
#
# Epoch 00356: val_loss did not improve from 22.10679
# Epoch 357/50000
#
# Epoch 00357: val_loss did not improve from 22.10679
# Epoch 358/50000
#
# Epoch 00358: val_loss did not improve from 22.10679
# Epoch 359/50000
#
# Epoch 00359: val_loss did not improve from 22.10679
# Epoch 360/50000
#
# Epoch 00360: val_loss did not improve from 22.10679
# Epoch 361/50000
#
# Epoch 00361: val_loss did not improve from 22.10679
# Epoch 362/50000
#
# Epoch 00362: val_loss did not improve from 22.10679
# Epoch 363/50000
#
# Epoch 00363: val_loss did not improve from 22.10679
# Epoch 364/50000
#
# Epoch 00364: val_loss did not improve from 22.10679
# Epoch 365/50000
#
# Epoch 00365: val_loss did not improve from 22.10679
# Epoch 366/50000
#
# Epoch 00366: val_loss did not improve from 22.10679
# Epoch 367/50000
#
# Epoch 00367: val_loss did not improve from 22.10679
# Epoch 368/50000
#
# Epoch 00368: val_loss did not improve from 22.10679
# Epoch 369/50000
#
# Epoch 00369: val_loss did not improve from 22.10679
# Epoch 370/50000
#
# Epoch 00370: val_loss did not improve from 22.10679
# Epoch 371/50000
#
# Epoch 00371: val_loss did not improve from 22.10679
# Epoch 372/50000
#
# Epoch 00372: val_loss did not improve from 22.10679
# Epoch 373/50000
#
# Epoch 00373: val_loss did not improve from 22.10679
# Epoch 374/50000
#
# Epoch 00374: val_loss did not improve from 22.10679
# Epoch 375/50000
#
# Epoch 00375: val_loss did not improve from 22.10679
# Epoch 376/50000
#
# Epoch 00376: val_loss did not improve from 22.10679
# Epoch 377/50000
#
# Epoch 00377: val_loss did not improve from 22.10679
# Epoch 378/50000
#
# Epoch 00378: val_loss did not improve from 22.10679
# Epoch 379/50000
#
# Epoch 00379: val_loss did not improve from 22.10679
# Epoch 380/50000
#
# Epoch 00380: val_loss did not improve from 22.10679
# Epoch 381/50000
#
# Epoch 00381: val_loss did not improve from 22.10679
# Epoch 382/50000
#
# Epoch 00382: val_loss did not improve from 22.10679
# Epoch 383/50000
#
# Epoch 00383: val_loss did not improve from 22.10679
# Epoch 384/50000
#
# Epoch 00384: val_loss did not improve from 22.10679
# Epoch 385/50000
#
# Epoch 00385: val_loss did not improve from 22.10679
# Epoch 386/50000
#
# Epoch 00386: val_loss did not improve from 22.10679
# Epoch 387/50000
#
# Epoch 00387: val_loss did not improve from 22.10679
# Epoch 388/50000
#
# Epoch 00388: val_loss did not improve from 22.10679
# Epoch 389/50000
#
# Epoch 00389: val_loss did not improve from 22.10679
# Epoch 390/50000
#
# Epoch 00390: val_loss did not improve from 22.10679
# Epoch 391/50000
#
# Epoch 00391: val_loss did not improve from 22.10679
# Epoch 392/50000
#
# Epoch 00392: val_loss did not improve from 22.10679
# Epoch 393/50000
#
# Epoch 00393: val_loss did not improve from 22.10679
# Epoch 394/50000
#
# Epoch 00394: val_loss did not improve from 22.10679
# Epoch 395/50000
#
# Epoch 00395: val_loss did not improve from 22.10679
# Epoch 396/50000
#
# Epoch 00396: val_loss did not improve from 22.10679
# Epoch 397/50000
#
# Epoch 00397: val_loss did not improve from 22.10679
# Epoch 398/50000
#
# Epoch 00398: val_loss did not improve from 22.10679
# Epoch 399/50000
#
# Epoch 00399: val_loss did not improve from 22.10679
# Epoch 400/50000
#
# Epoch 00400: val_loss did not improve from 22.10679
# Epoch 401/50000
#
# Epoch 00401: val_loss did not improve from 22.10679
# Epoch 402/50000
#
# Epoch 00402: val_loss did not improve from 22.10679
# Epoch 403/50000
#
# Epoch 00403: val_loss did not improve from 22.10679
# Epoch 404/50000
#
# Epoch 00404: val_loss did not improve from 22.10679
# Epoch 405/50000
#
# Epoch 00405: val_loss did not improve from 22.10679
# Epoch 406/50000
#
# Epoch 00406: val_loss did not improve from 22.10679
# Epoch 407/50000
#
# Epoch 00407: val_loss did not improve from 22.10679
# Epoch 408/50000
#
# Epoch 00408: val_loss did not improve from 22.10679
# Epoch 409/50000
#
# Epoch 00409: val_loss did not improve from 22.10679
# Epoch 410/50000
#
# Epoch 00410: val_loss did not improve from 22.10679
# Epoch 411/50000
#
# Epoch 00411: val_loss did not improve from 22.10679
# Epoch 412/50000
#
# Epoch 00412: val_loss did not improve from 22.10679
# Epoch 413/50000
#
# Epoch 00413: val_loss did not improve from 22.10679
# Epoch 414/50000
#
# Epoch 00414: val_loss did not improve from 22.10679
# Epoch 415/50000
#
# Epoch 00415: val_loss did not improve from 22.10679
# Epoch 416/50000
#
# Epoch 00416: val_loss did not improve from 22.10679
# Epoch 417/50000
#
# Epoch 00417: val_loss did not improve from 22.10679
# Epoch 418/50000
#
# Epoch 00418: val_loss did not improve from 22.10679
# Epoch 419/50000
#
# Epoch 00419: val_loss did not improve from 22.10679
# Epoch 420/50000
#
# Epoch 00420: val_loss did not improve from 22.10679
# Epoch 421/50000
#
# Epoch 00421: val_loss did not improve from 22.10679
# Epoch 422/50000
#
# Epoch 00422: val_loss did not improve from 22.10679
# Epoch 423/50000
#
# Epoch 00423: val_loss did not improve from 22.10679
# Epoch 424/50000
#
# Epoch 00424: val_loss did not improve from 22.10679
# Epoch 425/50000
#
# Epoch 00425: val_loss did not improve from 22.10679
# Epoch 426/50000
#
# Epoch 00426: val_loss did not improve from 22.10679
# Epoch 427/50000
#
# Epoch 00427: val_loss did not improve from 22.10679
# Epoch 428/50000
#
# Epoch 00428: val_loss did not improve from 22.10679
# Epoch 429/50000
#
# Epoch 00429: val_loss did not improve from 22.10679
# Epoch 430/50000
#
# Epoch 00430: val_loss did not improve from 22.10679
# Epoch 431/50000
#
# Epoch 00431: val_loss did not improve from 22.10679
# Epoch 432/50000
#
# Epoch 00432: val_loss did not improve from 22.10679
# Epoch 433/50000
#
# Epoch 00433: val_loss did not improve from 22.10679
# Epoch 434/50000
#
# Epoch 00434: val_loss did not improve from 22.10679
# Epoch 435/50000
#
# Epoch 00435: val_loss did not improve from 22.10679
# Epoch 436/50000
#
# Epoch 00436: val_loss did not improve from 22.10679
# Epoch 437/50000
#
# Epoch 00437: val_loss did not improve from 22.10679
# Epoch 438/50000
#
# Epoch 00438: val_loss did not improve from 22.10679
# Epoch 439/50000
#
# Epoch 00439: val_loss did not improve from 22.10679
# Epoch 440/50000
#
# Epoch 00440: val_loss did not improve from 22.10679
# Epoch 441/50000
#
# Epoch 00441: val_loss did not improve from 22.10679
# Epoch 442/50000
#
# Epoch 00442: val_loss did not improve from 22.10679
# Epoch 443/50000
# Epoch 00443: val_loss did not improve from 22.10679
# Epoch 444/50000
#
# Epoch 00444: val_loss did not improve from 22.10679
# Epoch 445/50000
#
# Epoch 00445: val_loss did not improve from 22.10679
# Epoch 446/50000
#
# Epoch 00446: val_loss did not improve from 22.10679
# Epoch 447/50000
#
# Epoch 00447: val_loss did not improve from 22.10679
# Epoch 448/50000
#
# Epoch 00448: val_loss did not improve from 22.10679
# Epoch 449/50000
#
# Epoch 00449: val_loss did not improve from 22.10679
# Epoch 450/50000
#
# Epoch 00450: val_loss did not improve from 22.10679
# Epoch 451/50000
#
# Epoch 00451: val_loss did not improve from 22.10679
# Epoch 452/50000
#
# Epoch 00452: val_loss did not improve from 22.10679
# Epoch 453/50000
#
# Epoch 00453: val_loss did not improve from 22.10679
# Epoch 454/50000
#
# Epoch 00454: val_loss did not improve from 22.10679
# Epoch 455/50000
#
# Epoch 00455: val_loss did not improve from 22.10679
# Epoch 456/50000
#
# Epoch 00456: val_loss did not improve from 22.10679
# Epoch 457/50000
#
# Epoch 00457: val_loss did not improve from 22.10679
# Epoch 458/50000
#
# Epoch 00458: val_loss did not improve from 22.10679
# Epoch 459/50000
#
# Epoch 00459: val_loss did not improve from 22.10679
# Epoch 460/50000
#
# Epoch 00460: val_loss did not improve from 22.10679
# Epoch 461/50000
#
# Epoch 00461: val_loss did not improve from 22.10679
# Epoch 462/50000
#
# Epoch 00462: val_loss did not improve from 22.10679
# Epoch 463/50000
#
# Epoch 00463: val_loss did not improve from 22.10679
# Epoch 464/50000
#
# Epoch 00464: val_loss did not improve from 22.10679
# Epoch 465/50000
#
# Epoch 00465: val_loss did not improve from 22.10679
# Epoch 466/50000
#
# Epoch 00466: val_loss did not improve from 22.10679
# Epoch 467/50000
#
# Epoch 00467: val_loss did not improve from 22.10679
# Epoch 468/50000
#
# Epoch 00468: val_loss did not improve from 22.10679
# Epoch 469/50000
#
# Epoch 00469: val_loss did not improve from 22.10679
# Epoch 470/50000
#
# Epoch 00470: val_loss did not improve from 22.10679
# Epoch 471/50000
#
# Epoch 00471: val_loss did not improve from 22.10679
# Epoch 472/50000
#
# Epoch 00472: val_loss did not improve from 22.10679
# Epoch 473/50000
#
# Epoch 00473: val_loss did not improve from 22.10679
# Epoch 474/50000
#
# Epoch 00474: val_loss did not improve from 22.10679
# Epoch 475/50000
#
# Epoch 00475: val_loss did not improve from 22.10679
# Epoch 476/50000
#
# Epoch 00476: val_loss did not improve from 22.10679
# Epoch 477/50000
#
# Epoch 00477: val_loss did not improve from 22.10679
# Epoch 478/50000
#
# Epoch 00478: val_loss did not improve from 22.10679
# Epoch 479/50000
#
# Epoch 00479: val_loss did not improve from 22.10679
# Epoch 480/50000
#
# Epoch 00480: val_loss did not improve from 22.10679
# Epoch 481/50000
#
# Epoch 00481: val_loss did not improve from 22.10679
# Epoch 482/50000
#
# Epoch 00482: val_loss did not improve from 22.10679
# Epoch 483/50000
#
# Epoch 00483: val_loss did not improve from 22.10679
# Epoch 484/50000
#
# Epoch 00484: val_loss did not improve from 22.10679
# Epoch 485/50000
#
# Epoch 00485: val_loss did not improve from 22.10679
# Epoch 486/50000
#
# Epoch 00486: val_loss did not improve from 22.10679
# Epoch 487/50000
#
# Epoch 00487: val_loss did not improve from 22.10679
# Epoch 488/50000
#
# Epoch 00488: val_loss did not improve from 22.10679
# Epoch 489/50000
#
# Epoch 00489: val_loss did not improve from 22.10679
# Epoch 490/50000
#
# Epoch 00490: val_loss did not improve from 22.10679
# Epoch 491/50000
#
# Epoch 00491: val_loss did not improve from 22.10679
# Epoch 492/50000
#
# Epoch 00492: val_loss did not improve from 22.10679
# Epoch 493/50000
#
# Epoch 00493: val_loss did not improve from 22.10679
# Epoch 494/50000
#
# Epoch 00494: val_loss did not improve from 22.10679
# Epoch 495/50000
#
# Epoch 00495: val_loss did not improve from 22.10679
# Epoch 496/50000
#
# Epoch 00496: val_loss did not improve from 22.10679
# Epoch 497/50000
#
# Epoch 00497: val_loss did not improve from 22.10679
# Epoch 498/50000
#
# Epoch 00498: val_loss did not improve from 22.10679
# Epoch 499/50000
#
# Epoch 00499: val_loss did not improve from 22.10679
# Epoch 500/50000
#
# Epoch 00500: val_loss did not improve from 22.10679
# Epoch 501/50000
#
# Epoch 00501: val_loss did not improve from 22.10679
# Epoch 502/50000
#
# Epoch 00502: val_loss did not improve from 22.10679
# Epoch 503/50000
#
# Epoch 00503: val_loss did not improve from 22.10679
# Epoch 504/50000
#
# Epoch 00504: val_loss did not improve from 22.10679
# Epoch 505/50000
#
# Epoch 00505: val_loss did not improve from 22.10679
# Epoch 506/50000
#
# Epoch 00506: val_loss did not improve from 22.10679
# Epoch 507/50000
#
# Epoch 00507: val_loss did not improve from 22.10679
# Epoch 508/50000
#
# Epoch 00508: val_loss did not improve from 22.10679
# Epoch 509/50000
#
# Epoch 00509: val_loss did not improve from 22.10679
# Epoch 510/50000
#
# Epoch 00510: val_loss did not improve from 22.10679
# Epoch 511/50000
#
# Epoch 00511: val_loss did not improve from 22.10679
# Epoch 512/50000
#
# Epoch 00512: val_loss did not improve from 22.10679
# Epoch 513/50000
#
# Epoch 00513: val_loss did not improve from 22.10679
# Epoch 514/50000
#
# Epoch 00514: val_loss did not improve from 22.10679
# Epoch 515/50000
#
# Epoch 00515: val_loss did not improve from 22.10679
# Epoch 516/50000
#
# Epoch 00516: val_loss did not improve from 22.10679
# Epoch 517/50000
#
# Epoch 00517: val_loss did not improve from 22.10679
# Epoch 518/50000
#
# Epoch 00518: val_loss did not improve from 22.10679
# Epoch 519/50000
#
# Epoch 00519: val_loss did not improve from 22.10679
# Epoch 520/50000
#
# Epoch 00520: val_loss did not improve from 22.10679
# Epoch 521/50000
#
# Epoch 00521: val_loss did not improve from 22.10679
# Epoch 522/50000
#
# Epoch 00522: val_loss did not improve from 22.10679
# Epoch 523/50000
#
# Epoch 00523: val_loss did not improve from 22.10679
# Epoch 524/50000
#
# Epoch 00524: val_loss did not improve from 22.10679
# Epoch 525/50000
#
# Epoch 00525: val_loss did not improve from 22.10679
# Epoch 526/50000
#
# Epoch 00526: val_loss did not improve from 22.10679
# Epoch 527/50000
#
# Epoch 00527: val_loss did not improve from 22.10679
# Epoch 528/50000
#
# Epoch 00528: val_loss did not improve from 22.10679
# Epoch 529/50000
#
# Epoch 00529: val_loss did not improve from 22.10679
# Epoch 530/50000
#
# Epoch 00530: val_loss did not improve from 22.10679
# Epoch 531/50000
#
# Epoch 00531: val_loss did not improve from 22.10679
# Epoch 532/50000
#
# Epoch 00532: val_loss did not improve from 22.10679
# Epoch 533/50000
#
# Epoch 00533: val_loss did not improve from 22.10679
# Epoch 534/50000
#
# Epoch 00534: val_loss did not improve from 22.10679
# Epoch 535/50000
#
# Epoch 00535: val_loss did not improve from 22.10679
# Epoch 536/50000
#
# Epoch 00536: val_loss did not improve from 22.10679
# Epoch 537/50000
#
# Epoch 00537: val_loss did not improve from 22.10679
# Epoch 538/50000
#
# Epoch 00538: val_loss did not improve from 22.10679
# Epoch 539/50000
#
# Epoch 00539: val_loss did not improve from 22.10679
# Epoch 540/50000
#
# Epoch 00540: val_loss did not improve from 22.10679
# Epoch 541/50000
#
# Epoch 00541: val_loss did not improve from 22.10679
# Epoch 542/50000
#
# Epoch 00542: val_loss did not improve from 22.10679
# Epoch 543/50000
#
# Epoch 00543: val_loss did not improve from 22.10679
# Epoch 544/50000
#
# Epoch 00544: val_loss did not improve from 22.10679
# Epoch 545/50000
#
# Epoch 00545: val_loss did not improve from 22.10679
# Epoch 546/50000
#
# Epoch 00546: val_loss did not improve from 22.10679
# Epoch 547/50000
#
# Epoch 00547: val_loss did not improve from 22.10679
# Epoch 548/50000
#
# Epoch 00548: val_loss did not improve from 22.10679
# Epoch 549/50000
#
# Epoch 00549: val_loss did not improve from 22.10679
# Epoch 550/50000
#
# Epoch 00550: val_loss did not improve from 22.10679
# Epoch 551/50000
#
# Epoch 00551: val_loss did not improve from 22.10679
# Epoch 552/50000
#
# Epoch 00552: val_loss did not improve from 22.10679
# Epoch 553/50000
#
# Epoch 00553: val_loss did not improve from 22.10679
# Epoch 554/50000
#
# Epoch 00554: val_loss did not improve from 22.10679
# Epoch 555/50000
#
# Epoch 00555: val_loss did not improve from 22.10679
# Epoch 556/50000
#
# Epoch 00556: val_loss did not improve from 22.10679
# Epoch 557/50000
#
# Epoch 00557: val_loss did not improve from 22.10679
# Epoch 558/50000
#
# Epoch 00558: val_loss did not improve from 22.10679
# Epoch 559/50000
#
# Epoch 00559: val_loss did not improve from 22.10679
# Epoch 560/50000
#
# Epoch 00560: val_loss did not improve from 22.10679
# Epoch 561/50000
#
# Epoch 00561: val_loss did not improve from 22.10679
# Epoch 562/50000
# Epoch 00562: val_loss did not improve from 22.10679
# Epoch 563/50000
#
# Epoch 00563: val_loss did not improve from 22.10679
# Epoch 564/50000
#
# Epoch 00564: val_loss did not improve from 22.10679
# Epoch 565/50000
#
# Epoch 00565: val_loss did not improve from 22.10679
# Epoch 566/50000
#
# Epoch 00566: val_loss did not improve from 22.10679
# Epoch 567/50000
#
# Epoch 00567: val_loss did not improve from 22.10679
# Epoch 568/50000
#
# Epoch 00568: val_loss did not improve from 22.10679
# Epoch 569/50000
#
# Epoch 00569: val_loss did not improve from 22.10679
# Epoch 570/50000
#
# Epoch 00570: val_loss did not improve from 22.10679
# Epoch 571/50000
#
# Epoch 00571: val_loss did not improve from 22.10679
# Epoch 572/50000
#
# Epoch 00572: val_loss did not improve from 22.10679
# Epoch 573/50000
#
# Epoch 00573: val_loss did not improve from 22.10679
# Epoch 574/50000
#
# Epoch 00574: val_loss did not improve from 22.10679
# Epoch 575/50000
#
# Epoch 00575: val_loss did not improve from 22.10679
# Epoch 576/50000
#
# Epoch 00576: val_loss did not improve from 22.10679
# Epoch 577/50000
#
# Epoch 00577: val_loss did not improve from 22.10679
# Epoch 578/50000
#
# Epoch 00578: val_loss did not improve from 22.10679
# Epoch 579/50000
#
# Epoch 00579: val_loss did not improve from 22.10679
# Epoch 580/50000
#
# Epoch 00580: val_loss did not improve from 22.10679
# Epoch 581/50000
#
# Epoch 00581: val_loss did not improve from 22.10679
# Epoch 582/50000
#
# Epoch 00582: val_loss did not improve from 22.10679
# Epoch 583/50000
#
# Epoch 00583: val_loss did not improve from 22.10679
# Epoch 584/50000
#
# Epoch 00584: val_loss did not improve from 22.10679
# Epoch 585/50000
#
# Epoch 00585: val_loss did not improve from 22.10679
# Epoch 586/50000
#
# Epoch 00586: val_loss did not improve from 22.10679
# Epoch 587/50000
#
# Epoch 00587: val_loss did not improve from 22.10679
# Epoch 588/50000
#
# Epoch 00588: val_loss did not improve from 22.10679
# Epoch 589/50000
#
# Epoch 00589: val_loss did not improve from 22.10679
# Epoch 590/50000
#
# Epoch 00590: val_loss did not improve from 22.10679
# Epoch 591/50000
#
# Epoch 00591: val_loss did not improve from 22.10679
# Epoch 592/50000
#
# Epoch 00592: val_loss did not improve from 22.10679
# Epoch 593/50000
#
# Epoch 00593: val_loss did not improve from 22.10679
# Epoch 594/50000
#
# Epoch 00594: val_loss did not improve from 22.10679
# Epoch 595/50000
#
# Epoch 00595: val_loss did not improve from 22.10679
# Epoch 596/50000
#
# Epoch 00596: val_loss did not improve from 22.10679
# Epoch 597/50000
#
# Epoch 00597: val_loss did not improve from 22.10679
# Epoch 598/50000
#
# Epoch 00598: val_loss did not improve from 22.10679
# Epoch 599/50000
#
# Epoch 00599: val_loss did not improve from 22.10679
# Epoch 600/50000
#
# Epoch 00600: val_loss did not improve from 22.10679
# Epoch 601/50000
#
# Epoch 00601: val_loss did not improve from 22.10679
# Epoch 602/50000
#
# Epoch 00602: val_loss did not improve from 22.10679
# Epoch 603/50000
#
# Epoch 00603: val_loss did not improve from 22.10679
# Epoch 604/50000
#
# Epoch 00604: val_loss did not improve from 22.10679
# Epoch 605/50000
#
# Epoch 00605: val_loss did not improve from 22.10679
# Epoch 606/50000
#
# Epoch 00606: val_loss did not improve from 22.10679
# Epoch 607/50000
#
# Epoch 00607: val_loss did not improve from 22.10679
# Epoch 608/50000
#
# Epoch 00608: val_loss did not improve from 22.10679
# Epoch 609/50000
#
# Epoch 00609: val_loss did not improve from 22.10679
# Epoch 610/50000
#
# Epoch 00610: val_loss did not improve from 22.10679
# Epoch 611/50000
#
# Epoch 00611: val_loss did not improve from 22.10679
# Epoch 612/50000
#
# Epoch 00612: val_loss did not improve from 22.10679
# Epoch 613/50000
#
# Epoch 00613: val_loss did not improve from 22.10679
# Epoch 614/50000
#
# Epoch 00614: val_loss did not improve from 22.10679
# Epoch 615/50000
#
# Epoch 00615: val_loss did not improve from 22.10679
# Epoch 616/50000
#
# Epoch 00616: val_loss did not improve from 22.10679
# Epoch 617/50000
#
# Epoch 00617: val_loss did not improve from 22.10679
# Epoch 618/50000
#
# Epoch 00618: val_loss did not improve from 22.10679
# Epoch 619/50000
#
# Epoch 00619: val_loss did not improve from 22.10679
# Epoch 620/50000
#
# Epoch 00620: val_loss did not improve from 22.10679
# Epoch 621/50000
#
# Epoch 00621: val_loss did not improve from 22.10679
# Epoch 622/50000
#
# Epoch 00622: val_loss did not improve from 22.10679
# Epoch 623/50000
#
# Epoch 00623: val_loss did not improve from 22.10679
# Epoch 624/50000
#
# Epoch 00624: val_loss did not improve from 22.10679
# Epoch 625/50000
#
# Epoch 00625: val_loss did not improve from 22.10679
# Epoch 626/50000
#
# Epoch 00626: val_loss did not improve from 22.10679
# Epoch 627/50000
#
# Epoch 00627: val_loss did not improve from 22.10679
# Epoch 628/50000
#
# Epoch 00628: val_loss did not improve from 22.10679
# Epoch 629/50000
#
# Epoch 00629: val_loss did not improve from 22.10679
# Epoch 630/50000
#
# Epoch 00630: val_loss did not improve from 22.10679
# Epoch 631/50000
#
# Epoch 00631: val_loss did not improve from 22.10679
# Epoch 632/50000
#
# Epoch 00632: val_loss did not improve from 22.10679
# Epoch 633/50000
#
# Epoch 00633: val_loss did not improve from 22.10679
# Epoch 634/50000
#
# Epoch 00634: val_loss did not improve from 22.10679
# Epoch 635/50000
#
# Epoch 00635: val_loss did not improve from 22.10679
# Epoch 636/50000
#
# Epoch 00636: val_loss did not improve from 22.10679
# Epoch 637/50000
#
# Epoch 00637: val_loss did not improve from 22.10679
# Epoch 638/50000
#
# Epoch 00638: val_loss did not improve from 22.10679
# Epoch 639/50000
#
# Epoch 00639: val_loss did not improve from 22.10679
# Epoch 640/50000
#
# Epoch 00640: val_loss did not improve from 22.10679
# Epoch 641/50000
#
# Epoch 00641: val_loss did not improve from 22.10679
# Epoch 642/50000
#
# Epoch 00642: val_loss did not improve from 22.10679
# Epoch 643/50000
#
# Epoch 00643: val_loss did not improve from 22.10679
# Epoch 644/50000
#
# Epoch 00644: val_loss did not improve from 22.10679
# Epoch 645/50000
#
# Epoch 00645: val_loss did not improve from 22.10679
# Epoch 646/50000
#
# Epoch 00646: val_loss did not improve from 22.10679
# Epoch 647/50000
#
# Epoch 00647: val_loss did not improve from 22.10679
# Epoch 648/50000
#
# Epoch 00648: val_loss did not improve from 22.10679
# Epoch 649/50000
#
# Epoch 00649: val_loss did not improve from 22.10679
# Epoch 650/50000
#
# Epoch 00650: val_loss did not improve from 22.10679
# Epoch 651/50000
#
# Epoch 00651: val_loss did not improve from 22.10679
# Epoch 652/50000
#
# Epoch 00652: val_loss did not improve from 22.10679
# Epoch 653/50000
#
# Epoch 00653: val_loss did not improve from 22.10679
# Epoch 654/50000
#
# Epoch 00654: val_loss improved from 22.10679 to 22.02012, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 655/50000
#
# Epoch 00655: val_loss did not improve from 22.02012
# Epoch 656/50000
#
# Epoch 00656: val_loss did not improve from 22.02012
# Epoch 657/50000
#
# Epoch 00657: val_loss did not improve from 22.02012
# Epoch 658/50000
#
# Epoch 00658: val_loss did not improve from 22.02012
# Epoch 659/50000
#
# Epoch 00659: val_loss did not improve from 22.02012
# Epoch 660/50000
#
# ...
# Epoch 1038/50000
#
# Epoch 01038: val_loss did not improve from 21.86345
# Epoch 1039/50000
#
# Epoch 01039: val_loss did not improve from 21.86345
# Epoch 1040/50000
#
# Epoch 01040: val_loss did not improve from 21.86345
# Epoch 1041/50000
#
# Epoch 01041: val_loss did not improve from 21.86345
# Epoch 1042/50000
#
# Epoch 01042: val_loss did not improve from 21.86345
# Epoch 1043/50000
#
# Epoch 01043: val_loss did not improve from 21.86345
# Epoch 1044/50000
#
# Epoch 01044: val_loss did not improve from 21.86345
# Epoch 1045/50000
#
# Epoch 01045: val_loss did not improve from 21.86345
# Epoch 1046/50000
#
# Epoch 01046: val_loss did not improve from 21.86345
# Epoch 1047/50000
#
# Epoch 01047: val_loss did not improve from 21.86345
# Epoch 1048/50000
#
# Epoch 01048: val_loss did not improve from 21.86345
# Epoch 1049/50000
#
# Epoch 01049: val_loss improved from 21.86345 to 21.65907, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 1050/50000
#
# Epoch 01050: val_loss did not improve from 21.65907
# Epoch 1051/50000
#
# Epoch 01051: val_loss did not improve from 21.65907
# Epoch 1052/50000
#
# Epoch 01052: val_loss did not improve from 21.65907
# Epoch 1053/50000
#
# Epoch 01053: val_loss did not improve from 21.65907
# Epoch 1054/50000
#
# Epoch 01054: val_loss did not improve from 21.65907
# Epoch 1055/50000
#
# Epoch 01055: val_loss did not improve from 21.65907
# Epoch 1056/50000
#
# Epoch 01056: val_loss did not improve from 21.65907
# Epoch 1057/50000
#
# Epoch 01057: val_loss did not improve from 21.65907
# Epoch 1058/50000
#
# Epoch 01058: val_loss did not improve from 21.65907
# Epoch 1059/50000
#
# Epoch 01059: val_loss did not improve from 21.65907
# Epoch 1060/50000
#
# Epoch 01060: val_loss did not improve from 21.65907
# Epoch 1061/50000
#
# Epoch 01061: val_loss did not improve from 21.65907
# Epoch 1062/50000
#
# Epoch 01062: val_loss did not improve from 21.65907
# Epoch 1063/50000
#
# Epoch 01063: val_loss did not improve from 21.65907
# Epoch 1064/50000
#
# Epoch 01064: val_loss did not improve from 21.65907
# Epoch 1065/50000
#
# Epoch 01065: val_loss did not improve from 21.65907
# Epoch 1066/50000
#
# Epoch 01066: val_loss did not improve from 21.65907
# Epoch 1067/50000
#
# Epoch 01067: val_loss did not improve from 21.65907
# Epoch 1068/50000
#
# Epoch 01068: val_loss did not improve from 21.65907
# Epoch 1069/50000
#
# Epoch 01069: val_loss did not improve from 21.65907
# Epoch 1070/50000
#
# Epoch 01070: val_loss did not improve from 21.65907
# Epoch 1071/50000
#
# Epoch 01071: val_loss did not improve from 21.65907
# Epoch 1072/50000
#
# Epoch 01072: val_loss did not improve from 21.65907
# Epoch 1073/50000
#
# Epoch 01073: val_loss did not improve from 21.65907
# Epoch 1074/50000
#
# Epoch 01074: val_loss did not improve from 21.65907
# Epoch 1075/50000
#
# Epoch 01075: val_loss did not improve from 21.65907
# Epoch 1076/50000
#
# Epoch 01076: val_loss did not improve from 21.65907
# Epoch 1077/50000
#
# Epoch 01077: val_loss did not improve from 21.65907
# Epoch 1078/50000
#
# Epoch 01078: val_loss did not improve from 21.65907
# Epoch 1079/50000
#
# Epoch 01079: val_loss did not improve from 21.65907
# Epoch 1080/50000
#
# Epoch 01080: val_loss did not improve from 21.65907
# Epoch 1081/50000
#
# Epoch 01081: val_loss did not improve from 21.65907
# Epoch 1082/50000
#
# Epoch 01082: val_loss did not improve from 21.65907
# Epoch 1083/50000
#
# Epoch 01083: val_loss did not improve from 21.65907
# Epoch 1084/50000
#
# Epoch 01084: val_loss did not improve from 21.65907
# Epoch 1085/50000
#
# Epoch 01085: val_loss did not improve from 21.65907
# Epoch 1086/50000
#
# Epoch 01086: val_loss did not improve from 21.65907
# Epoch 1087/50000
#
# Epoch 01087: val_loss did not improve from 21.65907
# Epoch 1088/50000
#
# Epoch 01088: val_loss did not improve from 21.65907
# Epoch 1089/50000
#
# Epoch 01089: val_loss did not improve from 21.65907
# Epoch 1090/50000
#
# Epoch 01090: val_loss did not improve from 21.65907
# Epoch 1091/50000
#
# Epoch 01091: val_loss did not improve from 21.65907
# Epoch 1092/50000
#
# Epoch 01092: val_loss did not improve from 21.65907
# Epoch 1093/50000
#
# Epoch 01093: val_loss did not improve from 21.65907
# Epoch 1094/50000
#
# Epoch 01094: val_loss did not improve from 21.65907
# Epoch 1095/50000
#
# Epoch 01095: val_loss did not improve from 21.65907
# Epoch 1096/50000
#
# Epoch 01096: val_loss did not improve from 21.65907
# Epoch 1097/50000
#
# Epoch 01097: val_loss did not improve from 21.65907
# Epoch 1098/50000
#
# Epoch 01098: val_loss did not improve from 21.65907
# Epoch 1099/50000
#
# Epoch 01099: val_loss did not improve from 21.65907
# Epoch 1100/50000
#
# Epoch 01100: val_loss did not improve from 21.65907
# Epoch 1101/50000
#
# Epoch 01101: val_loss did not improve from 21.65907
# Epoch 1102/50000
#
# Epoch 01102: val_loss did not improve from 21.65907
# Epoch 1103/50000
#
# Epoch 01103: val_loss did not improve from 21.65907
# Epoch 1104/50000
#
# Epoch 01104: val_loss did not improve from 21.65907
# Epoch 1105/50000
#
# Epoch 01105: val_loss did not improve from 21.65907
# Epoch 1106/50000
#
# Epoch 01106: val_loss did not improve from 21.65907
# Epoch 1107/50000
#
# Epoch 01107: val_loss did not improve from 21.65907
# Epoch 1108/50000
#
# Epoch 01108: val_loss did not improve from 21.65907
# Epoch 1109/50000
#
# Epoch 01109: val_loss did not improve from 21.65907
# Epoch 1110/50000
#
# Epoch 01110: val_loss did not improve from 21.65907
# Epoch 1111/50000
#
# Epoch 01111: val_loss did not improve from 21.65907
# Epoch 1112/50000
#
# Epoch 01112: val_loss did not improve from 21.65907
# Epoch 1113/50000
#
# Epoch 01113: val_loss did not improve from 21.65907
# Epoch 1114/50000
#
# Epoch 01114: val_loss did not improve from 21.65907
# Epoch 1115/50000
#
# Epoch 01115: val_loss did not improve from 21.65907
# Epoch 1116/50000
#
# Epoch 01116: val_loss did not improve from 21.65907
# Epoch 1117/50000
#
# Epoch 01117: val_loss did not improve from 21.65907
# Epoch 1118/50000
#
# Epoch 01118: val_loss did not improve from 21.65907
# Epoch 1119/50000
#
# Epoch 01119: val_loss did not improve from 21.65907
# Epoch 1120/50000
#
# Epoch 01120: val_loss did not improve from 21.65907
# Epoch 1121/50000
#
# Epoch 01121: val_loss did not improve from 21.65907
# Epoch 1122/50000
#
# Epoch 01122: val_loss did not improve from 21.65907
# Epoch 1123/50000
#
# Epoch 01123: val_loss did not improve from 21.65907
# Epoch 1124/50000
#
# Epoch 01124: val_loss did not improve from 21.65907
# Epoch 1125/50000
#
# Epoch 01125: val_loss did not improve from 21.65907
# Epoch 1126/50000
#
# Epoch 01126: val_loss did not improve from 21.65907
# Epoch 1127/50000
#
# Epoch 01127: val_loss did not improve from 21.65907
# Epoch 1128/50000
#
# Epoch 01128: val_loss did not improve from 21.65907
# Epoch 1129/50000
#
# Epoch 01129: val_loss did not improve from 21.65907
# Epoch 1130/50000
#
# Epoch 01130: val_loss did not improve from 21.65907
# Epoch 1131/50000
#
# Epoch 01131: val_loss did not improve from 21.65907
# Epoch 1132/50000
#
# Epoch 01132: val_loss did not improve from 21.65907
# Epoch 1133/50000
#
# Epoch 01133: val_loss did not improve from 21.65907
# Epoch 1134/50000
#
# Epoch 01134: val_loss did not improve from 21.65907
# Epoch 1135/50000
#
# Epoch 01135: val_loss did not improve from 21.65907
# Epoch 1136/50000
#
# Epoch 01136: val_loss did not improve from 21.65907
# Epoch 1137/50000
#
# Epoch 01137: val_loss did not improve from 21.65907
# Epoch 1138/50000
#
# Epoch 01138: val_loss did not improve from 21.65907
# Epoch 1139/50000
#
# Epoch 01139: val_loss did not improve from 21.65907
# Epoch 1140/50000
#
# Epoch 01140: val_loss did not improve from 21.65907
# Epoch 1141/50000
#
# Epoch 01141: val_loss did not improve from 21.65907
# Epoch 1142/50000
#
# Epoch 01142: val_loss improved from 21.65907 to 21.54396, saving model to training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5
# Epoch 1143/50000
#
# Epoch 01143: val_loss did not improve from 21.54396
# Epoch 1144/50000
#
# Epoch 01144: val_loss did not improve from 21.54396
# Epoch 1145/50000
#
# Epoch 01145: val_loss did not improve from 21.54396
# Epoch 1146/50000
#
# Epoch 01146: val_loss did not improve from 21.54396
# Epoch 1147/50000
#
# Epoch 01147: val_loss did not improve from 21.54396
# Epoch 1148/50000
#
# Epoch 01148: val_loss did not improve from 21.54396
# Epoch 1149/50000
#
# Epoch 01149: val_loss did not improve from 21.54396
# Epoch 1150/50000
#
# Epoch 01150: val_loss did not improve from 21.54396
# Epoch 1151/50000
# Epoch 01151: val_loss did not improve from 21.54396
# Epoch 1152/50000
#
# Epoch 01152: val_loss did not improve from 21.54396
# Epoch 1153/50000
#
# Epoch 01153: val_loss did not improve from 21.54396
# Epoch 1154/50000
#
# Epoch 01154: val_loss did not improve from 21.54396
# Epoch 1155/50000
#
# Epoch 01155: val_loss did not improve from 21.54396
# Epoch 1156/50000
#
# Epoch 01156: val_loss did not improve from 21.54396
# Epoch 1157/50000
#
# Epoch 01157: val_loss did not improve from 21.54396
# Epoch 1158/50000
#
# Epoch 01158: val_loss did not improve from 21.54396
# Epoch 1159/50000
#
# Epoch 01159: val_loss did not improve from 21.54396
# Epoch 1160/50000
#
# Epoch 01160: val_loss did not improve from 21.54396
# Epoch 1161/50000
#
# Epoch 01161: val_loss did not improve from 21.54396
# Epoch 1162/50000
#
# Epoch 01162: val_loss did not improve from 21.54396
# Epoch 1163/50000
#
# Epoch 01163: val_loss did not improve from 21.54396
# Epoch 1164/50000
#
# Epoch 01164: val_loss did not improve from 21.54396
# Epoch 1165/50000
#
# Epoch 01165: val_loss did not improve from 21.54396
# Epoch 1166/50000
#
# Epoch 01166: val_loss did not improve from 21.54396
# Epoch 1167/50000
#
# Epoch 01167: val_loss did not improve from 21.54396
# Epoch 1168/50000
#
# Epoch 01168: val_loss did not improve from 21.54396
# Epoch 1169/50000
#
# Epoch 01169: val_loss did not improve from 21.54396
# Epoch 1170/50000
#
# Epoch 01170: val_loss did not improve from 21.54396
# Epoch 1171/50000
#
# Epoch 01171: val_loss did not improve from 21.54396
# Epoch 1172/50000
#
# Epoch 01172: val_loss did not improve from 21.54396
# Epoch 1173/50000
#
# Epoch 01173: val_loss did not improve from 21.54396
# Epoch 1174/50000
#
# Epoch 01174: val_loss did not improve from 21.54396
# Epoch 1175/50000
#
# Epoch 01175: val_loss did not improve from 21.54396
# Epoch 1176/50000
#
# Epoch 01176: val_loss did not improve from 21.54396
# Epoch 1177/50000
#
# Epoch 01177: val_loss did not improve from 21.54396
# Epoch 1178/50000
#
# Epoch 01178: val_loss did not improve from 21.54396
# Epoch 1179/50000
#
# Epoch 01179: val_loss did not improve from 21.54396
# Epoch 1180/50000
#
# Epoch 01180: val_loss did not improve from 21.54396
# Epoch 1181/50000
#
# Epoch 01181: val_loss did not improve from 21.54396
# Epoch 1182/50000
#
# Epoch 01182: val_loss did not improve from 21.54396
# Epoch 1183/50000
#
# Epoch 01183: val_loss did not improve from 21.54396
# Epoch 1184/50000
#
# Epoch 01184: val_loss did not improve from 21.54396
# Epoch 1185/50000
#
# Epoch 01185: val_loss did not improve from 21.54396
# Epoch 1186/50000
#
# Epoch 01186: val_loss did not improve from 21.54396
# Epoch 1187/50000
#
# Epoch 01187: val_loss did not improve from 21.54396
# Epoch 1188/50000
#
# Epoch 01188: val_loss did not improve from 21.54396
# Epoch 1189/50000
#
# Epoch 01189: val_loss did not improve from 21.54396
# Epoch 1190/50000
#
# Epoch 01190: val_loss did not improve from 21.54396
# Epoch 1191/50000
#
# Epoch 01191: val_loss did not improve from 21.54396
# Epoch 1192/50000
#
# Epoch 01192: val_loss did not improve from 21.54396
# Epoch 1193/50000
#
# Epoch 01193: val_loss did not improve from 21.54396
# Epoch 1194/50000
#
# Epoch 01194: val_loss did not improve from 21.54396
# Epoch 1195/50000
#
# Epoch 01195: val_loss did not improve from 21.54396
# Epoch 1196/50000
#
# Epoch 01196: val_loss did not improve from 21.54396
# Epoch 1197/50000
#
# Epoch 01197: val_loss did not improve from 21.54396
# Epoch 1198/50000
#
# Epoch 01198: val_loss did not improve from 21.54396
# Epoch 1199/50000
#
# Epoch 01199: val_loss did not improve from 21.54396
# Epoch 1200/50000
#
# Epoch 01200: val_loss did not improve from 21.54396
# Epoch 1201/50000
#
# Epoch 01201: val_loss did not improve from 21.54396
# Epoch 1202/50000
#
# Epoch 01202: val_loss did not improve from 21.54396
# Epoch 1203/50000
#
# Epoch 01203: val_loss did not improve from 21.54396
# Epoch 1204/50000
#
# Epoch 01204: val_loss did not improve from 21.54396
# Epoch 1205/50000
#
# Epoch 01205: val_loss did not improve from 21.54396
# Epoch 1206/50000
#
# Epoch 01206: val_loss did not improve from 21.54396
# Epoch 1207/50000
#
# Epoch 01207: val_loss did not improve from 21.54396
# Epoch 1208/50000
#
# Epoch 01208: val_loss did not improve from 21.54396
# Epoch 1209/50000
#
# Epoch 01209: val_loss did not improve from 21.54396
# Epoch 1210/50000
#
# Epoch 01210: val_loss did not improve from 21.54396
# Epoch 1211/50000
#
# Epoch 01211: val_loss did not improve from 21.54396
# Epoch 1212/50000
#
# Epoch 01212: val_loss did not improve from 21.54396
# Epoch 1213/50000
#
# Epoch 01213: val_loss did not improve from 21.54396
# Epoch 1214/50000
#
# Epoch 01214: val_loss did not improve from 21.54396
# Epoch 1215/50000
#
# Epoch 01215: val_loss did not improve from 21.54396
# Epoch 1216/50000
#
# Epoch 01216: val_loss did not improve from 21.54396
# Epoch 1217/50000
#
# Epoch 01217: val_loss did not improve from 21.54396
# Epoch 1218/50000
#
# Epoch 01218: val_loss did not improve from 21.54396
# Epoch 1219/50000
#
# Epoch 01219: val_loss did not improve from 21.54396
# Epoch 1220/50000
#
# Epoch 01220: val_loss did not improve from 21.54396
# Epoch 1221/50000
#
# Epoch 01221: val_loss did not improve from 21.54396
# Epoch 1222/50000
#
# Epoch 01222: val_loss did not improve from 21.54396
# Epoch 1223/50000
#
# Epoch 01223: val_loss did not improve from 21.54396
# Epoch 1224/50000
#
# Epoch 01224: val_loss did not improve from 21.54396
# Epoch 1225/50000
#
# Epoch 01225: val_loss did not improve from 21.54396
# Epoch 1226/50000
#
# Epoch 01226: val_loss did not improve from 21.54396
# Epoch 1227/50000
#
# Epoch 01227: val_loss did not improve from 21.54396
# Epoch 1228/50000
#
# Epoch 01228: val_loss did not improve from 21.54396
# Epoch 1229/50000
#
# Epoch 01229: val_loss did not improve from 21.54396
# Epoch 1230/50000
#
# Epoch 01230: val_loss did not improve from 21.54396
# Epoch 1231/50000
#
# Epoch 01231: val_loss did not improve from 21.54396
# Epoch 1232/50000
#
# Epoch 01232: val_loss did not improve from 21.54396
# Epoch 1233/50000
#
# Epoch 01233: val_loss did not improve from 21.54396
# Epoch 1234/50000
#
# Epoch 01234: val_loss did not improve from 21.54396
# Epoch 1235/50000
#
# Epoch 01235: val_loss did not improve from 21.54396
# Epoch 1236/50000
#
# Epoch 01236: val_loss did not improve from 21.54396
# Epoch 1237/50000
#
# Epoch 01237: val_loss did not improve from 21.54396
# Epoch 1238/50000
#
# Epoch 01238: val_loss did not improve from 21.54396
# Epoch 1239/50000
#
# Epoch 01239: val_loss did not improve from 21.54396
# Epoch 1240/50000
#
# Epoch 01240: val_loss did not improve from 21.54396
# Epoch 1241/50000
#
# Epoch 01241: val_loss did not improve from 21.54396
# Epoch 1242/50000
#
# Epoch 01242: val_loss did not improve from 21.54396
# Epoch 1243/50000
#
# Epoch 01243: val_loss did not improve from 21.54396
# Epoch 1244/50000
#
# Epoch 01244: val_loss did not improve from 21.54396
# Epoch 1245/50000
#
# Epoch 01245: val_loss did not improve from 21.54396
# Epoch 1246/50000
#
# Epoch 01246: val_loss did not improve from 21.54396
# Epoch 1247/50000
#
# Epoch 01247: val_loss did not improve from 21.54396
# Epoch 1248/50000
#
# Epoch 01248: val_loss did not improve from 21.54396
# Epoch 1249/50000
#
# Epoch 01249: val_loss did not improve from 21.54396
# Epoch 1250/50000
#
# Epoch 01250: val_loss did not improve from 21.54396
# Epoch 1251/50000
#
# Epoch 01251: val_loss did not improve from 21.54396
# Epoch 1252/50000
#
# Epoch 01252: val_loss did not improve from 21.54396
# Epoch 1253/50000
#
# Epoch 01253: val_loss did not improve from 21.54396
# Epoch 1254/50000
#
# Epoch 01254: val_loss did not improve from 21.54396
# Epoch 1255/50000
#
# Epoch 01255: val_loss did not improve from 21.54396
# Epoch 1256/50000
#
# Epoch 01256: val_loss did not improve from 21.54396
# Epoch 1257/50000
#
# Epoch 01257: val_loss did not improve from 21.54396
# Epoch 1258/50000
#
# Epoch 01258: val_loss did not improve from 21.54396
# Epoch 1259/50000
#
# Epoch 01259: val_loss did not improve from 21.54396
# Epoch 1260/50000
#
# Epoch 01260: val_loss did not improve from 21.54396
# Epoch 1261/50000
#
# Epoch 01261: val_loss did not improve from 21.54396
# Epoch 1262/50000
#
# Epoch 01262: val_loss did not improve from 21.54396
# Epoch 1263/50000

# %%
df = pd.DataFrame(hist.history)
df.plot(subplots=True, figsize=(12,15))

# %% [markdown]
# # Testing

# %%
model.load_weights('training/unseen_speakers/results/weights-convlstm-lfw-crop-ctc-cls-v5.hdf5')
model.input[0]

# %%
from keras.models import Model, Sequential

# %%
prediction_model = Model(inputs = model.input[0], outputs = [model.get_layer('ctc_softmax').output,model.get_layer('classification').output])

# %%
SVG(model_to_dot(prediction_model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import itertools


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=False):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(11, 11))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
g_test=datagen(data_partition='test',batch_size=16)
ctc_test = []
cls_test = []
true_data = []
for i in range(1):
    print(i/128, end='\r')
    x,y=next(g_test)
    for i in range(0,16):
        X = x['input'][i]
    #     print(X)
        y_true = x['source_str'][i]#words[np.argmax(y[0][i])]
#         print(y_true)
    #     print(Y)append(x['source_str'])
        ctc_preds, cls_preds = prediction_model.predict(np.expand_dims(X,0))
        cls = words[np.argmax(cls_preds)]
        decoded = K.ctc_decode(y_pred=ctc_preds, input_length=(30,) ,greedy=True, beam_width=50, top_paths=50)
        paths = [path.eval(session=K.get_session()) for path in decoded[0]]
        logprobs  = decoded[1].eval(session=K.get_session())
        preds = []
        for path in paths:
            preds.append(''.join([chr(65+v) for v in path[0] ]))
        preds = np.array(preds)[0]
        ctc_test.append(preds)
        cls_test.append(cls)
        true_data.append(y_true)

# %%
pd.DataFrame(np.transpose([ctc_test,cls_test,true_data]),columns=['ctc','cls','true'])

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl

labels = words
true_data, ctc_test, cls_test = np.array(true_data), np.array(ctc_test), np.array(cls_test)
print(true_data.shape, ctc_test.shape, cls_test.shape)
cm = confusion_matrix(true_data, ctc_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix ctc')
cm = confusion_matrix(true_data, cls_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix cls')
