# %%
import sys
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from scipy import ndimage
from keras.optimizers import Adadelta,Adam
from keras.callbacks import TensorBoard, CSVLogger, ModelCheckpoint
# from lipnet.lipreading.generators import BasicGenerator
# from lipnet.lipreading.callbacks import Statistics, Visualize
# from lipnet.lipreading.curriculums import Curriculum
# from lipnet.core.decoders import Decoder
# from lipnet.lipreading.helpers import labels_to_text
# from lipnet.utils.spell import Spell
from lipnet.model2 import LipNet
import numpy as np
import datetime
import cv2
import skvideo.io
import dlib
from scipy.misc import imresize
# from lipnet.lipreading.aligns import Align
import imageio
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
import random
import tensorflow as tf
import keras.backend as K
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

FACE_PREDICTOR_PATH  = os.path.join('common','predictors','shape_predictor_68_face_landmarks.dat')
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(FACE_PREDICTOR_PATH)

frames_count = 30
words_folder = 'training/unseen_speakers/datasets/lipread_mp4'
words = os.listdir(words_folder)
max_len = np.max([len(word) for word in words])
used_words = {''}
def datagen(data_partition = 'train', batch_size = 16):
    while True:
        counter = 0
        word_idx = np.random.randint(len(words))
        used_words.add(words[word_idx])
        train_folder = 'training/unseen_speakers/datasets/lipread_mp4/{0}/{1}/'.format(words[word_idx],data_partition)
    #         print(train_folder)
        files = os.listdir(train_folder)
        paths = list(set([x.split('.')[0] for x in files]))
        
        X_data = []#np.zeros((batch_size,))
        Y_data = []
        input_length = []
        label_length = []
        source_str = []
        while counter<batch_size:
#             print(counter)
            idx = np.random.randint(len(paths))
            path = os.path.join(train_folder,paths[idx]+'.mp4')
    #         src_str_path = os.path.join(train_folder,paths[idx]+'.txt')
    #         with open(src_str_path) as f:
    #             l = f.readlines()
    #             print(l)

            vid = imageio.get_reader(path,  'ffmpeg')
            frames = []
            end = 0
            for i in range(frames_count):
                end = i
                frames.append(vid.get_data(i))

            ###
#             print('vedio frame shape:',np.shape(frames), data_partition, paths[idx])
            frames = get_frames_mouth(detector,predictor, frames, paths[idx])
            
            # for completely turned faces dlib cant identify the lip hence cannot crop
            # this check ensures only vid croppings which are 50x100x3 are added in batch
#             print('mouth frame shape:',np.shape(frames), data_partition, paths[idx])

            if 'numpy.ndarray' in str(type(frames)) \
                    and len(np.shape(frames))==4 \
                    and np.shape(frames)[1] == 100 \
                    and np.shape(frames)[2] == 50:
            
                X_data.append(frames)


                ####
                Y_data.append([ord(c) - 65 for c in words[word_idx]]+[-1]*(max_len-len(words[word_idx])))
                input_length.append(frames_count)
                label_length.append(len(words[word_idx]))
                source_str.append(words[word_idx])
                counter+=1
            else:
                continue
        
        X_data = np.array(X_data).astype(np.float32) / 255 
        Y_data = np.array(Y_data)
        input_length = np.array(input_length)
        label_length = np.array(label_length)
        source_str = np.array(source_str)
        
        inputs = {'the_input': X_data,
                  'the_labels': Y_data,
                  'input_length': input_length,
                  'label_length': label_length,
                  'source_str': source_str  # used for visualization only
                  }
        outputs = {'ctc': np.zeros([batch_size])}
        
#         print('the_input:', inputs['the_input'].shape)
#         print('the_labels:', inputs['the_labels'].shape)
#         print('input_length:', inputs['input_length'].shape)
#         print('label_length:', inputs['label_length'].shape)
#         print('source_str:', inputs['source_str'].shape)
#         print('batch_frames_shape',X_data.shape, data_partition)
        yield (inputs, outputs)

# %%
def get_frames_mouth(detector, predictor, frames, word):
    try:
        MOUTH_WIDTH = 100
        MOUTH_HEIGHT = 50
        HORIZONTAL_PAD = 0.19
        normalize_ratio = None
        mouth_frames = []
        for frame in frames:
            dets = detector(frame, 1)
            shape = None
            for k, d in enumerate(dets):
                shape = predictor(frame, d)
                i = -1
            if shape is None: # Detector doesn't detect face, just return as is
                return frames
            mouth_points = []
            for part in shape.parts():
                i += 1
                if i < 48: # Only take mouth region
                    continue
                mouth_points.append((part.x,part.y))
            np_mouth_points = np.array(mouth_points)

            mouth_centroid = np.mean(np_mouth_points[:, -2:], axis=0)

            if normalize_ratio is None:
                mouth_left = np.min(np_mouth_points[:, :-1]) * (1.0 - HORIZONTAL_PAD)
                mouth_right = np.max(np_mouth_points[:, :-1]) * (1.0 + HORIZONTAL_PAD)

                normalize_ratio = MOUTH_WIDTH / float(mouth_right - mouth_left)

            new_img_shape = (int(frame.shape[0] * normalize_ratio), int(frame.shape[1] * normalize_ratio))
            resized_img = imresize(frame, new_img_shape)

            mouth_centroid_norm = mouth_centroid * normalize_ratio

            mouth_l = int(mouth_centroid_norm[0] - MOUTH_WIDTH / 2)
            mouth_r = int(mouth_centroid_norm[0] + MOUTH_WIDTH / 2)
            mouth_t = int(mouth_centroid_norm[1] - MOUTH_HEIGHT / 2)
            mouth_b = int(mouth_centroid_norm[1] + MOUTH_HEIGHT / 2)

            mouth_crop_image = resized_img[mouth_t:mouth_b, mouth_l:mouth_r]
            
            mouth_frames.append(ndimage.rotate(mouth_crop_image, 90))
    #     print('shape mouth frames:',np.shape(mouth_frames))
        return np.array(mouth_frames)
    except Exception as e:
        print(e)
        print(word)
        return []

# %%
# global lip_gen

run_name = datetime.datetime.now().strftime('%Y:%m:%d_%H:%M:%S')
run_name, start_epoch, stop_epoch, img_c, img_w, img_h, frames_n, absolute_max_string_len, minibatch_size = \
    run_name, 0, 1000, 3, 100, 50, 30, 12, 2



CURRENT_PATH = os.getcwd()+'/training/unseen_speakers'
DATASET_DIR  = os.path.join(CURRENT_PATH, 'datasets')
OUTPUT_DIR   = os.path.join(CURRENT_PATH, 'results')
LOG_DIR      = os.path.join(CURRENT_PATH, 'logs')
# if not os.path.exists('training/unseen_speakers/results/'+run_name):
#     os.makedirs('training/unseen_speakers/results/'+run_name)
if not os.path.exists('training/unseen_speakers/logs/'+run_name):
    os.makedirs('training/unseen_speakers/logs/'+run_name)

PREDICT_GREEDY      = False
PREDICT_BEAM_WIDTH  = 200
PREDICT_DICTIONARY  = os.path.join(CURRENT_PATH,'..','..','common','dictionaries','lfw.txt')
FACE_PREDICTOR_PATH  = os.path.join(CURRENT_PATH,'..','..','common','predictors','shape_predictor_68_face_landmarks.dat')

# def curriculum_rules(epoch):
#     return { 'sentence_length': -1, 'flip_probability': 0.5, 'jitter_probability': 0.05 }


# # def train(run_name, start_epoch, stop_epoch, img_c, img_w, img_h, frames_n, absolute_max_string_len, minibatch_size):
# curriculum = Curriculum(curriculum_rules)
# lip_gen = BasicGenerator(dataset_path=DATASET_DIR, #vtype = "face", face_predictor_path = FACE_PREDICTOR_PATH,
#                             minibatch_size=minibatch_size,
#                             img_c=img_c, img_w=img_w, img_h=img_h, frames_n=frames_n,
#                             absolute_max_string_len=absolute_max_string_len,
#                             curriculum=curriculum, start_epoch=start_epoch).build()
# lip_gen_train = datagen(data_partition='train', batch_size=5)
# lip_gen_val = datagen(data_partition='val', batch_size=5)

lipnet = LipNet(img_c=img_c, img_w=img_w, img_h=img_h, frames_n=frames_n,
                        absolute_max_string_len=absolute_max_string_len, output_size=27)
# lipnet.summary()
# adadelta = Adadelta(lr=0.0001, decay=1e-08, epsilon=1e-08)

adam = Adam(lr=0.00005, beta_1=0.9, beta_2=0.999, decay=1e-08)

# the loss calc occurs elsewhere, so use a dummy lambda func for the loss
lipnet.model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=adam, metrics=['accuracy'])


# spell = Spell(path=PREDICT_DICTIONARY)
# decoder = Decoder(greedy=PREDICT_GREEDY, beam_width=PREDICT_BEAM_WIDTH,
#                   postprocessors=[labels_to_text, spell.sentence])

# define callbacks
# statistics  = Statistics(lipnet, lip_gen.next_val(), decoder, 256, output_dir=os.path.join(OUTPUT_DIR, run_name))
# visualize   = Visualize(os.path.join(OUTPUT_DIR, run_name), lipnet, lip_gen.next_val(), decoder, num_display_sentences=minibatch_size)
tensorboard = TensorBoard(log_dir=os.path.join(LOG_DIR, run_name))
# csv_logger  = CSVLogger(os.path.join(LOG_DIR, "{}-{}.csv".format('training',run_name)), separator=',', append=True)
checkpoint  = ModelCheckpoint(save_best_only=True,
                              filepath='training/unseen_speakers/results/weights_lfw.hdf5'
                              , monitor='val_loss'
                              , verbose=1
                              , mode='min'
                              , period=1)
    
    # x = next(lip_gen.next_val())
    # for i in x:
    #     print('$$$$$----------', type(i))
# Out:
# y_pred (?, 30, 27)

# %%
# run_name = datetime.datetime.now().strftime('%Y:%m:%d:%H:%M:%S')
# train(run_name, 0, 1000, 3, 100, 50, 75, 32, 2)

# %%
# os.getcwd()+'training/unseen_speakers'

# %%
# g=lip_gen.next_train()
# inputs, outputs = next(g)

# %%
# inputs

# %%
# len('place green at t six now')

# %%
# len([ 15.,  11.,   0.,   2.,   4.,  26.,   6.,  17.,   4.,   4.,  13.,
#           26.,   0.,  19.,  26.,  19.,  26.,  18.,   8.,  23.,  26.,  13.,
#           14.,  22.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.])

# %%
# outputs

# %%
# load weight if necessary

start_epoch = 5000
if start_epoch > 0:
    weight_file = os.path.join(OUTPUT_DIR, 'weights_lfw.hdf5')
    lipnet.model.load_weights(weight_file)

lipnet.model.fit_generator(generator=datagen(data_partition='train', batch_size=2),
                    steps_per_epoch=1
                    , epochs=20000,
                    #steps_per_epoch=lip_gen.default_training_steps, epochs=stop_epoch,
                    validation_data=datagen(data_partition='val', batch_size=2)
                    , validation_steps=1,#validation_steps=lip_gen.default_validation_steps,
                    callbacks=[checkpoint,tensorboard],                         
                    initial_epoch=start_epoch, 
                    verbose=1)
                    #max_q_size=5,
                    #workers=2,
                    #pickle_safe=True)
# Out:
# Epoch 5001/20000
# 1/1 [==============================] - 10s 10s/step - loss: 20.7304 - acc: 0.0000e+00 - val_loss: 16.2407 - val_acc: 0.0000e+00
#
# Epoch 05001: val_loss improved from inf to 16.24070, saving model to training/unseen_speakers/results/weights_lfw.hdf5
# Epoch 5002/20000
# 1/1 [==============================] - 2s 2s/step - loss: 16.0404 - acc: 0.0000e+00 - val_loss: 21.5295 - val_acc: 0.0000e+00
#
# Epoch 05002: val_loss did not improve from 16.24070
# Epoch 5003/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.2030 - acc: 0.0000e+00 - val_loss: 20.1182 - val_acc: 0.0000e+00
#
# Epoch 05003: val_loss did not improve from 16.24070
# Epoch 5004/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.5738 - acc: 0.0000e+00 - val_loss: 14.5383 - val_acc: 0.0000e+00
#
# Epoch 05004: val_loss improved from 16.24070 to 14.53829, saving model to training/unseen_speakers/results/weights_lfw.hdf5
# Epoch 5005/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.5630 - acc: 0.0000e+00 - val_loss: 28.9649 - val_acc: 0.0000e+00
#
# Epoch 05005: val_loss did not improve from 14.53829
# Epoch 5006/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.2959 - acc: 0.0000e+00 - val_loss: 15.5515 - val_acc: 0.0000e+00
#
# Epoch 05006: val_loss did not improve from 14.53829
# Epoch 5007/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.5966 - acc: 0.0000e+00 - val_loss: 14.5448 - val_acc: 0.0000e+00
#
# Epoch 05007: val_loss did not improve from 14.53829
# Epoch 5008/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.4371 - acc: 0.0000e+00 - val_loss: 24.0215 - val_acc: 0.0000e+00
#
# Epoch 05008: val_loss did not improve from 14.53829
# Epoch 5009/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.2133 - acc: 0.0000e+00 - val_loss: 17.9152 - val_acc: 0.0000e+00
#
# Epoch 05009: val_loss did not improve from 14.53829
# Epoch 5010/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.6871 - acc: 0.0000e+00 - val_loss: 15.5561 - val_acc: 0.0000e+00
#
# Epoch 05010: val_loss did not improve from 14.53829
# Epoch 5011/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.1049 - acc: 0.0000e+00 - val_loss: 19.6250 - val_acc: 0.0000e+00
#
# Epoch 05011: val_loss did not improve from 14.53829
# Epoch 5012/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.8214 - acc: 0.0000e+00 - val_loss: 20.7846 - val_acc: 0.0000e+00
#
# Epoch 05012: val_loss did not improve from 14.53829
# Epoch 5013/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.3995 - acc: 0.0000e+00 - val_loss: 19.6972 - val_acc: 0.0000e+00
#
# Epoch 05013: val_loss did not improve from 14.53829
# Epoch 5014/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.5528 - acc: 0.0000e+00 - val_loss: 20.3696 - val_acc: 0.0000e+00
#
# Epoch 05014: val_loss did not improve from 14.53829
# Epoch 5015/20000
# 1/1 [==============================] - 6s 6s/step - loss: 36.6761 - acc: 0.0000e+00 - val_loss: 22.8557 - val_acc: 0.0000e+00
#
# Epoch 05015: val_loss did not improve from 14.53829
# Epoch 5016/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.5163 - acc: 0.0000e+00 - val_loss: 22.2957 - val_acc: 0.0000e+00
#
# Epoch 05016: val_loss did not improve from 14.53829
# Epoch 5017/20000
# 1/1 [==============================] - 9s 9s/step - loss: 13.0491 - acc: 0.0000e+00 - val_loss: 24.1242 - val_acc: 0.0000e+00
#
# Epoch 05017: val_loss did not improve from 14.53829
# Epoch 5018/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.4027 - acc: 0.0000e+00 - val_loss: 26.8186 - val_acc: 0.0000e+00
#
# Epoch 05018: val_loss did not improve from 14.53829
# Epoch 5019/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.6510 - acc: 0.0000e+00 - val_loss: 23.1506 - val_acc: 0.0000e+00
#
# Epoch 05019: val_loss did not improve from 14.53829
# Epoch 5020/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.4068 - acc: 0.0000e+00 - val_loss: 11.2203 - val_acc: 0.0000e+00
#
# Epoch 05020: val_loss improved from 14.53829 to 11.22034, saving model to training/unseen_speakers/results/weights_lfw.hdf5
# Epoch 5021/20000
# 1/1 [==============================] - 5s 5s/step - loss: 17.3978 - acc: 0.0000e+00 - val_loss: 14.6905 - val_acc: 0.0000e+00
#
# Epoch 05021: val_loss did not improve from 11.22034
# Epoch 5022/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.0231 - acc: 0.0000e+00 - val_loss: 13.9938 - val_acc: 0.0000e+00
#
# Epoch 05022: val_loss did not improve from 11.22034
# Epoch 5023/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.5372 - acc: 0.0000e+00 - val_loss: 16.8405 - val_acc: 0.0000e+00
#
# Epoch 05023: val_loss did not improve from 11.22034
# Epoch 5024/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.4855 - acc: 0.0000e+00 - val_loss: 19.8877 - val_acc: 0.0000e+00
#
# Epoch 05024: val_loss did not improve from 11.22034
# Epoch 5025/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.9984 - acc: 0.0000e+00 - val_loss: 22.1361 - val_acc: 0.0000e+00
#
# Epoch 05025: val_loss did not improve from 11.22034
# Epoch 5026/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.7066 - acc: 0.0000e+00 - val_loss: 23.1739 - val_acc: 0.0000e+00
#
# Epoch 05026: val_loss did not improve from 11.22034
# Epoch 5027/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.4094 - acc: 0.0000e+00 - val_loss: 16.0941 - val_acc: 0.0000e+00
#
# Epoch 05027: val_loss did not improve from 11.22034
# Epoch 5028/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.3365 - acc: 0.0000e+00 - val_loss: 19.5606 - val_acc: 0.0000e+00
#
# Epoch 05028: val_loss did not improve from 11.22034
# Epoch 5029/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.3900 - acc: 0.0000e+00 - val_loss: 17.4840 - val_acc: 0.0000e+00
#
# Epoch 05029: val_loss did not improve from 11.22034
# Epoch 5030/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.8506 - acc: 0.0000e+00 - val_loss: 20.5724 - val_acc: 0.0000e+00
#
# Epoch 05030: val_loss did not improve from 11.22034
# Epoch 5031/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.3175 - acc: 0.0000e+00 - val_loss: 23.0497 - val_acc: 0.0000e+00
#
# Epoch 05031: val_loss did not improve from 11.22034
# Epoch 5032/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.1115 - acc: 0.0000e+00 - val_loss: 17.8583 - val_acc: 0.0000e+00
#
# Epoch 05032: val_loss did not improve from 11.22034
# Epoch 5033/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.1695 - acc: 0.0000e+00 - val_loss: 15.3743 - val_acc: 0.0000e+00
#
# Epoch 05033: val_loss did not improve from 11.22034
# Epoch 5034/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.4268 - acc: 0.0000e+00 - val_loss: 21.2113 - val_acc: 0.0000e+00
#
# Epoch 05034: val_loss did not improve from 11.22034
# Epoch 5035/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.4897 - acc: 0.0000e+00 - val_loss: 23.9823 - val_acc: 0.0000e+00
#
# Epoch 05035: val_loss did not improve from 11.22034
# Epoch 5036/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.2474 - acc: 0.0000e+00 - val_loss: 22.9143 - val_acc: 0.0000e+00
#
# Epoch 05036: val_loss did not improve from 11.22034
# Epoch 5037/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.4509 - acc: 0.0000e+00 - val_loss: 15.0569 - val_acc: 0.0000e+00
#
# Epoch 05037: val_loss did not improve from 11.22034
# Epoch 5038/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.2878 - acc: 0.0000e+00 - val_loss: 23.9163 - val_acc: 0.0000e+00
#
# Epoch 05038: val_loss did not improve from 11.22034
# Epoch 5039/20000
# 1/1 [==============================] - 6s 6s/step - loss: 31.6293 - acc: 0.0000e+00 - val_loss: 28.6622 - val_acc: 0.0000e+00
#
# Epoch 05039: val_loss did not improve from 11.22034
# Epoch 5040/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.1598 - acc: 0.0000e+00 - val_loss: 23.2285 - val_acc: 0.0000e+00
#
# Epoch 05040: val_loss did not improve from 11.22034
# Epoch 5041/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.5740 - acc: 0.0000e+00 - val_loss: 24.2770 - val_acc: 0.0000e+00
# Epoch 05041: val_loss did not improve from 11.22034
# Epoch 5042/20000
# 1/1 [==============================] - 6s 6s/step - loss: 27.4453 - acc: 0.0000e+00 - val_loss: 14.0979 - val_acc: 0.0000e+00
#
# Epoch 05042: val_loss did not improve from 11.22034
# Epoch 5043/20000
# 1/1 [==============================] - 6s 6s/step - loss: 27.4483 - acc: 0.0000e+00 - val_loss: 17.2239 - val_acc: 0.0000e+00
#
# Epoch 05043: val_loss did not improve from 11.22034
# Epoch 5044/20000
# 1/1 [==============================] - 9s 9s/step - loss: 17.9219 - acc: 0.0000e+00 - val_loss: 15.0434 - val_acc: 0.0000e+00
#
# Epoch 05044: val_loss did not improve from 11.22034
# Epoch 5045/20000
# 1/1 [==============================] - 6s 6s/step - loss: 34.9317 - acc: 0.0000e+00 - val_loss: 17.4123 - val_acc: 0.0000e+00
#
# Epoch 05045: val_loss did not improve from 11.22034
# Epoch 5046/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.9768 - acc: 0.0000e+00 - val_loss: 19.3984 - val_acc: 0.0000e+00
#
# Epoch 05046: val_loss did not improve from 11.22034
# Epoch 5047/20000
# 1/1 [==============================] - 6s 6s/step - loss: 12.3574 - acc: 0.0000e+00 - val_loss: 17.1551 - val_acc: 0.0000e+00
#
# Epoch 05047: val_loss did not improve from 11.22034
# Epoch 5048/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.8280 - acc: 0.0000e+00 - val_loss: 24.3439 - val_acc: 0.0000e+00
#
# Epoch 05048: val_loss did not improve from 11.22034
# Epoch 5049/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.6326 - acc: 0.0000e+00 - val_loss: 18.8952 - val_acc: 0.0000e+00
#
# Epoch 05049: val_loss did not improve from 11.22034
# Epoch 5050/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.0713 - acc: 0.0000e+00 - val_loss: 16.6095 - val_acc: 0.0000e+00
#
# Epoch 05050: val_loss did not improve from 11.22034
# Epoch 5051/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.2758 - acc: 0.0000e+00 - val_loss: 27.6114 - val_acc: 0.0000e+00
#
# Epoch 05051: val_loss did not improve from 11.22034
# Epoch 5052/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.0854 - acc: 0.0000e+00 - val_loss: 14.7739 - val_acc: 0.0000e+00
#
# Epoch 05052: val_loss did not improve from 11.22034
# Epoch 5053/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.9321 - acc: 0.0000e+00 - val_loss: 14.9666 - val_acc: 0.0000e+00
#
# Epoch 05053: val_loss did not improve from 11.22034
# Epoch 5054/20000
# 1/1 [==============================] - 6s 6s/step - loss: 33.4341 - acc: 0.0000e+00 - val_loss: 14.9807 - val_acc: 0.0000e+00
#
# Epoch 05054: val_loss did not improve from 11.22034
# Epoch 5055/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.3142 - acc: 0.0000e+00 - val_loss: 22.1230 - val_acc: 0.0000e+00
#
# Epoch 05055: val_loss did not improve from 11.22034
# Epoch 5056/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.6350 - acc: 0.0000e+00 - val_loss: 27.1762 - val_acc: 0.0000e+00
#
# Epoch 05056: val_loss did not improve from 11.22034
# Epoch 5057/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.8622 - acc: 0.0000e+00 - val_loss: 15.3459 - val_acc: 0.0000e+00
#
# Epoch 05057: val_loss did not improve from 11.22034
# Epoch 5058/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.3038 - acc: 0.0000e+00 - val_loss: 18.7272 - val_acc: 0.0000e+00
#
# Epoch 05058: val_loss did not improve from 11.22034
# Epoch 5059/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.5162 - acc: 0.0000e+00 - val_loss: 18.4517 - val_acc: 0.0000e+00
#
# Epoch 05059: val_loss did not improve from 11.22034
# Epoch 5060/20000
# 1/1 [==============================] - 9s 9s/step - loss: 15.3551 - acc: 0.0000e+00 - val_loss: 20.6594 - val_acc: 0.0000e+00
#
# Epoch 05060: val_loss did not improve from 11.22034
# Epoch 5061/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.9363 - acc: 0.0000e+00 - val_loss: 14.3138 - val_acc: 0.0000e+00
#
# Epoch 05061: val_loss did not improve from 11.22034
# Epoch 5062/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.5545 - acc: 0.0000e+00 - val_loss: 15.0918 - val_acc: 0.0000e+00
#
# Epoch 05062: val_loss did not improve from 11.22034
# Epoch 5063/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.1308 - acc: 0.0000e+00 - val_loss: 14.3882 - val_acc: 0.0000e+00
#
# Epoch 05063: val_loss did not improve from 11.22034
# Epoch 5064/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.3210 - acc: 0.0000e+00 - val_loss: 26.6923 - val_acc: 0.0000e+00
#
# Epoch 05064: val_loss did not improve from 11.22034
# Epoch 5065/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.9820 - acc: 0.0000e+00 - val_loss: 20.7057 - val_acc: 0.0000e+00
#
# Epoch 05065: val_loss did not improve from 11.22034
# Epoch 5066/20000
# 1/1 [==============================] - 6s 6s/step - loss: 12.9367 - acc: 0.0000e+00 - val_loss: 33.3332 - val_acc: 0.0000e+00
#
# Epoch 05066: val_loss did not improve from 11.22034
# Epoch 5067/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.1071 - acc: 0.0000e+00 - val_loss: 24.1179 - val_acc: 0.0000e+00
#
# Epoch 05067: val_loss did not improve from 11.22034
# Epoch 5068/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.1649 - acc: 0.0000e+00 - val_loss: 21.6508 - val_acc: 0.0000e+00
#
# Epoch 05068: val_loss did not improve from 11.22034
# Epoch 5069/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.7392 - acc: 0.0000e+00 - val_loss: 14.3499 - val_acc: 0.0000e+00
#
# Epoch 05069: val_loss did not improve from 11.22034
# Epoch 5070/20000
# 1/1 [==============================] - 5s 5s/step - loss: 27.9713 - acc: 0.0000e+00 - val_loss: 15.3115 - val_acc: 0.0000e+00
#
# Epoch 05070: val_loss did not improve from 11.22034
# Epoch 5071/20000
# 1/1 [==============================] - 6s 6s/step - loss: 12.4791 - acc: 0.0000e+00 - val_loss: 22.4098 - val_acc: 0.0000e+00
#
# Epoch 05071: val_loss did not improve from 11.22034
# Epoch 5072/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.6512 - acc: 0.0000e+00 - val_loss: 15.8265 - val_acc: 0.0000e+00
#
# Epoch 05072: val_loss did not improve from 11.22034
# Epoch 5073/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.6453 - acc: 0.0000e+00 - val_loss: 23.7357 - val_acc: 0.0000e+00
#
# Epoch 05073: val_loss did not improve from 11.22034
# Epoch 5074/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.2956 - acc: 0.0000e+00 - val_loss: 17.9086 - val_acc: 0.0000e+00
#
# Epoch 05074: val_loss did not improve from 11.22034
# Epoch 5075/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.8702 - acc: 0.0000e+00 - val_loss: 12.0386 - val_acc: 0.0000e+00
#
# Epoch 05075: val_loss did not improve from 11.22034
# Epoch 5076/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.7747 - acc: 0.0000e+00 - val_loss: 17.5114 - val_acc: 0.0000e+00
#
# Epoch 05076: val_loss did not improve from 11.22034
# Epoch 5077/20000
# 1/1 [==============================] - 6s 6s/step - loss: 26.1768 - acc: 0.0000e+00 - val_loss: 17.4484 - val_acc: 0.0000e+00
#
# Epoch 05077: val_loss did not improve from 11.22034
# Epoch 5078/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.1605 - acc: 0.0000e+00 - val_loss: 30.6359 - val_acc: 0.0000e+00
#
# Epoch 05078: val_loss did not improve from 11.22034
# Epoch 5079/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.5273 - acc: 0.0000e+00 - val_loss: 13.6342 - val_acc: 0.0000e+00
#
# Epoch 05079: val_loss did not improve from 11.22034
# Epoch 5080/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.9552 - acc: 0.0000e+00 - val_loss: 15.0332 - val_acc: 0.0000e+00
#
# Epoch 05080: val_loss did not improve from 11.22034
# Epoch 5081/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.2839 - acc: 0.0000e+00 - val_loss: 18.8125 - val_acc: 0.0000e+00
#
# Epoch 05081: val_loss did not improve from 11.22034
# Epoch 5082/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.8958 - acc: 0.0000e+00 - val_loss: 16.5719 - val_acc: 0.0000e+00
#
# Epoch 05082: val_loss did not improve from 11.22034
# Epoch 5083/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.9715 - acc: 0.0000e+00 - val_loss: 13.5640 - val_acc: 0.0000e+00
# Epoch 05083: val_loss did not improve from 11.22034
# Epoch 5084/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.7352 - acc: 0.0000e+00 - val_loss: 32.8505 - val_acc: 0.0000e+00
#
# Epoch 05084: val_loss did not improve from 11.22034
# Epoch 5085/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.9902 - acc: 0.0000e+00 - val_loss: 20.5022 - val_acc: 0.0000e+00
#
# Epoch 05085: val_loss did not improve from 11.22034
# Epoch 5086/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.6268 - acc: 0.0000e+00 - val_loss: 30.3573 - val_acc: 0.0000e+00
#
# Epoch 05086: val_loss did not improve from 11.22034
# Epoch 5087/20000
# 1/1 [==============================] - 8s 8s/step - loss: 20.3316 - acc: 0.0000e+00 - val_loss: 20.1089 - val_acc: 0.0000e+00
#
# Epoch 05087: val_loss did not improve from 11.22034
# Epoch 5088/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.0587 - acc: 0.0000e+00 - val_loss: 20.9804 - val_acc: 0.0000e+00
#
# Epoch 05088: val_loss did not improve from 11.22034
# Epoch 5089/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.0984 - acc: 0.0000e+00 - val_loss: 15.1539 - val_acc: 0.0000e+00
#
# Epoch 05089: val_loss did not improve from 11.22034
# Epoch 5090/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.7830 - acc: 0.0000e+00 - val_loss: 20.4091 - val_acc: 0.0000e+00
#
# Epoch 05090: val_loss did not improve from 11.22034
# Epoch 5091/20000
# 1/1 [==============================] - 7s 7s/step - loss: 16.9247 - acc: 0.0000e+00 - val_loss: 32.2515 - val_acc: 0.0000e+00
#
# Epoch 05091: val_loss did not improve from 11.22034
# Epoch 5092/20000
# 1/1 [==============================] - 6s 6s/step - loss: 29.7297 - acc: 0.0000e+00 - val_loss: 14.4693 - val_acc: 0.0000e+00
#
# Epoch 05092: val_loss did not improve from 11.22034
# Epoch 5093/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.2136 - acc: 0.0000e+00 - val_loss: 13.2900 - val_acc: 0.0000e+00
#
# Epoch 05093: val_loss did not improve from 11.22034
# Epoch 5094/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.1443 - acc: 0.0000e+00 - val_loss: 15.1779 - val_acc: 0.0000e+00
#
# Epoch 05094: val_loss did not improve from 11.22034
# Epoch 5095/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.8252 - acc: 0.0000e+00 - val_loss: 18.8377 - val_acc: 0.0000e+00
#
# Epoch 05095: val_loss did not improve from 11.22034
# Epoch 5096/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.9133 - acc: 0.0000e+00 - val_loss: 18.9154 - val_acc: 0.0000e+00
#
# Epoch 05096: val_loss did not improve from 11.22034
# Epoch 5097/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.9547 - acc: 0.0000e+00 - val_loss: 24.2230 - val_acc: 0.0000e+00
#
# Epoch 05097: val_loss did not improve from 11.22034
# Epoch 5098/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.9631 - acc: 0.0000e+00 - val_loss: 20.5742 - val_acc: 0.0000e+00
#
# Epoch 05098: val_loss did not improve from 11.22034
# Epoch 5099/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.5584 - acc: 0.0000e+00 - val_loss: 17.7034 - val_acc: 0.0000e+00
#
# Epoch 05099: val_loss did not improve from 11.22034
# Epoch 5100/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.6492 - acc: 0.0000e+00 - val_loss: 29.4411 - val_acc: 0.0000e+00
#
# Epoch 05100: val_loss did not improve from 11.22034
# Epoch 5101/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.9783 - acc: 0.0000e+00 - val_loss: 14.2958 - val_acc: 0.0000e+00
#
# Epoch 05101: val_loss did not improve from 11.22034
# Epoch 5102/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.0305 - acc: 0.0000e+00 - val_loss: 17.8923 - val_acc: 0.0000e+00
#
# Epoch 05102: val_loss did not improve from 11.22034
# Epoch 5103/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.7012 - acc: 0.0000e+00 - val_loss: 19.5662 - val_acc: 0.0000e+00
#
# Epoch 05103: val_loss did not improve from 11.22034
# Epoch 5104/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.4770 - acc: 0.0000e+00 - val_loss: 25.2719 - val_acc: 0.0000e+00
#
# Epoch 05104: val_loss did not improve from 11.22034
# Epoch 5105/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.0768 - acc: 0.0000e+00 - val_loss: 23.8366 - val_acc: 0.0000e+00
#
# Epoch 05105: val_loss did not improve from 11.22034
# Epoch 5106/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.1731 - acc: 0.0000e+00 - val_loss: 16.9091 - val_acc: 0.0000e+00
#
# Epoch 05106: val_loss did not improve from 11.22034
# Epoch 5107/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.2245 - acc: 0.0000e+00 - val_loss: 17.0490 - val_acc: 0.0000e+00
#
# Epoch 05107: val_loss did not improve from 11.22034
# Epoch 5108/20000
# 1/1 [==============================] - 5s 5s/step - loss: 15.2386 - acc: 0.0000e+00 - val_loss: 19.7285 - val_acc: 0.0000e+00
#
# Epoch 05108: val_loss did not improve from 11.22034
# Epoch 5109/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.9327 - acc: 0.0000e+00 - val_loss: 17.7253 - val_acc: 0.0000e+00
#
# Epoch 05109: val_loss did not improve from 11.22034
# Epoch 5110/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.1210 - acc: 0.0000e+00 - val_loss: 15.1994 - val_acc: 0.0000e+00
#
# Epoch 05110: val_loss did not improve from 11.22034
# Epoch 5111/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.8183 - acc: 0.0000e+00 - val_loss: 14.6270 - val_acc: 0.0000e+00
#
# Epoch 05111: val_loss did not improve from 11.22034
# Epoch 5112/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.3454 - acc: 0.0000e+00 - val_loss: 16.8815 - val_acc: 0.0000e+00
#
# Epoch 05112: val_loss did not improve from 11.22034
# Epoch 5113/20000
# 1/1 [==============================] - 6s 6s/step - loss: 25.0950 - acc: 0.0000e+00 - val_loss: 17.0396 - val_acc: 0.0000e+00
#
# Epoch 05113: val_loss did not improve from 11.22034
# Epoch 5114/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.6228 - acc: 0.0000e+00 - val_loss: 16.6929 - val_acc: 0.0000e+00
#
# Epoch 05114: val_loss did not improve from 11.22034
# Epoch 5115/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.6918 - acc: 0.0000e+00 - val_loss: 15.7578 - val_acc: 0.0000e+00
#
# Epoch 05115: val_loss did not improve from 11.22034
# Epoch 5116/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.8614 - acc: 0.0000e+00 - val_loss: 15.0257 - val_acc: 0.0000e+00
#
# Epoch 05116: val_loss did not improve from 11.22034
# Epoch 5117/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.2995 - acc: 0.0000e+00 - val_loss: 34.0029 - val_acc: 0.0000e+00
#
# Epoch 05117: val_loss did not improve from 11.22034
# Epoch 5118/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.2798 - acc: 0.0000e+00 - val_loss: 24.6271 - val_acc: 0.0000e+00
#
# Epoch 05118: val_loss did not improve from 11.22034
# Epoch 5119/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.3677 - acc: 0.0000e+00 - val_loss: 17.0531 - val_acc: 0.0000e+00
#
# Epoch 05119: val_loss did not improve from 11.22034
# Epoch 5120/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.3886 - acc: 0.0000e+00 - val_loss: 15.3595 - val_acc: 0.0000e+00
#
# Epoch 05120: val_loss did not improve from 11.22034
# Epoch 5121/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.0113 - acc: 0.0000e+00 - val_loss: 22.4422 - val_acc: 0.0000e+00
#
# Epoch 05121: val_loss did not improve from 11.22034
# Epoch 5122/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.5148 - acc: 0.0000e+00 - val_loss: 16.5922 - val_acc: 0.0000e+00
#
# Epoch 05122: val_loss did not improve from 11.22034
# Epoch 5123/20000
# 1/1 [==============================] - 6s 6s/step - loss: 32.6363 - acc: 0.0000e+00 - val_loss: 25.7372 - val_acc: 0.0000e+00
#
# Epoch 05123: val_loss did not improve from 11.22034
# Epoch 5124/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.6132 - acc: 0.0000e+00 - val_loss: 20.9696 - val_acc: 0.0000e+00
#
# Epoch 05124: val_loss did not improve from 11.22034
# Epoch 5125/20000
# 1/1 [==============================] - 9s 9s/step - loss: 19.2351 - acc: 0.0000e+00 - val_loss: 14.9291 - val_acc: 0.0000e+00
# Epoch 05125: val_loss did not improve from 11.22034
# Epoch 5126/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.1443 - acc: 0.0000e+00 - val_loss: 25.7856 - val_acc: 0.0000e+00
#
# Epoch 05126: val_loss did not improve from 11.22034
# Epoch 5127/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.9202 - acc: 0.0000e+00 - val_loss: 23.0969 - val_acc: 0.0000e+00
#
# Epoch 05127: val_loss did not improve from 11.22034
# Epoch 5128/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.8553 - acc: 0.0000e+00 - val_loss: 18.7149 - val_acc: 0.0000e+00
#
# Epoch 05128: val_loss did not improve from 11.22034
# Epoch 5129/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.6194 - acc: 0.0000e+00 - val_loss: 18.4564 - val_acc: 0.0000e+00
#
# Epoch 05129: val_loss did not improve from 11.22034
# Epoch 5130/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.4312 - acc: 0.0000e+00 - val_loss: 20.9648 - val_acc: 0.0000e+00
#
# Epoch 05130: val_loss did not improve from 11.22034
# Epoch 5131/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.8599 - acc: 0.0000e+00 - val_loss: 28.3910 - val_acc: 0.0000e+00
#
# Epoch 05131: val_loss did not improve from 11.22034
# Epoch 5132/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.2120 - acc: 0.0000e+00 - val_loss: 23.4277 - val_acc: 0.0000e+00
#
# Epoch 05132: val_loss did not improve from 11.22034
# Epoch 5133/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.2198 - acc: 0.0000e+00 - val_loss: 11.5839 - val_acc: 0.0000e+00
#
# Epoch 05133: val_loss did not improve from 11.22034
# Epoch 5134/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.5572 - acc: 0.0000e+00 - val_loss: 27.5708 - val_acc: 0.0000e+00
#
# Epoch 05134: val_loss did not improve from 11.22034
# Epoch 5135/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.9032 - acc: 0.0000e+00 - val_loss: 17.3849 - val_acc: 0.0000e+00
#
# Epoch 05135: val_loss did not improve from 11.22034
# Epoch 5136/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.4498 - acc: 0.0000e+00 - val_loss: 16.5614 - val_acc: 0.0000e+00
#
# Epoch 05136: val_loss did not improve from 11.22034
# Epoch 5137/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.9050 - acc: 0.0000e+00 - val_loss: 14.0231 - val_acc: 0.0000e+00
#
# Epoch 05137: val_loss did not improve from 11.22034
# Epoch 5138/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.4796 - acc: 0.0000e+00 - val_loss: 18.4683 - val_acc: 0.0000e+00
#
# Epoch 05138: val_loss did not improve from 11.22034
# Epoch 5139/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.0583 - acc: 0.0000e+00 - val_loss: 13.5052 - val_acc: 0.0000e+00
#
# Epoch 05139: val_loss did not improve from 11.22034
# Epoch 5140/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.5954 - acc: 0.0000e+00 - val_loss: 17.7553 - val_acc: 0.0000e+00
#
# Epoch 05140: val_loss did not improve from 11.22034
# Epoch 5141/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.7024 - acc: 0.0000e+00 - val_loss: 23.8558 - val_acc: 0.0000e+00
#
# Epoch 05141: val_loss did not improve from 11.22034
# Epoch 5142/20000
# 1/1 [==============================] - 6s 6s/step - loss: 25.5752 - acc: 0.0000e+00 - val_loss: 17.5381 - val_acc: 0.0000e+00
#
# Epoch 05142: val_loss did not improve from 11.22034
# Epoch 5143/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.6304 - acc: 0.0000e+00 - val_loss: 22.2042 - val_acc: 0.0000e+00
#
# Epoch 05143: val_loss did not improve from 11.22034
# Epoch 5144/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.1855 - acc: 0.0000e+00 - val_loss: 17.4880 - val_acc: 0.0000e+00
#
# Epoch 05144: val_loss did not improve from 11.22034
# Epoch 5145/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.5491 - acc: 0.0000e+00 - val_loss: 12.7190 - val_acc: 0.0000e+00
#
# Epoch 05145: val_loss did not improve from 11.22034
# Epoch 5146/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.1191 - acc: 0.0000e+00 - val_loss: 18.2319 - val_acc: 0.0000e+00
#
# Epoch 05146: val_loss did not improve from 11.22034
# Epoch 5147/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.1709 - acc: 0.0000e+00 - val_loss: 21.3917 - val_acc: 0.0000e+00
#
# Epoch 05147: val_loss did not improve from 11.22034
# Epoch 5148/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.6730 - acc: 0.0000e+00 - val_loss: 13.9717 - val_acc: 0.0000e+00
#
# Epoch 05148: val_loss did not improve from 11.22034
# Epoch 5149/20000
# 1/1 [==============================] - 7s 7s/step - loss: 17.1714 - acc: 0.0000e+00 - val_loss: 18.8045 - val_acc: 0.0000e+00
#
# Epoch 05149: val_loss did not improve from 11.22034
# Epoch 5150/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.3263 - acc: 0.0000e+00 - val_loss: 27.7875 - val_acc: 0.0000e+00
#
# Epoch 05150: val_loss did not improve from 11.22034
# Epoch 5151/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.4101 - acc: 0.0000e+00 - val_loss: 36.3782 - val_acc: 0.0000e+00
#
# Epoch 05151: val_loss did not improve from 11.22034
# Epoch 5152/20000
# 1/1 [==============================] - 6s 6s/step - loss: 26.5555 - acc: 0.0000e+00 - val_loss: 18.5505 - val_acc: 0.0000e+00
#
# Epoch 05152: val_loss did not improve from 11.22034
# Epoch 5153/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.0531 - acc: 0.0000e+00 - val_loss: 24.7613 - val_acc: 0.0000e+00
#
# Epoch 05153: val_loss did not improve from 11.22034
# Epoch 5154/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.2154 - acc: 0.0000e+00 - val_loss: 23.6944 - val_acc: 0.0000e+00
#
# Epoch 05154: val_loss did not improve from 11.22034
# Epoch 5155/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.0811 - acc: 0.0000e+00 - val_loss: 17.0587 - val_acc: 0.0000e+00
#
# Epoch 05155: val_loss did not improve from 11.22034
# Epoch 5156/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.9674 - acc: 0.0000e+00 - val_loss: 15.0064 - val_acc: 0.0000e+00
#
# Epoch 05156: val_loss did not improve from 11.22034
# Epoch 5157/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.3222 - acc: 0.0000e+00 - val_loss: 18.4720 - val_acc: 0.0000e+00
#
# Epoch 05157: val_loss did not improve from 11.22034
# Epoch 5158/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.2852 - acc: 0.0000e+00 - val_loss: 17.4235 - val_acc: 0.0000e+00
#
# Epoch 05158: val_loss did not improve from 11.22034
# Epoch 5159/20000
# 1/1 [==============================] - 6s 6s/step - loss: 25.9739 - acc: 0.0000e+00 - val_loss: 12.0068 - val_acc: 0.0000e+00
#
# Epoch 05159: val_loss did not improve from 11.22034
# Epoch 5160/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.0121 - acc: 0.0000e+00 - val_loss: 26.4099 - val_acc: 0.0000e+00
#
# Epoch 05160: val_loss did not improve from 11.22034
# Epoch 5161/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.5848 - acc: 0.0000e+00 - val_loss: 15.0472 - val_acc: 0.0000e+00
#
# Epoch 05161: val_loss did not improve from 11.22034
# Epoch 5162/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.5933 - acc: 0.0000e+00 - val_loss: 19.5082 - val_acc: 0.0000e+00
#
# Epoch 05162: val_loss did not improve from 11.22034
# Epoch 5163/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.0125 - acc: 0.0000e+00 - val_loss: 17.0846 - val_acc: 0.0000e+00
#
# Epoch 05163: val_loss did not improve from 11.22034
# Epoch 5164/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.8987 - acc: 0.0000e+00 - val_loss: 15.6313 - val_acc: 0.0000e+00
#
# Epoch 05164: val_loss did not improve from 11.22034
# Epoch 5165/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.0389 - acc: 0.0000e+00 - val_loss: 14.9793 - val_acc: 0.0000e+00
#
# Epoch 05165: val_loss did not improve from 11.22034
# Epoch 5166/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.9739 - acc: 0.0000e+00 - val_loss: 14.4789 - val_acc: 0.0000e+00
#
# Epoch 05166: val_loss did not improve from 11.22034
# Epoch 5167/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.6021 - acc: 0.0000e+00 - val_loss: 23.0219 - val_acc: 0.0000e+00
# Epoch 05167: val_loss did not improve from 11.22034
# Epoch 5168/20000
# 1/1 [==============================] - 7s 7s/step - loss: 15.2074 - acc: 0.0000e+00 - val_loss: 24.9611 - val_acc: 0.0000e+00
#
# Epoch 05168: val_loss did not improve from 11.22034
# Epoch 5169/20000
# 1/1 [==============================] - 6s 6s/step - loss: 12.1387 - acc: 0.0000e+00 - val_loss: 18.1580 - val_acc: 0.0000e+00
#
# Epoch 05169: val_loss did not improve from 11.22034
# Epoch 5170/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.8197 - acc: 0.0000e+00 - val_loss: 21.0062 - val_acc: 0.0000e+00
#
# Epoch 05170: val_loss did not improve from 11.22034
# Epoch 5171/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.3110 - acc: 0.0000e+00 - val_loss: 20.1634 - val_acc: 0.0000e+00
#
# Epoch 05171: val_loss did not improve from 11.22034
# Epoch 5172/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.3408 - acc: 0.0000e+00 - val_loss: 28.4559 - val_acc: 0.0000e+00
#
# Epoch 05172: val_loss did not improve from 11.22034
# Epoch 5173/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.0632 - acc: 0.0000e+00 - val_loss: 13.5925 - val_acc: 0.0000e+00
#
# Epoch 05173: val_loss did not improve from 11.22034
# Epoch 5174/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.9169 - acc: 0.0000e+00 - val_loss: 16.9670 - val_acc: 0.0000e+00
#
# Epoch 05174: val_loss did not improve from 11.22034
# Epoch 5175/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.9304 - acc: 0.0000e+00 - val_loss: 24.6814 - val_acc: 0.0000e+00
#
# Epoch 05175: val_loss did not improve from 11.22034
# Epoch 5176/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.6829 - acc: 0.0000e+00 - val_loss: 17.7138 - val_acc: 0.0000e+00
#
# Epoch 05176: val_loss did not improve from 11.22034
# Epoch 5177/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.7284 - acc: 0.0000e+00 - val_loss: 21.4225 - val_acc: 0.0000e+00
#
# Epoch 05177: val_loss did not improve from 11.22034
# Epoch 5178/20000
# 1/1 [==============================] - 6s 6s/step - loss: 27.7460 - acc: 0.0000e+00 - val_loss: 15.8606 - val_acc: 0.0000e+00
#
# Epoch 05178: val_loss did not improve from 11.22034
# Epoch 5179/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.3136 - acc: 0.0000e+00 - val_loss: 16.5472 - val_acc: 0.0000e+00
#
# Epoch 05179: val_loss did not improve from 11.22034
# Epoch 5180/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.3454 - acc: 0.0000e+00 - val_loss: 26.3287 - val_acc: 0.0000e+00
#
# Epoch 05180: val_loss did not improve from 11.22034
# Epoch 5181/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.0025 - acc: 0.0000e+00 - val_loss: 20.7621 - val_acc: 0.0000e+00
#
# Epoch 05181: val_loss did not improve from 11.22034
# Epoch 5182/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.1854 - acc: 0.0000e+00 - val_loss: 16.7903 - val_acc: 0.0000e+00
#
# Epoch 05182: val_loss did not improve from 11.22034
# Epoch 5183/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.8789 - acc: 0.0000e+00 - val_loss: 13.6029 - val_acc: 0.0000e+00
#
# Epoch 05183: val_loss did not improve from 11.22034
# Epoch 5184/20000
# 1/1 [==============================] - 6s 6s/step - loss: 12.0562 - acc: 0.0000e+00 - val_loss: 12.6596 - val_acc: 0.0000e+00
#
# Epoch 05184: val_loss did not improve from 11.22034
# Epoch 5185/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.0954 - acc: 0.0000e+00 - val_loss: 18.9430 - val_acc: 0.0000e+00
#
# Epoch 05185: val_loss did not improve from 11.22034
# Epoch 5186/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.4764 - acc: 0.0000e+00 - val_loss: 29.9506 - val_acc: 0.0000e+00
#
# Epoch 05186: val_loss did not improve from 11.22034
# Epoch 5187/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.0897 - acc: 0.0000e+00 - val_loss: 24.9396 - val_acc: 0.0000e+00
#
# Epoch 05187: val_loss did not improve from 11.22034
# Epoch 5188/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.5614 - acc: 0.0000e+00 - val_loss: 20.0872 - val_acc: 0.0000e+00
#
# Epoch 05188: val_loss did not improve from 11.22034
# Epoch 5189/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.6858 - acc: 0.0000e+00 - val_loss: 20.1296 - val_acc: 0.0000e+00
#
# Epoch 05189: val_loss did not improve from 11.22034
# Epoch 5190/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.3876 - acc: 0.0000e+00 - val_loss: 18.2111 - val_acc: 0.0000e+00
#
# Epoch 05190: val_loss did not improve from 11.22034
# Epoch 5191/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.1506 - acc: 0.0000e+00 - val_loss: 18.2629 - val_acc: 0.0000e+00
#
# Epoch 05191: val_loss did not improve from 11.22034
# Epoch 5192/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.1633 - acc: 0.0000e+00 - val_loss: 11.9334 - val_acc: 0.0000e+00
#
# Epoch 05192: val_loss did not improve from 11.22034
# Epoch 5193/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.5033 - acc: 0.0000e+00 - val_loss: 23.6307 - val_acc: 0.0000e+00
#
# Epoch 05193: val_loss did not improve from 11.22034
# Epoch 5194/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.1710 - acc: 0.0000e+00 - val_loss: 12.5748 - val_acc: 0.0000e+00
#
# Epoch 05194: val_loss did not improve from 11.22034
# Epoch 5195/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.3128 - acc: 0.0000e+00 - val_loss: 16.1115 - val_acc: 0.0000e+00
#
# Epoch 05195: val_loss did not improve from 11.22034
# Epoch 5196/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.7550 - acc: 0.0000e+00 - val_loss: 15.0603 - val_acc: 0.0000e+00
#
# Epoch 05196: val_loss did not improve from 11.22034
# Epoch 5197/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.7042 - acc: 0.0000e+00 - val_loss: 28.1038 - val_acc: 0.0000e+00
#
# Epoch 05197: val_loss did not improve from 11.22034
# Epoch 5198/20000
# 1/1 [==============================] - 6s 6s/step - loss: 33.2256 - acc: 0.0000e+00 - val_loss: 13.1109 - val_acc: 0.0000e+00
#
# Epoch 05198: val_loss did not improve from 11.22034
# Epoch 5199/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.3731 - acc: 0.0000e+00 - val_loss: 17.4381 - val_acc: 0.0000e+00
#
# Epoch 05199: val_loss did not improve from 11.22034
# Epoch 5200/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.1510 - acc: 0.0000e+00 - val_loss: 12.6534 - val_acc: 0.0000e+00
#
# Epoch 05200: val_loss did not improve from 11.22034
# Epoch 5201/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.8155 - acc: 0.0000e+00 - val_loss: 23.2466 - val_acc: 0.0000e+00
#
# Epoch 05201: val_loss did not improve from 11.22034
# Epoch 5202/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.9364 - acc: 0.0000e+00 - val_loss: 29.5255 - val_acc: 0.0000e+00
#
# Epoch 05202: val_loss did not improve from 11.22034
# Epoch 5203/20000
# 1/1 [==============================] - 6s 6s/step - loss: 26.6820 - acc: 0.0000e+00 - val_loss: 20.6341 - val_acc: 0.0000e+00
#
# Epoch 05203: val_loss did not improve from 11.22034
# Epoch 5204/20000
# 1/1 [==============================] - 6s 6s/step - loss: 25.7582 - acc: 0.0000e+00 - val_loss: 21.4300 - val_acc: 0.0000e+00
#
# Epoch 05204: val_loss did not improve from 11.22034
# Epoch 5205/20000
# 1/1 [==============================] - 6s 6s/step - loss: 25.3716 - acc: 0.0000e+00 - val_loss: 13.7743 - val_acc: 0.0000e+00
#
# Epoch 05205: val_loss did not improve from 11.22034
# Epoch 5206/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.0316 - acc: 0.0000e+00 - val_loss: 23.3004 - val_acc: 0.0000e+00
#
# Epoch 05206: val_loss did not improve from 11.22034
# Epoch 5207/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.8800 - acc: 0.0000e+00 - val_loss: 18.9184 - val_acc: 0.0000e+00
#
# Epoch 05207: val_loss did not improve from 11.22034
# Epoch 5208/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.5516 - acc: 0.0000e+00 - val_loss: 16.0077 - val_acc: 0.0000e+00
#
# Epoch 05208: val_loss did not improve from 11.22034
# Epoch 5209/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.0979 - acc: 0.0000e+00 - val_loss: 16.6768 - val_acc: 0.0000e+00
# Epoch 05209: val_loss did not improve from 11.22034
# Epoch 5210/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.8232 - acc: 0.0000e+00 - val_loss: 15.5390 - val_acc: 0.0000e+00
#
# Epoch 05210: val_loss did not improve from 11.22034
# Epoch 5211/20000
# 1/1 [==============================] - 6s 6s/step - loss: 33.2104 - acc: 0.0000e+00 - val_loss: 22.4160 - val_acc: 0.0000e+00
#
# Epoch 05211: val_loss did not improve from 11.22034
# Epoch 5212/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.9265 - acc: 0.0000e+00 - val_loss: 18.2618 - val_acc: 0.0000e+00
#
# Epoch 05212: val_loss did not improve from 11.22034
# Epoch 5213/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.4967 - acc: 0.0000e+00 - val_loss: 14.3643 - val_acc: 0.0000e+00
#
# Epoch 05213: val_loss did not improve from 11.22034
# Epoch 5214/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.0410 - acc: 0.0000e+00 - val_loss: 24.3806 - val_acc: 0.0000e+00
#
# Epoch 05214: val_loss did not improve from 11.22034
# Epoch 5215/20000
# 1/1 [==============================] - 8s 8s/step - loss: 20.2694 - acc: 0.0000e+00 - val_loss: 32.0671 - val_acc: 0.0000e+00
#
# Epoch 05215: val_loss did not improve from 11.22034
# Epoch 5216/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.6562 - acc: 0.0000e+00 - val_loss: 24.1646 - val_acc: 0.0000e+00
#
# Epoch 05216: val_loss did not improve from 11.22034
# Epoch 5217/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.2328 - acc: 0.0000e+00 - val_loss: 14.6029 - val_acc: 0.0000e+00
#
# Epoch 05217: val_loss did not improve from 11.22034
# Epoch 5218/20000
# 1/1 [==============================] - 7s 7s/step - loss: 17.0824 - acc: 0.0000e+00 - val_loss: 20.5541 - val_acc: 0.0000e+00
#
# Epoch 05218: val_loss did not improve from 11.22034
# Epoch 5219/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.9996 - acc: 0.0000e+00 - val_loss: 19.8421 - val_acc: 0.0000e+00
#
# Epoch 05219: val_loss did not improve from 11.22034
# Epoch 5220/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.6668 - acc: 0.0000e+00 - val_loss: 18.9551 - val_acc: 0.0000e+00
#
# Epoch 05220: val_loss did not improve from 11.22034
# Epoch 5221/20000
# 1/1 [==============================] - 6s 6s/step - loss: 29.5215 - acc: 0.0000e+00 - val_loss: 23.5309 - val_acc: 0.0000e+00
#
# Epoch 05221: val_loss did not improve from 11.22034
# Epoch 5222/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.3869 - acc: 0.0000e+00 - val_loss: 14.3551 - val_acc: 0.0000e+00
#
# Epoch 05222: val_loss did not improve from 11.22034
# Epoch 5223/20000
# 1/1 [==============================] - 6s 6s/step - loss: 27.4970 - acc: 0.0000e+00 - val_loss: 24.8775 - val_acc: 0.0000e+00
#
# Epoch 05223: val_loss did not improve from 11.22034
# Epoch 5224/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.6711 - acc: 0.0000e+00 - val_loss: 14.5678 - val_acc: 0.0000e+00
#
# Epoch 05224: val_loss did not improve from 11.22034
# Epoch 5225/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.1922 - acc: 0.0000e+00 - val_loss: 14.2684 - val_acc: 0.0000e+00
#
# Epoch 05225: val_loss did not improve from 11.22034
# Epoch 5226/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.2394 - acc: 0.0000e+00 - val_loss: 18.7736 - val_acc: 0.0000e+00
#
# Epoch 05226: val_loss did not improve from 11.22034
# Epoch 5227/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.1770 - acc: 0.0000e+00 - val_loss: 18.3690 - val_acc: 0.0000e+00
#
# Epoch 05227: val_loss did not improve from 11.22034
# Epoch 5228/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.3440 - acc: 0.0000e+00 - val_loss: 14.5175 - val_acc: 0.0000e+00
#
# Epoch 05228: val_loss did not improve from 11.22034
# Epoch 5229/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.7467 - acc: 0.0000e+00 - val_loss: 17.4210 - val_acc: 0.0000e+00
#
# Epoch 05229: val_loss did not improve from 11.22034
# Epoch 5230/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.8958 - acc: 0.0000e+00 - val_loss: 18.5896 - val_acc: 0.0000e+00
#
# Epoch 05230: val_loss did not improve from 11.22034
# Epoch 5231/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.3751 - acc: 0.0000e+00 - val_loss: 23.1914 - val_acc: 0.0000e+00
#
# Epoch 05231: val_loss did not improve from 11.22034
# Epoch 5232/20000
# 1/1 [==============================] - 6s 6s/step - loss: 27.8748 - acc: 0.0000e+00 - val_loss: 14.4376 - val_acc: 0.0000e+00
#
# Epoch 05232: val_loss did not improve from 11.22034
# Epoch 5233/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.8562 - acc: 0.0000e+00 - val_loss: 25.9459 - val_acc: 0.0000e+00
#
# Epoch 05233: val_loss did not improve from 11.22034
# Epoch 5234/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.9112 - acc: 0.0000e+00 - val_loss: 23.2001 - val_acc: 0.0000e+00
#
# Epoch 05234: val_loss did not improve from 11.22034
# Epoch 5235/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.8767 - acc: 0.0000e+00 - val_loss: 21.8113 - val_acc: 0.0000e+00
#
# Epoch 05235: val_loss did not improve from 11.22034
# Epoch 5236/20000
# 1/1 [==============================] - 8s 8s/step - loss: 21.3991 - acc: 0.0000e+00 - val_loss: 16.5546 - val_acc: 0.0000e+00
#
# Epoch 05236: val_loss did not improve from 11.22034
# Epoch 5237/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.3945 - acc: 0.0000e+00 - val_loss: 22.2185 - val_acc: 0.0000e+00
#
# Epoch 05237: val_loss did not improve from 11.22034
# Epoch 5238/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.2535 - acc: 0.0000e+00 - val_loss: 22.5536 - val_acc: 0.0000e+00
#
# Epoch 05238: val_loss did not improve from 11.22034
# Epoch 5239/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.2563 - acc: 0.0000e+00 - val_loss: 19.6531 - val_acc: 0.0000e+00
#
# Epoch 05239: val_loss did not improve from 11.22034
# Epoch 5240/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.2274 - acc: 0.0000e+00 - val_loss: 31.0701 - val_acc: 0.0000e+00
#
# Epoch 05240: val_loss did not improve from 11.22034
# Epoch 5241/20000
# 1/1 [==============================] - 6s 6s/step - loss: 24.1753 - acc: 0.0000e+00 - val_loss: 16.7381 - val_acc: 0.0000e+00
#
# Epoch 05241: val_loss did not improve from 11.22034
# Epoch 5242/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.3014 - acc: 0.0000e+00 - val_loss: 30.0393 - val_acc: 0.0000e+00
#
# Epoch 05242: val_loss did not improve from 11.22034
# Epoch 5243/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.0808 - acc: 0.0000e+00 - val_loss: 14.0072 - val_acc: 0.0000e+00
#
# Epoch 05243: val_loss did not improve from 11.22034
# Epoch 5244/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.2305 - acc: 0.0000e+00 - val_loss: 20.8875 - val_acc: 0.0000e+00
#
# ...
#
# Epoch 17546: val_loss did not improve from 10.47193
# Epoch 17547/20000
# 1/1 [==============================] - 5s 5s/step - loss: 21.6096 - acc: 0.0000e+00 - val_loss: 17.1970 - val_acc: 0.0000e+00
#
# Epoch 17547: val_loss did not improve from 10.47193
# Epoch 17548/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.7089 - acc: 0.0000e+00 - val_loss: 16.0100 - val_acc: 0.0000e+00
#
# Epoch 17548: val_loss did not improve from 10.47193
# Epoch 17549/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.4480 - acc: 0.0000e+00 - val_loss: 19.2740 - val_acc: 0.0000e+00
#
# Epoch 17549: val_loss did not improve from 10.47193
# Epoch 17550/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.4122 - acc: 0.0000e+00 - val_loss: 14.8582 - val_acc: 0.0000e+00
#
# Epoch 17550: val_loss did not improve from 10.47193
# Epoch 17551/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.0110 - acc: 0.0000e+00 - val_loss: 13.0082 - val_acc: 0.0000e+00
#
# Epoch 17551: val_loss did not improve from 10.47193
# Epoch 17552/20000
# 1/1 [==============================] - 5s 5s/step - loss: 20.5878 - acc: 0.0000e+00 - val_loss: 21.8823 - val_acc: 0.0000e+00
#
# Epoch 17552: val_loss did not improve from 10.47193
# Epoch 17553/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.0841 - acc: 0.0000e+00 - val_loss: 19.1266 - val_acc: 0.0000e+00
#
# Epoch 17553: val_loss did not improve from 10.47193
# Epoch 17554/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.0301 - acc: 0.0000e+00 - val_loss: 16.9737 - val_acc: 0.0000e+00
#
# Epoch 17554: val_loss did not improve from 10.47193
# Epoch 17555/20000
# 1/1 [==============================] - 6s 6s/step - loss: 22.3663 - acc: 0.0000e+00 - val_loss: 18.5945 - val_acc: 0.0000e+00
#
# Epoch 17555: val_loss did not improve from 10.47193
# Epoch 17556/20000
# 1/1 [==============================] - 5s 5s/step - loss: 20.2649 - acc: 0.0000e+00 - val_loss: 18.4972 - val_acc: 0.0000e+00
#
# Epoch 17556: val_loss did not improve from 10.47193
# Epoch 17557/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.3513 - acc: 0.0000e+00 - val_loss: 20.0677 - val_acc: 0.0000e+00
#
# Epoch 17557: val_loss did not improve from 10.47193
# Epoch 17558/20000
# 1/1 [==============================] - 6s 6s/step - loss: 17.1332 - acc: 0.0000e+00 - val_loss: 20.0498 - val_acc: 0.0000e+00
#
# Epoch 17558: val_loss did not improve from 10.47193
# Epoch 17559/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.6621 - acc: 0.0000e+00 - val_loss: 16.7915 - val_acc: 0.0000e+00
#
# Epoch 17559: val_loss did not improve from 10.47193
# Epoch 17560/20000
# 1/1 [==============================] - 5s 5s/step - loss: 15.0614 - acc: 0.0000e+00 - val_loss: 15.0111 - val_acc: 0.0000e+00
#
# Epoch 17560: val_loss did not improve from 10.47193
# Epoch 17561/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.0130 - acc: 0.0000e+00 - val_loss: 20.8777 - val_acc: 0.0000e+00
#
# Epoch 17561: val_loss did not improve from 10.47193
# Epoch 17562/20000
# 1/1 [==============================] - 5s 5s/step - loss: 15.3367 - acc: 0.0000e+00 - val_loss: 16.8119 - val_acc: 0.0000e+00
#
# Epoch 17562: val_loss did not improve from 10.47193
# Epoch 17563/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.0355 - acc: 0.0000e+00 - val_loss: 23.4150 - val_acc: 0.0000e+00
#
# Epoch 17563: val_loss did not improve from 10.47193
# Epoch 17564/20000
# 1/1 [==============================] - 8s 8s/step - loss: 31.6553 - acc: 0.0000e+00 - val_loss: 19.1201 - val_acc: 0.0000e+00
#
# Epoch 17564: val_loss did not improve from 10.47193
# Epoch 17565/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.5767 - acc: 0.0000e+00 - val_loss: 14.4520 - val_acc: 0.0000e+00
#
# Epoch 17565: val_loss did not improve from 10.47193
# Epoch 17566/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.7695 - acc: 0.0000e+00 - val_loss: 14.3073 - val_acc: 0.0000e+00
#
# Epoch 17566: val_loss did not improve from 10.47193
# Epoch 17567/20000
# 1/1 [==============================] - 5s 5s/step - loss: 21.0833 - acc: 0.0000e+00 - val_loss: 18.4443 - val_acc: 0.0000e+00
#
# Epoch 17567: val_loss did not improve from 10.47193
# Epoch 17568/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.7030 - acc: 0.0000e+00 - val_loss: 16.6248 - val_acc: 0.0000e+00
#
# Epoch 17568: val_loss did not improve from 10.47193
# Epoch 17569/20000
# 1/1 [==============================] - 6s 6s/step - loss: 25.0870 - acc: 0.0000e+00 - val_loss: 15.3422 - val_acc: 0.0000e+00
# Epoch 17569: val_loss did not improve from 10.47193
# Epoch 17570/20000
# 1/1 [==============================] - 6s 6s/step - loss: 26.8102 - acc: 0.0000e+00 - val_loss: 18.0023 - val_acc: 0.0000e+00
#
# Epoch 17570: val_loss did not improve from 10.47193
# Epoch 17571/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.0550 - acc: 0.0000e+00 - val_loss: 24.8572 - val_acc: 0.0000e+00
#
# Epoch 17571: val_loss did not improve from 10.47193
# Epoch 17572/20000
# 1/1 [==============================] - 5s 5s/step - loss: 15.2705 - acc: 0.0000e+00 - val_loss: 15.7727 - val_acc: 0.0000e+00
#
# Epoch 17572: val_loss did not improve from 10.47193
# Epoch 17573/20000
# 1/1 [==============================] - 5s 5s/step - loss: 20.1236 - acc: 0.0000e+00 - val_loss: 13.4313 - val_acc: 0.0000e+00
#
# Epoch 17573: val_loss did not improve from 10.47193
# Epoch 17574/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.0714 - acc: 0.0000e+00 - val_loss: 21.0953 - val_acc: 0.0000e+00
#
# Epoch 17574: val_loss did not improve from 10.47193
# Epoch 17575/20000
# 1/1 [==============================] - 5s 5s/step - loss: 17.8355 - acc: 0.0000e+00 - val_loss: 17.8897 - val_acc: 0.0000e+00
#
# Epoch 17575: val_loss did not improve from 10.47193
# Epoch 17576/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.2357 - acc: 0.0000e+00 - val_loss: 19.8064 - val_acc: 0.0000e+00
#
# Epoch 17576: val_loss did not improve from 10.47193
# Epoch 17577/20000
# 1/1 [==============================] - 5s 5s/step - loss: 31.3163 - acc: 0.0000e+00 - val_loss: 12.2031 - val_acc: 0.0000e+00
#
# Epoch 17577: val_loss did not improve from 10.47193
# Epoch 17578/20000
# 1/1 [==============================] - 6s 6s/step - loss: 14.7686 - acc: 0.0000e+00 - val_loss: 17.3505 - val_acc: 0.0000e+00
#
# Epoch 17578: val_loss did not improve from 10.47193
# Epoch 17579/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.5654 - acc: 0.0000e+00 - val_loss: 17.8283 - val_acc: 0.0000e+00
#
# Epoch 17579: val_loss did not improve from 10.47193
# Epoch 17580/20000
# 1/1 [==============================] - 5s 5s/step - loss: 24.5107 - acc: 0.0000e+00 - val_loss: 14.9954 - val_acc: 0.0000e+00
#
# Epoch 17580: val_loss did not improve from 10.47193
# Epoch 17581/20000
# 1/1 [==============================] - 5s 5s/step - loss: 16.9008 - acc: 0.0000e+00 - val_loss: 15.6239 - val_acc: 0.0000e+00
#
# Epoch 17581: val_loss did not improve from 10.47193
# Epoch 17582/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.3301 - acc: 0.0000e+00 - val_loss: 30.4730 - val_acc: 0.0000e+00
#
# Epoch 17582: val_loss did not improve from 10.47193
# Epoch 17583/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.2063 - acc: 0.0000e+00 - val_loss: 30.2630 - val_acc: 0.0000e+00
#
# Epoch 17583: val_loss did not improve from 10.47193
# Epoch 17584/20000
# 1/1 [==============================] - 6s 6s/step - loss: 20.0362 - acc: 0.0000e+00 - val_loss: 26.8839 - val_acc: 0.0000e+00
#
# Epoch 17584: val_loss did not improve from 10.47193
# Epoch 17585/20000
# 1/1 [==============================] - 6s 6s/step - loss: 23.9848 - acc: 0.0000e+00 - val_loss: 19.7515 - val_acc: 0.0000e+00
#
# Epoch 17585: val_loss did not improve from 10.47193
# Epoch 17586/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.0983 - acc: 0.0000e+00 - val_loss: 18.7588 - val_acc: 0.0000e+00
#
# Epoch 17586: val_loss did not improve from 10.47193
# Epoch 17587/20000
# 1/1 [==============================] - 5s 5s/step - loss: 16.9939 - acc: 0.0000e+00 - val_loss: 13.4346 - val_acc: 0.0000e+00
#
# Epoch 17587: val_loss did not improve from 10.47193
# Epoch 17588/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.9502 - acc: 0.0000e+00 - val_loss: 13.2945 - val_acc: 0.0000e+00
#
# Epoch 17588: val_loss did not improve from 10.47193
# Epoch 17589/20000
# 1/1 [==============================] - 8s 8s/step - loss: 25.7537 - acc: 0.0000e+00 - val_loss: 19.3975 - val_acc: 0.0000e+00
#
# Epoch 17589: val_loss did not improve from 10.47193
# Epoch 17590/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.2409 - acc: 0.0000e+00 - val_loss: 16.5819 - val_acc: 0.0000e+00
#
# Epoch 17590: val_loss did not improve from 10.47193
# Epoch 17591/20000
# 1/1 [==============================] - 5s 5s/step - loss: 19.1074 - acc: 0.0000e+00 - val_loss: 16.3226 - val_acc: 0.0000e+00
#
# Epoch 17591: val_loss did not improve from 10.47193
# Epoch 17592/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.8073 - acc: 0.0000e+00 - val_loss: 15.1436 - val_acc: 0.0000e+00
#
# Epoch 17592: val_loss did not improve from 10.47193
# Epoch 17593/20000
# 1/1 [==============================] - 5s 5s/step - loss: 13.3346 - acc: 0.0000e+00 - val_loss: 20.3644 - val_acc: 0.0000e+00
#
# Epoch 17593: val_loss did not improve from 10.47193
# Epoch 17594/20000
# 1/1 [==============================] - 5s 5s/step - loss: 31.6341 - acc: 0.0000e+00 - val_loss: 14.6373 - val_acc: 0.0000e+00
#
# Epoch 17594: val_loss did not improve from 10.47193
# Epoch 17595/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.9734 - acc: 0.0000e+00 - val_loss: 12.7827 - val_acc: 0.0000e+00
#
# Epoch 17595: val_loss did not improve from 10.47193
# Epoch 17596/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.0509 - acc: 0.0000e+00 - val_loss: 20.6465 - val_acc: 0.0000e+00
#
# Epoch 17596: val_loss did not improve from 10.47193
# Epoch 17597/20000
# 1/1 [==============================] - 6s 6s/step - loss: 28.0511 - acc: 0.0000e+00 - val_loss: 27.8559 - val_acc: 0.0000e+00
#
# Epoch 17597: val_loss did not improve from 10.47193
# Epoch 17598/20000
# 1/1 [==============================] - 5s 5s/step - loss: 18.5437 - acc: 0.0000e+00 - val_loss: 21.5944 - val_acc: 0.0000e+00
#
# Epoch 17598: val_loss did not improve from 10.47193
# Epoch 17599/20000
# 1/1 [==============================] - 6s 6s/step - loss: 29.1435 - acc: 0.0000e+00 - val_loss: 16.0710 - val_acc: 0.0000e+00
#
# Epoch 17599: val_loss did not improve from 10.47193
# Epoch 17600/20000
# 1/1 [==============================] - 5s 5s/step - loss: 19.0644 - acc: 0.0000e+00 - val_loss: 19.5864 - val_acc: 0.0000e+00
#
# Epoch 17600: val_loss did not improve from 10.47193
# Epoch 17601/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.1368 - acc: 0.0000e+00 - val_loss: 19.0931 - val_acc: 0.0000e+00
#
# Epoch 17601: val_loss did not improve from 10.47193
# Epoch 17602/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.0083 - acc: 0.0000e+00 - val_loss: 15.3032 - val_acc: 0.0000e+00
#
# Epoch 17602: val_loss did not improve from 10.47193
# Epoch 17603/20000
# 1/1 [==============================] - 5s 5s/step - loss: 18.5547 - acc: 0.0000e+00 - val_loss: 14.1858 - val_acc: 0.0000e+00
#
# Epoch 17603: val_loss did not improve from 10.47193
# Epoch 17604/20000
# 1/1 [==============================] - 5s 5s/step - loss: 17.1817 - acc: 0.0000e+00 - val_loss: 19.2311 - val_acc: 0.0000e+00
#
# Epoch 17604: val_loss did not improve from 10.47193
# Epoch 17605/20000
# 1/1 [==============================] - 5s 5s/step - loss: 24.9404 - acc: 0.0000e+00 - val_loss: 25.1836 - val_acc: 0.0000e+00
#
# Epoch 17605: val_loss did not improve from 10.47193
# Epoch 17606/20000
# 1/1 [==============================] - 5s 5s/step - loss: 17.8996 - acc: 0.0000e+00 - val_loss: 19.0728 - val_acc: 0.0000e+00
#
# Epoch 17606: val_loss did not improve from 10.47193
# Epoch 17607/20000
# 1/1 [==============================] - 5s 5s/step - loss: 16.2976 - acc: 0.0000e+00 - val_loss: 24.7219 - val_acc: 0.0000e+00
#
# Epoch 17607: val_loss did not improve from 10.47193
# Epoch 17608/20000
# 1/1 [==============================] - 5s 5s/step - loss: 28.6710 - acc: 0.0000e+00 - val_loss: 22.1273 - val_acc: 0.0000e+00
#
# Epoch 17608: val_loss did not improve from 10.47193
# Epoch 17609/20000
# 1/1 [==============================] - 6s 6s/step - loss: 21.0232 - acc: 0.0000e+00 - val_loss: 17.1560 - val_acc: 0.0000e+00
#
# Epoch 17609: val_loss did not improve from 10.47193
# Epoch 17610/20000
# 1/1 [==============================] - 5s 5s/step - loss: 15.4211 - acc: 0.0000e+00 - val_loss: 16.8014 - val_acc: 0.0000e+00
#
# Epoch 17610: val_loss did not improve from 10.47193
# Epoch 17611/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.8958 - acc: 0.0000e+00 - val_loss: 19.6705 - val_acc: 0.0000e+00
# Epoch 17611: val_loss did not improve from 10.47193
# Epoch 17612/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.1461 - acc: 0.0000e+00 - val_loss: 23.4347 - val_acc: 0.0000e+00
#
# Epoch 17612: val_loss did not improve from 10.47193
# Epoch 17613/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.4768 - acc: 0.0000e+00 - val_loss: 23.1798 - val_acc: 0.0000e+00
#
# Epoch 17613: val_loss did not improve from 10.47193
# Epoch 17614/20000
# 1/1 [==============================] - 5s 5s/step - loss: 14.7771 - acc: 0.0000e+00 - val_loss: 15.2612 - val_acc: 0.0000e+00
#
# Epoch 17614: val_loss did not improve from 10.47193
# Epoch 17615/20000
# 1/1 [==============================] - 6s 6s/step - loss: 18.6425 - acc: 0.0000e+00 - val_loss: 16.3725 - val_acc: 0.0000e+00
#
# Epoch 17615: val_loss did not improve from 10.47193
# Epoch 17616/20000
# 1/1 [==============================] - 5s 5s/step - loss: 18.3331 - acc: 0.0000e+00 - val_loss: 35.0191 - val_acc: 0.0000e+00
#
# Epoch 17616: val_loss did not improve from 10.47193
# Epoch 17617/20000
# 1/1 [==============================] - 6s 6s/step - loss: 19.2968 - acc: 0.0000e+00 - val_loss: 19.4820 - val_acc: 0.0000e+00
#
# Epoch 17617: val_loss did not improve from 10.47193
# Epoch 17618/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.3353 - acc: 0.0000e+00 - val_loss: 25.8650 - val_acc: 0.0000e+00
#
# Epoch 17618: val_loss did not improve from 10.47193
# Epoch 17619/20000
# 1/1 [==============================] - 6s 6s/step - loss: 15.7465 - acc: 0.0000e+00 - val_loss: 12.9691 - val_acc: 0.0000e+00
#
# Epoch 17619: val_loss did not improve from 10.47193
# Epoch 17620/20000
# 1/1 [==============================] - 6s 6s/step - loss: 16.0051 - acc: 0.0000e+00 - val_loss: 26.5621 - val_acc: 0.0000e+00
#
# Epoch 17620: val_loss did not improve from 10.47193
# Epoch 17621/20000
# 1/1 [==============================] - 7s 7s/step - loss: 21.0727 - acc: 0.0000e+00 - val_loss: 21.8597 - val_acc: 0.0000e+00
#
# Epoch 17621: val_loss did not improve from 10.47193
# Epoch 17622/20000
# 1/1 [==============================] - 5s 5s/step - loss: 17.9042 - acc: 0.0000e+00 - val_loss: 16.8308 - val_acc: 0.0000e+00
#
# Epoch 17622: val_loss did not improve from 10.47193
# Epoch 17623/20000
# 1/1 [==============================] - 6s 6s/step - loss: 31.6014 - acc: 0.0000e+00 - val_loss: 24.6965 - val_acc: 0.0000e+00
#
# Epoch 17623: val_loss did not improve from 10.47193
# Epoch 17624/20000
# 1/1 [==============================] - 6s 6s/step - loss: 31.2118 - acc: 0.0000e+00 - val_loss: 14.7663 - val_acc: 0.0000e+00
#
# Epoch 17624: val_loss did not improve from 10.47193
# Epoch 17625/20000
# 1/1 [==============================] - 6s 6s/step - loss: 13.0274 - acc: 0.0000e+00 - val_loss: 14.9409 - val_acc: 0.0000e+00
#
# Epoch 17625: val_loss did not improve from 10.47193
# Epoch 17626/20000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# g=datagen(data_partition='test', batch_size=1)
# x,y = next(g)

# %%
['EVERYONE',
 'EVENTS',
 'EVERYBODY',
 'CLOUD',
 'RIGHTS',
 'AUTHORITIES',
 'WITHIN',
 'SEVERAL',
 'ABSOLUTELY',
 'WINDS',
 'AFTERNOON',
 'BETWEEN',
 'TALKING',
 'AGREEMENT',
 'PRICES',
 'MEETING',
 'AFFAIRS',
 'SERIOUS',
 'SUNSHINE',
 'OPPOSITION',
 'REALLY',
 'SOUTH',
 'MEMBERS',
 'UNDER',
 'FIGURES',
 'RATHER',
 'COUNCIL',
 'AMERICAN',
 'PERSONAL',
 'HAPPENED',
 'PUBLIC',
 'CAPITAL',
 'IMPACT',
 'FINAL',
 'LOCAL',
 'CLEAR',
 'STAFF',
 'TAKING',
 'FOLLOWING',
 'BEFORE',
 'NUMBER',
 'ACCESS',
 'AFRICA',
 'BUILDING',
 'GIVEN',
 'PERSON',
 'SERVICES',
 'HOMES',
 'TRYING',
 'CHINA',
 'MESSAGE',
 'WRONG',
 'YEARS',
 'AGREE',
 'STATE',
 'ISLAMIC',
 'SERIES',
 'OBAMA',
 'NEEDS',
 'TERMS',
 'EVIDENCE',
 'COUNTRIES',
 'RUSSIA',
 'QUESTIONS',
 'PHONE',
 'YOUNG',
 'ACTUALLY',
 'MINISTERS',
 'INCREASE',
 'SPENT',
 'DURING',
 'OTHER',
 'PARTIES',
 'JUSTICE',
 'POLITICAL',
 'SOMETHING',
 'SYRIAN',
 'NEVER',
 'TOWARDS',
 'HOURS',
 'GERMANY',
 'NIGHT',
 'HOUSE',
 'DOING',
 'CHARGES',
 'HUMAN',
 'UNDERSTAND',
 'THREE',
 'PRETTY',
 'PROBLEM',
 'FRONT',
 'PROCESS',
 'IMMIGRATION',
 'SCHOOL',
 'BEING',
 'WEEKS',
 'HEAVY',
 'ALWAYS',
 'PRICE',
 'GREECE',
 'LITTLE',
 'DEFICIT',
 'EXPECTED',
 'BUDGET',
 'AREAS',
 'UNTIL',
 'WATER',
 'COMES',
 'ARRESTED',
 'GROUND',
 'CRIME',
 'DECIDED',
 'JAMES',
 'AHEAD',
 'WESTERN',
 'SCOTLAND',
 'ACTION',
 'POWERS',
 'ASKING',
 'SMALL',
 'BORDER',
 'SPEND',
 'POSITION',
 'CENTRAL',
 'HAPPENING',
 'MATTER',
 'RUSSIAN',
 'FORMER',
 'OFFICERS',
 'CURRENT',
 'WELFARE',
 'QUESTION',
 'SINGLE',
 'MINUTES',
 'TOGETHER',
 'EXPECT',
 'PLANS',
 'THOSE',
 'PRESS',
 'PLACES',
 'CAMPAIGN',
 'TOMORROW',
 'REFERENDUM',
 'FRENCH',
 'INVOLVED',
 'HISTORY',
 'WEAPONS',
 'ALREADY',
 'DETAILS',
 'SIDES',
 'THINK',
 'FORWARD',
 'AMONG',
 'COURT',
 'MIGHT',
 'WALES',
 'MEMBER',
 'COUPLE',
 'EDITOR',
 'EXAMPLE',
 'ANNOUNCED',
 'RUNNING',
 'WOMEN',
 'STARTED',
 'WEEKEND',
 'CONFERENCE',
 'PROTECT',
 'CLAIMS',
 'GROUP',
 'EUROPEAN',
 'POLITICS',
 'MURDER',
 'STATES',
 'SUPPORT',
 'ACCORDING',
 'ALLEGATIONS',
 'INSIDE',
 'WITHOUT',
 'AMERICA',
 'GROWING',
 'WARNING',
 'SIMPLY',
 'ALMOST',
 'SHOULD',
 'COMMUNITY',
 'STRONG',
 'SEVEN',
 'COURSE',
 'WAITING',
 'BRITISH',
 'CONSERVATIVE',
 'SEEMS',
 'IRELAND',
 'GUILTY',
 'POLICY',
 'CHILDREN',
 'ENOUGH',
 'EVENING',
 'SINCE',
 'BILLION',
 'AFFECTED',
 'MEANS',
 'CONFLICT',
 'STAGE',
 'CUSTOMERS',
 'EASTERN',
 'RECORD',
 'CHIEF',
 'COMPANIES',
 'EVERYTHING',
 'MANCHESTER',
 'NORTH',
 'MAJOR',
 'WORDS',
 'MIGRANTS',
 'CHANCE',
 'FOCUS',
 'BUILD',
 'OFTEN',
 'CRISIS',
 'HAVING',
 'UNION',
 'POINT',
 'HOSPITAL',
 'ANSWER',
 'INVESTMENT',
 'SENIOR',
 'IMPORTANT',
 'THOUGHT',
 'BETTER',
 'THEIR',
 'CHALLENGE',
 'RIGHT',
 'NUMBERS',
 'MASSIVE',
 'POTENTIAL',
 'WHOLE',
 'AGAIN',
 'LEADER',
 'GREAT',
 'ASKED',
 'CALLED',
 'REPORT',
 'ELECTION',
 'JUDGE',
 'COMPANY',
 'FAMILIES',
 'LARGE',
 'ENERGY',
 'EXTRA',
 'PLACE',
 'HEALTH',
 'THOUSANDS',
 'OFFICE',
 'FORCE',
 'WORKERS',
 'DESPITE',
 'WANTED',
 'MILITARY',
 'WORLD',
 'REMEMBER',
 'SITUATION',
 'LOOKING',
 'ENGLAND',
 'DIFFERENT',
 'LATEST',
 'PARTY',
 'DAVID',
 'GIVING',
 'DEATH',
 'RESULT',
 'INDEPENDENT',
 'SAYING',
 'REASON',
 'INFLATION',
 'ISSUES',
 'TRADE',
 'THIRD',
 'MINISTER',
 'QUITE',
 'FOOTBALL',
 'LIVING',
 'PATIENTS',
 'AFTER',
 'INFORMATION',
 'TONIGHT',
 'EMERGENCY',
 'BENEFIT',
 'WATCHING',
 'STATEMENT',
 'LEAVE',
 'EDUCATION',
 'WELCOME',
 'BECOME',
 'HAPPEN',
 'LATER',
 'BEHIND',
 'AGAINST',
 'SPENDING',
 'BRING',
 'FAMILY',
 'PRESIDENT',
 'DIFFERENCE',
 'MARKET',
 'THESE',
 'POWER',
 'SECTOR',
 'EXACTLY',
 'LEAST',
 'INDUSTRY',
 'MEDIA',
 'CAMERON',
 'FRIDAY',
 'EARLY',
 'LEGAL',
 'BANKS',
 'MOMENT',
 'UNITED',
 'ALLOW',
 'TEMPERATURES',
 'SECURITY',
 'MONTH',
 'WHERE',
 'VIOLENCE',
 'LEADERSHIP',
 'ANOTHER',
 'POLICE',
 'TRIAL',
 'THERE',
 'HEARD',
 'CONTINUE',
 'WOULD',
 'USING',
 'PRIVATE',
 'GEORGE',
 'WANTS',
 'FIGHTING',
 'SOCIAL',
 'STORY',
 'LONGER',
 'START',
 'SECRETARY',
 'ATTACK',
 'SIGNIFICANT',
 'MAJORITY',
 'MONEY',
 'VOTERS',
 'ECONOMY',
 'ISSUE',
 'AMOUNT',
 'PEOPLE',
 'BROUGHT',
 'BECAUSE',
 'FIGHT',
 'GLOBAL',
 'CONCERNS',
 'NATIONAL',
 'INQUIRY',
 'MOVING',
 'LEADERS',
 'GAMES',
 'NORTHERN',
 'ANYTHING',
 'COMING',
 'PERHAPS',
 'STREET',
 'BELIEVE',
 'FOUND',
 'OTHERS',
 'HOUSING',
 'MORNING',
 'WORKING',
 'MILLIONS',
 'BUSINESSES',
 'SPEAKING',
 'STAND',
 'LIVES',
 'WESTMINSTER',
 'LONDON',
 'FOREIGN',
 'PARTS',
 'BENEFITS',
 'FURTHER',
 'CANNOT',
 'BLACK',
 'BRITAIN',
 'SHORT',
 'PAYING',
 'THEMSELVES',
 'DEGREES',
 'MIDDLE',
 'ALLOWED',
 'TAKEN',
 'THINGS',
 'SENSE',
 'POLITICIANS',
 'PRESSURE',
 'STILL',
 'CLOSE',
 'SERVICE',
 'WEATHER',
 'PROBABLY',
 'LABOUR',
 'ABUSE',
 'SUNDAY',
 'MAYBE',
 'HIGHER',
 'OFFICIALS',
 'ACCUSED',
 'THREAT',
 'ATTACKS',
 'GOVERNMENT',
 'RULES',
 'OPERATION',
 'COUNTRY',
 'NOTHING',
 'FORCES',
 'HUNDREDS',
 'EUROPE',
 'SOMEONE',
 'SYRIA',
 'KILLED',
 'WHETHER',
 'GOING',
 'DIFFICULT',
 'WHILE',
 'PRISON',
 'ABOUT',
 'SECOND',
 'MAKING',
 'TODAY',
 'ACROSS',
 'WHICH',
 'SPECIAL',
 'DEBATE',
 'CHARGE',
 'BIGGEST',
 'THING',
 'MONTHS',
 'GETTING',
 'PARLIAMENT',
 'KNOWN',
 'AROUND',
 'THROUGH',
 'CANCER',
 'MEDICAL',
 'MEASURES',
 'CHILD',
 'ORDER',
 'TALKS',
 'POSSIBLE',
 'SOUTHERN',
 'RATES',
 'FIRST',
 'PROBLEMS',
 'CONTROL',
 'RETURN',
 'FINANCIAL',
 'RESPONSE',
 'MAKES',
 'HEART',
 'TRUST',
 'CERTAINLY',
 'YESTERDAY',
 'SCHOOLS',
 'LEVEL',
 'LIKELY',
 'PROVIDE',
 'PERIOD',
 'DECISION',
 'WORST',
 'CHANGES',
 'PRIME',
 'CHANGE',
 'BUSINESS',
 'RECENT',
 'SYSTEM',
 'LEVELS',
 'MISSING',
 'ECONOMIC',
 'CASES',
 'FACING',
 'GROWTH',
 'GENERAL',
 'INTEREST',
 'MILLION',
 'FRANCE',
 'SPEECH',
 'EVERY',
 'VICTIMS',
 'REPORTS',
 'FUTURE',
 'SCOTTISH',
 'SOCIETY',
 'ITSELF',
 'COULD',
 'PARENTS',
 'TIMES',
 'DESCRIBED',
 'OUTSIDE']

# %%
words
# Out:
# ['EVERYONE',
#  'EVENTS',
#  'EVERYBODY',
#  'CLOUD',
#  'RIGHTS',
#  'AUTHORITIES',
#  'WITHIN',
#  'SEVERAL',
#  'ABSOLUTELY',
#  'WINDS',
#  'AFTERNOON',
#  'BETWEEN',
#  'TALKING',
#  'AGREEMENT',
#  'PRICES',
#  'MEETING',
#  'AFFAIRS',
#  'SERIOUS',
#  'SUNSHINE',
#  'OPPOSITION',
#  'REALLY',
#  'SOUTH',
#  'MEMBERS',
#  'UNDER',
#  'FIGURES',
#  'RATHER',
#  'COUNCIL',
#  'AMERICAN',
#  'PERSONAL',
#  'HAPPENED',
#  'PUBLIC',
#  'CAPITAL',
#  'IMPACT',
#  'FINAL',
#  'LOCAL',
#  'CLEAR',
#  'STAFF',
#  'TAKING',
#  'FOLLOWING',
#  'BEFORE',
#  'NUMBER',
#  'ACCESS',
#  'AFRICA',
#  'BUILDING',
#  'GIVEN',
#  'PERSON',
#  'SERVICES',
#  'HOMES',
#  'TRYING',
#  'CHINA',
#  'MESSAGE',
#  'WRONG',
#  'YEARS',
#  'AGREE',
#  'STATE',
#  'ISLAMIC',
#  'SERIES',
#  'OBAMA',
#  'NEEDS',
#  'TERMS',
#  'EVIDENCE',
#  'COUNTRIES',
#  'RUSSIA',
#  'QUESTIONS',
#  'PHONE',
#  'YOUNG',
#  'ACTUALLY',
#  'MINISTERS',
#  'INCREASE',
#  'SPENT',
#  'DURING',
#  'OTHER',
#  'PARTIES',
#  'JUSTICE',
#  'POLITICAL',
#  'SOMETHING',
#  'SYRIAN',
#  'NEVER',
#  'TOWARDS',
#  'HOURS',
#  'GERMANY',
#  'NIGHT',
#  'HOUSE',
#  'DOING',
#  'CHARGES',
#  'HUMAN',
#  'UNDERSTAND',
#  'THREE',
#  'PRETTY',
#  'PROBLEM',
#  'FRONT',
#  'PROCESS',
#  'IMMIGRATION',
#  'SCHOOL',
#  'BEING',
#  'WEEKS',
#  'HEAVY',
#  'ALWAYS',
#  'PRICE',
#  'GREECE',
#  'LITTLE',
#  'DEFICIT',
#  'EXPECTED',
#  'BUDGET',
#  'AREAS',
#  'UNTIL',
#  'WATER',
#  'COMES',
#  'ARRESTED',
#  'GROUND',
#  'CRIME',
#  'DECIDED',
#  'JAMES',
#  'AHEAD',
#  'WESTERN',
#  'SCOTLAND',
#  'ACTION',
#  'POWERS',
#  'ASKING',
#  'SMALL',
#  'BORDER',
#  'SPEND',
#  'POSITION',
#  'CENTRAL',
#  'HAPPENING',
#  'MATTER',
#  'RUSSIAN',
#  'FORMER',
#  'OFFICERS',
#  'CURRENT',
#  'WELFARE',
#  'QUESTION',
#  'SINGLE',
#  'MINUTES',
#  'TOGETHER',
#  'EXPECT',
#  'PLANS',
#  'THOSE',
#  'PRESS',
#  'PLACES',
#  'CAMPAIGN',
#  'TOMORROW',
#  'REFERENDUM',
#  'FRENCH',
#  'INVOLVED',
#  'HISTORY',
#  'WEAPONS',
#  'ALREADY',
#  'DETAILS',
#  'SIDES',
#  'THINK',
#  'FORWARD',
#  'AMONG',
#  'COURT',
#  'MIGHT',
#  'WALES',
#  'MEMBER',
#  'COUPLE',
#  'EDITOR',
#  'EXAMPLE',
#  'ANNOUNCED',
#  'RUNNING',
#  'WOMEN',
#  'STARTED',
#  'WEEKEND',
#  'CONFERENCE',
#  'PROTECT',
#  'CLAIMS',
#  'GROUP',
#  'EUROPEAN',
#  'POLITICS',
#  'MURDER',
#  'STATES',
#  'SUPPORT',
#  'ACCORDING',
#  'ALLEGATIONS',
#  'INSIDE',
#  'WITHOUT',
#  'AMERICA',
#  'GROWING',
#  'WARNING',
#  'SIMPLY',
#  'ALMOST',
#  'SHOULD',
#  'COMMUNITY',
#  'STRONG',
#  'SEVEN',
#  'COURSE',
#  'WAITING',
#  'BRITISH',
#  'CONSERVATIVE',
#  'SEEMS',
#  'IRELAND',
#  'GUILTY',
#  'POLICY',
#  'CHILDREN',
#  'ENOUGH',
#  'EVENING',
#  'SINCE',
#  'BILLION',
#  'AFFECTED',
#  'MEANS',
#  'CONFLICT',
#  'STAGE',
#  'CUSTOMERS',
#  'EASTERN',
#  'RECORD',
#  'CHIEF',
#  'COMPANIES',
#  'EVERYTHING',
#  'MANCHESTER',
#  'NORTH',
#  'MAJOR',
#  'WORDS',
#  'MIGRANTS',
#  'CHANCE',
#  'FOCUS',
#  'BUILD',
#  'OFTEN',
#  'CRISIS',
#  'HAVING',
#  'UNION',
#  'POINT',
#  'HOSPITAL',
#  'ANSWER',
#  'INVESTMENT',
#  'SENIOR',
#  'IMPORTANT',
#  'THOUGHT',
#  'BETTER',
#  'THEIR',
#  'CHALLENGE',
#  'RIGHT',
#  'NUMBERS',
#  'MASSIVE',
#  'POTENTIAL',
#  'WHOLE',
#  'AGAIN',
#  'LEADER',
#  'GREAT',
#  'ASKED',
#  'CALLED',
#  'REPORT',
#  'ELECTION',
#  'JUDGE',
#  'COMPANY',
#  'FAMILIES',
#  'LARGE',
#  'ENERGY',
#  'EXTRA',
#  'PLACE',
#  'HEALTH',
#  'THOUSANDS',
#  'OFFICE',
#  'FORCE',
#  'WORKERS',
#  'DESPITE',
#  'WANTED',
#  'MILITARY',
#  'WORLD',
#  'REMEMBER',
#  'SITUATION',
#  'LOOKING',
#  'ENGLAND',
#  'DIFFERENT',
#  'LATEST',
#  'PARTY',
#  'DAVID',
#  'GIVING',
#  'DEATH',
#  'RESULT',
#  'INDEPENDENT',
#  'SAYING',
#  'REASON',
#  'INFLATION',
#  'ISSUES',
#  'TRADE',
#  'THIRD',
#  'MINISTER',
#  'QUITE',
#  'FOOTBALL',
#  'LIVING',
#  'PATIENTS',
#  'AFTER',
#  'INFORMATION',
#  'TONIGHT',
#  'EMERGENCY',
#  'BENEFIT',
#  'WATCHING',
#  'STATEMENT',
#  'LEAVE',
#  'EDUCATION',
#  'WELCOME',
#  'BECOME',
#  'HAPPEN',
#  'LATER',
#  'BEHIND',
#  'AGAINST',
#  'SPENDING',
#  'BRING',
#  'FAMILY',
#  'PRESIDENT',
#  'DIFFERENCE',
#  'MARKET',
#  'THESE',
#  'POWER',
#  'SECTOR',
#  'EXACTLY',
#  'LEAST',
#  'INDUSTRY',
#  'MEDIA',
#  'CAMERON',
#  'FRIDAY',
#  'EARLY',
#  'LEGAL',
#  'BANKS',
#  'MOMENT',
#  'UNITED',
#  'ALLOW',
#  'TEMPERATURES',
#  'SECURITY',
#  'MONTH',
#  'WHERE',
#  'VIOLENCE',
#  'LEADERSHIP',
#  'ANOTHER',
#  'POLICE',
#  'TRIAL',
#  'THERE',
#  'HEARD',
#  'CONTINUE',
#  'WOULD',
#  'USING',
#  'PRIVATE',
#  'GEORGE',
#  'WANTS',
#  'FIGHTING',
#  'SOCIAL',
#  'STORY',
#  'LONGER',
#  'START',
#  'SECRETARY',
#  'ATTACK',
#  'SIGNIFICANT',
#  'MAJORITY',
#  'MONEY',
#  'VOTERS',
#  'ECONOMY',
#  'ISSUE',
#  'AMOUNT',
#  'PEOPLE',
#  'BROUGHT',
#  'BECAUSE',
#  'FIGHT',
#  'GLOBAL',
#  'CONCERNS',
#  'NATIONAL',
#  'INQUIRY',
#  'MOVING',
#  'LEADERS',
#  'GAMES',
#  'NORTHERN',
#  'ANYTHING',
#  'COMING',
#  'PERHAPS',
#  'STREET',
#  'BELIEVE',
#  'FOUND',
#  'OTHERS',
#  'HOUSING',
#  'MORNING',
#  'WORKING',
#  'MILLIONS',
#  'BUSINESSES',
#  'SPEAKING',
#  'STAND',
#  'LIVES',
#  'WESTMINSTER',
#  'LONDON',
#  'FOREIGN',
#  'PARTS',
#  'BENEFITS',
#  'FURTHER',
#  'CANNOT',
#  'BLACK',
#  'BRITAIN',
#  'SHORT',
#  'PAYING',
#  'THEMSELVES',
#  'DEGREES',
#  'MIDDLE',
#  'ALLOWED',
#  'TAKEN',
#  'THINGS',
#  'SENSE',
#  'POLITICIANS',
#  'PRESSURE',
#  'STILL',
#  'CLOSE',
#  'SERVICE',
#  'WEATHER',
#  'PROBABLY',
#  'LABOUR',
#  'ABUSE',
#  'SUNDAY',
#  'MAYBE',
#  'HIGHER',
#  'OFFICIALS',
#  'ACCUSED',
#  'THREAT',
#  'ATTACKS',
#  'GOVERNMENT',
#  'RULES',
#  'OPERATION',
#  'COUNTRY',
#  'NOTHING',
#  'FORCES',
#  'HUNDREDS',
#  'EUROPE',
#  'SOMEONE',
#  'SYRIA',
#  'KILLED',
#  'WHETHER',
#  'GOING',
#  'DIFFICULT',
#  'WHILE',
#  'PRISON',
#  'ABOUT',
#  'SECOND',
#  'MAKING',
#  'TODAY',
#  'ACROSS',
#  'WHICH',
#  'SPECIAL',
#  'DEBATE',
#  'CHARGE',
#  'BIGGEST',
#  'THING',
#  'MONTHS',
#  'GETTING',
#  'PARLIAMENT',
#  'KNOWN',
#  'AROUND',
#  'THROUGH',
#  'CANCER',
#  'MEDICAL',
#  'MEASURES',
#  'CHILD',
#  'ORDER',
#  'TALKS',
#  'POSSIBLE',
#  'SOUTHERN',
#  'RATES',
#  'FIRST',
#  'PROBLEMS',
#  'CONTROL',
#  'RETURN',
#  'FINANCIAL',
#  'RESPONSE',
#  'MAKES',
#  'HEART',
#  'TRUST',
#  'CERTAINLY',
#  'YESTERDAY',
#  'SCHOOLS',
#  'LEVEL',
#  'LIKELY',
#  'PROVIDE',
#  'PERIOD',
#  'DECISION',
#  'WORST',
#  'CHANGES',
#  'PRIME',
#  'CHANGE',
#  'BUSINESS',
#  'RECENT',
#  'SYSTEM',
#  'LEVELS',
#  'MISSING',
#  'ECONOMIC',
#  'CASES',
#  'FACING',
#  'GROWTH',
#  'GENERAL',
#  'INTEREST',
#  'MILLION',
#  'FRANCE',
#  'SPEECH',
#  'EVERY',
#  'VICTIMS',
#  'REPORTS',
#  'FUTURE',
#  'SCOTTISH',
#  'SOCIETY',
#  'ITSELF',
#  'COULD',
#  'PARENTS',
#  'TIMES',
#  'DESCRIBED',
#  'OUTSIDE']

# %%
# x['the_input'][0].shape, x['source_str'], x['the_labels']

# %%
# # im = batch_frames[1][25]
# import matplotlib.pyplot as plt
# %matplotlib inline
# # generator = datagen(min_row_number=0,max_row_number=200000, batch_size= 6)
# # X,Y = next(generator)
# X = x['the_input'][0]
# # print(X.shape, Y.shape)
# def plot_data(x,ax):
# #     x = x.reshape((size,size))
#     ax.imshow(x, cmap='gray')
# #     if y is not None:
# #         ax.scatter(y[0::2] , y[1::2] , marker='x', s=10)
# fig = plt.figure(figsize=(30,30))
# fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
# for i in range(30):
#     ax = fig.add_subplot(1, 30, i + 1, xticks=[], yticks=[])
#     plot_data(X[i], ax)

# %%
# # import io
# # import base64
# # from IPython.display import HTML

# # video = io.open('evaluation/samples/test.mp4', 'r+b').read()
# # encoded = base64.b64encode(video)
# # HTML(data='''<video alt="test" controls>
# #                 <source src="data:video/mp4;base64,{0}" type="video/mp4" />
# #              </video>'''.format(encoded.decode('ascii')))
# im = cv2.imread('training/unseen_speakers/test_pic.jpg')
# ims = get_frames_mouth(detector, predictor, [im])
# plt.imshow(ims[0][...,::-1])

# %%
# # np.max([len(word) for word in words])
# type(np.array([1,2]))

# %%
# lipnet.predict(np.array([X]))

# %%
# m = []
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append(1)
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([[1],[1],[1]])
# np.array(m).shape
t = {1,2,3,4,5}
t.add(5)
t.add(6)

# %%
t
