# %%
import sys
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from scipy import ndimage
from keras.optimizers import Adadelta,Adam
from keras.callbacks import TensorBoard, CSVLogger, ModelCheckpoint
# from lipnet.lipreading.generators import BasicGenerator
# from lipnet.lipreading.callbacks import Statistics, Visualize
# from lipnet.lipreading.curriculums import Curriculum
# from lipnet.core.decoders import Decoder
# from lipnet.lipreading.helpers import labels_to_text
# from lipnet.utils.spell import Spell
from lipnet.model2 import LipNet
import numpy as np
import datetime
import cv2
import skvideo.io
import dlib
from scipy.misc import imresize
# from lipnet.lipreading.aligns import Align
import imageio
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
import random
import tensorflow as tf
import keras.backend as K
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

FACE_PREDICTOR_PATH  = os.path.join('common','predictors','shape_predictor_68_face_landmarks.dat')
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(FACE_PREDICTOR_PATH)

frames_count = 30
words_folder = 'training/unseen_speakers/TARGET/datasets/lipread_mp4'
words = os.listdir(words_folder)
words = ['EVERYONE',
 'EVENTS',
 'EVERYBODY',
 'CLOUD',
 'RIGHTS',
 'AUTHORITIES',
 'WITHIN',
 'SEVERAL',
 'ABSOLUTELY',
 'WINDS',
 'AFTERNOON',
 'BETWEEN',
 'TALKING',
 'AGREEMENT',
 'PRICES'] #words[:2]
words = [s.upper() for s in words]
max_len = 12 #np.max([len(word) for word in words])
used_words = {''}
print(words)
def datagen(data_partition = 'train', batch_size = 16):
    while True:
        counter = 0
        word_idx = np.random.randint(len(words))
        used_words.add(words[word_idx])
        train_folder = 'training/unseen_speakers/TARGET/datasets/lipread_mp4/{0}/{1}/'.format(words[word_idx],data_partition)
    #         print(train_folder)
        files = os.listdir(train_folder)
#         print(files)
        paths = list(set([x.split('.')[0] for x in files]))
        
        X_data = []#np.zeros((batch_size,))
        Y_data = []
        input_length = []
        label_length = []
        source_str = []
        while counter<batch_size:
#             print(counter)
            idx = np.random.randint(len(paths))
            path = os.path.join(train_folder,paths[idx])
            frames = []
            for img_name in sorted(os.listdir(path)):
                img = cv2.imread(os.path.join(path,img_name))
                frames.append(img[...,::-1])
            frames = np.array(frames)
            if len(frames.shape)==4:
                frames = np.rollaxis(frames,2, start=1)
    #             print(path)
    #             print(frames.shape)
    #             print('---------')
                if 'numpy.ndarray' in str(type(frames)) \
                        and len(np.shape(frames))==4 \
                        and np.shape(frames)[1] == 100 \
                        and np.shape(frames)[2] == 50:

                    X_data.append(frames)


                    ####
                    Y_data.append([ord(c) - 65 for c in words[word_idx]]+[-1]*(max_len-len(words[word_idx])))
                    input_length.append(frames_count)
                    label_length.append(len(words[word_idx]))
                    source_str.append(words[word_idx])
                    counter+=1
                else:
                    continue
            else:
                print('error:', frames.shape, path)
                continue

        X_data = np.array(X_data).astype(np.float32) / 255 
        Y_data = np.array(Y_data)
        input_length = np.array(input_length)
        label_length = np.array(label_length)
        source_str = np.array(source_str)
        
        inputs = {'the_input': X_data,
                  'the_labels': Y_data,
                  'input_length': input_length,
                  'label_length': label_length,
                  'source_str': source_str  # used for visualization only
                  }
        outputs = {'ctc': np.zeros([batch_size])}
        
#         print('the_input:', inputs['the_input'].shape)
#         print('the_labels:', inputs['the_labels'].shape)
#         print('input_length:', inputs['input_length'].shape)
#         print('label_length:', inputs['label_length'].shape)
#         print('source_str:', inputs['source_str'].shape)
#         print('batch_frames_shape',X_data.shape, data_partition)
        yield (inputs, outputs)
# Out:
# ['EVERYONE', 'EVENTS', 'EVERYBODY', 'CLOUD', 'RIGHTS', 'AUTHORITIES', 'WITHIN', 'SEVERAL', 'ABSOLUTELY', 'WINDS', 'AFTERNOON', 'BETWEEN', 'TALKING', 'AGREEMENT', 'PRICES']

# %%
# global lip_gen

run_name = datetime.datetime.now().strftime('%Y:%m:%d_%H:%M:%S')
run_name, start_epoch, stop_epoch, img_c, img_w, img_h, frames_n, absolute_max_string_len, minibatch_size = \
    run_name, 0, 1000, 3, 100, 50, 30, 12, 2



CURRENT_PATH = os.getcwd()+'/training/unseen_speakers'
DATASET_DIR  = os.path.join(CURRENT_PATH, 'datasets')
OUTPUT_DIR   = os.path.join(CURRENT_PATH, 'results')
LOG_DIR      = os.path.join(CURRENT_PATH, 'logs')
# if not os.path.exists('training/unseen_speakers/results/'+run_name):
#     os.makedirs('training/unseen_speakers/results/'+run_name)
if not os.path.exists('training/unseen_speakers/logs/'+run_name):
    os.makedirs('training/unseen_speakers/logs/'+run_name)

PREDICT_GREEDY      = False
PREDICT_BEAM_WIDTH  = 200
PREDICT_DICTIONARY  = os.path.join(CURRENT_PATH,'..','..','common','dictionaries','lfw.txt')
FACE_PREDICTOR_PATH  = os.path.join(CURRENT_PATH,'..','..','common','predictors','shape_predictor_68_face_landmarks.dat')

# def curriculum_rules(epoch):
#     return { 'sentence_length': -1, 'flip_probability': 0.5, 'jitter_probability': 0.05 }


# # def train(run_name, start_epoch, stop_epoch, img_c, img_w, img_h, frames_n, absolute_max_string_len, minibatch_size):
# curriculum = Curriculum(curriculum_rules)
# lip_gen = BasicGenerator(dataset_path=DATASET_DIR, #vtype = "face", face_predictor_path = FACE_PREDICTOR_PATH,
#                             minibatch_size=minibatch_size,
#                             img_c=img_c, img_w=img_w, img_h=img_h, frames_n=frames_n,
#                             absolute_max_string_len=absolute_max_string_len,
#                             curriculum=curriculum, start_epoch=start_epoch).build()
# lip_gen_train = datagen(data_partition='train', batch_size=5)
# lip_gen_val = datagen(data_partition='val', batch_size=5)

lipnet = LipNet(img_c=img_c, img_w=img_w, img_h=img_h, frames_n=frames_n,
                        absolute_max_string_len=absolute_max_string_len, output_size=27)
# lipnet.summary()
# adadelta = Adadelta(lr=0.0001, decay=1e-08, epsilon=1e-08)

adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=1e-08)

# the loss calc occurs elsewhere, so use a dummy lambda func for the loss
lipnet.model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=adam, metrics=['accuracy'])


# spell = Spell(path=PREDICT_DICTIONARY)
# decoder = Decoder(greedy=PREDICT_GREEDY, beam_width=PREDICT_BEAM_WIDTH,
#                   postprocessors=[labels_to_text, spell.sentence])

# define callbacks
# statistics  = Statistics(lipnet, lip_gen.next_val(), decoder, 256, output_dir=os.path.join(OUTPUT_DIR, run_name))
# visualize   = Visualize(os.path.join(OUTPUT_DIR, run_name), lipnet, lip_gen.next_val(), decoder, num_display_sentences=minibatch_size)
tensorboard = TensorBoard(log_dir=os.path.join(LOG_DIR, 'crop-'+run_name))
# csv_logger  = CSVLogger(os.path.join(LOG_DIR, "{}-{}.csv".format('training',run_name)), separator=',', append=True)
checkpoint  = ModelCheckpoint(save_best_only=True,
                              filepath='training/unseen_speakers/results/weights_lfw-crop.hdf5'
                              , monitor='val_loss'
                              , verbose=1
                              , mode='min'
                              , period=1)
    
    # x = next(lip_gen.next_val())
    # for i in x:
    #     print('$$$$$----------', type(i))
# Out:
# y_pred (?, 30, 27)

# %%
# run_name = datetime.datetime.now().strftime('%Y:%m:%d:%H:%M:%S')
# train(run_name, 0, 1000, 3, 100, 50, 75, 32, 2)

# %%
# os.getcwd()+'training/unseen_speakers'

# %%
# g=lip_gen.next_train()
# inputs, outputs = next(g)

# %%
# inputs

# %%
# len('place green at t six now')

# %%
# len([ 15.,  11.,   0.,   2.,   4.,  26.,   6.,  17.,   4.,   4.,  13.,
#           26.,   0.,  19.,  26.,  19.,  26.,  18.,   8.,  23.,  26.,  13.,
#           14.,  22.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.,  -1.])

# %%
# words

# %%
# load weight if necessary

start_epoch = 85
if start_epoch > 0:
    weight_file = os.path.join(OUTPUT_DIR, 'weights_lfw-crop.hdf5')
    lipnet.model.load_weights(weight_file)

lipnet.model.fit_generator(generator=datagen(data_partition='train', batch_size=32),
                    steps_per_epoch=1
                    , epochs=50000,
                    #steps_per_epoch=lip_gen.default_training_steps, epochs=stop_epoch,
                    validation_data=datagen(data_partition='val', batch_size=32)
                    , validation_steps=1,#validation_steps=lip_gen.default_validation_steps,
                    callbacks=[checkpoint,tensorboard],                         
                    initial_epoch=start_epoch, 
                    verbose=1)
                    #max_q_size=5,
                    #workers=2,
                    #pickle_safe=True)
# Out:
# Epoch 86/50000
# 1/1 [==============================] - 4s 4s/step - loss: 16.6640 - acc: 0.0000e+00 - val_loss: 29.2938 - val_acc: 0.0000e+00
#
# Epoch 00086: val_loss improved from inf to 29.29377, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 87/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 20.3870 - acc: 0.0000e+00 - val_loss: 24.2630 - val_acc: 0.0000e+00
#
# Epoch 00087: val_loss improved from 29.29377 to 24.26301, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 88/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 14.8257 - acc: 0.0000e+00 - val_loss: 38.4674 - val_acc: 0.0000e+00
#
# Epoch 00088: val_loss did not improve from 24.26301
# Epoch 89/50000
# 1/1 [==============================] - 0s 334ms/step - loss: 24.9116 - acc: 0.0000e+00 - val_loss: 25.9389 - val_acc: 0.0000e+00
#
# Epoch 00089: val_loss did not improve from 24.26301
# Epoch 90/50000
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
# 1/1 [==============================] - 0s 325ms/step - loss: 20.3844 - acc: 0.0000e+00 - val_loss: 17.8856 - val_acc: 0.0000e+00
#
# Epoch 00090: val_loss improved from 24.26301 to 17.88559, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 91/50000
# 1/1 [==============================] - 0s 327ms/step - loss: 20.2371 - acc: 0.0000e+00 - val_loss: 21.4941 - val_acc: 0.0000e+00
#
# Epoch 00091: val_loss did not improve from 17.88559
# Epoch 92/50000
# 1/1 [==============================] - 0s 334ms/step - loss: 18.9904 - acc: 0.0000e+00 - val_loss: 27.7924 - val_acc: 0.0000e+00
#
# Epoch 00092: val_loss did not improve from 17.88559
# Epoch 93/50000
# 1/1 [==============================] - 0s 324ms/step - loss: 20.0163 - acc: 0.0000e+00 - val_loss: 19.6367 - val_acc: 0.0000e+00
#
# Epoch 00093: val_loss did not improve from 17.88559
# Epoch 94/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 20.8375 - acc: 0.0000e+00 - val_loss: 28.0656 - val_acc: 0.0000e+00
#
# Epoch 00094: val_loss did not improve from 17.88559
# Epoch 95/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 18.9931 - acc: 0.0000e+00 - val_loss: 19.5815 - val_acc: 0.0000e+00
#
# Epoch 00095: val_loss did not improve from 17.88559
# Epoch 96/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 34.6299 - acc: 0.0000e+00 - val_loss: 37.7693 - val_acc: 0.0000e+00
#
# Epoch 00096: val_loss did not improve from 17.88559
# Epoch 97/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 17.8921 - acc: 0.0000e+00 - val_loss: 18.8428 - val_acc: 0.0000e+00
#
# Epoch 00097: val_loss did not improve from 17.88559
# Epoch 98/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 26.7333 - acc: 0.0000e+00 - val_loss: 30.2338 - val_acc: 0.0000e+00
#
# Epoch 00098: val_loss did not improve from 17.88559
# Epoch 99/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 36.1234 - acc: 0.0000e+00 - val_loss: 15.1630 - val_acc: 0.0000e+00
#
# Epoch 00099: val_loss improved from 17.88559 to 15.16296, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 100/50000
# 1/1 [==============================] - 0s 330ms/step - loss: 19.8245 - acc: 0.0000e+00 - val_loss: 14.4724 - val_acc: 0.0000e+00
#
# Epoch 00100: val_loss improved from 15.16296 to 14.47242, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 101/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 22.0416 - acc: 0.0000e+00 - val_loss: 14.9340 - val_acc: 0.0000e+00
#
# Epoch 00101: val_loss did not improve from 14.47242
# Epoch 102/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 18.9911 - acc: 0.0000e+00 - val_loss: 23.1889 - val_acc: 0.0000e+00
#
# Epoch 00102: val_loss did not improve from 14.47242
# Epoch 103/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 25.1633 - acc: 0.0000e+00 - val_loss: 30.8216 - val_acc: 0.0000e+00
#
# Epoch 00103: val_loss did not improve from 14.47242
# Epoch 104/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 15.8616 - acc: 0.0000e+00 - val_loss: 24.3670 - val_acc: 0.0000e+00
#
# Epoch 00104: val_loss did not improve from 14.47242
# Epoch 105/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 16.9170 - acc: 0.0000e+00 - val_loss: 29.4179 - val_acc: 0.0000e+00
#
# Epoch 00105: val_loss did not improve from 14.47242
# Epoch 106/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 16.0242 - acc: 0.0000e+00 - val_loss: 32.9401 - val_acc: 0.0000e+00
#
# Epoch 00106: val_loss did not improve from 14.47242
# Epoch 107/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 16.3040 - acc: 0.0000e+00 - val_loss: 21.8206 - val_acc: 0.0000e+00
#
# Epoch 00107: val_loss did not improve from 14.47242
# Epoch 108/50000
# 1/1 [==============================] - 0s 317ms/step - loss: 29.5814 - acc: 0.0000e+00 - val_loss: 33.2502 - val_acc: 0.0000e+00
#
# Epoch 00108: val_loss did not improve from 14.47242
# Epoch 109/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 23.3558 - acc: 0.0000e+00 - val_loss: 17.7900 - val_acc: 0.0000e+00
#
# Epoch 00109: val_loss did not improve from 14.47242
# Epoch 110/50000
# 1/1 [==============================] - 0s 365ms/step - loss: 24.4174 - acc: 0.0000e+00 - val_loss: 13.6110 - val_acc: 0.0000e+00
#
# Epoch 00110: val_loss improved from 14.47242 to 13.61104, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 111/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 17.5793 - acc: 0.0000e+00 - val_loss: 25.2693 - val_acc: 0.0000e+00
#
# Epoch 00111: val_loss did not improve from 13.61104
# Epoch 112/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 31.2945 - acc: 0.0000e+00 - val_loss: 24.9507 - val_acc: 0.0000e+00
#
# Epoch 00112: val_loss did not improve from 13.61104
# Epoch 113/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 30.6262 - acc: 0.0000e+00 - val_loss: 29.5849 - val_acc: 0.0000e+00
#
# Epoch 00113: val_loss did not improve from 13.61104
# Epoch 114/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 22.9426 - acc: 0.0000e+00 - val_loss: 28.7853 - val_acc: 0.0000e+00
#
# Epoch 00114: val_loss did not improve from 13.61104
# Epoch 115/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 17.2840 - acc: 0.0000e+00 - val_loss: 15.5961 - val_acc: 0.0000e+00
#
# Epoch 00115: val_loss did not improve from 13.61104
# Epoch 116/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 20.5222 - acc: 0.0000e+00 - val_loss: 14.9387 - val_acc: 0.0000e+00
#
# Epoch 00116: val_loss did not improve from 13.61104
# Epoch 117/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 17.2244 - acc: 0.0000e+00 - val_loss: 15.1144 - val_acc: 0.0000e+00
#
# Epoch 00117: val_loss did not improve from 13.61104
# Epoch 118/50000
# 1/1 [==============================] - 0s 334ms/step - loss: 32.6696 - acc: 0.0000e+00 - val_loss: 17.9451 - val_acc: 0.0000e+00
#
# Epoch 00118: val_loss did not improve from 13.61104
# Epoch 119/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 28.0252 - acc: 0.0000e+00 - val_loss: 28.3387 - val_acc: 0.0000e+00
#
# Epoch 00119: val_loss did not improve from 13.61104
# Epoch 120/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 19.8758 - acc: 0.0000e+00 - val_loss: 17.9032 - val_acc: 0.0000e+00
#
# Epoch 00120: val_loss did not improve from 13.61104
# Epoch 121/50000
# 1/1 [==============================] - 0s 325ms/step - loss: 25.4821 - acc: 0.0000e+00 - val_loss: 19.1671 - val_acc: 0.0000e+00
#
# Epoch 00121: val_loss did not improve from 13.61104
# Epoch 122/50000
# 1/1 [==============================] - 0s 395ms/step - loss: 32.7235 - acc: 0.0000e+00 - val_loss: 18.9267 - val_acc: 0.0000e+00
#
# Epoch 00122: val_loss did not improve from 13.61104
# Epoch 123/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 26.7051 - acc: 0.0000e+00 - val_loss: 32.0884 - val_acc: 0.0000e+00
#
# Epoch 00123: val_loss did not improve from 13.61104
# Epoch 124/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 19.7240 - acc: 0.0000e+00 - val_loss: 18.4237 - val_acc: 0.0000e+00
# Epoch 00124: val_loss did not improve from 13.61104
# Epoch 125/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 18.9958 - acc: 0.0000e+00 - val_loss: 25.5839 - val_acc: 0.0000e+00
#
# Epoch 00125: val_loss did not improve from 13.61104
# Epoch 126/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 22.4435 - acc: 0.0000e+00 - val_loss: 26.1411 - val_acc: 0.0000e+00
#
# Epoch 00126: val_loss did not improve from 13.61104
# Epoch 127/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 26.2070 - acc: 0.0000e+00 - val_loss: 18.3980 - val_acc: 0.0000e+00
#
# Epoch 00127: val_loss did not improve from 13.61104
# Epoch 128/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 22.0106 - acc: 0.0000e+00 - val_loss: 19.1870 - val_acc: 0.0000e+00
#
# Epoch 00128: val_loss did not improve from 13.61104
# Epoch 129/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 23.6603 - acc: 0.0000e+00 - val_loss: 18.2013 - val_acc: 0.0000e+00
#
# Epoch 00129: val_loss did not improve from 13.61104
# Epoch 130/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 25.6602 - acc: 0.0000e+00 - val_loss: 22.9385 - val_acc: 0.0000e+00
#
# Epoch 00130: val_loss did not improve from 13.61104
# Epoch 131/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 20.7094 - acc: 0.0000e+00 - val_loss: 33.6495 - val_acc: 0.0000e+00
#
# Epoch 00131: val_loss did not improve from 13.61104
# Epoch 132/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 25.2971 - acc: 0.0000e+00 - val_loss: 22.3831 - val_acc: 0.0000e+00
#
# Epoch 00132: val_loss did not improve from 13.61104
# Epoch 133/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 25.1083 - acc: 0.0000e+00 - val_loss: 17.5301 - val_acc: 0.0000e+00
#
# Epoch 00133: val_loss did not improve from 13.61104
# Epoch 134/50000
# 1/1 [==============================] - 0s 326ms/step - loss: 32.5741 - acc: 0.0000e+00 - val_loss: 17.5657 - val_acc: 0.0000e+00
#
# Epoch 00134: val_loss did not improve from 13.61104
# Epoch 135/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 23.7810 - acc: 0.0000e+00 - val_loss: 26.1614 - val_acc: 0.0000e+00
#
# Epoch 00135: val_loss did not improve from 13.61104
# Epoch 136/50000
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/AUTHORITIES/train/AUTHORITIES_00912
# 1/1 [==============================] - 0s 314ms/step - loss: 20.3944 - acc: 0.0000e+00 - val_loss: 21.7579 - val_acc: 0.0000e+00
#
# Epoch 00136: val_loss did not improve from 13.61104
# Epoch 137/50000
# 1/1 [==============================] - 0s 321ms/step - loss: 15.5063 - acc: 0.0000e+00 - val_loss: 23.2273 - val_acc: 0.0000e+00
#
# Epoch 00137: val_loss did not improve from 13.61104
# Epoch 138/50000
# 1/1 [==============================] - 0s 302ms/step - loss: 19.8707 - acc: 0.0000e+00 - val_loss: 18.9753 - val_acc: 0.0000e+00
#
# Epoch 00138: val_loss did not improve from 13.61104
# Epoch 139/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 20.9902 - acc: 0.0000e+00 - val_loss: 21.4640 - val_acc: 0.0000e+00
#
# Epoch 00139: val_loss did not improve from 13.61104
# Epoch 140/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 19.0986 - acc: 0.0000e+00 - val_loss: 34.0394 - val_acc: 0.0000e+00
#
# Epoch 00140: val_loss did not improve from 13.61104
# Epoch 141/50000
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00316
# 1/1 [==============================] - 0s 307ms/step - loss: 19.1101 - acc: 0.0000e+00 - val_loss: 18.9256 - val_acc: 0.0000e+00
#
# Epoch 00141: val_loss did not improve from 13.61104
# Epoch 142/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 27.1479 - acc: 0.0000e+00 - val_loss: 19.0586 - val_acc: 0.0000e+00
#
# Epoch 00142: val_loss did not improve from 13.61104
# Epoch 143/50000
# 1/1 [==============================] - 0s 330ms/step - loss: 13.5689 - acc: 0.0000e+00 - val_loss: 21.5142 - val_acc: 0.0000e+00
#
# Epoch 00143: val_loss did not improve from 13.61104
# Epoch 144/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 28.7641 - acc: 0.0000e+00 - val_loss: 22.7690 - val_acc: 0.0000e+00
#
# Epoch 00144: val_loss did not improve from 13.61104
# Epoch 145/50000
# 1/1 [==============================] - 0s 328ms/step - loss: 12.9443 - acc: 0.0000e+00 - val_loss: 27.3058 - val_acc: 0.0000e+00
#
# Epoch 00145: val_loss did not improve from 13.61104
# Epoch 146/50000
# 1/1 [==============================] - 0s 354ms/step - loss: 21.2186 - acc: 0.0000e+00 - val_loss: 22.8653 - val_acc: 0.0000e+00
#
# Epoch 00146: val_loss did not improve from 13.61104
# Epoch 147/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 35.4108 - acc: 0.0000e+00 - val_loss: 24.4076 - val_acc: 0.0000e+00
#
# Epoch 00147: val_loss did not improve from 13.61104
# Epoch 148/50000
# 1/1 [==============================] - 0s 326ms/step - loss: 12.4379 - acc: 0.0000e+00 - val_loss: 18.6033 - val_acc: 0.0000e+00
#
# Epoch 00148: val_loss did not improve from 13.61104
# Epoch 149/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 17.0650 - acc: 0.0000e+00 - val_loss: 19.1912 - val_acc: 0.0000e+00
#
# Epoch 00149: val_loss did not improve from 13.61104
# Epoch 150/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 33.8931 - acc: 0.0000e+00 - val_loss: 25.0409 - val_acc: 0.0000e+00
#
# Epoch 00150: val_loss did not improve from 13.61104
# Epoch 151/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 20.3603 - acc: 0.0000e+00 - val_loss: 19.1915 - val_acc: 0.0000e+00
#
# Epoch 00151: val_loss did not improve from 13.61104
# Epoch 152/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 26.0203 - acc: 0.0000e+00 - val_loss: 11.5427 - val_acc: 0.0000e+00
#
# Epoch 00152: val_loss improved from 13.61104 to 11.54269, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 153/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 27.4702 - acc: 0.0000e+00 - val_loss: 24.7579 - val_acc: 0.0000e+00
#
# Epoch 00153: val_loss did not improve from 11.54269
# Epoch 154/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 12.7221 - acc: 0.0000e+00 - val_loss: 30.9639 - val_acc: 0.0000e+00
#
# Epoch 00154: val_loss did not improve from 11.54269
# Epoch 155/50000
# 1/1 [==============================] - 0s 334ms/step - loss: 25.6604 - acc: 0.0000e+00 - val_loss: 20.6577 - val_acc: 0.0000e+00
#
# Epoch 00155: val_loss did not improve from 11.54269
# Epoch 156/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 31.6131 - acc: 0.0000e+00 - val_loss: 26.0639 - val_acc: 0.0000e+00
#
# Epoch 00156: val_loss did not improve from 11.54269
# Epoch 157/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 24.9923 - acc: 0.0000e+00 - val_loss: 24.1539 - val_acc: 0.0000e+00
#
# Epoch 00157: val_loss did not improve from 11.54269
# Epoch 158/50000
# 1/1 [==============================] - 0s 331ms/step - loss: 23.2308 - acc: 0.0000e+00 - val_loss: 19.8948 - val_acc: 0.0000e+00
#
# Epoch 00158: val_loss did not improve from 11.54269
# Epoch 159/50000
# 1/1 [==============================] - 0s 378ms/step - loss: 31.8992 - acc: 0.0000e+00 - val_loss: 19.9047 - val_acc: 0.0000e+00
#
# Epoch 00159: val_loss did not improve from 11.54269
# Epoch 160/50000
# 1/1 [==============================] - 0s 331ms/step - loss: 18.9519 - acc: 0.0000e+00 - val_loss: 23.4774 - val_acc: 0.0000e+00
#
# Epoch 00160: val_loss did not improve from 11.54269
# Epoch 161/50000
# 1/1 [==============================] - 0s 326ms/step - loss: 15.6930 - acc: 0.0000e+00 - val_loss: 29.4705 - val_acc: 0.0000e+00
#
# Epoch 00161: val_loss did not improve from 11.54269
# Epoch 162/50000
# 1/1 [==============================] - 0s 317ms/step - loss: 19.2661 - acc: 0.0000e+00 - val_loss: 18.2961 - val_acc: 0.0000e+00
#
# Epoch 00162: val_loss did not improve from 11.54269
# Epoch 163/50000
# 1/1 [==============================] - 0s 315ms/step - loss: 25.7152 - acc: 0.0000e+00 - val_loss: 17.3291 - val_acc: 0.0000e+00
#
# Epoch 00163: val_loss did not improve from 11.54269
# Epoch 164/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 19.1924 - acc: 0.0000e+00 - val_loss: 18.3108 - val_acc: 0.0000e+00
# Epoch 00164: val_loss did not improve from 11.54269
# Epoch 165/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 25.4730 - acc: 0.0000e+00 - val_loss: 23.5508 - val_acc: 0.0000e+00
#
# Epoch 00165: val_loss did not improve from 11.54269
# Epoch 166/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 21.3047 - acc: 0.0000e+00 - val_loss: 27.4709 - val_acc: 0.0000e+00
#
# Epoch 00166: val_loss did not improve from 11.54269
# Epoch 167/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 18.1984 - acc: 0.0000e+00 - val_loss: 29.8686 - val_acc: 0.0000e+00
#
# Epoch 00167: val_loss did not improve from 11.54269
# Epoch 168/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 25.1266 - acc: 0.0000e+00 - val_loss: 29.3326 - val_acc: 0.0000e+00
#
# Epoch 00168: val_loss did not improve from 11.54269
# Epoch 169/50000
# 1/1 [==============================] - 0s 303ms/step - loss: 20.6286 - acc: 0.0000e+00 - val_loss: 24.0230 - val_acc: 0.0000e+00
#
# Epoch 00169: val_loss did not improve from 11.54269
# Epoch 170/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 15.2705 - acc: 0.0000e+00 - val_loss: 24.0054 - val_acc: 0.0000e+00
#
# Epoch 00170: val_loss did not improve from 11.54269
# Epoch 171/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 15.9865 - acc: 0.0000e+00 - val_loss: 29.3193 - val_acc: 0.0000e+00
#
# Epoch 00171: val_loss did not improve from 11.54269
# Epoch 172/50000
# 1/1 [==============================] - 0s 325ms/step - loss: 18.9097 - acc: 0.0000e+00 - val_loss: 24.0639 - val_acc: 0.0000e+00
#
# Epoch 00172: val_loss did not improve from 11.54269
# Epoch 173/50000
# 1/1 [==============================] - 0s 371ms/step - loss: 19.5735 - acc: 0.0000e+00 - val_loss: 30.2332 - val_acc: 0.0000e+00
#
# Epoch 00173: val_loss did not improve from 11.54269
# Epoch 174/50000
# 1/1 [==============================] - 0s 302ms/step - loss: 23.1887 - acc: 0.0000e+00 - val_loss: 17.9734 - val_acc: 0.0000e+00
#
# Epoch 00174: val_loss did not improve from 11.54269
# Epoch 175/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 18.2582 - acc: 0.0000e+00 - val_loss: 22.7447 - val_acc: 0.0000e+00
#
# Epoch 00175: val_loss did not improve from 11.54269
# Epoch 176/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 14.6932 - acc: 0.0000e+00 - val_loss: 31.8894 - val_acc: 0.0000e+00
#
# Epoch 00176: val_loss did not improve from 11.54269
# Epoch 177/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 18.6604 - acc: 0.0000e+00 - val_loss: 23.0240 - val_acc: 0.0000e+00
#
# Epoch 00177: val_loss did not improve from 11.54269
# Epoch 178/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 32.5544 - acc: 0.0000e+00 - val_loss: 23.0528 - val_acc: 0.0000e+00
#
# Epoch 00178: val_loss did not improve from 11.54269
# Epoch 179/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 19.4455 - acc: 0.0000e+00 - val_loss: 24.7614 - val_acc: 0.0000e+00
#
# Epoch 00179: val_loss did not improve from 11.54269
# Epoch 180/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 13.7550 - acc: 0.0000e+00 - val_loss: 13.2746 - val_acc: 0.0000e+00
#
# Epoch 00180: val_loss did not improve from 11.54269
# Epoch 181/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 24.7458 - acc: 0.0000e+00 - val_loss: 25.9060 - val_acc: 0.0000e+00
#
# Epoch 00181: val_loss did not improve from 11.54269
# Epoch 182/50000
# 1/1 [==============================] - 0s 350ms/step - loss: 17.3908 - acc: 0.0000e+00 - val_loss: 16.4896 - val_acc: 0.0000e+00
#
# Epoch 00182: val_loss did not improve from 11.54269
# Epoch 183/50000
# 1/1 [==============================] - 0s 302ms/step - loss: 31.3711 - acc: 0.0000e+00 - val_loss: 12.3137 - val_acc: 0.0000e+00
#
# Epoch 00183: val_loss did not improve from 11.54269
# Epoch 184/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 26.1649 - acc: 0.0000e+00 - val_loss: 28.9990 - val_acc: 0.0000e+00
#
# Epoch 00184: val_loss did not improve from 11.54269
# Epoch 185/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 23.9107 - acc: 0.0000e+00 - val_loss: 17.5979 - val_acc: 0.0000e+00
#
# Epoch 00185: val_loss did not improve from 11.54269
# Epoch 186/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 18.8920 - acc: 0.0000e+00 - val_loss: 32.8106 - val_acc: 0.0000e+00
#
# Epoch 00186: val_loss did not improve from 11.54269
# Epoch 187/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 17.3755 - acc: 0.0000e+00 - val_loss: 27.9569 - val_acc: 0.0000e+00
#
# Epoch 00187: val_loss did not improve from 11.54269
# Epoch 188/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 23.8768 - acc: 0.0000e+00 - val_loss: 23.0435 - val_acc: 0.0000e+00
#
# Epoch 00188: val_loss did not improve from 11.54269
# Epoch 189/50000
# 1/1 [==============================] - 0s 335ms/step - loss: 16.0459 - acc: 0.0000e+00 - val_loss: 26.8904 - val_acc: 0.0000e+00
#
# Epoch 00189: val_loss did not improve from 11.54269
# Epoch 190/50000
# 1/1 [==============================] - 0s 327ms/step - loss: 25.7987 - acc: 0.0000e+00 - val_loss: 12.2109 - val_acc: 0.0000e+00
#
# Epoch 00190: val_loss did not improve from 11.54269
# Epoch 191/50000
# 1/1 [==============================] - 0s 358ms/step - loss: 16.4676 - acc: 0.0000e+00 - val_loss: 12.1944 - val_acc: 0.0000e+00
#
# Epoch 00191: val_loss did not improve from 11.54269
# Epoch 192/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 22.1709 - acc: 0.0000e+00 - val_loss: 27.4366 - val_acc: 0.0000e+00
#
# Epoch 00192: val_loss did not improve from 11.54269
# Epoch 193/50000
# 1/1 [==============================] - 0s 335ms/step - loss: 16.6614 - acc: 0.0000e+00 - val_loss: 20.5267 - val_acc: 0.0000e+00
#
# Epoch 00193: val_loss did not improve from 11.54269
# Epoch 194/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 16.3792 - acc: 0.0000e+00 - val_loss: 15.1361 - val_acc: 0.0000e+00
#
# Epoch 00194: val_loss did not improve from 11.54269
# Epoch 195/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 27.0454 - acc: 0.0000e+00 - val_loss: 35.4813 - val_acc: 0.0000e+00
#
# Epoch 00195: val_loss did not improve from 11.54269
# Epoch 196/50000
# 1/1 [==============================] - 0s 369ms/step - loss: 15.5384 - acc: 0.0000e+00 - val_loss: 27.1894 - val_acc: 0.0000e+00
#
# Epoch 00196: val_loss did not improve from 11.54269
# Epoch 197/50000
# 1/1 [==============================] - 0s 344ms/step - loss: 24.1096 - acc: 0.0000e+00 - val_loss: 20.6019 - val_acc: 0.0000e+00
#
# Epoch 00197: val_loss did not improve from 11.54269
# Epoch 198/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 23.3004 - acc: 0.0000e+00 - val_loss: 13.1972 - val_acc: 0.0000e+00
#
# Epoch 00198: val_loss did not improve from 11.54269
# Epoch 199/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 15.6598 - acc: 0.0000e+00 - val_loss: 28.4548 - val_acc: 0.0000e+00
#
# Epoch 00199: val_loss did not improve from 11.54269
# Epoch 200/50000
# 1/1 [==============================] - 0s 341ms/step - loss: 19.4957 - acc: 0.0000e+00 - val_loss: 20.1306 - val_acc: 0.0000e+00
#
# Epoch 00200: val_loss did not improve from 11.54269
# Epoch 201/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 14.2464 - acc: 0.0000e+00 - val_loss: 25.5007 - val_acc: 0.0000e+00
#
# Epoch 00201: val_loss did not improve from 11.54269
# Epoch 202/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 14.7417 - acc: 0.0000e+00 - val_loss: 36.4110 - val_acc: 0.0000e+00
#
# Epoch 00202: val_loss did not improve from 11.54269
# Epoch 203/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 14.4527 - acc: 0.0000e+00 - val_loss: 22.5446 - val_acc: 0.0000e+00
#
# Epoch 00203: val_loss did not improve from 11.54269
# Epoch 204/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 29.7447 - acc: 0.0000e+00 - val_loss: 18.7993 - val_acc: 0.0000e+00
#
# Epoch 00204: val_loss did not improve from 11.54269
# Epoch 205/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 29.4180 - acc: 0.0000e+00 - val_loss: 36.0903 - val_acc: 0.0000e+00
#
# Epoch 00205: val_loss did not improve from 11.54269
# Epoch 206/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 14.9935 - acc: 0.0000e+00 - val_loss: 18.1414 - val_acc: 0.0000e+00
# Epoch 00206: val_loss did not improve from 11.54269
# Epoch 207/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 13.4416 - acc: 0.0000e+00 - val_loss: 22.5795 - val_acc: 0.0000e+00
#
# Epoch 00207: val_loss did not improve from 11.54269
# Epoch 208/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 35.1728 - acc: 0.0000e+00 - val_loss: 20.0411 - val_acc: 0.0000e+00
#
# Epoch 00208: val_loss did not improve from 11.54269
# Epoch 209/50000
# 1/1 [==============================] - 0s 353ms/step - loss: 17.3244 - acc: 0.0000e+00 - val_loss: 25.3466 - val_acc: 0.0000e+00
#
# Epoch 00209: val_loss did not improve from 11.54269
# Epoch 210/50000
# 1/1 [==============================] - 0s 302ms/step - loss: 12.9838 - acc: 0.0000e+00 - val_loss: 18.0270 - val_acc: 0.0000e+00
#
# Epoch 00210: val_loss did not improve from 11.54269
# Epoch 211/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 12.3147 - acc: 0.0000e+00 - val_loss: 10.8923 - val_acc: 0.0000e+00
#
# Epoch 00211: val_loss improved from 11.54269 to 10.89228, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 212/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 11.8502 - acc: 0.0000e+00 - val_loss: 12.9113 - val_acc: 0.0000e+00
#
# Epoch 00212: val_loss did not improve from 10.89228
# Epoch 213/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 22.6535 - acc: 0.0000e+00 - val_loss: 25.8078 - val_acc: 0.0000e+00
#
# Epoch 00213: val_loss did not improve from 10.89228
# Epoch 214/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 10.5904 - acc: 0.0000e+00 - val_loss: 17.0084 - val_acc: 0.0000e+00
#
# Epoch 00214: val_loss did not improve from 10.89228
# Epoch 215/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 18.9512 - acc: 0.0000e+00 - val_loss: 8.8800 - val_acc: 0.0000e+00
#
# Epoch 00215: val_loss improved from 10.89228 to 8.88002, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 216/50000
# 1/1 [==============================] - 0s 328ms/step - loss: 17.5856 - acc: 0.0000e+00 - val_loss: 23.7620 - val_acc: 0.0000e+00
#
# Epoch 00216: val_loss did not improve from 8.88002
# Epoch 217/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 28.1248 - acc: 0.0000e+00 - val_loss: 17.0529 - val_acc: 0.0000e+00
#
# Epoch 00217: val_loss did not improve from 8.88002
# Epoch 218/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 26.2938 - acc: 0.0000e+00 - val_loss: 14.0927 - val_acc: 0.0000e+00
#
# Epoch 00218: val_loss did not improve from 8.88002
# Epoch 219/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 27.6612 - acc: 0.0000e+00 - val_loss: 8.6111 - val_acc: 0.0000e+00
#
# Epoch 00219: val_loss improved from 8.88002 to 8.61113, saving model to training/unseen_speakers/results/weights_lfw-crop.hdf5
# Epoch 220/50000
# 1/1 [==============================] - 0s 302ms/step - loss: 25.8220 - acc: 0.0000e+00 - val_loss: 16.6751 - val_acc: 0.0000e+00
#
# Epoch 00220: val_loss did not improve from 8.61113
# Epoch 221/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 18.9848 - acc: 0.0000e+00 - val_loss: 15.5528 - val_acc: 0.0000e+00
#
# Epoch 00221: val_loss did not improve from 8.61113
# Epoch 222/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 26.6478 - acc: 0.0000e+00 - val_loss: 34.5926 - val_acc: 0.0000e+00
#
# Epoch 00222: val_loss did not improve from 8.61113
# Epoch 223/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 24.2102 - acc: 0.0000e+00 - val_loss: 16.1252 - val_acc: 0.0000e+00
#
# Epoch 00223: val_loss did not improve from 8.61113
# Epoch 224/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 33.0033 - acc: 0.0000e+00 - val_loss: 16.6371 - val_acc: 0.0000e+00
#
# Epoch 00224: val_loss did not improve from 8.61113
# Epoch 225/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 20.7761 - acc: 0.0000e+00 - val_loss: 32.4831 - val_acc: 0.0000e+00
#
# Epoch 00225: val_loss did not improve from 8.61113
# Epoch 226/50000
# 1/1 [==============================] - 0s 321ms/step - loss: 26.1249 - acc: 0.0000e+00 - val_loss: 13.8825 - val_acc: 0.0000e+00
#
# Epoch 00226: val_loss did not improve from 8.61113
# Epoch 227/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 24.6369 - acc: 0.0000e+00 - val_loss: 22.1534 - val_acc: 0.0000e+00
#
# Epoch 00227: val_loss did not improve from 8.61113
# Epoch 228/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 19.8397 - acc: 0.0000e+00 - val_loss: 14.1596 - val_acc: 0.0000e+00
#
# Epoch 00228: val_loss did not improve from 8.61113
# Epoch 229/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 23.9498 - acc: 0.0000e+00 - val_loss: 22.5234 - val_acc: 0.0000e+00
#
# Epoch 00229: val_loss did not improve from 8.61113
# Epoch 230/50000
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00116
# 1/1 [==============================] - 0s 308ms/step - loss: 20.5838 - acc: 0.0000e+00 - val_loss: 19.4007 - val_acc: 0.0000e+00
#
# Epoch 00230: val_loss did not improve from 8.61113
# Epoch 231/50000
# 1/1 [==============================] - 0s 333ms/step - loss: 14.9966 - acc: 0.0000e+00 - val_loss: 18.0579 - val_acc: 0.0000e+00
#
# Epoch 00231: val_loss did not improve from 8.61113
# Epoch 232/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 18.4923 - acc: 0.0000e+00 - val_loss: 22.9708 - val_acc: 0.0000e+00
#
# Epoch 00232: val_loss did not improve from 8.61113
# Epoch 233/50000
# 1/1 [==============================] - 0s 330ms/step - loss: 24.3588 - acc: 0.0000e+00 - val_loss: 21.3449 - val_acc: 0.0000e+00
#
# Epoch 00233: val_loss did not improve from 8.61113
# Epoch 234/50000
# 1/1 [==============================] - 0s 395ms/step - loss: 32.8181 - acc: 0.0000e+00 - val_loss: 19.0909 - val_acc: 0.0000e+00
#
# Epoch 00234: val_loss did not improve from 8.61113
# Epoch 235/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 24.0423 - acc: 0.0000e+00 - val_loss: 33.5275 - val_acc: 0.0000e+00
#
# Epoch 00235: val_loss did not improve from 8.61113
# Epoch 236/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 24.4847 - acc: 0.0000e+00 - val_loss: 23.3926 - val_acc: 0.0000e+00
#
# Epoch 00236: val_loss did not improve from 8.61113
# Epoch 237/50000
# 1/1 [==============================] - 0s 328ms/step - loss: 13.5533 - acc: 0.0000e+00 - val_loss: 21.9876 - val_acc: 0.0000e+00
#
# Epoch 00237: val_loss did not improve from 8.61113
# Epoch 238/50000
# 1/1 [==============================] - 0s 328ms/step - loss: 19.1294 - acc: 0.0000e+00 - val_loss: 18.2915 - val_acc: 0.0000e+00
#
# Epoch 00238: val_loss did not improve from 8.61113
# Epoch 239/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 20.1382 - acc: 0.0000e+00 - val_loss: 15.3220 - val_acc: 0.0000e+00
#
# Epoch 00239: val_loss did not improve from 8.61113
# Epoch 240/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 19.0805 - acc: 0.0000e+00 - val_loss: 17.6613 - val_acc: 0.0000e+00
#
# Epoch 00240: val_loss did not improve from 8.61113
# Epoch 241/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 18.7089 - acc: 0.0000e+00 - val_loss: 31.2770 - val_acc: 0.0000e+00
#
# Epoch 00241: val_loss did not improve from 8.61113
# Epoch 242/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 22.5552 - acc: 0.0000e+00 - val_loss: 17.7188 - val_acc: 0.0000e+00
#
# Epoch 00242: val_loss did not improve from 8.61113
# Epoch 243/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 22.1576 - acc: 0.0000e+00 - val_loss: 21.1325 - val_acc: 0.0000e+00
#
# Epoch 00243: val_loss did not improve from 8.61113
# Epoch 244/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 21.5809 - acc: 0.0000e+00 - val_loss: 21.1113 - val_acc: 0.0000e+00
#
# Epoch 00244: val_loss did not improve from 8.61113
# Epoch 245/50000
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
# 1/1 [==============================] - 0s 363ms/step - loss: 31.5544 - acc: 0.0000e+00 - val_loss: 22.6114 - val_acc: 0.0000e+00
#
# Epoch 00245: val_loss did not improve from 8.61113
# Epoch 246/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 18.7091 - acc: 0.0000e+00 - val_loss: 13.6060 - val_acc: 0.0000e+00
# Epoch 00246: val_loss did not improve from 8.61113
# Epoch 247/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 17.2831 - acc: 0.0000e+00 - val_loss: 13.7296 - val_acc: 0.0000e+00
#
# Epoch 00247: val_loss did not improve from 8.61113
# Epoch 248/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 19.2891 - acc: 0.0000e+00 - val_loss: 18.2289 - val_acc: 0.0000e+00
#
# Epoch 00248: val_loss did not improve from 8.61113
# Epoch 249/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 18.8049 - acc: 0.0000e+00 - val_loss: 17.2423 - val_acc: 0.0000e+00
#
# Epoch 00249: val_loss did not improve from 8.61113
# Epoch 250/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 23.2188 - acc: 0.0000e+00 - val_loss: 13.8213 - val_acc: 0.0000e+00
#
# Epoch 00250: val_loss did not improve from 8.61113
# Epoch 251/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 19.6522 - acc: 0.0000e+00 - val_loss: 13.9972 - val_acc: 0.0000e+00
#
# Epoch 00251: val_loss did not improve from 8.61113
# Epoch 252/50000
# 1/1 [==============================] - 0s 329ms/step - loss: 16.9423 - acc: 0.0000e+00 - val_loss: 19.6912 - val_acc: 0.0000e+00
#
# Epoch 00252: val_loss did not improve from 8.61113
# Epoch 253/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 17.9031 - acc: 0.0000e+00 - val_loss: 20.0412 - val_acc: 0.0000e+00
#
# Epoch 00253: val_loss did not improve from 8.61113
# Epoch 254/50000
# 1/1 [==============================] - 0s 340ms/step - loss: 17.5088 - acc: 0.0000e+00 - val_loss: 35.8403 - val_acc: 0.0000e+00
#
# Epoch 00254: val_loss did not improve from 8.61113
# Epoch 255/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 24.9782 - acc: 0.0000e+00 - val_loss: 16.1710 - val_acc: 0.0000e+00
#
# Epoch 00255: val_loss did not improve from 8.61113
# Epoch 256/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 22.6968 - acc: 0.0000e+00 - val_loss: 27.5203 - val_acc: 0.0000e+00
#
# Epoch 00256: val_loss did not improve from 8.61113
# Epoch 257/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 29.6284 - acc: 0.0000e+00 - val_loss: 20.5659 - val_acc: 0.0000e+00
#
# Epoch 00257: val_loss did not improve from 8.61113
# Epoch 258/50000
# 1/1 [==============================] - 0s 328ms/step - loss: 20.5259 - acc: 0.0000e+00 - val_loss: 20.4446 - val_acc: 0.0000e+00
#
# Epoch 00258: val_loss did not improve from 8.61113
# Epoch 259/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 33.6185 - acc: 0.0000e+00 - val_loss: 21.0404 - val_acc: 0.0000e+00
#
# Epoch 00259: val_loss did not improve from 8.61113
# Epoch 260/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 23.4327 - acc: 0.0000e+00 - val_loss: 24.3726 - val_acc: 0.0000e+00
#
# Epoch 00260: val_loss did not improve from 8.61113
# Epoch 261/50000
# 1/1 [==============================] - 0s 303ms/step - loss: 23.7705 - acc: 0.0000e+00 - val_loss: 18.6886 - val_acc: 0.0000e+00
#
# Epoch 00261: val_loss did not improve from 8.61113
# Epoch 262/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 16.7211 - acc: 0.0000e+00 - val_loss: 15.9744 - val_acc: 0.0000e+00
#
# Epoch 00262: val_loss did not improve from 8.61113
# Epoch 263/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 19.7065 - acc: 0.0000e+00 - val_loss: 22.2980 - val_acc: 0.0000e+00
#
# Epoch 00263: val_loss did not improve from 8.61113
# Epoch 264/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 25.2465 - acc: 0.0000e+00 - val_loss: 15.0278 - val_acc: 0.0000e+00
#
# Epoch 00264: val_loss did not improve from 8.61113
# Epoch 265/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 18.7827 - acc: 0.0000e+00 - val_loss: 20.8972 - val_acc: 0.0000e+00
#
# Epoch 00265: val_loss did not improve from 8.61113
# Epoch 266/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 16.7925 - acc: 0.0000e+00 - val_loss: 16.5600 - val_acc: 0.0000e+00
#
# Epoch 00266: val_loss did not improve from 8.61113
# Epoch 267/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 28.6130 - acc: 0.0000e+00 - val_loss: 14.1457 - val_acc: 0.0000e+00
#
# Epoch 00267: val_loss did not improve from 8.61113
# Epoch 268/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 16.5738 - acc: 0.0000e+00 - val_loss: 31.3232 - val_acc: 0.0000e+00
#
# Epoch 00268: val_loss did not improve from 8.61113
# Epoch 269/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 26.8895 - acc: 0.0000e+00 - val_loss: 18.1045 - val_acc: 0.0000e+00
#
# Epoch 00269: val_loss did not improve from 8.61113
# Epoch 270/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 29.5707 - acc: 0.0000e+00 - val_loss: 23.5098 - val_acc: 0.0000e+00
#
# Epoch 00270: val_loss did not improve from 8.61113
# Epoch 271/50000
# 1/1 [==============================] - 0s 331ms/step - loss: 21.3473 - acc: 0.0000e+00 - val_loss: 23.4745 - val_acc: 0.0000e+00
#
# Epoch 00271: val_loss did not improve from 8.61113
# Epoch 272/50000
# 1/1 [==============================] - 0s 387ms/step - loss: 15.7206 - acc: 0.0000e+00 - val_loss: 20.7878 - val_acc: 0.0000e+00
#
# Epoch 00272: val_loss did not improve from 8.61113
# Epoch 273/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 26.0917 - acc: 0.0000e+00 - val_loss: 23.5290 - val_acc: 0.0000e+00
#
# Epoch 00273: val_loss did not improve from 8.61113
# Epoch 274/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 20.7809 - acc: 0.0000e+00 - val_loss: 14.6183 - val_acc: 0.0000e+00
#
# Epoch 00274: val_loss did not improve from 8.61113
# Epoch 275/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 23.1286 - acc: 0.0000e+00 - val_loss: 20.1021 - val_acc: 0.0000e+00
#
# Epoch 00275: val_loss did not improve from 8.61113
# Epoch 276/50000
# 1/1 [==============================] - 0s 303ms/step - loss: 28.5230 - acc: 0.0000e+00 - val_loss: 23.9881 - val_acc: 0.0000e+00
#
# Epoch 00276: val_loss did not improve from 8.61113
# Epoch 277/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 15.6560 - acc: 0.0000e+00 - val_loss: 16.9836 - val_acc: 0.0000e+00
#
# Epoch 00277: val_loss did not improve from 8.61113
# Epoch 278/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 24.7846 - acc: 0.0000e+00 - val_loss: 29.0036 - val_acc: 0.0000e+00
#
# Epoch 00278: val_loss did not improve from 8.61113
# Epoch 279/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 17.7790 - acc: 0.0000e+00 - val_loss: 24.0004 - val_acc: 0.0000e+00
#
# Epoch 00279: val_loss did not improve from 8.61113
# Epoch 280/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 15.9922 - acc: 0.0000e+00 - val_loss: 23.6592 - val_acc: 0.0000e+00
#
# Epoch 00280: val_loss did not improve from 8.61113
# Epoch 281/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 24.1498 - acc: 0.0000e+00 - val_loss: 14.1513 - val_acc: 0.0000e+00
#
# Epoch 00281: val_loss did not improve from 8.61113
# Epoch 282/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 22.4664 - acc: 0.0000e+00 - val_loss: 18.6697 - val_acc: 0.0000e+00
#
# Epoch 00282: val_loss did not improve from 8.61113
# Epoch 283/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 18.9474 - acc: 0.0000e+00 - val_loss: 22.7148 - val_acc: 0.0000e+00
#
# Epoch 00283: val_loss did not improve from 8.61113
# Epoch 284/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 15.4139 - acc: 0.0000e+00 - val_loss: 29.2912 - val_acc: 0.0000e+00
#
# Epoch 00284: val_loss did not improve from 8.61113
# Epoch 285/50000
# 1/1 [==============================] - 0s 327ms/step - loss: 25.3409 - acc: 0.0000e+00 - val_loss: 17.4691 - val_acc: 0.0000e+00
#
# Epoch 00285: val_loss did not improve from 8.61113
# Epoch 286/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 25.1606 - acc: 0.0000e+00 - val_loss: 20.8445 - val_acc: 0.0000e+00
#
# Epoch 00286: val_loss did not improve from 8.61113
# Epoch 287/50000
# 1/1 [==============================] - 0s 333ms/step - loss: 14.2462 - acc: 0.0000e+00 - val_loss: 12.8468 - val_acc: 0.0000e+00
#
# Epoch 00287: val_loss did not improve from 8.61113
# Epoch 288/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 14.0650 - acc: 0.0000e+00 - val_loss: 20.7428 - val_acc: 0.0000e+00
# Epoch 00288: val_loss did not improve from 8.61113
# Epoch 289/50000
# 1/1 [==============================] - 0s 317ms/step - loss: 13.4197 - acc: 0.0000e+00 - val_loss: 26.4883 - val_acc: 0.0000e+00
#
# Epoch 00289: val_loss did not improve from 8.61113
# Epoch 290/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 24.0853 - acc: 0.0000e+00 - val_loss: 17.3308 - val_acc: 0.0000e+00
#
# Epoch 00290: val_loss did not improve from 8.61113
# Epoch 291/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 12.1551 - acc: 0.0000e+00 - val_loss: 23.4353 - val_acc: 0.0000e+00
#
# Epoch 00291: val_loss did not improve from 8.61113
# Epoch 292/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 20.6652 - acc: 0.0000e+00 - val_loss: 24.3107 - val_acc: 0.0000e+00
#
# Epoch 00292: val_loss did not improve from 8.61113
# Epoch 293/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 17.1080 - acc: 0.0000e+00 - val_loss: 14.8072 - val_acc: 0.0000e+00
#
# Epoch 00293: val_loss did not improve from 8.61113
# Epoch 294/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 27.9141 - acc: 0.0000e+00 - val_loss: 15.4060 - val_acc: 0.0000e+00
#
# Epoch 00294: val_loss did not improve from 8.61113
# Epoch 295/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 17.3104 - acc: 0.0000e+00 - val_loss: 20.5769 - val_acc: 0.0000e+00
#
# Epoch 00295: val_loss did not improve from 8.61113
# Epoch 296/50000
# 1/1 [==============================] - 0s 315ms/step - loss: 20.6331 - acc: 0.0000e+00 - val_loss: 23.7980 - val_acc: 0.0000e+00
#
# Epoch 00296: val_loss did not improve from 8.61113
# Epoch 297/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 23.7383 - acc: 0.0000e+00 - val_loss: 9.5236 - val_acc: 0.0000e+00
#
# Epoch 00297: val_loss did not improve from 8.61113
# Epoch 298/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 15.2148 - acc: 0.0000e+00 - val_loss: 16.5704 - val_acc: 0.0000e+00
#
# Epoch 00298: val_loss did not improve from 8.61113
# Epoch 299/50000
# 1/1 [==============================] - 0s 331ms/step - loss: 16.7941 - acc: 0.0000e+00 - val_loss: 26.2350 - val_acc: 0.0000e+00
#
# Epoch 00299: val_loss did not improve from 8.61113
# Epoch 300/50000
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
# 1/1 [==============================] - 0s 370ms/step - loss: 22.3858 - acc: 0.0000e+00 - val_loss: 23.4649 - val_acc: 0.0000e+00
#
# Epoch 00300: val_loss did not improve from 8.61113
# Epoch 301/50000
# 1/1 [==============================] - 0s 303ms/step - loss: 17.4553 - acc: 0.0000e+00 - val_loss: 18.7387 - val_acc: 0.0000e+00
#
# Epoch 00301: val_loss did not improve from 8.61113
# Epoch 302/50000
# 1/1 [==============================] - 0s 327ms/step - loss: 19.3192 - acc: 0.0000e+00 - val_loss: 18.0957 - val_acc: 0.0000e+00
#
# Epoch 00302: val_loss did not improve from 8.61113
# Epoch 303/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 17.8875 - acc: 0.0000e+00 - val_loss: 18.2879 - val_acc: 0.0000e+00
#
# Epoch 00303: val_loss did not improve from 8.61113
# Epoch 304/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 31.9682 - acc: 0.0000e+00 - val_loss: 24.1351 - val_acc: 0.0000e+00
#
# Epoch 00304: val_loss did not improve from 8.61113
# Epoch 305/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 18.5652 - acc: 0.0000e+00 - val_loss: 22.1964 - val_acc: 0.0000e+00
#
# Epoch 00305: val_loss did not improve from 8.61113
# Epoch 306/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 16.3765 - acc: 0.0000e+00 - val_loss: 30.4700 - val_acc: 0.0000e+00
#
# Epoch 00306: val_loss did not improve from 8.61113
# Epoch 307/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 13.1808 - acc: 0.0000e+00 - val_loss: 36.2512 - val_acc: 0.0000e+00
#
# Epoch 00307: val_loss did not improve from 8.61113
# Epoch 308/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 25.9508 - acc: 0.0000e+00 - val_loss: 23.2213 - val_acc: 0.0000e+00
#
# Epoch 00308: val_loss did not improve from 8.61113
# Epoch 309/50000
# 1/1 [==============================] - 0s 388ms/step - loss: 11.6512 - acc: 0.0000e+00 - val_loss: 12.3227 - val_acc: 0.0000e+00
#
# Epoch 00309: val_loss did not improve from 8.61113
# Epoch 310/50000
# 1/1 [==============================] - 0s 359ms/step - loss: 11.6649 - acc: 0.0000e+00 - val_loss: 24.3139 - val_acc: 0.0000e+00
#
# Epoch 00310: val_loss did not improve from 8.61113
# Epoch 311/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 19.7525 - acc: 0.0000e+00 - val_loss: 12.1883 - val_acc: 0.0000e+00
#
# Epoch 00311: val_loss did not improve from 8.61113
# Epoch 312/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 24.2061 - acc: 0.0000e+00 - val_loss: 24.7813 - val_acc: 0.0000e+00
#
# Epoch 00312: val_loss did not improve from 8.61113
# Epoch 313/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 17.2132 - acc: 0.0000e+00 - val_loss: 15.2943 - val_acc: 0.0000e+00
#
# Epoch 00313: val_loss did not improve from 8.61113
# Epoch 314/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 23.9983 - acc: 0.0000e+00 - val_loss: 11.7881 - val_acc: 0.0000e+00
#
# Epoch 00314: val_loss did not improve from 8.61113
# Epoch 315/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 24.6246 - acc: 0.0000e+00 - val_loss: 23.7837 - val_acc: 0.0000e+00
#
# Epoch 00315: val_loss did not improve from 8.61113
# Epoch 316/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 24.5656 - acc: 0.0000e+00 - val_loss: 17.0800 - val_acc: 0.0000e+00
#
# Epoch 00316: val_loss did not improve from 8.61113
# Epoch 317/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 24.5075 - acc: 0.0000e+00 - val_loss: 18.3294 - val_acc: 0.0000e+00
#
# Epoch 00317: val_loss did not improve from 8.61113
# Epoch 318/50000
# 1/1 [==============================] - 0s 358ms/step - loss: 30.4789 - acc: 0.0000e+00 - val_loss: 16.6842 - val_acc: 0.0000e+00
#
# Epoch 00318: val_loss did not improve from 8.61113
# Epoch 319/50000
# 1/1 [==============================] - 0s 301ms/step - loss: 16.4574 - acc: 0.0000e+00 - val_loss: 15.3198 - val_acc: 0.0000e+00
#
# Epoch 00319: val_loss did not improve from 8.61113
# Epoch 320/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 16.4988 - acc: 0.0000e+00 - val_loss: 11.9266 - val_acc: 0.0000e+00
#
# Epoch 00320: val_loss did not improve from 8.61113
# Epoch 321/50000
# 1/1 [==============================] - 0s 315ms/step - loss: 13.6411 - acc: 0.0000e+00 - val_loss: 15.1920 - val_acc: 0.0000e+00
#
# Epoch 00321: val_loss did not improve from 8.61113
# Epoch 322/50000
# ...
# Epoch 01671: val_loss did not improve from 8.61113
# Epoch 1672/50000
# 1/1 [==============================] - 0s 323ms/step - loss: 20.2928 - acc: 0.0000e+00 - val_loss: 15.1178 - val_acc: 0.0000e+00
#
# Epoch 01672: val_loss did not improve from 8.61113
# Epoch 1673/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 16.3377 - acc: 0.0000e+00 - val_loss: 15.8187 - val_acc: 0.0000e+00
#
# Epoch 01673: val_loss did not improve from 8.61113
# Epoch 1674/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 14.0070 - acc: 0.0000e+00 - val_loss: 15.3707 - val_acc: 0.0000e+00
#
# Epoch 01674: val_loss did not improve from 8.61113
# Epoch 1675/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 17.3510 - acc: 0.0000e+00 - val_loss: 14.9162 - val_acc: 0.0000e+00
#
# Epoch 01675: val_loss did not improve from 8.61113
# Epoch 1676/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 17.2395 - acc: 0.0000e+00 - val_loss: 19.4322 - val_acc: 0.0000e+00
#
# Epoch 01676: val_loss did not improve from 8.61113
# Epoch 1677/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 17.1794 - acc: 0.0000e+00 - val_loss: 15.9194 - val_acc: 0.0000e+00
#
# Epoch 01677: val_loss did not improve from 8.61113
# Epoch 1678/50000
# 1/1 [==============================] - 0s 317ms/step - loss: 12.1439 - acc: 0.0000e+00 - val_loss: 15.0833 - val_acc: 0.0000e+00
#
# Epoch 01678: val_loss did not improve from 8.61113
# Epoch 1679/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 18.4096 - acc: 0.0000e+00 - val_loss: 13.1343 - val_acc: 0.0000e+00
#
# Epoch 01679: val_loss did not improve from 8.61113
# Epoch 1680/50000
# 1/1 [==============================] - 0s 323ms/step - loss: 13.3934 - acc: 0.0000e+00 - val_loss: 28.7318 - val_acc: 0.0000e+00
#
# Epoch 01680: val_loss did not improve from 8.61113
# Epoch 1681/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 13.1163 - acc: 0.0000e+00 - val_loss: 18.4752 - val_acc: 0.0000e+00
#
# Epoch 01681: val_loss did not improve from 8.61113
# Epoch 1682/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 14.2825 - acc: 0.0000e+00 - val_loss: 11.7740 - val_acc: 0.0000e+00
#
# Epoch 01682: val_loss did not improve from 8.61113
# Epoch 1683/50000
# 1/1 [==============================] - 0s 319ms/step - loss: 15.2297 - acc: 0.0000e+00 - val_loss: 18.1875 - val_acc: 0.0000e+00
#
# Epoch 01683: val_loss did not improve from 8.61113
# Epoch 1684/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 20.0018 - acc: 0.0000e+00 - val_loss: 30.0551 - val_acc: 0.0000e+00
#
# Epoch 01684: val_loss did not improve from 8.61113
# Epoch 1685/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 11.4371 - acc: 0.0000e+00 - val_loss: 30.8992 - val_acc: 0.0000e+00
#
# Epoch 01685: val_loss did not improve from 8.61113
# Epoch 1686/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 17.2750 - acc: 0.0000e+00 - val_loss: 13.5321 - val_acc: 0.0000e+00
#
# Epoch 01686: val_loss did not improve from 8.61113
# Epoch 1687/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 17.3937 - acc: 0.0000e+00 - val_loss: 21.4367 - val_acc: 0.0000e+00
#
# Epoch 01687: val_loss did not improve from 8.61113
# Epoch 1688/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 18.6359 - acc: 0.0000e+00 - val_loss: 16.1190 - val_acc: 0.0000e+00
#
# Epoch 01688: val_loss did not improve from 8.61113
# Epoch 1689/50000
# 1/1 [==============================] - 0s 335ms/step - loss: 10.7380 - acc: 0.0000e+00 - val_loss: 14.8441 - val_acc: 0.0000e+00
#
# Epoch 01689: val_loss did not improve from 8.61113
# Epoch 1690/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 20.4971 - acc: 0.0000e+00 - val_loss: 13.4550 - val_acc: 0.0000e+00
#
# Epoch 01690: val_loss did not improve from 8.61113
# Epoch 1691/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 21.4985 - acc: 0.0000e+00 - val_loss: 15.9633 - val_acc: 0.0000e+00
#
# Epoch 01691: val_loss did not improve from 8.61113
# Epoch 1692/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 15.1338 - acc: 0.0000e+00 - val_loss: 21.7503 - val_acc: 0.0000e+00
#
# Epoch 01692: val_loss did not improve from 8.61113
# Epoch 1693/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 19.4576 - acc: 0.0000e+00 - val_loss: 32.2800 - val_acc: 0.0000e+00
#
# Epoch 01693: val_loss did not improve from 8.61113
# Epoch 1694/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 22.3916 - acc: 0.0000e+00 - val_loss: 18.5195 - val_acc: 0.0000e+00
#
# Epoch 01694: val_loss did not improve from 8.61113
# Epoch 1695/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 20.8892 - acc: 0.0000e+00 - val_loss: 32.0281 - val_acc: 0.0000e+00
#
# Epoch 01695: val_loss did not improve from 8.61113
# Epoch 1696/50000
# 1/1 [==============================] - 0s 321ms/step - loss: 14.9314 - acc: 0.0000e+00 - val_loss: 17.6500 - val_acc: 0.0000e+00
#
# Epoch 01696: val_loss did not improve from 8.61113
# Epoch 1697/50000
# 1/1 [==============================] - 0s 317ms/step - loss: 10.5489 - acc: 0.0000e+00 - val_loss: 16.0484 - val_acc: 0.0000e+00
#
# Epoch 01697: val_loss did not improve from 8.61113
# Epoch 1698/50000
# 1/1 [==============================] - 0s 344ms/step - loss: 31.2099 - acc: 0.0000e+00 - val_loss: 17.8462 - val_acc: 0.0000e+00
#
# Epoch 01698: val_loss did not improve from 8.61113
# Epoch 1699/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 11.5164 - acc: 0.0000e+00 - val_loss: 31.1131 - val_acc: 0.0000e+00
#
# Epoch 01699: val_loss did not improve from 8.61113
# Epoch 1700/50000
# 1/1 [==============================] - 0s 317ms/step - loss: 14.8351 - acc: 0.0000e+00 - val_loss: 14.9731 - val_acc: 0.0000e+00
# Epoch 01700: val_loss did not improve from 8.61113
# Epoch 1701/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 14.4903 - acc: 0.0000e+00 - val_loss: 11.5605 - val_acc: 0.0000e+00
#
# Epoch 01701: val_loss did not improve from 8.61113
# Epoch 1702/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 14.6024 - acc: 0.0000e+00 - val_loss: 14.9147 - val_acc: 0.0000e+00
#
# Epoch 01702: val_loss did not improve from 8.61113
# Epoch 1703/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 11.8232 - acc: 0.0000e+00 - val_loss: 10.3428 - val_acc: 0.0000e+00
#
# Epoch 01703: val_loss did not improve from 8.61113
# Epoch 1704/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 14.1123 - acc: 0.0000e+00 - val_loss: 11.0917 - val_acc: 0.0000e+00
#
# Epoch 01704: val_loss did not improve from 8.61113
# Epoch 1705/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 17.3023 - acc: 0.0000e+00 - val_loss: 14.5056 - val_acc: 0.0000e+00
#
# Epoch 01705: val_loss did not improve from 8.61113
# Epoch 1706/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 14.3535 - acc: 0.0000e+00 - val_loss: 14.1371 - val_acc: 0.0000e+00
#
# Epoch 01706: val_loss did not improve from 8.61113
# Epoch 1707/50000
# 1/1 [==============================] - 0s 342ms/step - loss: 17.3063 - acc: 0.0000e+00 - val_loss: 12.8978 - val_acc: 0.0000e+00
#
# Epoch 01707: val_loss did not improve from 8.61113
# Epoch 1708/50000
# 1/1 [==============================] - 0s 306ms/step - loss: 19.0176 - acc: 0.0000e+00 - val_loss: 12.5527 - val_acc: 0.0000e+00
#
# Epoch 01708: val_loss did not improve from 8.61113
# Epoch 1709/50000
# 1/1 [==============================] - 0s 304ms/step - loss: 30.0933 - acc: 0.0000e+00 - val_loss: 16.7464 - val_acc: 0.0000e+00
#
# Epoch 01709: val_loss did not improve from 8.61113
# Epoch 1710/50000
# 1/1 [==============================] - 0s 301ms/step - loss: 21.8064 - acc: 0.0000e+00 - val_loss: 18.2019 - val_acc: 0.0000e+00
#
# Epoch 01710: val_loss did not improve from 8.61113
# Epoch 1711/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 15.9227 - acc: 0.0000e+00 - val_loss: 10.8071 - val_acc: 0.0000e+00
#
# Epoch 01711: val_loss did not improve from 8.61113
# Epoch 1712/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 16.4278 - acc: 0.0000e+00 - val_loss: 17.7485 - val_acc: 0.0000e+00
#
# Epoch 01712: val_loss did not improve from 8.61113
# Epoch 1713/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 15.6189 - acc: 0.0000e+00 - val_loss: 17.7231 - val_acc: 0.0000e+00
#
# Epoch 01713: val_loss did not improve from 8.61113
# Epoch 1714/50000
# 1/1 [==============================] - 0s 315ms/step - loss: 15.2398 - acc: 0.0000e+00 - val_loss: 13.7134 - val_acc: 0.0000e+00
#
# Epoch 01714: val_loss did not improve from 8.61113
# Epoch 1715/50000
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
# 1/1 [==============================] - 0s 309ms/step - loss: 20.6644 - acc: 0.0000e+00 - val_loss: 11.7291 - val_acc: 0.0000e+00
#
# Epoch 01715: val_loss did not improve from 8.61113
# Epoch 1716/50000
# 1/1 [==============================] - 0s 351ms/step - loss: 20.4010 - acc: 0.0000e+00 - val_loss: 11.9463 - val_acc: 0.0000e+00
#
# Epoch 01716: val_loss did not improve from 8.61113
# Epoch 1717/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 28.0884 - acc: 0.0000e+00 - val_loss: 18.3757 - val_acc: 0.0000e+00
#
# Epoch 01717: val_loss did not improve from 8.61113
# Epoch 1718/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 16.7708 - acc: 0.0000e+00 - val_loss: 18.7203 - val_acc: 0.0000e+00
#
# Epoch 01718: val_loss did not improve from 8.61113
# Epoch 1719/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 19.2869 - acc: 0.0000e+00 - val_loss: 14.6715 - val_acc: 0.0000e+00
#
# Epoch 01719: val_loss did not improve from 8.61113
# Epoch 1720/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 20.1819 - acc: 0.0000e+00 - val_loss: 17.0217 - val_acc: 0.0000e+00
#
# Epoch 01720: val_loss did not improve from 8.61113
# Epoch 1721/50000
# 1/1 [==============================] - 0s 318ms/step - loss: 19.1523 - acc: 0.0000e+00 - val_loss: 20.1746 - val_acc: 0.0000e+00
#
# Epoch 01721: val_loss did not improve from 8.61113
# Epoch 1722/50000
# 1/1 [==============================] - 0s 315ms/step - loss: 16.9718 - acc: 0.0000e+00 - val_loss: 21.2094 - val_acc: 0.0000e+00
#
# Epoch 01722: val_loss did not improve from 8.61113
# Epoch 1723/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 16.6236 - acc: 0.0000e+00 - val_loss: 26.1643 - val_acc: 0.0000e+00
#
# Epoch 01723: val_loss did not improve from 8.61113
# Epoch 1724/50000
# 1/1 [==============================] - 0s 330ms/step - loss: 14.9117 - acc: 0.0000e+00 - val_loss: 15.8785 - val_acc: 0.0000e+00
#
# Epoch 01724: val_loss did not improve from 8.61113
# Epoch 1725/50000
# 1/1 [==============================] - 0s 349ms/step - loss: 13.4270 - acc: 0.0000e+00 - val_loss: 19.1189 - val_acc: 0.0000e+00
#
# Epoch 01725: val_loss did not improve from 8.61113
# Epoch 1726/50000
# 1/1 [==============================] - 0s 320ms/step - loss: 14.8940 - acc: 0.0000e+00 - val_loss: 12.5825 - val_acc: 0.0000e+00
#
# Epoch 01726: val_loss did not improve from 8.61113
# Epoch 1727/50000
# 1/1 [==============================] - 0s 321ms/step - loss: 16.8075 - acc: 0.0000e+00 - val_loss: 14.5460 - val_acc: 0.0000e+00
#
# Epoch 01727: val_loss did not improve from 8.61113
# Epoch 1728/50000
# 1/1 [==============================] - 0s 311ms/step - loss: 16.5873 - acc: 0.0000e+00 - val_loss: 14.3185 - val_acc: 0.0000e+00
#
# Epoch 01728: val_loss did not improve from 8.61113
# Epoch 1729/50000
# 1/1 [==============================] - 0s 327ms/step - loss: 18.6061 - acc: 0.0000e+00 - val_loss: 16.3406 - val_acc: 0.0000e+00
#
# Epoch 01729: val_loss did not improve from 8.61113
# Epoch 1730/50000
# 1/1 [==============================] - 0s 307ms/step - loss: 19.3006 - acc: 0.0000e+00 - val_loss: 12.3812 - val_acc: 0.0000e+00
#
# Epoch 01730: val_loss did not improve from 8.61113
# Epoch 1731/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 11.4574 - acc: 0.0000e+00 - val_loss: 14.5812 - val_acc: 0.0000e+00
#
# Epoch 01731: val_loss did not improve from 8.61113
# Epoch 1732/50000
# 1/1 [==============================] - 0s 312ms/step - loss: 18.1504 - acc: 0.0000e+00 - val_loss: 16.2859 - val_acc: 0.0000e+00
#
# Epoch 01732: val_loss did not improve from 8.61113
# Epoch 1733/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 11.1381 - acc: 0.0000e+00 - val_loss: 10.9879 - val_acc: 0.0000e+00
#
# Epoch 01733: val_loss did not improve from 8.61113
# Epoch 1734/50000
# 1/1 [==============================] - 0s 327ms/step - loss: 14.1186 - acc: 0.0000e+00 - val_loss: 16.5502 - val_acc: 0.0000e+00
#
# Epoch 01734: val_loss did not improve from 8.61113
# Epoch 1735/50000
# 1/1 [==============================] - 0s 308ms/step - loss: 18.1695 - acc: 0.0000e+00 - val_loss: 15.0196 - val_acc: 0.0000e+00
#
# Epoch 01735: val_loss did not improve from 8.61113
# Epoch 1736/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 16.8063 - acc: 0.0000e+00 - val_loss: 14.2181 - val_acc: 0.0000e+00
#
# Epoch 01736: val_loss did not improve from 8.61113
# Epoch 1737/50000
# 1/1 [==============================] - 0s 317ms/step - loss: 18.2285 - acc: 0.0000e+00 - val_loss: 17.1530 - val_acc: 0.0000e+00
#
# Epoch 01737: val_loss did not improve from 8.61113
# Epoch 1738/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 20.9835 - acc: 0.0000e+00 - val_loss: 17.0112 - val_acc: 0.0000e+00
#
# Epoch 01738: val_loss did not improve from 8.61113
# Epoch 1739/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 14.4547 - acc: 0.0000e+00 - val_loss: 21.4498 - val_acc: 0.0000e+00
#
# Epoch 01739: val_loss did not improve from 8.61113
# Epoch 1740/50000
# 1/1 [==============================] - 0s 330ms/step - loss: 9.9127 - acc: 0.0000e+00 - val_loss: 21.9358 - val_acc: 0.0000e+00
#
# Epoch 01740: val_loss did not improve from 8.61113
# Epoch 1741/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 28.4417 - acc: 0.0000e+00 - val_loss: 21.9760 - val_acc: 0.0000e+00
# Epoch 01741: val_loss did not improve from 8.61113
# Epoch 1742/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 15.5323 - acc: 0.0000e+00 - val_loss: 18.1765 - val_acc: 0.0000e+00
#
# Epoch 01742: val_loss did not improve from 8.61113
# Epoch 1743/50000
# 1/1 [==============================] - 0s 305ms/step - loss: 12.5619 - acc: 0.0000e+00 - val_loss: 9.5145 - val_acc: 0.0000e+00
#
# Epoch 01743: val_loss did not improve from 8.61113
# Epoch 1744/50000
# 1/1 [==============================] - 0s 330ms/step - loss: 13.8369 - acc: 0.0000e+00 - val_loss: 18.2277 - val_acc: 0.0000e+00
#
# Epoch 01744: val_loss did not improve from 8.61113
# Epoch 1745/50000
# 1/1 [==============================] - 0s 322ms/step - loss: 19.5099 - acc: 0.0000e+00 - val_loss: 12.6932 - val_acc: 0.0000e+00
#
# Epoch 01745: val_loss did not improve from 8.61113
# Epoch 1746/50000
# 1/1 [==============================] - 0s 310ms/step - loss: 12.1674 - acc: 0.0000e+00 - val_loss: 17.0051 - val_acc: 0.0000e+00
#
# Epoch 01746: val_loss did not improve from 8.61113
# Epoch 1747/50000
# 1/1 [==============================] - 0s 315ms/step - loss: 14.2194 - acc: 0.0000e+00 - val_loss: 20.1406 - val_acc: 0.0000e+00
#
# Epoch 01747: val_loss did not improve from 8.61113
# Epoch 1748/50000
# 1/1 [==============================] - 0s 314ms/step - loss: 16.4639 - acc: 0.0000e+00 - val_loss: 12.3707 - val_acc: 0.0000e+00
#
# Epoch 01748: val_loss did not improve from 8.61113
# Epoch 1749/50000
# 1/1 [==============================] - 0s 309ms/step - loss: 24.3088 - acc: 0.0000e+00 - val_loss: 16.4607 - val_acc: 0.0000e+00
#
# Epoch 01749: val_loss did not improve from 8.61113
# Epoch 1750/50000
# 1/1 [==============================] - 0s 316ms/step - loss: 24.0259 - acc: 0.0000e+00 - val_loss: 12.6051 - val_acc: 0.0000e+00
#
# Epoch 01750: val_loss did not improve from 8.61113
# Epoch 1751/50000
# 1/1 [==============================] - 0s 313ms/step - loss: 14.0862 - acc: 0.0000e+00 - val_loss: 12.5177 - val_acc: 0.0000e+00
#
# Epoch 01751: val_loss did not improve from 8.61113
# Epoch 1752/50000

# %%
# g=datagen(data_partition='test', batch_size=1)
# x,y = next(g)

# %%
# used_words

# %%
# x['the_input'][0].shape, x['source_str'], x['the_labels']

# %%
# # im = batch_frames[1][25]
# import matplotlib.pyplot as plt
# %matplotlib inline
# # generator = datagen(min_row_number=0,max_row_number=200000, batch_size= 6)
# # X,Y = next(generator)
# X = x['the_input'][0]
# # print(X.shape, Y.shape)
# def plot_data(x,ax):
# #     x = x.reshape((size,size))
#     ax.imshow(x, cmap='gray')
# #     if y is not None:
# #         ax.scatter(y[0::2] , y[1::2] , marker='x', s=10)
# fig = plt.figure(figsize=(30,30))
# fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
# for i in range(30):
#     ax = fig.add_subplot(1, 30, i + 1, xticks=[], yticks=[])
#     plot_data(X[i], ax)

# %%
# # import io
# # import base64
# # from IPython.display import HTML

# # video = io.open('evaluation/samples/test.mp4', 'r+b').read()
# # encoded = base64.b64encode(video)
# # HTML(data='''<video alt="test" controls>
# #                 <source src="data:video/mp4;base64,{0}" type="video/mp4" />
# #              </video>'''.format(encoded.decode('ascii')))
# im = cv2.imread('training/unseen_speakers/test_pic.jpg')
# ims = get_frames_mouth(detector, predictor, [im])
# plt.imshow(ims[0][...,::-1])

# %%
# # np.max([len(word) for word in words])
# type(np.array([1,2]))

# %%
# lipnet.predict(np.array([X]))

# %%
# m = []
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append([[1,1],[1,1],[1,1]])
# m.append(1)
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([1,1,1])
# # m.append([[1],[1],[1]])
# np.array(m).shape
t = {1,2,3,4,5}
t.add(5)
t.add(6)

# %%
t
