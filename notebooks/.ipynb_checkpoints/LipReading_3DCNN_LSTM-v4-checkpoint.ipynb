# %%
import tensorflow as tf
from keras.models import model_from_json
import os
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import imageio
from matplotlib import pyplot as plt
import warnings
import cv2
import pandas as pd
from mtcnn.mtcnn import MTCNN
import keras.backend as K
from keras.layers import MaxPooling3D, SpatialDropout3D, Activation, Input, Dense, Conv3D, MaxPooling2D, UpSampling2D,Lambda, TimeDistributed,Flatten, BatchNormalization
from keras.models import Model
from keras import backend as K
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
warnings.filterwarnings("ignore")
from keras.callbacks import TensorBoard, CSVLogger, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# words = [
#     'BETWEEN'
# ,'OPPOSITION'
# ,'EVERYBODY'
# ,'GOVERNMENT'
# ,'THEMSELVES'
# ,'ABSOLUTELY'
# ,'SEVERAL'
# ,'WESTMINSTER'
# ,'CONFERENCE'
# ,'AFTERNOON'
# ,'AGREEMENT'
# ,'REFERENDUM'
# ,'FINANCIAL'
# ,'TEMPERATURES'
# ,'EXPECTED'
# ,'IMMIGRATION'
# ,'INDEPENDENT'
# ,'SIGNIFICANT'
# ,'CONSERVATIVE'
# ,'EMERGENCY'
# ,'PARLIAMENT'
# ]
# # df = pd.DataFrame()
# # df['words']=sorted(words)
# # df['id']=list(range(len(words)))
# # df.to_csv('words_v2.csv')

# %%
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

# %%
frames_count = 30
# words_folder = 'training/unseen_speakers/TARGET/datasets/lipread_mp4'
words = pd.read_csv('words.csv')['words']
max_len = 12 #np.max([len(word) for word in words])
train_path = "training/unseen_speakers/TARGET/datasets/lipread_mp4"
def datagen(train_path="", data_partition = 'train', batch_size = 16):
    while True:
        counter = 0
        
        X_data = []#np.zeros((batch_size,))
        Y_data = []
        input_length = []
        label_length = []
        source_str = []
        word_id = []
        while counter<batch_size:
#             print(counter)
            word_idx = np.random.randint(len(words))
#             print('data part:', data_partition, ', word index', word_idx)
            
            train_folder = train_path+'/{0}/{1}/'.format(words[word_idx],data_partition)
        #         print(train_folder)
            files = os.listdir(train_folder)
        #         print(files)
            paths = list(set([x.split('.')[0] for x in files]))
        
            idx = np.random.randint(len(paths))
            path = os.path.join(train_folder,paths[idx])
#             print(path)
            frames = []
            for img_name in sorted(os.listdir(path)):
                img = cv2.imread(os.path.join(path,img_name))
                frames.append(img)
            frames = np.array(frames)
#             print(frames.shape, path)
            if len(frames.shape)==4:
                frames = np.rollaxis(frames,2, start=1)
    #             print(path)
    #             print(frames.shape)
    #             print('---------')
                if 'numpy.ndarray' in str(type(frames)) \
                        and len(np.shape(frames))==4 \
                        and np.shape(frames)[1] == 100 \
                        and np.shape(frames)[2] == 50:
#                     print(frames.shape, path)
                    if len(frames)<30:
                        diff = 30-len(frames)
            #             print(fr[-1].shape)
                        for i in range(diff):
                            frames = np.insert(arr = frames,values = frames[-1], obj=[-1], axis = 0)
                    X_data.append(frames)
                    ####
                    Y_data.append([ord(c) - 65 for c in words[word_idx]]+[-1]*(max_len-len(words[word_idx])))
                    input_length.append(frames_count)
                    label_length.append(len(words[word_idx]))
                    source_str.append(words[word_idx])
                    word_id.append(word_idx)
                    counter+=1
#                     print(counter)
                else:
                    continue
            else:
                print('error:', frames.shape, path)
                continue

        X_data = np.array(X_data).astype(np.float32) / 255 
        Y_data = np.array(Y_data)
        input_length = np.array(input_length)
        label_length = np.array(label_length)
        source_str = np.array(source_str)
        
        inputs = {'the_input': X_data,
                  'the_labels': Y_data,
                  'input_length': input_length,
                  'label_length': label_length,
                  'source_str': source_str  # used for visualization only
                  }
        ctc_outpts = np.zeros([batch_size])
        classes = to_categorical(y=word_id,num_classes=len(words))   
        
#         print('the_input:', inputs['the_input'].shape)
#         print('the_labels:', inputs['the_labels'].shape)
#         print('input_length:', inputs['input_length'].shape)
#         print('label_length:', inputs['label_length'].shape)
#         print('source_str:', inputs['source_str'].shape)
#         print('batch_frames_shape',X_data.shape, data_partition)

        yield inputs, [classes,ctc_outpts]

# %%
def _ctc_lambda_func(args):
    labels, y_pred, input_length, label_length = args
    y_pred = y_pred[:, :, :]
    return K.tf.keras.backend.ctc_batch_cost(labels, y_pred, input_length, label_length)
with open('LipReading_model.json') as f:
    loadedmodel = f.read()
lm = model_from_json(loadedmodel)
_max3 = lm.get_layer('max3').output
_labels = lm.get_layer('the_labels').output
_y_pred = lm.get_layer('softmax').output
_input_length = lm.get_layer('input_length').output
_label_length = lm.get_layer('label_length').output
# td = TimeDistributed(Dense(32))(_y_pred)
# fl = Conv3D(kernel_size=(1,1,1),filters=128)(_max3)
conv = Conv3D(128, (2, 2, 2), strides=(1, 2, 2), kernel_initializer='he_normal', name='e_conv', padding='same')(_max3)
batch = BatchNormalization(name='e_batch')(conv)
actv = Activation('relu', name='e_actv')(batch)
drop = SpatialDropout3D(0.5)(actv)
_maxp = MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), name='e_max')(drop)
fl = Flatten()(_maxp)
fl = Dense(2048, activation='relu')(fl)
fl = Dense(1024, activation='relu')(fl)
classification_output=Dense(len(words),activation='softmax', name='classification')(fl)
ctc_loss = Lambda(_ctc_lambda_func, output_shape=(1,), name='ctc')([_labels,_y_pred,_input_length,_label_length])
model = Model(inputs=lm.input, outputs=[classification_output,ctc_loss])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_input (InputLayer)          (None, 30, 100, 50,  0
# __________________________________________________________________________________________________
# zero1 (ZeroPadding3D)           (None, 32, 104, 54,  0           the_input[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv3D)                  (None, 30, 50, 25, 3 7232        zero1[0][0]
# __________________________________________________________________________________________________
# batc1 (BatchNormalization)      (None, 30, 50, 25, 3 128         conv1[0][0]
# __________________________________________________________________________________________________
# actv1 (Activation)              (None, 30, 50, 25, 3 0           batc1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_19 (SpatialDr (None, 30, 50, 25, 3 0           actv1[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling3D)             (None, 30, 25, 12, 3 0           spatial_dropout3d_19[0][0]
# __________________________________________________________________________________________________
# zero2 (ZeroPadding3D)           (None, 32, 29, 16, 3 0           max1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv3D)                  (None, 30, 25, 12, 6 153664      zero2[0][0]
# __________________________________________________________________________________________________
# batc2 (BatchNormalization)      (None, 30, 25, 12, 6 256         conv2[0][0]
# __________________________________________________________________________________________________
# actv2 (Activation)              (None, 30, 25, 12, 6 0           batc2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_20 (SpatialDr (None, 30, 25, 12, 6 0           actv2[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling3D)             (None, 30, 12, 6, 64 0           spatial_dropout3d_20[0][0]
# __________________________________________________________________________________________________
# zero3 (ZeroPadding3D)           (None, 32, 14, 8, 64 0           max2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv3D)                  (None, 30, 12, 6, 96 165984      zero3[0][0]
# __________________________________________________________________________________________________
# batc3 (BatchNormalization)      (None, 30, 12, 6, 96 384         conv3[0][0]
# __________________________________________________________________________________________________
# actv3 (Activation)              (None, 30, 12, 6, 96 0           batc3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_21 (SpatialDr (None, 30, 12, 6, 96 0           actv3[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling3D)             (None, 30, 6, 3, 96) 0           spatial_dropout3d_21[0][0]
# __________________________________________________________________________________________________
# e_conv (Conv3D)                 (None, 30, 3, 2, 128 98432       max3[0][0]
# __________________________________________________________________________________________________
# e_batch (BatchNormalization)    (None, 30, 3, 2, 128 512         e_conv[0][0]
# __________________________________________________________________________________________________
# e_actv (Activation)             (None, 30, 3, 2, 128 0           e_batch[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_1 (SpatialDro (None, 30, 3, 2, 128 0           e_actv[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 30, 1728)     0           max3[0][0]
# __________________________________________________________________________________________________
# e_max (MaxPooling3D)            (None, 30, 1, 1, 128 0           spatial_dropout3d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_13 (Bidirectional (None, 30, 512)      3048960     time_distributed_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3840)         0           e_max[0][0]
# __________________________________________________________________________________________________
# bidirectional_14 (Bidirectional (None, 30, 512)      1181184     bidirectional_13[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         7866368     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 30, 28)       14364       bidirectional_14[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         2098176     dense_1[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 12)           0
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 30, 28)       0           dense1[0][0]
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# classification (Dense)          (None, 20)           20500       dense_2[0][0]
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           the_labels[0][0]
#                                                                  softmax[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 14,656,144
# Trainable params: 14,655,504
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
SVG(model_to_dot(model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
# word_idx = np.random.randint(len(words))
# #             print('data part:', data_partition, ', word index', word_idx)

# train_folder = 'training/unseen_speakers/lrw_cropped/{0}/{1}/'.format(words[word_idx],'train')
# #         print(train_folder)

# files = os.listdir(train_folder)

# paths = list(set([x.split('.')[0] for x in files]))
# idx = np.random.randint(len(paths))
# path = os.path.join(train_folder,paths[idx])
# path = 'training/unseen_speakers/lrw_cropped/FINANCIAL/train/FINANCIAL_00001/'
# print(path)
# frames = []
# for img_name in sorted(os.listdir(path)):
#     img = cv2.imread(os.path.join(path,img_name))
#     frames.append(img)
# frames = np.array(frames)
# frames.shape

# %%
g_tr=datagen(train_path=train_path, data_partition='train',batch_size=64)
g_val=datagen(train_path=train_path, data_partition='test',batch_size=64)

# %%
x,y=next(g_tr)
display(x['the_input'].shape,x['the_input'].min(),x['the_input'].max(),x['the_labels'],x['input_length'],x['label_length'],x['source_str'])
np.argmax(y[0],axis=1)
# Out:
# (64, 30, 100, 50, 3)
# 0.0
# 1.0
# array([[ 0,  5,  5,  0,  8, 17, 18, -1, -1, -1, -1, -1],
#        [14, 15, 15, 14, 18,  8, 19,  8, 14, 13, -1, -1],
#        [17,  8,  6,  7, 19, 18, -1, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 17, 24, 14, 13,  4, -1, -1, -1, -1],
#        [15, 17,  8,  2,  4, 18, -1, -1, -1, -1, -1, -1],
#        [ 0, 20, 19,  7, 14, 17,  8, 19,  8,  4, 18, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [18, 20, 13, 18,  7,  8, 13,  4, -1, -1, -1, -1],
#        [ 0,  1, 18, 14, 11, 20, 19,  4, 11, 24, -1, -1],
#        [22,  8, 13,  3, 18, -1, -1, -1, -1, -1, -1, -1],
#        [18,  4, 21,  4, 17,  0, 11, -1, -1, -1, -1, -1],
#        [22,  8, 13,  3, 18, -1, -1, -1, -1, -1, -1, -1],
#        [18,  4, 17,  8, 14, 20, 18, -1, -1, -1, -1, -1],
#        [17,  8,  6,  7, 19, 18, -1, -1, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 13, 19, 18, -1, -1, -1, -1, -1, -1],
#        [15, 17,  8,  2,  4, 18, -1, -1, -1, -1, -1, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [19,  0, 11, 10,  8, 13,  6, -1, -1, -1, -1, -1],
#        [ 0,  5, 19,  4, 17, 13, 14, 14, 13, -1, -1, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [ 4, 21,  4, 17, 24, 14, 13,  4, -1, -1, -1, -1],
#        [ 0,  5, 19,  4, 17, 13, 14, 14, 13, -1, -1, -1],
#        [19,  0, 11, 10,  8, 13,  6, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 13, 19, 18, -1, -1, -1, -1, -1, -1],
#        [ 0,  1, 18, 14, 11, 20, 19,  4, 11, 24, -1, -1],
#        [ 4, 21,  4, 13, 19, 18, -1, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 13, 19, 18, -1, -1, -1, -1, -1, -1],
#        [12,  4,  4, 19,  8, 13,  6, -1, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [ 4, 21,  4, 17, 24,  1, 14,  3, 24, -1, -1, -1],
#        [18, 20, 13, 18,  7,  8, 13,  4, -1, -1, -1, -1],
#        [ 0, 20, 19,  7, 14, 17,  8, 19,  8,  4, 18, -1],
#        [18,  4, 21,  4, 17,  0, 11, -1, -1, -1, -1, -1],
#        [18,  4, 21,  4, 17,  0, 11, -1, -1, -1, -1, -1],
#        [19,  0, 11, 10,  8, 13,  6, -1, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [14, 15, 15, 14, 18,  8, 19,  8, 14, 13, -1, -1],
#        [ 4, 21,  4, 17, 24, 14, 13,  4, -1, -1, -1, -1],
#        [ 4, 21,  4, 13, 19, 18, -1, -1, -1, -1, -1, -1],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [ 1,  4, 19, 22,  4,  4, 13, -1, -1, -1, -1, -1],
#        [18, 20, 13, 18,  7,  8, 13,  4, -1, -1, -1, -1],
#        [17,  8,  6,  7, 19, 18, -1, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 17, 24, 14, 13,  4, -1, -1, -1, -1],
#        [ 4, 21,  4, 17, 24, 14, 13,  4, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [ 0,  6, 17,  4,  4, 12,  4, 13, 19, -1, -1, -1],
#        [17,  8,  6,  7, 19, 18, -1, -1, -1, -1, -1, -1],
#        [15, 17,  8,  2,  4, 18, -1, -1, -1, -1, -1, -1],
#        [22,  8, 13,  3, 18, -1, -1, -1, -1, -1, -1, -1],
#        [19,  0, 11, 10,  8, 13,  6, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 13, 19, 18, -1, -1, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 17, 24,  1, 14,  3, 24, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [ 2, 11, 14, 20,  3, -1, -1, -1, -1, -1, -1, -1],
#        [22,  8, 13,  3, 18, -1, -1, -1, -1, -1, -1, -1],
#        [ 4, 21,  4, 17, 24, 14, 13,  4, -1, -1, -1, -1]])
# array([30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30])
# array([ 7, 10,  6,  8,  6, 11,  9,  9,  8, 10,  5,  7,  5,  7,  6,  5,  6,
#         6,  9,  7,  9,  9,  8,  9,  7,  6, 10,  6,  6,  7,  5,  9,  9,  8,
#        11,  7,  7,  7,  5,  7,  5,  5, 10,  8,  6,  7,  7,  8,  6,  8,  8,
#         5,  9,  6,  6,  5,  7,  6,  5,  9,  5,  5,  5,  8])
# array(['AFFAIRS', 'OPPOSITION', 'RIGHTS', 'EVERYONE', 'PRICES',
#        'AUTHORITIES', 'AGREEMENT', 'AGREEMENT', 'SUNSHINE', 'ABSOLUTELY',
#        'WINDS', 'SEVERAL', 'WINDS', 'SERIOUS', 'RIGHTS', 'CLOUD',
#        'EVENTS', 'PRICES', 'AGREEMENT', 'TALKING', 'AFTERNOON',
#        'AGREEMENT', 'EVERYONE', 'AFTERNOON', 'TALKING', 'EVENTS',
#        'ABSOLUTELY', 'EVENTS', 'EVENTS', 'MEETING', 'CLOUD', 'AGREEMENT',
#        'EVERYBODY', 'SUNSHINE', 'AUTHORITIES', 'SEVERAL', 'SEVERAL',
#        'TALKING', 'CLOUD', 'BETWEEN', 'CLOUD', 'CLOUD', 'OPPOSITION',
#        'EVERYONE', 'EVENTS', 'BETWEEN', 'BETWEEN', 'SUNSHINE', 'RIGHTS',
#        'EVERYONE', 'EVERYONE', 'CLOUD', 'AGREEMENT', 'RIGHTS', 'PRICES',
#        'WINDS', 'TALKING', 'EVENTS', 'CLOUD', 'EVERYBODY', 'CLOUD',
#        'CLOUD', 'WINDS', 'EVERYONE'], dtype='<U11')
# array([ 6,  1, 16,  2, 14,  9, 19, 19, 12, 10,  4, 11,  4,  5, 16,  8,  3,
#        14, 19, 18, 17, 19,  2, 17, 18,  3, 10,  3,  3, 15,  8, 19, 13, 12,
#         9, 11, 11, 18,  8,  0,  8,  8,  1,  2,  3,  0,  0, 12, 16,  2,  2,
#         8, 19, 16, 14,  4, 18,  3,  8, 13,  8,  8,  4,  2])

# %%
[(word,len(word)) for word in words]
# Out:
# [('BETWEEN', 7),
#  ('OPPOSITION', 10),
#  ('EVERYONE', 8),
#  ('EVENTS', 6),
#  ('WINDS', 5),
#  ('SERIOUS', 7),
#  ('AFFAIRS', 7),
#  ('WITHIN', 6),
#  ('CLOUD', 5),
#  ('AUTHORITIES', 11),
#  ('ABSOLUTELY', 10),
#  ('SEVERAL', 7),
#  ('SUNSHINE', 8),
#  ('EVERYBODY', 9),
#  ('PRICES', 6),
#  ('MEETING', 7),
#  ('RIGHTS', 6),
#  ('AFTERNOON', 9),
#  ('TALKING', 7),
#  ('AGREEMENT', 9)]

# %%
X = x['the_input'][10]
print()
fig = plt.figure(figsize=(30,30))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(30):
    ax = fig.add_subplot(1, 30, i + 1, xticks=[], yticks=[])
    ax.imshow(X[i])

# %%
import datetime
datetime = str(datetime.datetime.now())
LOG_DIR = 'training/unseen_speakers/logs/'
run_name = datetime.replace(' ','_').replace('.','_')
print('run_name:',run_name)
tensorboard = TensorBoard(log_dir=os.path.join(LOG_DIR, run_name))
# csv_logger  = CSVLogger(os.path.join(LOG_DIR, "{}-{}.csv".format('training',run_name)), separator=',', append=True)
checkpoint  = ModelCheckpoint(save_best_only=True,
                              filepath='training/unseen_speakers/results/weights_lfw-crop-ctc_classification-v4.hdf5'
                              , monitor='val_loss'
                              , verbose=1
                              , mode='min'
                              , period=1)
# Out:
# run_name: 2019-03-08_15:12:22_985569

# %%
# def test_loss(y_true, y_pred): 
#     return y_pred

# %%
from keras.optimizers import Adadelta,Adam
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=1e-08)
# _labels = lm.get_layer('the_labels').output
# _y_pred = lm.get_layer('softmax').output
# _input_length = lm.get_layer('input_length').output
# _label_length = lm.get_layer('label_length').output
# model.add_loss(ctc_loss)
losses = {
    'ctc':lambda y_true,y_pred:y_pred,
    'classification':'categorical_crossentropy'
}
model.compile(loss=losses, optimizer=adam, metrics=['accuracy'])

# %%
EPOCHS = 60000+10000
# model.load_weights('training/unseen_speakers/results/weights_lfw-crop-ctc_classification-v1.hdf5')
hist = model.fit_generator(g_tr
                    , steps_per_epoch=1
                    , epochs=EPOCHS
                    #steps_per_epoch=lip_gen.default_training_steps, epochs=stop_epoch,
                    , validation_data=g_val
                    , validation_steps=1
                    ,callbacks=[checkpoint,tensorboard]
                    ,initial_epoch=10000
                    ,verbose=0)
                    #max_q_size=5,
                    #workers=2,
                    #pickle_safe=True)
# Out:
# Epoch 10001: val_loss did not improve from 1.20370
#
# Epoch 10002: val_loss did not improve from 1.20370
#
# Epoch 10003: val_loss did not improve from 1.20370
#
# Epoch 10004: val_loss did not improve from 1.20370
#
# Epoch 10005: val_loss did not improve from 1.20370
#
# Epoch 10006: val_loss did not improve from 1.20370
#
# Epoch 10007: val_loss did not improve from 1.20370
#
# Epoch 10008: val_loss did not improve from 1.20370
#
# Epoch 10009: val_loss did not improve from 1.20370
#
# Epoch 10010: val_loss did not improve from 1.20370
#
# Epoch 10011: val_loss did not improve from 1.20370
#
# Epoch 10012: val_loss did not improve from 1.20370
#
# Epoch 10013: val_loss did not improve from 1.20370
#
# Epoch 10014: val_loss did not improve from 1.20370
#
# Epoch 10015: val_loss did not improve from 1.20370
#
# Epoch 10016: val_loss did not improve from 1.20370
#
# Epoch 10017: val_loss did not improve from 1.20370
#
# Epoch 10018: val_loss did not improve from 1.20370
#
# Epoch 10019: val_loss did not improve from 1.20370
#
# Epoch 10020: val_loss did not improve from 1.20370
#
# Epoch 10021: val_loss did not improve from 1.20370
#
# Epoch 10022: val_loss did not improve from 1.20370
#
# Epoch 10023: val_loss did not improve from 1.20370
#
# Epoch 10024: val_loss did not improve from 1.20370
#
# Epoch 10025: val_loss did not improve from 1.20370
#
# Epoch 10026: val_loss did not improve from 1.20370
#
# Epoch 10027: val_loss did not improve from 1.20370
#
# Epoch 10028: val_loss did not improve from 1.20370
#
# Epoch 10029: val_loss did not improve from 1.20370
#
# Epoch 10030: val_loss did not improve from 1.20370
#
# Epoch 10031: val_loss did not improve from 1.20370
#
# Epoch 10032: val_loss did not improve from 1.20370
#
# Epoch 10033: val_loss did not improve from 1.20370
#
# Epoch 10034: val_loss did not improve from 1.20370
#
# Epoch 10035: val_loss did not improve from 1.20370
#
# Epoch 10036: val_loss did not improve from 1.20370
#
# Epoch 10037: val_loss did not improve from 1.20370
#
# Epoch 10038: val_loss did not improve from 1.20370
#
# Epoch 10039: val_loss did not improve from 1.20370
#
# Epoch 10040: val_loss did not improve from 1.20370
#
# Epoch 10041: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
#
# Epoch 10042: val_loss did not improve from 1.20370
#
# Epoch 10043: val_loss did not improve from 1.20370
#
# Epoch 10044: val_loss did not improve from 1.20370
#
# Epoch 10045: val_loss did not improve from 1.20370
#
# Epoch 10046: val_loss did not improve from 1.20370
#
# Epoch 10047: val_loss did not improve from 1.20370
#
# Epoch 10048: val_loss did not improve from 1.20370
#
# Epoch 10049: val_loss did not improve from 1.20370
#
# Epoch 10050: val_loss did not improve from 1.20370
#
# Epoch 10051: val_loss did not improve from 1.20370
#
# Epoch 10052: val_loss did not improve from 1.20370
#
# Epoch 10053: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/PRICES/train/PRICES_00087
#
# Epoch 10054: val_loss did not improve from 1.20370
#
# Epoch 10055: val_loss did not improve from 1.20370
#
# Epoch 10056: val_loss did not improve from 1.20370
#
# Epoch 10057: val_loss did not improve from 1.20370
#
# Epoch 10058: val_loss did not improve from 1.20370
#
# Epoch 10059: val_loss did not improve from 1.20370
#
# Epoch 10060: val_loss did not improve from 1.20370
#
# Epoch 10061: val_loss did not improve from 1.20370
#
# Epoch 10062: val_loss did not improve from 1.20370
#
# Epoch 10063: val_loss did not improve from 1.20370
#
# Epoch 10064: val_loss did not improve from 1.20370
#
# Epoch 10065: val_loss did not improve from 1.20370
#
# Epoch 10066: val_loss did not improve from 1.20370
#
# Epoch 10067: val_loss did not improve from 1.20370
#
# Epoch 10068: val_loss did not improve from 1.20370
#
# Epoch 10069: val_loss did not improve from 1.20370
#
# Epoch 10070: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
#
# Epoch 10071: val_loss did not improve from 1.20370
#
# Epoch 10072: val_loss did not improve from 1.20370
#
# Epoch 10073: val_loss did not improve from 1.20370
#
# Epoch 10074: val_loss did not improve from 1.20370
#
# Epoch 10075: val_loss did not improve from 1.20370
#
# Epoch 10076: val_loss did not improve from 1.20370
#
# Epoch 10077: val_loss did not improve from 1.20370
#
# Epoch 10078: val_loss did not improve from 1.20370
#
# Epoch 10079: val_loss did not improve from 1.20370
#
# Epoch 10080: val_loss did not improve from 1.20370
#
# Epoch 10081: val_loss did not improve from 1.20370
#
# Epoch 10082: val_loss did not improve from 1.20370
#
# Epoch 10083: val_loss did not improve from 1.20370
#
# Epoch 10084: val_loss did not improve from 1.20370
#
# Epoch 10085: val_loss did not improve from 1.20370
#
# Epoch 10086: val_loss did not improve from 1.20370
#
# Epoch 10087: val_loss did not improve from 1.20370
#
# Epoch 10088: val_loss did not improve from 1.20370
#
# Epoch 10089: val_loss did not improve from 1.20370
#
# Epoch 10090: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
#
# Epoch 10091: val_loss did not improve from 1.20370
#
# Epoch 10092: val_loss did not improve from 1.20370
#
# Epoch 10093: val_loss did not improve from 1.20370
#
# Epoch 10094: val_loss did not improve from 1.20370
#
# Epoch 10095: val_loss did not improve from 1.20370
#
# Epoch 10096: val_loss did not improve from 1.20370
#
# Epoch 10097: val_loss did not improve from 1.20370
#
# Epoch 10098: val_loss did not improve from 1.20370
#
# Epoch 10099: val_loss did not improve from 1.20370
#
# Epoch 10100: val_loss did not improve from 1.20370
#
# Epoch 10101: val_loss did not improve from 1.20370
#
# Epoch 10102: val_loss did not improve from 1.20370
#
# Epoch 10103: val_loss did not improve from 1.20370
#
# Epoch 10104: val_loss did not improve from 1.20370
#
# Epoch 10105: val_loss did not improve from 1.20370
#
# Epoch 10106: val_loss did not improve from 1.20370
#
# Epoch 10107: val_loss did not improve from 1.20370
#
# Epoch 10108: val_loss did not improve from 1.20370
#
# Epoch 10109: val_loss did not improve from 1.20370
#
# Epoch 10110: val_loss did not improve from 1.20370
#
# Epoch 10111: val_loss did not improve from 1.20370
#
# Epoch 10112: val_loss did not improve from 1.20370
#
# Epoch 10113: val_loss did not improve from 1.20370
#
# Epoch 10114: val_loss did not improve from 1.20370
#
# Epoch 10115: val_loss did not improve from 1.20370
#
# Epoch 10116: val_loss did not improve from 1.20370
#
# Epoch 10117: val_loss did not improve from 1.20370
#
# Epoch 10118: val_loss did not improve from 1.20370
#
# Epoch 10119: val_loss did not improve from 1.20370
#
# Epoch 10120: val_loss did not improve from 1.20370
#
# Epoch 10121: val_loss did not improve from 1.20370
#
# Epoch 10122: val_loss did not improve from 1.20370
#
# Epoch 10123: val_loss did not improve from 1.20370
#
# Epoch 10124: val_loss did not improve from 1.20370
#
# Epoch 10125: val_loss did not improve from 1.20370
#
# Epoch 10126: val_loss did not improve from 1.20370
#
# Epoch 10127: val_loss did not improve from 1.20370
#
# Epoch 10128: val_loss did not improve from 1.20370
#
# Epoch 10129: val_loss did not improve from 1.20370
#
# Epoch 10130: val_loss did not improve from 1.20370
#
# Epoch 10131: val_loss did not improve from 1.20370
#
# Epoch 10132: val_loss did not improve from 1.20370
#
# Epoch 10133: val_loss did not improve from 1.20370
#
# Epoch 10134: val_loss did not improve from 1.20370
#
# Epoch 10135: val_loss did not improve from 1.20370
#
# Epoch 10136: val_loss did not improve from 1.20370
#
# Epoch 10137: val_loss did not improve from 1.20370
#
# Epoch 10138: val_loss did not improve from 1.20370
#
# Epoch 10139: val_loss did not improve from 1.20370
#
# Epoch 10140: val_loss did not improve from 1.20370
#
# Epoch 10141: val_loss did not improve from 1.20370
#
# Epoch 10142: val_loss did not improve from 1.20370
#
# Epoch 10143: val_loss did not improve from 1.20370
#
# Epoch 10144: val_loss did not improve from 1.20370
#
# Epoch 10145: val_loss did not improve from 1.20370
#
# Epoch 10146: val_loss did not improve from 1.20370
#
# Epoch 10147: val_loss did not improve from 1.20370
#
# Epoch 10148: val_loss did not improve from 1.20370
#
# Epoch 10149: val_loss did not improve from 1.20370
#
# Epoch 10150: val_loss did not improve from 1.20370
#
# Epoch 10151: val_loss did not improve from 1.20370
# Epoch 10152: val_loss did not improve from 1.20370
#
# Epoch 10153: val_loss did not improve from 1.20370
#
# Epoch 10154: val_loss did not improve from 1.20370
#
# Epoch 10155: val_loss did not improve from 1.20370
#
# Epoch 10156: val_loss did not improve from 1.20370
#
# Epoch 10157: val_loss did not improve from 1.20370
#
# Epoch 10158: val_loss did not improve from 1.20370
#
# Epoch 10159: val_loss did not improve from 1.20370
#
# Epoch 10160: val_loss did not improve from 1.20370
#
# Epoch 10161: val_loss did not improve from 1.20370
#
# Epoch 10162: val_loss did not improve from 1.20370
#
# Epoch 10163: val_loss did not improve from 1.20370
#
# Epoch 10164: val_loss did not improve from 1.20370
#
# Epoch 10165: val_loss did not improve from 1.20370
#
# Epoch 10166: val_loss did not improve from 1.20370
#
# Epoch 10167: val_loss did not improve from 1.20370
#
# Epoch 10168: val_loss did not improve from 1.20370
#
# Epoch 10169: val_loss did not improve from 1.20370
#
# Epoch 10170: val_loss did not improve from 1.20370
#
# Epoch 10171: val_loss did not improve from 1.20370
#
# Epoch 10172: val_loss did not improve from 1.20370
#
# Epoch 10173: val_loss did not improve from 1.20370
#
# Epoch 10174: val_loss did not improve from 1.20370
#
# Epoch 10175: val_loss did not improve from 1.20370
#
# Epoch 10176: val_loss did not improve from 1.20370
#
# Epoch 10177: val_loss did not improve from 1.20370
#
# Epoch 10178: val_loss did not improve from 1.20370
#
# Epoch 10179: val_loss did not improve from 1.20370
#
# Epoch 10180: val_loss did not improve from 1.20370
#
# Epoch 10181: val_loss did not improve from 1.20370
#
# Epoch 10182: val_loss did not improve from 1.20370
#
# Epoch 10183: val_loss did not improve from 1.20370
#
# Epoch 10184: val_loss did not improve from 1.20370
#
# Epoch 10185: val_loss did not improve from 1.20370
#
# Epoch 10186: val_loss did not improve from 1.20370
#
# Epoch 10187: val_loss did not improve from 1.20370
#
# Epoch 10188: val_loss did not improve from 1.20370
#
# Epoch 10189: val_loss did not improve from 1.20370
#
# Epoch 10190: val_loss did not improve from 1.20370
#
# Epoch 10191: val_loss did not improve from 1.20370
#
# Epoch 10192: val_loss did not improve from 1.20370
#
# Epoch 10193: val_loss did not improve from 1.20370
#
# Epoch 10194: val_loss did not improve from 1.20370
#
# Epoch 10195: val_loss did not improve from 1.20370
#
# Epoch 10196: val_loss did not improve from 1.20370
#
# Epoch 10197: val_loss did not improve from 1.20370
#
# Epoch 10198: val_loss did not improve from 1.20370
#
# Epoch 10199: val_loss did not improve from 1.20370
#
# Epoch 10200: val_loss did not improve from 1.20370
#
# Epoch 10201: val_loss did not improve from 1.20370
#
# Epoch 10202: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/WINDS/train/WINDS_00042
#
# Epoch 10203: val_loss did not improve from 1.20370
#
# Epoch 10204: val_loss did not improve from 1.20370
#
# Epoch 10205: val_loss did not improve from 1.20370
#
# Epoch 10206: val_loss did not improve from 1.20370
#
# Epoch 10207: val_loss did not improve from 1.20370
#
# Epoch 10208: val_loss did not improve from 1.20370
#
# Epoch 10209: val_loss did not improve from 1.20370
#
# Epoch 10210: val_loss did not improve from 1.20370
#
# Epoch 10211: val_loss did not improve from 1.20370
#
# Epoch 10212: val_loss did not improve from 1.20370
#
# Epoch 10213: val_loss did not improve from 1.20370
#
# Epoch 10214: val_loss did not improve from 1.20370
#
# Epoch 10215: val_loss did not improve from 1.20370
#
# Epoch 10216: val_loss did not improve from 1.20370
#
# Epoch 10217: val_loss did not improve from 1.20370
#
# Epoch 10218: val_loss did not improve from 1.20370
#
# Epoch 10219: val_loss did not improve from 1.20370
#
# Epoch 10220: val_loss did not improve from 1.20370
#
# Epoch 10221: val_loss did not improve from 1.20370
#
# Epoch 10222: val_loss did not improve from 1.20370
#
# Epoch 10223: val_loss did not improve from 1.20370
#
# Epoch 10224: val_loss did not improve from 1.20370
#
# Epoch 10225: val_loss did not improve from 1.20370
#
# Epoch 10226: val_loss did not improve from 1.20370
#
# Epoch 10227: val_loss did not improve from 1.20370
#
# Epoch 10228: val_loss did not improve from 1.20370
#
# Epoch 10229: val_loss did not improve from 1.20370
#
# Epoch 10230: val_loss did not improve from 1.20370
#
# Epoch 10231: val_loss did not improve from 1.20370
#
# Epoch 10232: val_loss did not improve from 1.20370
#
# Epoch 10233: val_loss did not improve from 1.20370
#
# Epoch 10234: val_loss did not improve from 1.20370
#
# Epoch 10235: val_loss did not improve from 1.20370
#
# Epoch 10236: val_loss did not improve from 1.20370
#
# Epoch 10237: val_loss did not improve from 1.20370
#
# Epoch 10238: val_loss did not improve from 1.20370
#
# Epoch 10239: val_loss did not improve from 1.20370
#
# Epoch 10240: val_loss did not improve from 1.20370
#
# Epoch 10241: val_loss did not improve from 1.20370
#
# Epoch 10242: val_loss did not improve from 1.20370
#
# Epoch 10243: val_loss did not improve from 1.20370
#
# Epoch 10244: val_loss did not improve from 1.20370
#
# Epoch 10245: val_loss did not improve from 1.20370
#
# Epoch 10246: val_loss did not improve from 1.20370
#
# Epoch 10247: val_loss did not improve from 1.20370
#
# Epoch 10248: val_loss did not improve from 1.20370
#
# Epoch 10249: val_loss did not improve from 1.20370
#
# Epoch 10250: val_loss did not improve from 1.20370
#
# Epoch 10251: val_loss did not improve from 1.20370
#
# Epoch 10252: val_loss did not improve from 1.20370
#
# Epoch 10253: val_loss did not improve from 1.20370
#
# Epoch 10254: val_loss did not improve from 1.20370
#
# Epoch 10255: val_loss did not improve from 1.20370
#
# Epoch 10256: val_loss did not improve from 1.20370
#
# Epoch 10257: val_loss did not improve from 1.20370
#
# Epoch 10258: val_loss did not improve from 1.20370
#
# Epoch 10259: val_loss did not improve from 1.20370
#
# Epoch 10260: val_loss did not improve from 1.20370
#
# Epoch 10261: val_loss did not improve from 1.20370
#
# Epoch 10262: val_loss did not improve from 1.20370
#
# Epoch 10263: val_loss did not improve from 1.20370
#
# Epoch 10264: val_loss did not improve from 1.20370
#
# Epoch 10265: val_loss did not improve from 1.20370
#
# Epoch 10266: val_loss did not improve from 1.20370
#
# Epoch 10267: val_loss did not improve from 1.20370
#
# Epoch 10268: val_loss did not improve from 1.20370
#
# Epoch 10269: val_loss did not improve from 1.20370
#
# Epoch 10270: val_loss did not improve from 1.20370
#
# Epoch 10271: val_loss did not improve from 1.20370
#
# Epoch 10272: val_loss did not improve from 1.20370
#
# Epoch 10273: val_loss did not improve from 1.20370
#
# Epoch 10274: val_loss did not improve from 1.20370
#
# Epoch 10275: val_loss did not improve from 1.20370
#
# Epoch 10276: val_loss did not improve from 1.20370
#
# Epoch 10277: val_loss did not improve from 1.20370
#
# Epoch 10278: val_loss did not improve from 1.20370
#
# Epoch 10279: val_loss did not improve from 1.20370
#
# Epoch 10280: val_loss did not improve from 1.20370
#
# Epoch 10281: val_loss did not improve from 1.20370
#
# Epoch 10282: val_loss did not improve from 1.20370
#
# Epoch 10283: val_loss did not improve from 1.20370
#
# Epoch 10284: val_loss did not improve from 1.20370
#
# Epoch 10285: val_loss did not improve from 1.20370
#
# Epoch 10286: val_loss did not improve from 1.20370
#
# Epoch 10287: val_loss did not improve from 1.20370
#
# Epoch 10288: val_loss did not improve from 1.20370
#
# Epoch 10289: val_loss did not improve from 1.20370
#
# Epoch 10290: val_loss did not improve from 1.20370
#
# Epoch 10291: val_loss did not improve from 1.20370
#
# Epoch 10292: val_loss did not improve from 1.20370
#
# Epoch 10293: val_loss did not improve from 1.20370
#
# Epoch 10294: val_loss did not improve from 1.20370
#
# Epoch 10295: val_loss did not improve from 1.20370
#
# Epoch 10296: val_loss did not improve from 1.20370
#
# Epoch 10297: val_loss did not improve from 1.20370
#
# Epoch 10298: val_loss did not improve from 1.20370
#
# Epoch 10299: val_loss did not improve from 1.20370
#
# Epoch 10300: val_loss did not improve from 1.20370
#
# Epoch 10301: val_loss did not improve from 1.20370
#
# Epoch 10302: val_loss did not improve from 1.20370
#
# Epoch 10303: val_loss did not improve from 1.20370
#
# Epoch 10304: val_loss did not improve from 1.20370
#
# Epoch 10305: val_loss did not improve from 1.20370
#
# Epoch 10306: val_loss did not improve from 1.20370
#
# Epoch 10307: val_loss did not improve from 1.20370
# Epoch 10308: val_loss did not improve from 1.20370
#
# Epoch 10309: val_loss did not improve from 1.20370
#
# Epoch 10310: val_loss did not improve from 1.20370
#
# Epoch 10311: val_loss did not improve from 1.20370
#
# Epoch 10312: val_loss did not improve from 1.20370
#
# Epoch 10313: val_loss did not improve from 1.20370
#
# Epoch 10314: val_loss did not improve from 1.20370
#
# Epoch 10315: val_loss did not improve from 1.20370
#
# Epoch 10316: val_loss did not improve from 1.20370
#
# Epoch 10317: val_loss did not improve from 1.20370
#
# Epoch 10318: val_loss did not improve from 1.20370
#
# Epoch 10319: val_loss did not improve from 1.20370
#
# Epoch 10320: val_loss did not improve from 1.20370
#
# Epoch 10321: val_loss did not improve from 1.20370
#
# Epoch 10322: val_loss did not improve from 1.20370
#
# Epoch 10323: val_loss did not improve from 1.20370
#
# Epoch 10324: val_loss did not improve from 1.20370
#
# Epoch 10325: val_loss did not improve from 1.20370
#
# Epoch 10326: val_loss did not improve from 1.20370
#
# Epoch 10327: val_loss did not improve from 1.20370
#
# Epoch 10328: val_loss did not improve from 1.20370
#
# Epoch 10329: val_loss did not improve from 1.20370
#
# Epoch 10330: val_loss did not improve from 1.20370
#
# Epoch 10331: val_loss did not improve from 1.20370
#
# Epoch 10332: val_loss did not improve from 1.20370
#
# Epoch 10333: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/PRICES/train/PRICES_00087
#
# Epoch 10334: val_loss did not improve from 1.20370
#
# Epoch 10335: val_loss did not improve from 1.20370
#
# Epoch 10336: val_loss did not improve from 1.20370
#
# Epoch 10337: val_loss did not improve from 1.20370
#
# Epoch 10338: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/RIGHTS/train/RIGHTS_00812
#
# Epoch 10339: val_loss did not improve from 1.20370
#
# Epoch 10340: val_loss did not improve from 1.20370
#
# Epoch 10341: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00116
#
# Epoch 10342: val_loss did not improve from 1.20370
#
# Epoch 10343: val_loss did not improve from 1.20370
#
# Epoch 10344: val_loss did not improve from 1.20370
#
# Epoch 10345: val_loss did not improve from 1.20370
#
# Epoch 10346: val_loss did not improve from 1.20370
#
# Epoch 10347: val_loss did not improve from 1.20370
#
# Epoch 10348: val_loss did not improve from 1.20370
#
# Epoch 10349: val_loss did not improve from 1.20370
#
# Epoch 10350: val_loss did not improve from 1.20370
#
# Epoch 10351: val_loss did not improve from 1.20370
#
# Epoch 10352: val_loss did not improve from 1.20370
#
# Epoch 10353: val_loss did not improve from 1.20370
#
# Epoch 10354: val_loss did not improve from 1.20370
#
# Epoch 10355: val_loss did not improve from 1.20370
#
# Epoch 10356: val_loss did not improve from 1.20370
#
# Epoch 10357: val_loss did not improve from 1.20370
#
# Epoch 10358: val_loss did not improve from 1.20370
#
# Epoch 10359: val_loss did not improve from 1.20370
#
# Epoch 10360: val_loss did not improve from 1.20370
#
# Epoch 10361: val_loss did not improve from 1.20370
#
# Epoch 10362: val_loss did not improve from 1.20370
#
# Epoch 10363: val_loss did not improve from 1.20370
#
# Epoch 10364: val_loss did not improve from 1.20370
#
# Epoch 10365: val_loss did not improve from 1.20370
#
# Epoch 10366: val_loss did not improve from 1.20370
#
# Epoch 10367: val_loss did not improve from 1.20370
#
# Epoch 10368: val_loss did not improve from 1.20370
#
# Epoch 10369: val_loss did not improve from 1.20370
#
# Epoch 10370: val_loss did not improve from 1.20370
#
# Epoch 10371: val_loss did not improve from 1.20370
#
# Epoch 10372: val_loss did not improve from 1.20370
#
# Epoch 10373: val_loss did not improve from 1.20370
#
# Epoch 10374: val_loss did not improve from 1.20370
#
# Epoch 10375: val_loss did not improve from 1.20370
#
# Epoch 10376: val_loss did not improve from 1.20370
#
# Epoch 10377: val_loss did not improve from 1.20370
#
# Epoch 10378: val_loss did not improve from 1.20370
#
# Epoch 10379: val_loss did not improve from 1.20370
#
# Epoch 10380: val_loss did not improve from 1.20370
#
# Epoch 10381: val_loss did not improve from 1.20370
#
# Epoch 10382: val_loss did not improve from 1.20370
#
# Epoch 10383: val_loss did not improve from 1.20370
#
# Epoch 10384: val_loss did not improve from 1.20370
#
# Epoch 10385: val_loss did not improve from 1.20370
#
# Epoch 10386: val_loss did not improve from 1.20370
#
# Epoch 10387: val_loss did not improve from 1.20370
#
# Epoch 10388: val_loss did not improve from 1.20370
#
# Epoch 10389: val_loss did not improve from 1.20370
#
# Epoch 10390: val_loss did not improve from 1.20370
#
# Epoch 10391: val_loss did not improve from 1.20370
#
# Epoch 10392: val_loss did not improve from 1.20370
#
# Epoch 10393: val_loss did not improve from 1.20370
#
# Epoch 10394: val_loss did not improve from 1.20370
#
# Epoch 10395: val_loss did not improve from 1.20370
#
# Epoch 10396: val_loss did not improve from 1.20370
#
# Epoch 10397: val_loss did not improve from 1.20370
#
# Epoch 10398: val_loss did not improve from 1.20370
#
# Epoch 10399: val_loss did not improve from 1.20370
#
# Epoch 10400: val_loss did not improve from 1.20370
#
# Epoch 10401: val_loss did not improve from 1.20370
#
# Epoch 10402: val_loss did not improve from 1.20370
#
# Epoch 10403: val_loss did not improve from 1.20370
#
# Epoch 10404: val_loss did not improve from 1.20370
#
# Epoch 10405: val_loss did not improve from 1.20370
#
# Epoch 10406: val_loss did not improve from 1.20370
#
# Epoch 10407: val_loss did not improve from 1.20370
#
# Epoch 10408: val_loss did not improve from 1.20370
#
# Epoch 10409: val_loss did not improve from 1.20370
#
# Epoch 10410: val_loss did not improve from 1.20370
#
# Epoch 10411: val_loss did not improve from 1.20370
#
# Epoch 10412: val_loss did not improve from 1.20370
#
# Epoch 10413: val_loss did not improve from 1.20370
#
# Epoch 10414: val_loss did not improve from 1.20370
#
# Epoch 10415: val_loss did not improve from 1.20370
#
# Epoch 10416: val_loss did not improve from 1.20370
#
# Epoch 10417: val_loss did not improve from 1.20370
#
# Epoch 10418: val_loss did not improve from 1.20370
#
# Epoch 10419: val_loss did not improve from 1.20370
#
# Epoch 10420: val_loss did not improve from 1.20370
#
# Epoch 10421: val_loss did not improve from 1.20370
#
# Epoch 10422: val_loss did not improve from 1.20370
#
# Epoch 10423: val_loss did not improve from 1.20370
#
# Epoch 10424: val_loss did not improve from 1.20370
#
# Epoch 10425: val_loss did not improve from 1.20370
#
# Epoch 10426: val_loss did not improve from 1.20370
#
# Epoch 10427: val_loss did not improve from 1.20370
#
# Epoch 10428: val_loss did not improve from 1.20370
#
# Epoch 10429: val_loss did not improve from 1.20370
#
# Epoch 10430: val_loss did not improve from 1.20370
#
# Epoch 10431: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/WINDS/train/WINDS_00042
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
#
# Epoch 10432: val_loss did not improve from 1.20370
#
# Epoch 10433: val_loss did not improve from 1.20370
#
# Epoch 10434: val_loss did not improve from 1.20370
#
# Epoch 10435: val_loss did not improve from 1.20370
#
# Epoch 10436: val_loss did not improve from 1.20370
#
# Epoch 10437: val_loss did not improve from 1.20370
#
# Epoch 10438: val_loss did not improve from 1.20370
#
# Epoch 10439: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00383
#
# Epoch 10440: val_loss did not improve from 1.20370
#
# Epoch 10441: val_loss did not improve from 1.20370
#
# Epoch 10442: val_loss did not improve from 1.20370
#
# Epoch 10443: val_loss did not improve from 1.20370
#
# Epoch 10444: val_loss did not improve from 1.20370
#
# Epoch 10445: val_loss did not improve from 1.20370
#
# Epoch 10446: val_loss did not improve from 1.20370
#
# Epoch 10447: val_loss did not improve from 1.20370
#
# Epoch 10448: val_loss did not improve from 1.20370
#
# Epoch 10449: val_loss did not improve from 1.20370
#
# Epoch 10450: val_loss did not improve from 1.20370
#
# Epoch 10451: val_loss did not improve from 1.20370
#
# Epoch 10452: val_loss did not improve from 1.20370
#
# Epoch 10453: val_loss did not improve from 1.20370
#
# Epoch 10454: val_loss did not improve from 1.20370
# Epoch 10455: val_loss did not improve from 1.20370
#
# Epoch 10456: val_loss did not improve from 1.20370
#
# Epoch 10457: val_loss did not improve from 1.20370
#
# Epoch 10458: val_loss did not improve from 1.20370
#
# Epoch 10459: val_loss did not improve from 1.20370
#
# Epoch 10460: val_loss did not improve from 1.20370
#
# Epoch 10461: val_loss did not improve from 1.20370
#
# Epoch 10462: val_loss did not improve from 1.20370
#
# Epoch 10463: val_loss did not improve from 1.20370
#
# Epoch 10464: val_loss did not improve from 1.20370
#
# Epoch 10465: val_loss did not improve from 1.20370
#
# Epoch 10466: val_loss did not improve from 1.20370
#
# Epoch 10467: val_loss did not improve from 1.20370
#
# Epoch 10468: val_loss did not improve from 1.20370
#
# Epoch 10469: val_loss did not improve from 1.20370
#
# Epoch 10470: val_loss did not improve from 1.20370
#
# Epoch 10471: val_loss did not improve from 1.20370
#
# Epoch 10472: val_loss did not improve from 1.20370
#
# Epoch 10473: val_loss did not improve from 1.20370
#
# Epoch 10474: val_loss did not improve from 1.20370
#
# Epoch 10475: val_loss did not improve from 1.20370
#
# Epoch 10476: val_loss did not improve from 1.20370
#
# Epoch 10477: val_loss did not improve from 1.20370
#
# Epoch 10478: val_loss did not improve from 1.20370
#
# Epoch 10479: val_loss did not improve from 1.20370
#
# Epoch 10480: val_loss did not improve from 1.20370
#
# Epoch 10481: val_loss did not improve from 1.20370
#
# Epoch 10482: val_loss did not improve from 1.20370
#
# Epoch 10483: val_loss did not improve from 1.20370
#
# Epoch 10484: val_loss did not improve from 1.20370
#
# Epoch 10485: val_loss did not improve from 1.20370
#
# Epoch 10486: val_loss did not improve from 1.20370
#
# Epoch 10487: val_loss did not improve from 1.20370
#
# Epoch 10488: val_loss did not improve from 1.20370
#
# Epoch 10489: val_loss did not improve from 1.20370
#
# Epoch 10490: val_loss did not improve from 1.20370
#
# Epoch 10491: val_loss did not improve from 1.20370
#
# Epoch 10492: val_loss did not improve from 1.20370
#
# Epoch 10493: val_loss did not improve from 1.20370
#
# Epoch 10494: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00316
#
# Epoch 10495: val_loss did not improve from 1.20370
#
# Epoch 10496: val_loss did not improve from 1.20370
#
# Epoch 10497: val_loss did not improve from 1.20370
#
# Epoch 10498: val_loss did not improve from 1.20370
#
# Epoch 10499: val_loss did not improve from 1.20370
#
# Epoch 10500: val_loss did not improve from 1.20370
#
# Epoch 10501: val_loss did not improve from 1.20370
#
# Epoch 10502: val_loss did not improve from 1.20370
#
# Epoch 10503: val_loss did not improve from 1.20370
#
# Epoch 10504: val_loss did not improve from 1.20370
#
# Epoch 10505: val_loss did not improve from 1.20370
#
# Epoch 10506: val_loss did not improve from 1.20370
#
# Epoch 10507: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00316
#
# Epoch 10508: val_loss did not improve from 1.20370
#
# Epoch 10509: val_loss did not improve from 1.20370
#
# Epoch 10510: val_loss did not improve from 1.20370
#
# Epoch 10511: val_loss did not improve from 1.20370
#
# Epoch 10512: val_loss did not improve from 1.20370
#
# Epoch 10513: val_loss did not improve from 1.20370
#
# Epoch 10514: val_loss did not improve from 1.20370
#
# Epoch 10515: val_loss did not improve from 1.20370
#
# Epoch 10516: val_loss did not improve from 1.20370
#
# Epoch 10517: val_loss did not improve from 1.20370
#
# Epoch 10518: val_loss did not improve from 1.20370
#
# Epoch 10519: val_loss did not improve from 1.20370
#
# Epoch 10520: val_loss did not improve from 1.20370
#
# Epoch 10521: val_loss did not improve from 1.20370
#
# Epoch 10522: val_loss did not improve from 1.20370
#
# Epoch 10523: val_loss did not improve from 1.20370
#
# Epoch 10524: val_loss did not improve from 1.20370
#
# Epoch 10525: val_loss did not improve from 1.20370
#
# Epoch 10526: val_loss did not improve from 1.20370
#
# Epoch 10527: val_loss did not improve from 1.20370
#
# Epoch 10528: val_loss did not improve from 1.20370
#
# Epoch 10529: val_loss did not improve from 1.20370
#
# Epoch 10530: val_loss did not improve from 1.20370
#
# Epoch 10531: val_loss did not improve from 1.20370
#
# Epoch 10532: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00031
#
# Epoch 10533: val_loss did not improve from 1.20370
#
# Epoch 10534: val_loss did not improve from 1.20370
#
# Epoch 10535: val_loss did not improve from 1.20370
#
# Epoch 10536: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
#
# Epoch 10537: val_loss did not improve from 1.20370
#
# Epoch 10538: val_loss did not improve from 1.20370
#
# Epoch 10539: val_loss did not improve from 1.20370
#
# Epoch 10540: val_loss did not improve from 1.20370
#
# Epoch 10541: val_loss did not improve from 1.20370
#
# Epoch 10542: val_loss did not improve from 1.20370
#
# Epoch 10543: val_loss did not improve from 1.20370
#
# Epoch 10544: val_loss did not improve from 1.20370
#
# Epoch 10545: val_loss did not improve from 1.20370
#
# Epoch 10546: val_loss did not improve from 1.20370
#
# Epoch 10547: val_loss did not improve from 1.20370
#
# Epoch 10548: val_loss did not improve from 1.20370
#
# Epoch 10549: val_loss did not improve from 1.20370
#
# Epoch 10550: val_loss did not improve from 1.20370
#
# Epoch 10551: val_loss did not improve from 1.20370
#
# Epoch 10552: val_loss did not improve from 1.20370
#
# Epoch 10553: val_loss did not improve from 1.20370
#
# Epoch 10554: val_loss did not improve from 1.20370
#
# Epoch 10555: val_loss did not improve from 1.20370
#
# Epoch 10556: val_loss did not improve from 1.20370
#
# Epoch 10557: val_loss did not improve from 1.20370
#
# Epoch 10558: val_loss did not improve from 1.20370
#
# Epoch 10559: val_loss did not improve from 1.20370
#
# Epoch 10560: val_loss did not improve from 1.20370
#
# Epoch 10561: val_loss did not improve from 1.20370
#
# Epoch 10562: val_loss did not improve from 1.20370
#
# Epoch 10563: val_loss did not improve from 1.20370
#
# Epoch 10564: val_loss did not improve from 1.20370
#
# Epoch 10565: val_loss did not improve from 1.20370
#
# Epoch 10566: val_loss did not improve from 1.20370
#
# Epoch 10567: val_loss did not improve from 1.20370
#
# Epoch 10568: val_loss did not improve from 1.20370
#
# Epoch 10569: val_loss did not improve from 1.20370
#
# Epoch 10570: val_loss did not improve from 1.20370
#
# Epoch 10571: val_loss did not improve from 1.20370
#
# Epoch 10572: val_loss did not improve from 1.20370
#
# Epoch 10573: val_loss did not improve from 1.20370
#
# Epoch 10574: val_loss did not improve from 1.20370
#
# Epoch 10575: val_loss did not improve from 1.20370
#
# Epoch 10576: val_loss did not improve from 1.20370
#
# Epoch 10577: val_loss did not improve from 1.20370
#
# Epoch 10578: val_loss did not improve from 1.20370
#
# Epoch 10579: val_loss did not improve from 1.20370
#
# Epoch 10580: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
#
# Epoch 10581: val_loss did not improve from 1.20370
#
# Epoch 10582: val_loss did not improve from 1.20370
#
# Epoch 10583: val_loss did not improve from 1.20370
#
# Epoch 10584: val_loss did not improve from 1.20370
#
# Epoch 10585: val_loss did not improve from 1.20370
#
# Epoch 10586: val_loss did not improve from 1.20370
#
# Epoch 10587: val_loss did not improve from 1.20370
#
# Epoch 10588: val_loss did not improve from 1.20370
#
# Epoch 10589: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/WINDS/train/WINDS_00042
#
# Epoch 10590: val_loss did not improve from 1.20370
#
# Epoch 10591: val_loss did not improve from 1.20370
#
# Epoch 10592: val_loss did not improve from 1.20370
#
# Epoch 10593: val_loss did not improve from 1.20370
#
# Epoch 10594: val_loss did not improve from 1.20370
#
# Epoch 10595: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00383
#
# Epoch 10596: val_loss did not improve from 1.20370
#
# Epoch 10597: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/WINDS/train/WINDS_00042
#
# Epoch 10598: val_loss did not improve from 1.20370
# Epoch 10599: val_loss did not improve from 1.20370
#
# Epoch 10600: val_loss did not improve from 1.20370
#
# Epoch 10601: val_loss did not improve from 1.20370
#
# Epoch 10602: val_loss did not improve from 1.20370
#
# Epoch 10603: val_loss did not improve from 1.20370
#
# Epoch 10604: val_loss did not improve from 1.20370
#
# Epoch 10605: val_loss did not improve from 1.20370
#
# Epoch 10606: val_loss did not improve from 1.20370
#
# Epoch 10607: val_loss did not improve from 1.20370
#
# Epoch 10608: val_loss did not improve from 1.20370
#
# Epoch 10609: val_loss did not improve from 1.20370
#
# Epoch 10610: val_loss did not improve from 1.20370
#
# Epoch 10611: val_loss did not improve from 1.20370
#
# Epoch 10612: val_loss did not improve from 1.20370
#
# Epoch 10613: val_loss did not improve from 1.20370
#
# Epoch 10614: val_loss did not improve from 1.20370
#
# Epoch 10615: val_loss did not improve from 1.20370
#
# Epoch 10616: val_loss did not improve from 1.20370
#
# Epoch 10617: val_loss did not improve from 1.20370
#
# Epoch 10618: val_loss did not improve from 1.20370
#
# Epoch 10619: val_loss did not improve from 1.20370
#
# Epoch 10620: val_loss did not improve from 1.20370
#
# Epoch 10621: val_loss did not improve from 1.20370
#
# Epoch 10622: val_loss did not improve from 1.20370
#
# Epoch 10623: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/PRICES/train/PRICES_00087
#
# Epoch 10624: val_loss did not improve from 1.20370
#
# Epoch 10625: val_loss did not improve from 1.20370
#
# Epoch 10626: val_loss did not improve from 1.20370
#
# Epoch 10627: val_loss did not improve from 1.20370
#
# Epoch 10628: val_loss did not improve from 1.20370
#
# Epoch 10629: val_loss did not improve from 1.20370
#
# Epoch 10630: val_loss did not improve from 1.20370
#
# Epoch 10631: val_loss did not improve from 1.20370
#
# Epoch 10632: val_loss did not improve from 1.20370
#
# Epoch 10633: val_loss did not improve from 1.20370
#
# Epoch 10634: val_loss did not improve from 1.20370
#
# Epoch 10635: val_loss did not improve from 1.20370
#
# Epoch 10636: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/RIGHTS/train/RIGHTS_00812
#
# Epoch 10637: val_loss did not improve from 1.20370
#
# Epoch 10638: val_loss did not improve from 1.20370
#
# Epoch 10639: val_loss did not improve from 1.20370
#
# Epoch 10640: val_loss did not improve from 1.20370
#
# Epoch 10641: val_loss did not improve from 1.20370
#
# Epoch 10642: val_loss did not improve from 1.20370
#
# Epoch 10643: val_loss did not improve from 1.20370
#
# Epoch 10644: val_loss did not improve from 1.20370
#
# Epoch 10645: val_loss did not improve from 1.20370
#
# Epoch 10646: val_loss did not improve from 1.20370
#
# Epoch 10647: val_loss did not improve from 1.20370
#
# Epoch 10648: val_loss did not improve from 1.20370
#
# Epoch 10649: val_loss did not improve from 1.20370
#
# Epoch 10650: val_loss did not improve from 1.20370
#
# Epoch 10651: val_loss did not improve from 1.20370
#
# Epoch 10652: val_loss did not improve from 1.20370
#
# Epoch 10653: val_loss did not improve from 1.20370
#
# Epoch 10654: val_loss did not improve from 1.20370
#
# Epoch 10655: val_loss did not improve from 1.20370
#
# Epoch 10656: val_loss did not improve from 1.20370
#
# Epoch 10657: val_loss did not improve from 1.20370
#
# Epoch 10658: val_loss did not improve from 1.20370
#
# Epoch 10659: val_loss did not improve from 1.20370
#
# Epoch 10660: val_loss did not improve from 1.20370
#
# Epoch 10661: val_loss did not improve from 1.20370
#
# Epoch 10662: val_loss did not improve from 1.20370
#
# Epoch 10663: val_loss did not improve from 1.20370
#
# Epoch 10664: val_loss did not improve from 1.20370
#
# Epoch 10665: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/RIGHTS/train/RIGHTS_00812
#
# Epoch 10666: val_loss did not improve from 1.20370
#
# Epoch 10667: val_loss did not improve from 1.20370
#
# Epoch 10668: val_loss did not improve from 1.20370
#
# Epoch 10669: val_loss did not improve from 1.20370
#
# Epoch 10670: val_loss did not improve from 1.20370
#
# Epoch 10671: val_loss did not improve from 1.20370
#
# Epoch 10672: val_loss did not improve from 1.20370
#
# Epoch 10673: val_loss did not improve from 1.20370
#
# Epoch 10674: val_loss did not improve from 1.20370
#
# Epoch 10675: val_loss did not improve from 1.20370
#
# Epoch 10676: val_loss did not improve from 1.20370
#
# Epoch 10677: val_loss did not improve from 1.20370
#
# Epoch 10678: val_loss did not improve from 1.20370
#
# Epoch 10679: val_loss did not improve from 1.20370
#
# Epoch 10680: val_loss did not improve from 1.20370
#
# Epoch 10681: val_loss did not improve from 1.20370
#
# Epoch 10682: val_loss did not improve from 1.20370
#
# Epoch 10683: val_loss did not improve from 1.20370
#
# Epoch 10684: val_loss did not improve from 1.20370
#
# Epoch 10685: val_loss did not improve from 1.20370
#
# Epoch 10686: val_loss did not improve from 1.20370
#
# Epoch 10687: val_loss did not improve from 1.20370
#
# Epoch 10688: val_loss did not improve from 1.20370
#
# Epoch 10689: val_loss did not improve from 1.20370
#
# Epoch 10690: val_loss did not improve from 1.20370
#
# Epoch 10691: val_loss did not improve from 1.20370
#
# Epoch 10692: val_loss did not improve from 1.20370
#
# Epoch 10693: val_loss did not improve from 1.20370
#
# Epoch 10694: val_loss did not improve from 1.20370
#
# Epoch 10695: val_loss did not improve from 1.20370
#
# Epoch 10696: val_loss did not improve from 1.20370
#
# Epoch 10697: val_loss did not improve from 1.20370
#
# Epoch 10698: val_loss did not improve from 1.20370
#
# Epoch 10699: val_loss did not improve from 1.20370
#
# Epoch 10700: val_loss did not improve from 1.20370
#
# Epoch 10701: val_loss did not improve from 1.20370
#
# Epoch 10702: val_loss did not improve from 1.20370
#
# Epoch 10703: val_loss did not improve from 1.20370
#
# Epoch 10704: val_loss did not improve from 1.20370
#
# Epoch 10705: val_loss did not improve from 1.20370
#
# Epoch 10706: val_loss did not improve from 1.20370
#
# Epoch 10707: val_loss did not improve from 1.20370
#
# Epoch 10708: val_loss did not improve from 1.20370
#
# Epoch 10709: val_loss did not improve from 1.20370
#
# Epoch 10710: val_loss did not improve from 1.20370
#
# Epoch 10711: val_loss did not improve from 1.20370
#
# Epoch 10712: val_loss did not improve from 1.20370
#
# Epoch 10713: val_loss did not improve from 1.20370
#
# Epoch 10714: val_loss did not improve from 1.20370
#
# Epoch 10715: val_loss did not improve from 1.20370
#
# Epoch 10716: val_loss did not improve from 1.20370
#
# Epoch 10717: val_loss did not improve from 1.20370
#
# Epoch 10718: val_loss did not improve from 1.20370
#
# Epoch 10719: val_loss did not improve from 1.20370
#
# Epoch 10720: val_loss did not improve from 1.20370
#
# Epoch 10721: val_loss did not improve from 1.20370
#
# Epoch 10722: val_loss did not improve from 1.20370
#
# Epoch 10723: val_loss did not improve from 1.20370
#
# Epoch 10724: val_loss did not improve from 1.20370
#
# Epoch 10725: val_loss did not improve from 1.20370
#
# Epoch 10726: val_loss did not improve from 1.20370
#
# Epoch 10727: val_loss did not improve from 1.20370
#
# Epoch 10728: val_loss did not improve from 1.20370
#
# Epoch 10729: val_loss did not improve from 1.20370
#
# Epoch 10730: val_loss did not improve from 1.20370
#
# Epoch 10731: val_loss did not improve from 1.20370
#
# Epoch 10732: val_loss did not improve from 1.20370
#
# Epoch 10733: val_loss did not improve from 1.20370
#
# Epoch 10734: val_loss did not improve from 1.20370
#
# Epoch 10735: val_loss did not improve from 1.20370
#
# Epoch 10736: val_loss did not improve from 1.20370
#
# Epoch 10737: val_loss did not improve from 1.20370
#
# Epoch 10738: val_loss did not improve from 1.20370
#
# Epoch 10739: val_loss did not improve from 1.20370
#
# Epoch 10740: val_loss did not improve from 1.20370
#
# Epoch 10741: val_loss did not improve from 1.20370
#
# Epoch 10742: val_loss did not improve from 1.20370
#
# Epoch 10743: val_loss did not improve from 1.20370
#
# Epoch 10744: val_loss did not improve from 1.20370
#
# Epoch 10745: val_loss did not improve from 1.20370
#
# Epoch 10746: val_loss did not improve from 1.20370
#
# Epoch 10747: val_loss did not improve from 1.20370
#
# Epoch 10748: val_loss did not improve from 1.20370
#
# Epoch 10749: val_loss did not improve from 1.20370
#
# Epoch 10750: val_loss did not improve from 1.20370
#
# Epoch 10751: val_loss did not improve from 1.20370
# Epoch 10752: val_loss did not improve from 1.20370
#
# Epoch 10753: val_loss did not improve from 1.20370
#
# Epoch 10754: val_loss did not improve from 1.20370
#
# Epoch 10755: val_loss did not improve from 1.20370
#
# Epoch 10756: val_loss did not improve from 1.20370
#
# Epoch 10757: val_loss did not improve from 1.20370
#
# Epoch 10758: val_loss did not improve from 1.20370
#
# Epoch 10759: val_loss did not improve from 1.20370
#
# Epoch 10760: val_loss did not improve from 1.20370
#
# Epoch 10761: val_loss did not improve from 1.20370
#
# Epoch 10762: val_loss did not improve from 1.20370
#
# Epoch 10763: val_loss did not improve from 1.20370
#
# Epoch 10764: val_loss did not improve from 1.20370
#
# Epoch 10765: val_loss did not improve from 1.20370
#
# Epoch 10766: val_loss did not improve from 1.20370
#
# Epoch 10767: val_loss did not improve from 1.20370
#
# Epoch 10768: val_loss did not improve from 1.20370
#
# Epoch 10769: val_loss did not improve from 1.20370
#
# Epoch 10770: val_loss did not improve from 1.20370
#
# Epoch 10771: val_loss did not improve from 1.20370
#
# Epoch 10772: val_loss did not improve from 1.20370
#
# Epoch 10773: val_loss did not improve from 1.20370
#
# Epoch 10774: val_loss did not improve from 1.20370
#
# Epoch 10775: val_loss did not improve from 1.20370
#
# Epoch 10776: val_loss did not improve from 1.20370
#
# Epoch 10777: val_loss did not improve from 1.20370
#
# Epoch 10778: val_loss did not improve from 1.20370
#
# Epoch 10779: val_loss did not improve from 1.20370
#
# Epoch 10780: val_loss did not improve from 1.20370
#
# Epoch 10781: val_loss did not improve from 1.20370
#
# Epoch 10782: val_loss did not improve from 1.20370
#
# Epoch 10783: val_loss did not improve from 1.20370
#
# Epoch 10784: val_loss did not improve from 1.20370
#
# Epoch 10785: val_loss did not improve from 1.20370
#
# Epoch 10786: val_loss did not improve from 1.20370
#
# Epoch 10787: val_loss did not improve from 1.20370
#
# Epoch 10788: val_loss did not improve from 1.20370
#
# Epoch 10789: val_loss did not improve from 1.20370
#
# Epoch 10790: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00383
#
# Epoch 10791: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00031
#
# Epoch 10792: val_loss did not improve from 1.20370
#
# Epoch 10793: val_loss did not improve from 1.20370
#
# Epoch 10794: val_loss did not improve from 1.20370
#
# Epoch 10795: val_loss did not improve from 1.20370
#
# Epoch 10796: val_loss did not improve from 1.20370
#
# Epoch 10797: val_loss did not improve from 1.20370
#
# Epoch 10798: val_loss did not improve from 1.20370
#
# Epoch 10799: val_loss did not improve from 1.20370
#
# Epoch 10800: val_loss did not improve from 1.20370
#
# Epoch 10801: val_loss did not improve from 1.20370
#
# Epoch 10802: val_loss did not improve from 1.20370
#
# Epoch 10803: val_loss did not improve from 1.20370
#
# Epoch 10804: val_loss did not improve from 1.20370
#
# Epoch 10805: val_loss did not improve from 1.20370
#
# Epoch 10806: val_loss did not improve from 1.20370
#
# Epoch 10807: val_loss did not improve from 1.20370
#
# Epoch 10808: val_loss did not improve from 1.20370
#
# Epoch 10809: val_loss did not improve from 1.20370
#
# Epoch 10810: val_loss did not improve from 1.20370
#
# Epoch 10811: val_loss did not improve from 1.20370
#
# Epoch 10812: val_loss did not improve from 1.20370
#
# Epoch 10813: val_loss did not improve from 1.20370
#
# Epoch 10814: val_loss did not improve from 1.20370
#
# Epoch 10815: val_loss did not improve from 1.20370
#
# Epoch 10816: val_loss did not improve from 1.20370
#
# Epoch 10817: val_loss did not improve from 1.20370
#
# Epoch 10818: val_loss did not improve from 1.20370
#
# Epoch 10819: val_loss did not improve from 1.20370
#
# Epoch 10820: val_loss did not improve from 1.20370
#
# Epoch 10821: val_loss did not improve from 1.20370
#
# Epoch 10822: val_loss did not improve from 1.20370
#
# Epoch 10823: val_loss did not improve from 1.20370
#
# Epoch 10824: val_loss did not improve from 1.20370
#
# Epoch 10825: val_loss did not improve from 1.20370
#
# Epoch 10826: val_loss did not improve from 1.20370
#
# Epoch 10827: val_loss did not improve from 1.20370
#
# Epoch 10828: val_loss did not improve from 1.20370
#
# Epoch 10829: val_loss did not improve from 1.20370
#
# Epoch 10830: val_loss did not improve from 1.20370
#
# Epoch 10831: val_loss did not improve from 1.20370
#
# Epoch 10832: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00383
#
# Epoch 10833: val_loss did not improve from 1.20370
#
# Epoch 10834: val_loss did not improve from 1.20370
#
# Epoch 10835: val_loss did not improve from 1.20370
#
# Epoch 10836: val_loss did not improve from 1.20370
#
# Epoch 10837: val_loss did not improve from 1.20370
#
# Epoch 10838: val_loss did not improve from 1.20370
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00316
#
# Epoch 10839: val_loss did not improve from 1.20370
#
# Epoch 10840: val_loss did not improve from 1.20370
#
# Epoch 10841: val_loss did not improve from 1.20370
#
# Epoch 10842: val_loss did not improve from 1.20370
#
# Epoch 10843: val_loss did not improve from 1.20370
#
# Epoch 10844: val_loss did not improve from 1.20370
#
# Epoch 10845: val_loss did not improve from 1.20370
#
# Epoch 10846: val_loss did not improve from 1.20370
#
# Epoch 10847: val_loss did not improve from 1.20370
#
# Epoch 10848: val_loss did not improve from 1.20370
#
# Epoch 10849: val_loss did not improve from 1.20370
#
# Epoch 10850: val_loss did not improve from 1.20370
#
# Epoch 10851: val_loss did not improve from 1.20370
#
# Epoch 10852: val_loss did not improve from 1.20370
#
# Epoch 10853: val_loss did not improve from 1.20370
#
# Epoch 10854: val_loss did not improve from 1.20370
#
# Epoch 10855: val_loss did not improve from 1.20370
#
# Epoch 10856: val_loss did not improve from 1.20370
#
# Epoch 10857: val_loss did not improve from 1.20370
#
# Epoch 10858: val_loss did not improve from 1.20370
#
# Epoch 10859: val_loss did not improve from 1.20370
#
# Epoch 10860: val_loss did not improve from 1.20370
#
# Epoch 10861: val_loss did not improve from 1.20370
#
# Epoch 10862: val_loss did not improve from 1.20370
#
# Epoch 10863: val_loss did not improve from 1.20370
#
# Epoch 10864: val_loss did not improve from 1.20370
#
# Epoch 10865: val_loss did not improve from 1.20370
#
# Epoch 10866: val_loss did not improve from 1.20370
#
# Epoch 10867: val_loss did not improve from 1.20370
#
# Epoch 10868: val_loss did not improve from 1.20370
#
# Epoch 10869: val_loss did not improve from 1.20370
#
# Epoch 10870: val_loss did not improve from 1.20370
#
# Epoch 10871: val_loss did not improve from 1.20370
#
# Epoch 10872: val_loss did not improve from 1.20370
#
# Epoch 10873: val_loss did not improve from 1.20370
#
# Epoch 10874: val_loss did not improve from 1.20370
#
# Epoch 10875: val_loss did not improve from 1.20370
#
# Epoch 10876: val_loss did not improve from 1.20370
#
# ...
#
# Epoch 47603: val_loss did not improve from 0.10908
#
# Epoch 47604: val_loss did not improve from 0.10908
#
# Epoch 47605: val_loss did not improve from 0.10908
#
# Epoch 47606: val_loss did not improve from 0.10908
#
# Epoch 47607: val_loss did not improve from 0.10908
#
# Epoch 47608: val_loss did not improve from 0.10908
#
# Epoch 47609: val_loss did not improve from 0.10908
#
# Epoch 47610: val_loss did not improve from 0.10908
#
# Epoch 47611: val_loss did not improve from 0.10908
#
# Epoch 47612: val_loss did not improve from 0.10908
#
# Epoch 47613: val_loss did not improve from 0.10908
#
# Epoch 47614: val_loss did not improve from 0.10908
#
# Epoch 47615: val_loss did not improve from 0.10908
#
# Epoch 47616: val_loss did not improve from 0.10908
#
# Epoch 47617: val_loss did not improve from 0.10908
#
# Epoch 47618: val_loss did not improve from 0.10908
#
# Epoch 47619: val_loss did not improve from 0.10908
#
# Epoch 47620: val_loss did not improve from 0.10908
#
# Epoch 47621: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00116
#
# Epoch 47622: val_loss did not improve from 0.10908
#
# Epoch 47623: val_loss did not improve from 0.10908
#
# Epoch 47624: val_loss did not improve from 0.10908
#
# Epoch 47625: val_loss did not improve from 0.10908
#
# Epoch 47626: val_loss did not improve from 0.10908
#
# Epoch 47627: val_loss did not improve from 0.10908
#
# Epoch 47628: val_loss did not improve from 0.10908
#
# Epoch 47629: val_loss did not improve from 0.10908
#
# Epoch 47630: val_loss did not improve from 0.10908
#
# Epoch 47631: val_loss did not improve from 0.10908
#
# Epoch 47632: val_loss did not improve from 0.10908
#
# Epoch 47633: val_loss did not improve from 0.10908
#
# Epoch 47634: val_loss did not improve from 0.10908
#
# Epoch 47635: val_loss did not improve from 0.10908
#
# Epoch 47636: val_loss did not improve from 0.10908
#
# Epoch 47637: val_loss did not improve from 0.10908
#
# Epoch 47638: val_loss did not improve from 0.10908
#
# Epoch 47639: val_loss did not improve from 0.10908
#
# Epoch 47640: val_loss did not improve from 0.10908
#
# Epoch 47641: val_loss did not improve from 0.10908
#
# Epoch 47642: val_loss did not improve from 0.10908
#
# Epoch 47643: val_loss did not improve from 0.10908
#
# Epoch 47644: val_loss did not improve from 0.10908
#
# Epoch 47645: val_loss did not improve from 0.10908
#
# Epoch 47646: val_loss did not improve from 0.10908
#
# Epoch 47647: val_loss did not improve from 0.10908
#
# Epoch 47648: val_loss did not improve from 0.10908
#
# Epoch 47649: val_loss did not improve from 0.10908
#
# Epoch 47650: val_loss did not improve from 0.10908
#
# Epoch 47651: val_loss did not improve from 0.10908
#
# Epoch 47652: val_loss did not improve from 0.10908
#
# Epoch 47653: val_loss did not improve from 0.10908
#
# Epoch 47654: val_loss did not improve from 0.10908
#
# Epoch 47655: val_loss did not improve from 0.10908
#
# Epoch 47656: val_loss did not improve from 0.10908
#
# Epoch 47657: val_loss did not improve from 0.10908
#
# Epoch 47658: val_loss did not improve from 0.10908
#
# Epoch 47659: val_loss did not improve from 0.10908
#
# Epoch 47660: val_loss did not improve from 0.10908
#
# Epoch 47661: val_loss did not improve from 0.10908
#
# Epoch 47662: val_loss did not improve from 0.10908
#
# Epoch 47663: val_loss did not improve from 0.10908
#
# Epoch 47664: val_loss did not improve from 0.10908
#
# Epoch 47665: val_loss did not improve from 0.10908
#
# Epoch 47666: val_loss did not improve from 0.10908
#
# Epoch 47667: val_loss did not improve from 0.10908
#
# Epoch 47668: val_loss did not improve from 0.10908
#
# Epoch 47669: val_loss did not improve from 0.10908
#
# Epoch 47670: val_loss did not improve from 0.10908
#
# Epoch 47671: val_loss did not improve from 0.10908
#
# Epoch 47672: val_loss did not improve from 0.10908
#
# Epoch 47673: val_loss did not improve from 0.10908
#
# Epoch 47674: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00116
#
# Epoch 47675: val_loss did not improve from 0.10908
#
# Epoch 47676: val_loss did not improve from 0.10908
#
# Epoch 47677: val_loss did not improve from 0.10908
#
# Epoch 47678: val_loss did not improve from 0.10908
#
# Epoch 47679: val_loss did not improve from 0.10908
#
# Epoch 47680: val_loss did not improve from 0.10908
#
# Epoch 47681: val_loss did not improve from 0.10908
#
# Epoch 47682: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/WINDS/train/WINDS_00042
#
# Epoch 47683: val_loss did not improve from 0.10908
#
# Epoch 47684: val_loss did not improve from 0.10908
#
# Epoch 47685: val_loss did not improve from 0.10908
#
# Epoch 47686: val_loss did not improve from 0.10908
# Epoch 47687: val_loss did not improve from 0.10908
#
# Epoch 47688: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/AUTHORITIES/train/AUTHORITIES_00912
#
# Epoch 47689: val_loss did not improve from 0.10908
#
# Epoch 47690: val_loss did not improve from 0.10908
#
# Epoch 47691: val_loss did not improve from 0.10908
#
# Epoch 47692: val_loss did not improve from 0.10908
#
# Epoch 47693: val_loss did not improve from 0.10908
#
# Epoch 47694: val_loss did not improve from 0.10908
#
# Epoch 47695: val_loss did not improve from 0.10908
#
# Epoch 47696: val_loss did not improve from 0.10908
#
# Epoch 47697: val_loss did not improve from 0.10908
#
# Epoch 47698: val_loss did not improve from 0.10908
#
# Epoch 47699: val_loss did not improve from 0.10908
#
# Epoch 47700: val_loss did not improve from 0.10908
#
# Epoch 47701: val_loss did not improve from 0.10908
#
# Epoch 47702: val_loss did not improve from 0.10908
#
# Epoch 47703: val_loss did not improve from 0.10908
#
# Epoch 47704: val_loss did not improve from 0.10908
#
# Epoch 47705: val_loss did not improve from 0.10908
#
# Epoch 47706: val_loss did not improve from 0.10908
#
# Epoch 47707: val_loss did not improve from 0.10908
#
# Epoch 47708: val_loss did not improve from 0.10908
#
# Epoch 47709: val_loss did not improve from 0.10908
#
# Epoch 47710: val_loss did not improve from 0.10908
#
# Epoch 47711: val_loss did not improve from 0.10908
#
# Epoch 47712: val_loss did not improve from 0.10908
#
# Epoch 47713: val_loss did not improve from 0.10908
#
# Epoch 47714: val_loss did not improve from 0.10908
#
# Epoch 47715: val_loss did not improve from 0.10908
#
# Epoch 47716: val_loss did not improve from 0.10908
#
# Epoch 47717: val_loss did not improve from 0.10908
#
# Epoch 47718: val_loss did not improve from 0.10908
#
# Epoch 47719: val_loss did not improve from 0.10908
#
# Epoch 47720: val_loss did not improve from 0.10908
#
# Epoch 47721: val_loss did not improve from 0.10908
#
# Epoch 47722: val_loss did not improve from 0.10908
#
# Epoch 47723: val_loss did not improve from 0.10908
#
# Epoch 47724: val_loss did not improve from 0.10908
#
# Epoch 47725: val_loss did not improve from 0.10908
#
# Epoch 47726: val_loss did not improve from 0.10908
#
# Epoch 47727: val_loss did not improve from 0.10908
#
# Epoch 47728: val_loss did not improve from 0.10908
#
# Epoch 47729: val_loss did not improve from 0.10908
#
# Epoch 47730: val_loss did not improve from 0.10908
#
# Epoch 47731: val_loss did not improve from 0.10908
#
# Epoch 47732: val_loss did not improve from 0.10908
#
# Epoch 47733: val_loss did not improve from 0.10908
#
# Epoch 47734: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/RIGHTS/train/RIGHTS_00812
#
# Epoch 47735: val_loss did not improve from 0.10908
#
# Epoch 47736: val_loss did not improve from 0.10908
#
# Epoch 47737: val_loss did not improve from 0.10908
#
# Epoch 47738: val_loss did not improve from 0.10908
#
# Epoch 47739: val_loss did not improve from 0.10908
#
# Epoch 47740: val_loss did not improve from 0.10908
#
# Epoch 47741: val_loss did not improve from 0.10908
#
# Epoch 47742: val_loss did not improve from 0.10908
#
# Epoch 47743: val_loss did not improve from 0.10908
#
# Epoch 47744: val_loss did not improve from 0.10908
#
# Epoch 47745: val_loss did not improve from 0.10908
#
# Epoch 47746: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00383
#
# Epoch 47747: val_loss did not improve from 0.10908
#
# Epoch 47748: val_loss did not improve from 0.10908
#
# Epoch 47749: val_loss did not improve from 0.10908
#
# Epoch 47750: val_loss did not improve from 0.10908
#
# Epoch 47751: val_loss did not improve from 0.10908
#
# Epoch 47752: val_loss did not improve from 0.10908
#
# Epoch 47753: val_loss did not improve from 0.10908
#
# Epoch 47754: val_loss did not improve from 0.10908
#
# Epoch 47755: val_loss did not improve from 0.10908
#
# Epoch 47756: val_loss did not improve from 0.10908
#
# Epoch 47757: val_loss did not improve from 0.10908
#
# Epoch 47758: val_loss did not improve from 0.10908
#
# Epoch 47759: val_loss did not improve from 0.10908
#
# Epoch 47760: val_loss did not improve from 0.10908
#
# Epoch 47761: val_loss did not improve from 0.10908
#
# Epoch 47762: val_loss did not improve from 0.10908
#
# Epoch 47763: val_loss did not improve from 0.10908
#
# Epoch 47764: val_loss did not improve from 0.10908
#
# Epoch 47765: val_loss did not improve from 0.10908
#
# Epoch 47766: val_loss did not improve from 0.10908
#
# Epoch 47767: val_loss did not improve from 0.10908
#
# Epoch 47768: val_loss did not improve from 0.10908
#
# Epoch 47769: val_loss did not improve from 0.10908
#
# Epoch 47770: val_loss did not improve from 0.10908
#
# Epoch 47771: val_loss did not improve from 0.10908
#
# Epoch 47772: val_loss did not improve from 0.10908
#
# Epoch 47773: val_loss did not improve from 0.10908
#
# Epoch 47774: val_loss did not improve from 0.10908
#
# Epoch 47775: val_loss did not improve from 0.10908
#
# Epoch 47776: val_loss did not improve from 0.10908
#
# Epoch 47777: val_loss did not improve from 0.10908
#
# Epoch 47778: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/TALKING/train/TALKING_00383
#
# Epoch 47779: val_loss did not improve from 0.10908
#
# Epoch 47780: val_loss did not improve from 0.10908
#
# Epoch 47781: val_loss did not improve from 0.10908
#
# Epoch 47782: val_loss did not improve from 0.10908
#
# Epoch 47783: val_loss did not improve from 0.10908
#
# Epoch 47784: val_loss did not improve from 0.10908
#
# Epoch 47785: val_loss did not improve from 0.10908
#
# Epoch 47786: val_loss did not improve from 0.10908
#
# Epoch 47787: val_loss did not improve from 0.10908
#
# Epoch 47788: val_loss did not improve from 0.10908
#
# Epoch 47789: val_loss did not improve from 0.10908
#
# Epoch 47790: val_loss did not improve from 0.10908
#
# Epoch 47791: val_loss did not improve from 0.10908
#
# Epoch 47792: val_loss did not improve from 0.10908
#
# Epoch 47793: val_loss did not improve from 0.10908
#
# Epoch 47794: val_loss did not improve from 0.10908
#
# Epoch 47795: val_loss did not improve from 0.10908
#
# Epoch 47796: val_loss did not improve from 0.10908
#
# Epoch 47797: val_loss did not improve from 0.10908
#
# Epoch 47798: val_loss did not improve from 0.10908
#
# Epoch 47799: val_loss did not improve from 0.10908
#
# Epoch 47800: val_loss did not improve from 0.10908
#
# Epoch 47801: val_loss did not improve from 0.10908
#
# Epoch 47802: val_loss did not improve from 0.10908
#
# Epoch 47803: val_loss did not improve from 0.10908
#
# Epoch 47804: val_loss did not improve from 0.10908
#
# Epoch 47805: val_loss did not improve from 0.10908
#
# Epoch 47806: val_loss did not improve from 0.10908
#
# Epoch 47807: val_loss did not improve from 0.10908
#
# Epoch 47808: val_loss did not improve from 0.10908
#
# Epoch 47809: val_loss did not improve from 0.10908
#
# Epoch 47810: val_loss did not improve from 0.10908
#
# Epoch 47811: val_loss did not improve from 0.10908
#
# Epoch 47812: val_loss did not improve from 0.10908
#
# Epoch 47813: val_loss did not improve from 0.10908
#
# Epoch 47814: val_loss did not improve from 0.10908
#
# Epoch 47815: val_loss did not improve from 0.10908
#
# Epoch 47816: val_loss did not improve from 0.10908
#
# Epoch 47817: val_loss did not improve from 0.10908
#
# Epoch 47818: val_loss did not improve from 0.10908
#
# Epoch 47819: val_loss did not improve from 0.10908
#
# Epoch 47820: val_loss did not improve from 0.10908
#
# Epoch 47821: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360
#
# Epoch 47822: val_loss did not improve from 0.10908
#
# Epoch 47823: val_loss did not improve from 0.10908
#
# Epoch 47824: val_loss did not improve from 0.10908
#
# Epoch 47825: val_loss did not improve from 0.10908
#
# Epoch 47826: val_loss did not improve from 0.10908
#
# Epoch 47827: val_loss did not improve from 0.10908
#
# Epoch 47828: val_loss did not improve from 0.10908
#
# Epoch 47829: val_loss did not improve from 0.10908
#
# Epoch 47830: val_loss did not improve from 0.10908
#
# Epoch 47831: val_loss did not improve from 0.10908
#
# Epoch 47832: val_loss did not improve from 0.10908
#
# Epoch 47833: val_loss did not improve from 0.10908
#
# Epoch 47834: val_loss did not improve from 0.10908
#
# Epoch 47835: val_loss did not improve from 0.10908
# Epoch 47836: val_loss did not improve from 0.10908
#
# Epoch 47837: val_loss did not improve from 0.10908
#
# Epoch 47838: val_loss did not improve from 0.10908
#
# Epoch 47839: val_loss did not improve from 0.10908
#
# Epoch 47840: val_loss did not improve from 0.10908
#
# Epoch 47841: val_loss did not improve from 0.10908
#
# Epoch 47842: val_loss did not improve from 0.10908
#
# Epoch 47843: val_loss did not improve from 0.10908
#
# Epoch 47844: val_loss did not improve from 0.10908
#
# Epoch 47845: val_loss did not improve from 0.10908
#
# Epoch 47846: val_loss did not improve from 0.10908
#
# Epoch 47847: val_loss did not improve from 0.10908
#
# Epoch 47848: val_loss did not improve from 0.10908
#
# Epoch 47849: val_loss did not improve from 0.10908
#
# Epoch 47850: val_loss did not improve from 0.10908
#
# Epoch 47851: val_loss did not improve from 0.10908
#
# Epoch 47852: val_loss did not improve from 0.10908
#
# Epoch 47853: val_loss did not improve from 0.10908
#
# Epoch 47854: val_loss did not improve from 0.10908
#
# Epoch 47855: val_loss did not improve from 0.10908
#
# Epoch 47856: val_loss did not improve from 0.10908
#
# Epoch 47857: val_loss did not improve from 0.10908
#
# Epoch 47858: val_loss did not improve from 0.10908
#
# Epoch 47859: val_loss did not improve from 0.10908
#
# Epoch 47860: val_loss did not improve from 0.10908
#
# Epoch 47861: val_loss did not improve from 0.10908
#
# Epoch 47862: val_loss did not improve from 0.10908
#
# Epoch 47863: val_loss did not improve from 0.10908
#
# Epoch 47864: val_loss did not improve from 0.10908
#
# Epoch 47865: val_loss did not improve from 0.10908
#
# Epoch 47866: val_loss did not improve from 0.10908
#
# Epoch 47867: val_loss did not improve from 0.10908
#
# Epoch 47868: val_loss did not improve from 0.10908
#
# Epoch 47869: val_loss did not improve from 0.10908
#
# Epoch 47870: val_loss did not improve from 0.10908
#
# Epoch 47871: val_loss did not improve from 0.10908
#
# Epoch 47872: val_loss did not improve from 0.10908
#
# Epoch 47873: val_loss did not improve from 0.10908
#
# Epoch 47874: val_loss did not improve from 0.10908
#
# Epoch 47875: val_loss did not improve from 0.10908
#
# Epoch 47876: val_loss did not improve from 0.10908
#
# Epoch 47877: val_loss did not improve from 0.10908
#
# Epoch 47878: val_loss did not improve from 0.10908
#
# Epoch 47879: val_loss did not improve from 0.10908
#
# Epoch 47880: val_loss did not improve from 0.10908
#
# Epoch 47881: val_loss did not improve from 0.10908
#
# Epoch 47882: val_loss did not improve from 0.10908
#
# Epoch 47883: val_loss did not improve from 0.10908
#
# Epoch 47884: val_loss did not improve from 0.10908
#
# Epoch 47885: val_loss did not improve from 0.10908
#
# Epoch 47886: val_loss did not improve from 0.10908
#
# Epoch 47887: val_loss did not improve from 0.10908
#
# Epoch 47888: val_loss did not improve from 0.10908
#
# Epoch 47889: val_loss did not improve from 0.10908
#
# Epoch 47890: val_loss did not improve from 0.10908
#
# Epoch 47891: val_loss did not improve from 0.10908
#
# Epoch 47892: val_loss did not improve from 0.10908
#
# Epoch 47893: val_loss did not improve from 0.10908
# error: (30,) training/unseen_speakers/TARGET/datasets/lipread_mp4/EVERYONE/train/EVERYONE_00360

# %% [markdown]
# # Testing

# %%
model.load_weights('training/unseen_speakers/results/weights_lfw-crop-ctc_classification-v4.hdf5')
model.input[0]
# Out:
# <tf.Tensor 'the_input:0' shape=(?, 30, 100, 50, 3) dtype=float32>

# %%
from keras.models import Model, Sequential

# %%
prediction_model = Model(inputs = model.input[0], outputs = [model.get_layer('softmax').output,model.get_layer('classification').output])

# %%
SVG(model_to_dot(prediction_model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import itertools


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=False):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(11, 11))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
g_test=datagen(train_path=train_path,data_partition='val',batch_size=16)
ctc_test = []
cls_test = []
true_data = []
for i in range(128):
    print(i/128, end='\r')
    x,y=next(g_test)
    for i in range(0,16):
        X = x['the_input'][i]
    #     print(X)
        y_true = x['source_str'][i]#words[np.argmax(y[0][i])]
#         print(y_true)
    #     print(Y)append(x['source_str'])
        ctc_preds, cls_preds = prediction_model.predict(np.expand_dims(X,0))
        cls = words[np.argmax(cls_preds)]
        decoded = K.ctc_decode(y_pred=ctc_preds, input_length=(30,) ,greedy=True, beam_width=50, top_paths=50)
        paths = [path.eval(session=K.get_session()) for path in decoded[0]]
        logprobs  = decoded[1].eval(session=K.get_session())
        preds = []
        for path in paths:
            preds.append(''.join([chr(65+v) for v in path[0] ]))
        preds = np.array(preds)[0]
        ctc_test.append(preds)
        cls_test.append(cls)
        true_data.append(y_true)
# Out:
# WARNING:tensorflow:From /home/rbc/anaconda3/envs/tf-gpu/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:4303: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# 0.9921875

# %%
# (ctc_test,cls_test,true_data)

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl

labels = words
true_data, ctc_test, cls_test = np.array(true_data), np.array(ctc_test), np.array(cls_test)
print(true_data.shape, ctc_test.shape, cls_test.shape)
cm = confusion_matrix(true_data, ctc_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix ctc')
cm = confusion_matrix(true_data, cls_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix cls')
# Out:
# (2048,) (2048,) (2048,)
