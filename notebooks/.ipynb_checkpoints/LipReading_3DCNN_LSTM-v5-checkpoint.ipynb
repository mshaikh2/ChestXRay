# %%
import tensorflow as tf
from keras.models import model_from_json
import os
import numpy as np
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import imageio
from matplotlib import pyplot as plt
import warnings
import cv2
import pandas as pd
from mtcnn.mtcnn import MTCNN
import keras.backend as K
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D,Lambda, TimeDistributed,Flatten, GRU
from keras.models import Model
from keras import backend as K
from keras.utils import to_categorical
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
warnings.filterwarnings("ignore")
from keras.callbacks import TensorBoard, CSVLogger, ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
tf_config = tf.ConfigProto(allow_soft_placement=False)
tf_config.gpu_options.allow_growth = True
s = tf.Session(config=tf_config)
K.set_session(s)

# %%
def _ctc_lambda_func(args):
    labels, y_pred, input_length, label_length = args
    y_pred = y_pred[:, :, :]
    return K.tf.keras.backend.ctc_batch_cost(labels, y_pred, input_length, label_length)
with open('LipReading_model.json') as f:
    loadedmodel = f.read()
lm = model_from_json(loadedmodel)
gru2 = lm.get_layer('bidirectional_14').output
gru3 = GRU(units=512,return_sequences=False)(gru2)

# ctc
_labels = lm.get_layer('the_labels').output
_y_pred = lm.get_layer('softmax').output
_input_length = lm.get_layer('input_length').output
_label_length = lm.get_layer('label_length').output

# cls
td = Dense(1024)(gru3)

# fl = Flatten()(td)
classification_output=Dense(21,activation='softmax', name='classification')(td)
ctc_loss = Lambda(_ctc_lambda_func, output_shape=(1,), name='ctc')([_labels,_y_pred,_input_length,_label_length])
model = Model(inputs=lm.input, outputs=[classification_output,ctc_loss])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_input (InputLayer)          (None, 30, 100, 50,  0
# __________________________________________________________________________________________________
# zero1 (ZeroPadding3D)           (None, 32, 104, 54,  0           the_input[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv3D)                  (None, 30, 50, 25, 3 7232        zero1[0][0]
# __________________________________________________________________________________________________
# batc1 (BatchNormalization)      (None, 30, 50, 25, 3 128         conv1[0][0]
# __________________________________________________________________________________________________
# actv1 (Activation)              (None, 30, 50, 25, 3 0           batc1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_19 (SpatialDr (None, 30, 50, 25, 3 0           actv1[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling3D)             (None, 30, 25, 12, 3 0           spatial_dropout3d_19[0][0]
# __________________________________________________________________________________________________
# zero2 (ZeroPadding3D)           (None, 32, 29, 16, 3 0           max1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv3D)                  (None, 30, 25, 12, 6 153664      zero2[0][0]
# __________________________________________________________________________________________________
# batc2 (BatchNormalization)      (None, 30, 25, 12, 6 256         conv2[0][0]
# __________________________________________________________________________________________________
# actv2 (Activation)              (None, 30, 25, 12, 6 0           batc2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_20 (SpatialDr (None, 30, 25, 12, 6 0           actv2[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling3D)             (None, 30, 12, 6, 64 0           spatial_dropout3d_20[0][0]
# __________________________________________________________________________________________________
# zero3 (ZeroPadding3D)           (None, 32, 14, 8, 64 0           max2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv3D)                  (None, 30, 12, 6, 96 165984      zero3[0][0]
# __________________________________________________________________________________________________
# batc3 (BatchNormalization)      (None, 30, 12, 6, 96 384         conv3[0][0]
# __________________________________________________________________________________________________
# actv3 (Activation)              (None, 30, 12, 6, 96 0           batc3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_21 (SpatialDr (None, 30, 12, 6, 96 0           actv3[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling3D)             (None, 30, 6, 3, 96) 0           spatial_dropout3d_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 30, 1728)     0           max3[0][0]
# __________________________________________________________________________________________________
# bidirectional_13 (Bidirectional (None, 30, 512)      3048960     time_distributed_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_14 (Bidirectional (None, 30, 512)      1181184     bidirectional_13[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     (None, 512)          1574400     bidirectional_14[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 30, 28)       14364       bidirectional_14[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         525312      gru_1[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 12)           0
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 30, 28)       0           dense1[0][0]
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# classification (Dense)          (None, 21)           21525       dense_1[0][0]
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           the_labels[0][0]
#                                                                  softmax[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 6,693,393
# Trainable params: 6,693,009
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
SVG(model_to_dot(model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
frames_count = 30
# words_folder = 'training/unseen_speakers/TARGET/datasets/lipread_mp4'
words = pd.read_csv('words_v2.csv')['words']
max_len = np.max([len(word) for word in words])

def datagen(data_partition = 'train', batch_size = 16):
    while True:
        counter = 0
        
        X_data = []#np.zeros((batch_size,))
        Y_data = []
        input_length = []
        label_length = []
        source_str = []
        word_id = []
        while counter<batch_size:
#             print(counter)
            word_idx = np.random.randint(len(words))
#             print('data part:', data_partition, ', word index', word_idx)
            
            train_folder = 'training/unseen_speakers/lrw_cropped/{0}/{1}/'.format(words[word_idx],data_partition)
        #         print(train_folder)
            files = os.listdir(train_folder)
        #         print(files)
            paths = list(set([x.split('.')[0] for x in files]))
        
            idx = np.random.randint(len(paths))
            path = os.path.join(train_folder,paths[idx])
#             print(path)
            frames = []
            for img_name in sorted(os.listdir(path)):
                img = cv2.imread(os.path.join(path,img_name))
                frames.append(img)
            frames = np.array(frames)
#             print(frames.shape, path)
            if len(frames.shape)==4:
#                 frames = np.rollaxis(frames,2, start=1)
    #             print(path)
    #             print(frames.shape)
    #             print('---------')
                if 'numpy.ndarray' in str(type(frames)) \
                        and len(np.shape(frames))==4 \
                        and np.shape(frames)[1] == 100 \
                        and np.shape(frames)[2] == 50:
#                     print(frames.shape, path)
                    if len(frames)<30:
                        diff = 30-len(frames)
            #             print(fr[-1].shape)
                        for i in range(diff):
                            frames = np.insert(arr = frames,values = frames[-1], obj=[-1], axis = 0)
                    X_data.append(frames)
                    ####
                    Y_data.append([ord(c) - 65 for c in words[word_idx]]+[-1]*(max_len-len(words[word_idx])))
                    input_length.append(frames_count)
                    label_length.append(len(words[word_idx]))
                    source_str.append(words[word_idx])
                    word_id.append(word_idx)
                    counter+=1
#                     print(counter)
                else:
                    continue
            else:
                print('error:', frames.shape, path)
                continue

        X_data = np.array(X_data).astype(np.float32) / 255 
        Y_data = np.array(Y_data)
        input_length = np.array(input_length)
        label_length = np.array(label_length)
        source_str = np.array(source_str)
        
        inputs = {'the_input': X_data,
                  'the_labels': Y_data,
                  'input_length': input_length,
                  'label_length': label_length,
                  'source_str': source_str  # used for visualization only
                  }
        ctc_outpts = np.zeros([batch_size])
        classes = to_categorical(y=word_id,num_classes=len(words))   
        
#         print('the_input:', inputs['the_input'].shape)
#         print('the_labels:', inputs['the_labels'].shape)
#         print('input_length:', inputs['input_length'].shape)
#         print('label_length:', inputs['label_length'].shape)
#         print('source_str:', inputs['source_str'].shape)
#         print('batch_frames_shape',X_data.shape, data_partition)

        yield inputs, [classes,ctc_outpts]

# %%
g_tr=datagen(data_partition='train',batch_size=128)
g_val=datagen(data_partition='val',batch_size=128)

# %%
x,y=next(g_val)
display(x['the_input'].shape,x['the_input'].min(),x['the_input'].max(),x['the_labels'],x['input_length'],x['label_length'],x['source_str'])
np.argmax(y[0],axis=1)
# Out:
# (128, 30, 100, 50, 3)
# 0.0
# 1.0
# array([[ 2, 14, 13, ...,  8, 21,  4],
#        [19,  4, 12, ..., 17,  4, 18],
#        [ 6, 14, 21, ..., 19, -1, -1],
#        ...,
#        [15,  0, 17, ..., 19, -1, -1],
#        [19,  4, 12, ..., 17,  4, 18],
#        [ 4, 12,  4, ..., -1, -1, -1]])
# array([30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#        30, 30, 30, 30, 30, 30, 30, 30, 30])
# array([12, 12, 10,  7,  8, 10, 10,  9,  9, 11, 10, 10, 10,  7,  9, 12,  9,
#        11, 12, 10, 10, 10,  9,  7,  9,  9, 11, 12,  8, 10, 10,  9, 10, 12,
#         9, 12, 10, 10,  7, 10,  8,  9,  9, 10,  9, 11, 10, 10, 10,  9, 10,
#         8, 11, 12,  9, 11, 11, 10, 12,  8, 10, 10,  7,  9, 12, 10,  9, 10,
#         9,  8, 11,  9, 11,  7, 11, 10,  9,  8, 11, 12,  7,  9,  8, 11,  7,
#        10, 10, 11,  9, 10, 12,  7, 11, 12, 10, 11, 11,  9,  7, 10, 10, 11,
#        11, 10, 10, 10,  9,  9, 11, 10, 10, 10,  9,  7, 10,  9,  9, 12,  9,
#         7,  7, 10,  9,  9,  9, 10, 12,  9])
# array(['CONSERVATIVE', 'TEMPERATURES', 'GOVERNMENT', 'SEVERAL',
#        'EXPECTED', 'REFERENDUM', 'THEMSELVES', 'EVERYBODY', 'EMERGENCY',
#        'IMMIGRATION', 'REFERENDUM', 'ABSOLUTELY', 'REFERENDUM', 'BETWEEN',
#        'EMERGENCY', 'TEMPERATURES', 'EVERYBODY', 'WESTMINSTER',
#        'CONSERVATIVE', 'PARLIAMENT', 'CONFERENCE', 'OPPOSITION',
#        'EVERYBODY', 'BETWEEN', 'EVERYBODY', 'FINANCIAL', 'WESTMINSTER',
#        'TEMPERATURES', 'EXPECTED', 'PARLIAMENT', 'GOVERNMENT',
#        'EMERGENCY', 'THEMSELVES', 'CONSERVATIVE', 'AFTERNOON',
#        'CONSERVATIVE', 'PARLIAMENT', 'ABSOLUTELY', 'BETWEEN',
#        'CONFERENCE', 'EXPECTED', 'AGREEMENT', 'EMERGENCY', 'ABSOLUTELY',
#        'EVERYBODY', 'INDEPENDENT', 'PARLIAMENT', 'PARLIAMENT',
#        'REFERENDUM', 'EVERYBODY', 'REFERENDUM', 'EXPECTED', 'IMMIGRATION',
#        'CONSERVATIVE', 'AGREEMENT', 'INDEPENDENT', 'IMMIGRATION',
#        'ABSOLUTELY', 'CONSERVATIVE', 'EXPECTED', 'CONFERENCE',
#        'PARLIAMENT', 'BETWEEN', 'EMERGENCY', 'TEMPERATURES', 'PARLIAMENT',
#        'AGREEMENT', 'PARLIAMENT', 'AFTERNOON', 'EXPECTED', 'SIGNIFICANT',
#        'EVERYBODY', 'IMMIGRATION', 'BETWEEN', 'SIGNIFICANT', 'OPPOSITION',
#        'AFTERNOON', 'EXPECTED', 'WESTMINSTER', 'TEMPERATURES', 'BETWEEN',
#        'AGREEMENT', 'EXPECTED', 'IMMIGRATION', 'BETWEEN', 'GOVERNMENT',
#        'CONFERENCE', 'IMMIGRATION', 'EMERGENCY', 'GOVERNMENT',
#        'TEMPERATURES', 'BETWEEN', 'IMMIGRATION', 'CONSERVATIVE',
#        'ABSOLUTELY', 'IMMIGRATION', 'WESTMINSTER', 'AGREEMENT', 'SEVERAL',
#        'OPPOSITION', 'GOVERNMENT', 'WESTMINSTER', 'WESTMINSTER',
#        'OPPOSITION', 'REFERENDUM', 'CONFERENCE', 'FINANCIAL', 'AFTERNOON',
#        'IMMIGRATION', 'CONFERENCE', 'ABSOLUTELY', 'THEMSELVES',
#        'EVERYBODY', 'SEVERAL', 'CONFERENCE', 'EVERYBODY', 'EMERGENCY',
#        'TEMPERATURES', 'EVERYBODY', 'BETWEEN', 'SEVERAL', 'THEMSELVES',
#        'EMERGENCY', 'AGREEMENT', 'AGREEMENT', 'PARLIAMENT',
#        'TEMPERATURES', 'EMERGENCY'], dtype='<U12')
# array([ 5, 18, 10, 16,  8, 15, 19,  7,  6, 11, 15,  0, 15,  3,  6, 18,  7,
#        20,  5, 14,  4, 13,  7,  3,  7,  9, 20, 18,  8, 14, 10,  6, 19,  5,
#         1,  5, 14,  0,  3,  4,  8,  2,  6,  0,  7, 12, 14, 14, 15,  7, 15,
#         8, 11,  5,  2, 12, 11,  0,  5,  8,  4, 14,  3,  6, 18, 14,  2, 14,
#         1,  8, 17,  7, 11,  3, 17, 13,  1,  8, 20, 18,  3,  2,  8, 11,  3,
#        10,  4, 11,  6, 10, 18,  3, 11,  5,  0, 11, 20,  2, 16, 13, 10, 20,
#        20, 13, 15,  4,  9,  1, 11,  4,  0, 19,  7, 16,  4,  7,  6, 18,  7,
#         3, 16, 19,  6,  2,  2, 14, 18,  6])

# %%
words
# Out:
# 0       ABSOLUTELY
# 1        AFTERNOON
# 2        AGREEMENT
# 3          BETWEEN
# 4       CONFERENCE
# 5     CONSERVATIVE
# 6        EMERGENCY
# 7        EVERYBODY
# 8         EXPECTED
# 9        FINANCIAL
# 10      GOVERNMENT
# 11     IMMIGRATION
# 12     INDEPENDENT
# 13      OPPOSITION
# 14      PARLIAMENT
# 15      REFERENDUM
# 16         SEVERAL
# 17     SIGNIFICANT
# 18    TEMPERATURES
# 19      THEMSELVES
# 20     WESTMINSTER
# Name: words, dtype: object

# %%
X = x['the_input'][10]
print()
fig = plt.figure(figsize=(30,30))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(30):
    ax = fig.add_subplot(1, 30, i + 1, xticks=[], yticks=[])
    ax.imshow(X[i])

# %%
# tensorboard = TensorBoard(log_dir=os.path.join(LOG_DIR, 'tune-crop-'+run_name))
# csv_logger  = CSVLogger(os.path.join(LOG_DIR, "{}-{}.csv".format('training',run_name)), separator=',', append=True)
checkpoint  = ModelCheckpoint(save_best_only=True,
                              filepath='training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5'
                              , monitor='val_loss'
                              , verbose=1
                              , mode='min'
                              , period=1)
es = EarlyStopping(patience=10000, monitor='val_loss', min_delta=0.0005, mode='auto')

# %%
# def test_loss(y_true, y_pred): 
#     return y_pred

# %%
from keras.optimizers import Adadelta,Adam
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=1e-08)
# _labels = lm.get_layer('the_labels').output
# _y_pred = lm.get_layer('softmax').output
# _input_length = lm.get_layer('input_length').output
# _label_length = lm.get_layer('label_length').output
# model.add_loss(ctc_loss)
losses = {
    'ctc':lambda y_true,y_pred:y_pred,
    'classification':'categorical_crossentropy'
}
model.compile(loss=losses, optimizer=adam, metrics=['accuracy'])

# %%
EPOCHS = 50000
# model.load_weights('training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5')
hist = model.fit_generator(g_tr
                    , steps_per_epoch=1
                    , epochs=EPOCHS
                    #steps_per_epoch=lip_gen.default_training_steps, epochs=stop_epoch,
                    , validation_data=g_val
                    , validation_steps=1
                    ,callbacks=[checkpoint,es]
                    ,initial_epoch=0
                    ,verbose=3)
                    #max_q_size=5,
                    #workers=2,
                    #pickle_safe=True)
# Out:
# Epoch 1/50000
#
# Epoch 00001: val_loss improved from inf to 69.75608, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 2/50000
#
# Epoch 00002: val_loss improved from 69.75608 to 59.51804, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 3/50000
#
# Epoch 00003: val_loss improved from 59.51804 to 52.29150, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 4/50000
#
# Epoch 00004: val_loss improved from 52.29150 to 46.10154, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 5/50000
#
# Epoch 00005: val_loss did not improve from 46.10154
# Epoch 6/50000
#
# Epoch 00006: val_loss did not improve from 46.10154
# Epoch 7/50000
#
# Epoch 00007: val_loss did not improve from 46.10154
# Epoch 8/50000
#
# Epoch 00008: val_loss did not improve from 46.10154
# Epoch 9/50000
#
# Epoch 00009: val_loss improved from 46.10154 to 41.76971, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 10/50000
#
# Epoch 00010: val_loss improved from 41.76971 to 39.29167, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 11/50000
#
# Epoch 00011: val_loss did not improve from 39.29167
# Epoch 12/50000
#
# Epoch 00012: val_loss did not improve from 39.29167
# Epoch 13/50000
#
# Epoch 00013: val_loss did not improve from 39.29167
# Epoch 14/50000
#
# Epoch 00014: val_loss did not improve from 39.29167
# Epoch 15/50000
#
# Epoch 00015: val_loss improved from 39.29167 to 36.05744, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 16/50000
#
# Epoch 00016: val_loss improved from 36.05744 to 34.80936, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 17/50000
#
# Epoch 00017: val_loss improved from 34.80936 to 33.35006, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 18/50000
#
# Epoch 00018: val_loss improved from 33.35006 to 33.19549, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 19/50000
#
# Epoch 00019: val_loss did not improve from 33.19549
# Epoch 20/50000
#
# Epoch 00020: val_loss did not improve from 33.19549
# Epoch 21/50000
#
# Epoch 00021: val_loss did not improve from 33.19549
# Epoch 22/50000
#
# Epoch 00022: val_loss improved from 33.19549 to 32.56833, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 23/50000
#
# Epoch 00023: val_loss improved from 32.56833 to 32.53595, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 24/50000
#
# Epoch 00024: val_loss improved from 32.53595 to 32.18904, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 25/50000
#
# Epoch 00025: val_loss did not improve from 32.18904
# Epoch 26/50000
#
# Epoch 00026: val_loss did not improve from 32.18904
# Epoch 27/50000
#
# Epoch 00027: val_loss did not improve from 32.18904
# Epoch 28/50000
#
# Epoch 00028: val_loss did not improve from 32.18904
# Epoch 29/50000
#
# Epoch 00029: val_loss did not improve from 32.18904
# Epoch 30/50000
#
# Epoch 00030: val_loss did not improve from 32.18904
# Epoch 31/50000
#
# Epoch 00031: val_loss did not improve from 32.18904
# Epoch 32/50000
#
# Epoch 00032: val_loss did not improve from 32.18904
# Epoch 33/50000
#
# Epoch 00033: val_loss did not improve from 32.18904
# Epoch 34/50000
#
# Epoch 00034: val_loss did not improve from 32.18904
# Epoch 35/50000
#
# Epoch 00035: val_loss improved from 32.18904 to 32.15402, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 36/50000
#
# Epoch 00036: val_loss improved from 32.15402 to 31.81322, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 37/50000
#
# Epoch 00037: val_loss improved from 31.81322 to 31.47107, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 38/50000
#
# Epoch 00038: val_loss did not improve from 31.47107
# Epoch 39/50000
#
# Epoch 00039: val_loss did not improve from 31.47107
# Epoch 40/50000
#
# Epoch 00040: val_loss did not improve from 31.47107
# Epoch 41/50000
#
# Epoch 00041: val_loss did not improve from 31.47107
# Epoch 42/50000
#
# Epoch 00042: val_loss did not improve from 31.47107
# Epoch 43/50000
#
# Epoch 00043: val_loss improved from 31.47107 to 31.22706, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 44/50000
#
# Epoch 00044: val_loss improved from 31.22706 to 31.04273, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 45/50000
#
# Epoch 00045: val_loss did not improve from 31.04273
# Epoch 46/50000
#
# Epoch 00046: val_loss did not improve from 31.04273
# Epoch 47/50000
#
# Epoch 00047: val_loss did not improve from 31.04273
# Epoch 48/50000
#
# Epoch 00048: val_loss did not improve from 31.04273
# Epoch 49/50000
#
# Epoch 00049: val_loss did not improve from 31.04273
# Epoch 50/50000
#
# Epoch 00050: val_loss did not improve from 31.04273
# Epoch 51/50000
#
# Epoch 00051: val_loss did not improve from 31.04273
# Epoch 52/50000
#
# Epoch 00052: val_loss did not improve from 31.04273
# Epoch 53/50000
#
# Epoch 00053: val_loss did not improve from 31.04273
# Epoch 54/50000
#
# Epoch 00054: val_loss did not improve from 31.04273
# Epoch 55/50000
#
# Epoch 00055: val_loss did not improve from 31.04273
# Epoch 56/50000
#
# Epoch 00056: val_loss did not improve from 31.04273
# Epoch 57/50000
#
# Epoch 00057: val_loss did not improve from 31.04273
# Epoch 58/50000
#
# Epoch 00058: val_loss did not improve from 31.04273
# Epoch 59/50000
#
# Epoch 00059: val_loss did not improve from 31.04273
# Epoch 60/50000
#
# Epoch 00060: val_loss did not improve from 31.04273
# Epoch 61/50000
#
# Epoch 00061: val_loss did not improve from 31.04273
# Epoch 62/50000
#
# Epoch 00062: val_loss did not improve from 31.04273
# Epoch 63/50000
#
# Epoch 00063: val_loss did not improve from 31.04273
# Epoch 64/50000
#
# Epoch 00064: val_loss did not improve from 31.04273
# Epoch 65/50000
#
# Epoch 00065: val_loss improved from 31.04273 to 30.70086, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 66/50000
#
# Epoch 00066: val_loss improved from 30.70086 to 30.60459, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 67/50000
#
# Epoch 00067: val_loss did not improve from 30.60459
# Epoch 68/50000
#
# Epoch 00068: val_loss did not improve from 30.60459
# Epoch 69/50000
#
# Epoch 00069: val_loss did not improve from 30.60459
# Epoch 70/50000
#
# Epoch 00070: val_loss did not improve from 30.60459
# Epoch 71/50000
#
# Epoch 00071: val_loss did not improve from 30.60459
# Epoch 72/50000
#
# Epoch 00072: val_loss did not improve from 30.60459
# Epoch 73/50000
#
# Epoch 00073: val_loss did not improve from 30.60459
# Epoch 74/50000
#
# Epoch 00074: val_loss did not improve from 30.60459
# Epoch 75/50000
#
# Epoch 00075: val_loss did not improve from 30.60459
# Epoch 76/50000
#
# Epoch 00076: val_loss did not improve from 30.60459
# Epoch 77/50000
#
# Epoch 00077: val_loss did not improve from 30.60459
# Epoch 78/50000
#
# Epoch 00078: val_loss did not improve from 30.60459
# Epoch 79/50000
#
# Epoch 00079: val_loss did not improve from 30.60459
# Epoch 80/50000
#
# Epoch 00080: val_loss did not improve from 30.60459
# Epoch 81/50000
#
# Epoch 00081: val_loss did not improve from 30.60459
# Epoch 82/50000
#
# Epoch 00082: val_loss improved from 30.60459 to 30.59639, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 83/50000
#
# Epoch 00083: val_loss did not improve from 30.59639
# Epoch 84/50000
#
# Epoch 00084: val_loss did not improve from 30.59639
# Epoch 85/50000
#
# Epoch 00085: val_loss did not improve from 30.59639
# Epoch 86/50000
#
# Epoch 00086: val_loss did not improve from 30.59639
# Epoch 87/50000
#
# Epoch 00087: val_loss did not improve from 30.59639
# Epoch 88/50000
#
# Epoch 00088: val_loss did not improve from 30.59639
# Epoch 89/50000
#
# Epoch 00089: val_loss did not improve from 30.59639
# Epoch 90/50000
#
# Epoch 00090: val_loss did not improve from 30.59639
# Epoch 91/50000
#
# Epoch 00091: val_loss did not improve from 30.59639
# Epoch 92/50000
#
# Epoch 00092: val_loss did not improve from 30.59639
# Epoch 93/50000
#
# Epoch 00093: val_loss did not improve from 30.59639
# Epoch 94/50000
#
# Epoch 00094: val_loss did not improve from 30.59639
# Epoch 95/50000
# Epoch 00095: val_loss did not improve from 30.59639
# Epoch 96/50000
#
# Epoch 00096: val_loss did not improve from 30.59639
# Epoch 97/50000
#
# Epoch 00097: val_loss did not improve from 30.59639
# Epoch 98/50000
#
# Epoch 00098: val_loss did not improve from 30.59639
# Epoch 99/50000
#
# Epoch 00099: val_loss did not improve from 30.59639
# Epoch 100/50000
#
# Epoch 00100: val_loss did not improve from 30.59639
# Epoch 101/50000
#
# Epoch 00101: val_loss improved from 30.59639 to 30.57225, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 102/50000
#
# Epoch 00102: val_loss did not improve from 30.57225
# Epoch 103/50000
#
# Epoch 00103: val_loss improved from 30.57225 to 30.50350, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 104/50000
#
# Epoch 00104: val_loss did not improve from 30.50350
# Epoch 105/50000
#
# Epoch 00105: val_loss did not improve from 30.50350
# Epoch 106/50000
#
# Epoch 00106: val_loss did not improve from 30.50350
# Epoch 107/50000
#
# Epoch 00107: val_loss did not improve from 30.50350
# Epoch 108/50000
#
# Epoch 00108: val_loss did not improve from 30.50350
# Epoch 109/50000
#
# Epoch 00109: val_loss improved from 30.50350 to 30.43133, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 110/50000
#
# Epoch 00110: val_loss did not improve from 30.43133
# Epoch 111/50000
#
# Epoch 00111: val_loss did not improve from 30.43133
# Epoch 112/50000
#
# Epoch 00112: val_loss did not improve from 30.43133
# Epoch 113/50000
#
# Epoch 00113: val_loss did not improve from 30.43133
# Epoch 114/50000
#
# Epoch 00114: val_loss did not improve from 30.43133
# Epoch 115/50000
#
# Epoch 00115: val_loss did not improve from 30.43133
# Epoch 116/50000
#
# Epoch 00116: val_loss did not improve from 30.43133
# Epoch 117/50000
#
# Epoch 00117: val_loss did not improve from 30.43133
# Epoch 118/50000
#
# Epoch 00118: val_loss did not improve from 30.43133
# Epoch 119/50000
#
# Epoch 00119: val_loss improved from 30.43133 to 30.34076, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 120/50000
#
# Epoch 00120: val_loss improved from 30.34076 to 30.26532, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 121/50000
#
# Epoch 00121: val_loss did not improve from 30.26532
# Epoch 122/50000
#
# Epoch 00122: val_loss did not improve from 30.26532
# Epoch 123/50000
#
# Epoch 00123: val_loss improved from 30.26532 to 29.96274, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 124/50000
#
# Epoch 00124: val_loss did not improve from 29.96274
# Epoch 125/50000
#
# Epoch 00125: val_loss did not improve from 29.96274
# Epoch 126/50000
#
# Epoch 00126: val_loss did not improve from 29.96274
# Epoch 127/50000
#
# Epoch 00127: val_loss did not improve from 29.96274
# Epoch 128/50000
#
# Epoch 00128: val_loss did not improve from 29.96274
# Epoch 129/50000
#
# Epoch 00129: val_loss did not improve from 29.96274
# Epoch 130/50000
#
# Epoch 00130: val_loss did not improve from 29.96274
# Epoch 131/50000
#
# Epoch 00131: val_loss did not improve from 29.96274
# Epoch 132/50000
#
# Epoch 00132: val_loss did not improve from 29.96274
# Epoch 133/50000
#
# Epoch 00133: val_loss did not improve from 29.96274
# Epoch 134/50000
#
# Epoch 00134: val_loss did not improve from 29.96274
# Epoch 135/50000
#
# Epoch 00135: val_loss did not improve from 29.96274
# Epoch 136/50000
#
# Epoch 00136: val_loss improved from 29.96274 to 29.81101, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 137/50000
#
# Epoch 00137: val_loss did not improve from 29.81101
# Epoch 138/50000
#
# Epoch 00138: val_loss did not improve from 29.81101
# Epoch 139/50000
#
# Epoch 00139: val_loss did not improve from 29.81101
# Epoch 140/50000
#
# Epoch 00140: val_loss did not improve from 29.81101
# Epoch 141/50000
#
# Epoch 00141: val_loss did not improve from 29.81101
# Epoch 142/50000
#
# Epoch 00142: val_loss did not improve from 29.81101
# Epoch 143/50000
#
# Epoch 00143: val_loss did not improve from 29.81101
# Epoch 144/50000
#
# Epoch 00144: val_loss did not improve from 29.81101
# Epoch 145/50000
#
# Epoch 00145: val_loss did not improve from 29.81101
# Epoch 146/50000
#
# Epoch 00146: val_loss did not improve from 29.81101
# Epoch 147/50000
#
# Epoch 00147: val_loss did not improve from 29.81101
# Epoch 148/50000
#
# Epoch 00148: val_loss did not improve from 29.81101
# Epoch 149/50000
#
# Epoch 00149: val_loss did not improve from 29.81101
# Epoch 150/50000
#
# Epoch 00150: val_loss did not improve from 29.81101
# Epoch 151/50000
#
# Epoch 00151: val_loss did not improve from 29.81101
# Epoch 152/50000
#
# Epoch 00152: val_loss did not improve from 29.81101
# Epoch 153/50000
#
# Epoch 00153: val_loss did not improve from 29.81101
# Epoch 154/50000
#
# Epoch 00154: val_loss did not improve from 29.81101
# Epoch 155/50000
#
# Epoch 00155: val_loss did not improve from 29.81101
# Epoch 156/50000
#
# Epoch 00156: val_loss did not improve from 29.81101
# Epoch 157/50000
#
# Epoch 00157: val_loss did not improve from 29.81101
# Epoch 158/50000
#
# Epoch 00158: val_loss improved from 29.81101 to 29.77144, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 159/50000
#
# Epoch 00159: val_loss did not improve from 29.77144
# Epoch 160/50000
#
# Epoch 00160: val_loss did not improve from 29.77144
# Epoch 161/50000
#
# Epoch 00161: val_loss did not improve from 29.77144
# Epoch 162/50000
#
# Epoch 00162: val_loss did not improve from 29.77144
# Epoch 163/50000
#
# Epoch 00163: val_loss did not improve from 29.77144
# Epoch 164/50000
#
# Epoch 00164: val_loss did not improve from 29.77144
# Epoch 165/50000
#
# Epoch 00165: val_loss did not improve from 29.77144
# Epoch 166/50000
#
# Epoch 00166: val_loss did not improve from 29.77144
# Epoch 167/50000
#
# Epoch 00167: val_loss did not improve from 29.77144
# Epoch 168/50000
#
# Epoch 00168: val_loss did not improve from 29.77144
# Epoch 169/50000
#
# Epoch 00169: val_loss did not improve from 29.77144
# Epoch 170/50000
#
# Epoch 00170: val_loss did not improve from 29.77144
# Epoch 171/50000
#
# Epoch 00171: val_loss did not improve from 29.77144
# Epoch 172/50000
#
# Epoch 00172: val_loss did not improve from 29.77144
# Epoch 173/50000
#
# Epoch 00173: val_loss did not improve from 29.77144
# Epoch 174/50000
#
# Epoch 00174: val_loss improved from 29.77144 to 29.30707, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 175/50000
#
# Epoch 00175: val_loss did not improve from 29.30707
# Epoch 176/50000
#
# Epoch 00176: val_loss did not improve from 29.30707
# Epoch 177/50000
#
# Epoch 00177: val_loss did not improve from 29.30707
# Epoch 178/50000
#
# Epoch 00178: val_loss did not improve from 29.30707
# Epoch 179/50000
#
# Epoch 00179: val_loss did not improve from 29.30707
# Epoch 180/50000
#
# Epoch 00180: val_loss did not improve from 29.30707
# Epoch 181/50000
#
# Epoch 00181: val_loss did not improve from 29.30707
# Epoch 182/50000
#
# Epoch 00182: val_loss did not improve from 29.30707
# Epoch 183/50000
#
# Epoch 00183: val_loss did not improve from 29.30707
# Epoch 184/50000
#
# Epoch 00184: val_loss did not improve from 29.30707
# Epoch 185/50000
#
# Epoch 00185: val_loss did not improve from 29.30707
# Epoch 186/50000
#
# Epoch 00186: val_loss did not improve from 29.30707
# Epoch 187/50000
#
# Epoch 00187: val_loss did not improve from 29.30707
# Epoch 188/50000
#
# Epoch 00188: val_loss did not improve from 29.30707
# Epoch 189/50000
#
# Epoch 00189: val_loss did not improve from 29.30707
# Epoch 190/50000
#
# Epoch 00190: val_loss improved from 29.30707 to 29.26465, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 191/50000
#
# Epoch 00191: val_loss did not improve from 29.26465
# Epoch 192/50000
#
# Epoch 00192: val_loss did not improve from 29.26465
# Epoch 193/50000
#
# Epoch 00193: val_loss did not improve from 29.26465
# Epoch 194/50000
#
# Epoch 00194: val_loss did not improve from 29.26465
# Epoch 195/50000
#
# Epoch 00195: val_loss did not improve from 29.26465
# Epoch 196/50000
#
# Epoch 00196: val_loss did not improve from 29.26465
# Epoch 197/50000
#
# Epoch 00197: val_loss did not improve from 29.26465
# Epoch 198/50000
#
# Epoch 00198: val_loss did not improve from 29.26465
# Epoch 199/50000
#
# Epoch 00199: val_loss did not improve from 29.26465
# Epoch 200/50000
#
# Epoch 00200: val_loss did not improve from 29.26465
# Epoch 201/50000
#
# Epoch 00201: val_loss did not improve from 29.26465
# Epoch 202/50000
# Epoch 00202: val_loss did not improve from 29.26465
# Epoch 203/50000
#
# Epoch 00203: val_loss did not improve from 29.26465
# Epoch 204/50000
#
# Epoch 00204: val_loss did not improve from 29.26465
# Epoch 205/50000
#
# Epoch 00205: val_loss improved from 29.26465 to 29.10901, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 206/50000
#
# Epoch 00206: val_loss did not improve from 29.10901
# Epoch 207/50000
#
# Epoch 00207: val_loss did not improve from 29.10901
# Epoch 208/50000
#
# Epoch 00208: val_loss did not improve from 29.10901
# Epoch 209/50000
#
# Epoch 00209: val_loss did not improve from 29.10901
# Epoch 210/50000
#
# Epoch 00210: val_loss did not improve from 29.10901
# Epoch 211/50000
#
# Epoch 00211: val_loss did not improve from 29.10901
# Epoch 212/50000
#
# Epoch 00212: val_loss did not improve from 29.10901
# Epoch 213/50000
#
# Epoch 00213: val_loss did not improve from 29.10901
# Epoch 214/50000
#
# Epoch 00214: val_loss did not improve from 29.10901
# Epoch 215/50000
#
# Epoch 00215: val_loss did not improve from 29.10901
# Epoch 216/50000
#
# Epoch 00216: val_loss did not improve from 29.10901
# Epoch 217/50000
#
# Epoch 00217: val_loss did not improve from 29.10901
# Epoch 218/50000
#
# Epoch 00218: val_loss did not improve from 29.10901
# Epoch 219/50000
#
# Epoch 00219: val_loss did not improve from 29.10901
# Epoch 220/50000
#
# Epoch 00220: val_loss did not improve from 29.10901
# Epoch 221/50000
#
# Epoch 00221: val_loss did not improve from 29.10901
# Epoch 222/50000
#
# Epoch 00222: val_loss did not improve from 29.10901
# Epoch 223/50000
#
# Epoch 00223: val_loss did not improve from 29.10901
# Epoch 224/50000
#
# Epoch 00224: val_loss did not improve from 29.10901
# Epoch 225/50000
#
# Epoch 00225: val_loss did not improve from 29.10901
# Epoch 226/50000
#
# Epoch 00226: val_loss did not improve from 29.10901
# Epoch 227/50000
#
# Epoch 00227: val_loss improved from 29.10901 to 28.44314, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 228/50000
#
# Epoch 00228: val_loss did not improve from 28.44314
# Epoch 229/50000
#
# Epoch 00229: val_loss did not improve from 28.44314
# Epoch 230/50000
#
# Epoch 00230: val_loss did not improve from 28.44314
# Epoch 231/50000
#
# Epoch 00231: val_loss did not improve from 28.44314
# Epoch 232/50000
#
# Epoch 00232: val_loss did not improve from 28.44314
# Epoch 233/50000
#
# Epoch 00233: val_loss did not improve from 28.44314
# Epoch 234/50000
#
# Epoch 00234: val_loss did not improve from 28.44314
# Epoch 235/50000
#
# Epoch 00235: val_loss did not improve from 28.44314
# Epoch 236/50000
#
# Epoch 00236: val_loss did not improve from 28.44314
# Epoch 237/50000
#
# Epoch 00237: val_loss did not improve from 28.44314
# Epoch 238/50000
#
# Epoch 00238: val_loss did not improve from 28.44314
# Epoch 239/50000
#
# Epoch 00239: val_loss did not improve from 28.44314
# Epoch 240/50000
#
# Epoch 00240: val_loss did not improve from 28.44314
# Epoch 241/50000
#
# Epoch 00241: val_loss did not improve from 28.44314
# Epoch 242/50000
#
# Epoch 00242: val_loss did not improve from 28.44314
# Epoch 243/50000
#
# Epoch 00243: val_loss did not improve from 28.44314
# Epoch 244/50000
#
# Epoch 00244: val_loss did not improve from 28.44314
# Epoch 245/50000
#
# Epoch 00245: val_loss did not improve from 28.44314
# Epoch 246/50000
#
# Epoch 00246: val_loss did not improve from 28.44314
# Epoch 247/50000
#
# Epoch 00247: val_loss did not improve from 28.44314
# Epoch 248/50000
#
# Epoch 00248: val_loss did not improve from 28.44314
# Epoch 249/50000
#
# Epoch 00249: val_loss did not improve from 28.44314
# Epoch 250/50000
#
# Epoch 00250: val_loss did not improve from 28.44314
# Epoch 251/50000
#
# Epoch 00251: val_loss did not improve from 28.44314
# Epoch 252/50000
#
# Epoch 00252: val_loss did not improve from 28.44314
# Epoch 253/50000
#
# Epoch 00253: val_loss did not improve from 28.44314
# Epoch 254/50000
#
# Epoch 00254: val_loss did not improve from 28.44314
# Epoch 255/50000
#
# Epoch 00255: val_loss did not improve from 28.44314
# Epoch 256/50000
#
# Epoch 00256: val_loss did not improve from 28.44314
# Epoch 257/50000
#
# Epoch 00257: val_loss did not improve from 28.44314
# Epoch 258/50000
#
# Epoch 00258: val_loss did not improve from 28.44314
# Epoch 259/50000
#
# Epoch 00259: val_loss did not improve from 28.44314
# Epoch 260/50000
#
# Epoch 00260: val_loss did not improve from 28.44314
# Epoch 261/50000
#
# Epoch 00261: val_loss did not improve from 28.44314
# Epoch 262/50000
#
# Epoch 00262: val_loss did not improve from 28.44314
# Epoch 263/50000
#
# Epoch 00263: val_loss did not improve from 28.44314
# Epoch 264/50000
#
# Epoch 00264: val_loss did not improve from 28.44314
# Epoch 265/50000
#
# Epoch 00265: val_loss did not improve from 28.44314
# Epoch 266/50000
#
# Epoch 00266: val_loss did not improve from 28.44314
# Epoch 267/50000
#
# Epoch 00267: val_loss did not improve from 28.44314
# Epoch 268/50000
#
# Epoch 00268: val_loss did not improve from 28.44314
# Epoch 269/50000
#
# Epoch 00269: val_loss did not improve from 28.44314
# Epoch 270/50000
#
# Epoch 00270: val_loss did not improve from 28.44314
# Epoch 271/50000
#
# Epoch 00271: val_loss did not improve from 28.44314
# Epoch 272/50000
#
# Epoch 00272: val_loss did not improve from 28.44314
# Epoch 273/50000
#
# Epoch 00273: val_loss did not improve from 28.44314
# Epoch 274/50000
#
# Epoch 00274: val_loss did not improve from 28.44314
# Epoch 275/50000
#
# Epoch 00275: val_loss did not improve from 28.44314
# Epoch 276/50000
#
# Epoch 00276: val_loss did not improve from 28.44314
# Epoch 277/50000
#
# Epoch 00277: val_loss did not improve from 28.44314
# Epoch 278/50000
#
# Epoch 00278: val_loss did not improve from 28.44314
# Epoch 279/50000
#
# Epoch 00279: val_loss did not improve from 28.44314
# Epoch 280/50000
#
# Epoch 00280: val_loss did not improve from 28.44314
# Epoch 281/50000
#
# Epoch 00281: val_loss did not improve from 28.44314
# Epoch 282/50000
#
# Epoch 00282: val_loss did not improve from 28.44314
# Epoch 283/50000
#
# Epoch 00283: val_loss did not improve from 28.44314
# Epoch 284/50000
#
# Epoch 00284: val_loss did not improve from 28.44314
# Epoch 285/50000
#
# Epoch 00285: val_loss did not improve from 28.44314
# Epoch 286/50000
#
# Epoch 00286: val_loss did not improve from 28.44314
# Epoch 287/50000
#
# Epoch 00287: val_loss did not improve from 28.44314
# Epoch 288/50000
#
# Epoch 00288: val_loss did not improve from 28.44314
# Epoch 289/50000
#
# Epoch 00289: val_loss did not improve from 28.44314
# Epoch 290/50000
#
# Epoch 00290: val_loss did not improve from 28.44314
# Epoch 291/50000
#
# Epoch 00291: val_loss did not improve from 28.44314
# Epoch 292/50000
#
# Epoch 00292: val_loss did not improve from 28.44314
# Epoch 293/50000
#
# Epoch 00293: val_loss did not improve from 28.44314
# Epoch 294/50000
#
# Epoch 00294: val_loss did not improve from 28.44314
# Epoch 295/50000
#
# Epoch 00295: val_loss did not improve from 28.44314
# Epoch 296/50000
#
# Epoch 00296: val_loss did not improve from 28.44314
# Epoch 297/50000
#
# Epoch 00297: val_loss did not improve from 28.44314
# Epoch 298/50000
#
# Epoch 00298: val_loss did not improve from 28.44314
# Epoch 299/50000
#
# Epoch 00299: val_loss did not improve from 28.44314
# Epoch 300/50000
#
# Epoch 00300: val_loss did not improve from 28.44314
# Epoch 301/50000
#
# Epoch 00301: val_loss did not improve from 28.44314
# Epoch 302/50000
#
# Epoch 00302: val_loss improved from 28.44314 to 27.93352, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 303/50000
#
# Epoch 00303: val_loss did not improve from 27.93352
# Epoch 304/50000
#
# Epoch 00304: val_loss did not improve from 27.93352
# Epoch 305/50000
#
# Epoch 00305: val_loss did not improve from 27.93352
# Epoch 306/50000
#
# Epoch 00306: val_loss did not improve from 27.93352
# Epoch 307/50000
#
# Epoch 00307: val_loss did not improve from 27.93352
# Epoch 308/50000
#
# Epoch 00308: val_loss did not improve from 27.93352
# Epoch 309/50000
#
# Epoch 00309: val_loss did not improve from 27.93352
# Epoch 310/50000
#
# Epoch 00310: val_loss did not improve from 27.93352
# Epoch 311/50000
#
# Epoch 00311: val_loss did not improve from 27.93352
# Epoch 312/50000
#
# Epoch 00312: val_loss did not improve from 27.93352
# Epoch 313/50000
#
# Epoch 00313: val_loss did not improve from 27.93352
# Epoch 314/50000
#
# Epoch 00314: val_loss did not improve from 27.93352
# Epoch 315/50000
#
# Epoch 00315: val_loss did not improve from 27.93352
# Epoch 316/50000
#
# Epoch 00316: val_loss did not improve from 27.93352
# Epoch 317/50000
# Epoch 00317: val_loss did not improve from 27.93352
# Epoch 318/50000
#
# Epoch 00318: val_loss did not improve from 27.93352
# Epoch 319/50000
#
# Epoch 00319: val_loss did not improve from 27.93352
# Epoch 320/50000
#
# Epoch 00320: val_loss did not improve from 27.93352
# Epoch 321/50000
#
# Epoch 00321: val_loss did not improve from 27.93352
# Epoch 322/50000
#
# Epoch 00322: val_loss did not improve from 27.93352
# Epoch 323/50000
#
# Epoch 00323: val_loss did not improve from 27.93352
# Epoch 324/50000
#
# Epoch 00324: val_loss did not improve from 27.93352
# Epoch 325/50000
#
# Epoch 00325: val_loss did not improve from 27.93352
# Epoch 326/50000
#
# Epoch 00326: val_loss did not improve from 27.93352
# Epoch 327/50000
#
# Epoch 00327: val_loss did not improve from 27.93352
# Epoch 328/50000
#
# Epoch 00328: val_loss did not improve from 27.93352
# Epoch 329/50000
#
# Epoch 00329: val_loss did not improve from 27.93352
# Epoch 330/50000
#
# Epoch 00330: val_loss did not improve from 27.93352
# Epoch 331/50000
#
# Epoch 00331: val_loss did not improve from 27.93352
# Epoch 332/50000
#
# Epoch 00332: val_loss did not improve from 27.93352
# Epoch 333/50000
#
# Epoch 00333: val_loss did not improve from 27.93352
# Epoch 334/50000
#
# Epoch 00334: val_loss did not improve from 27.93352
# Epoch 335/50000
#
# Epoch 00335: val_loss did not improve from 27.93352
# Epoch 336/50000
#
# Epoch 00336: val_loss did not improve from 27.93352
# Epoch 337/50000
#
# Epoch 00337: val_loss did not improve from 27.93352
# Epoch 338/50000
#
# Epoch 00338: val_loss did not improve from 27.93352
# Epoch 339/50000
#
# Epoch 00339: val_loss did not improve from 27.93352
# Epoch 340/50000
#
# Epoch 00340: val_loss did not improve from 27.93352
# Epoch 341/50000
#
# Epoch 00341: val_loss did not improve from 27.93352
# Epoch 342/50000
#
# Epoch 00342: val_loss did not improve from 27.93352
# Epoch 343/50000
#
# Epoch 00343: val_loss did not improve from 27.93352
# Epoch 344/50000
#
# Epoch 00344: val_loss did not improve from 27.93352
# Epoch 345/50000
#
# Epoch 00345: val_loss did not improve from 27.93352
# Epoch 346/50000
#
# Epoch 00346: val_loss did not improve from 27.93352
# Epoch 347/50000
#
# Epoch 00347: val_loss did not improve from 27.93352
# Epoch 348/50000
#
# Epoch 00348: val_loss did not improve from 27.93352
# Epoch 349/50000
#
# Epoch 00349: val_loss did not improve from 27.93352
# Epoch 350/50000
#
# Epoch 00350: val_loss did not improve from 27.93352
# Epoch 351/50000
#
# Epoch 00351: val_loss did not improve from 27.93352
# Epoch 352/50000
#
# Epoch 00352: val_loss did not improve from 27.93352
# Epoch 353/50000
#
# Epoch 00353: val_loss did not improve from 27.93352
# Epoch 354/50000
#
# Epoch 00354: val_loss did not improve from 27.93352
# Epoch 355/50000
#
# Epoch 00355: val_loss did not improve from 27.93352
# Epoch 356/50000
#
# Epoch 00356: val_loss did not improve from 27.93352
# Epoch 357/50000
#
# Epoch 00357: val_loss did not improve from 27.93352
# Epoch 358/50000
#
# Epoch 00358: val_loss did not improve from 27.93352
# Epoch 359/50000
#
# Epoch 00359: val_loss did not improve from 27.93352
# Epoch 360/50000
#
# Epoch 00360: val_loss did not improve from 27.93352
# Epoch 361/50000
#
# Epoch 00361: val_loss did not improve from 27.93352
# Epoch 362/50000
#
# Epoch 00362: val_loss did not improve from 27.93352
# Epoch 363/50000
#
# Epoch 00363: val_loss did not improve from 27.93352
# Epoch 364/50000
#
# Epoch 00364: val_loss did not improve from 27.93352
# Epoch 365/50000
#
# Epoch 00365: val_loss did not improve from 27.93352
# Epoch 366/50000
#
# Epoch 00366: val_loss did not improve from 27.93352
# Epoch 367/50000
#
# Epoch 00367: val_loss did not improve from 27.93352
# Epoch 368/50000
#
# Epoch 00368: val_loss did not improve from 27.93352
# Epoch 369/50000
#
# Epoch 00369: val_loss did not improve from 27.93352
# Epoch 370/50000
#
# Epoch 00370: val_loss did not improve from 27.93352
# Epoch 371/50000
#
# Epoch 00371: val_loss did not improve from 27.93352
# Epoch 372/50000
#
# Epoch 00372: val_loss improved from 27.93352 to 27.90053, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 373/50000
#
# Epoch 00373: val_loss did not improve from 27.90053
# Epoch 374/50000
#
# Epoch 00374: val_loss improved from 27.90053 to 27.87132, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 375/50000
#
# Epoch 00375: val_loss did not improve from 27.87132
# Epoch 376/50000
#
# Epoch 00376: val_loss did not improve from 27.87132
# Epoch 377/50000
#
# Epoch 00377: val_loss did not improve from 27.87132
# Epoch 378/50000
#
# Epoch 00378: val_loss did not improve from 27.87132
# Epoch 379/50000
#
# Epoch 00379: val_loss did not improve from 27.87132
# Epoch 380/50000
#
# Epoch 00380: val_loss did not improve from 27.87132
# Epoch 381/50000
#
# Epoch 00381: val_loss did not improve from 27.87132
# Epoch 382/50000
#
# Epoch 00382: val_loss did not improve from 27.87132
# Epoch 383/50000
#
# Epoch 00383: val_loss did not improve from 27.87132
# Epoch 384/50000
#
# Epoch 00384: val_loss did not improve from 27.87132
# Epoch 385/50000
#
# Epoch 00385: val_loss did not improve from 27.87132
# Epoch 386/50000
#
# Epoch 00386: val_loss did not improve from 27.87132
# Epoch 387/50000
#
# Epoch 00387: val_loss did not improve from 27.87132
# Epoch 388/50000
#
# Epoch 00388: val_loss did not improve from 27.87132
# Epoch 389/50000
#
# Epoch 00389: val_loss did not improve from 27.87132
# Epoch 390/50000
#
# Epoch 00390: val_loss did not improve from 27.87132
# Epoch 391/50000
#
# Epoch 00391: val_loss did not improve from 27.87132
# Epoch 392/50000
#
# Epoch 00392: val_loss did not improve from 27.87132
# Epoch 393/50000
#
# Epoch 00393: val_loss did not improve from 27.87132
# Epoch 394/50000
#
# Epoch 00394: val_loss did not improve from 27.87132
# Epoch 395/50000
#
# Epoch 00395: val_loss did not improve from 27.87132
# Epoch 396/50000
#
# Epoch 00396: val_loss improved from 27.87132 to 27.77516, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 397/50000
#
# Epoch 00397: val_loss did not improve from 27.77516
# Epoch 398/50000
#
# Epoch 00398: val_loss did not improve from 27.77516
# Epoch 399/50000
#
# Epoch 00399: val_loss did not improve from 27.77516
# Epoch 400/50000
#
# Epoch 00400: val_loss did not improve from 27.77516
# Epoch 401/50000
#
# Epoch 00401: val_loss did not improve from 27.77516
# Epoch 402/50000
#
# Epoch 00402: val_loss did not improve from 27.77516
# Epoch 403/50000
#
# Epoch 00403: val_loss did not improve from 27.77516
# Epoch 404/50000
#
# Epoch 00404: val_loss did not improve from 27.77516
# Epoch 405/50000
#
# Epoch 00405: val_loss did not improve from 27.77516
# Epoch 406/50000
#
# Epoch 00406: val_loss did not improve from 27.77516
# Epoch 407/50000
#
# Epoch 00407: val_loss improved from 27.77516 to 27.76013, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 408/50000
#
# Epoch 00408: val_loss improved from 27.76013 to 27.69811, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 409/50000
#
# Epoch 00409: val_loss did not improve from 27.69811
# Epoch 410/50000
#
# Epoch 00410: val_loss did not improve from 27.69811
# Epoch 411/50000
#
# Epoch 00411: val_loss did not improve from 27.69811
# Epoch 412/50000
#
# Epoch 00412: val_loss did not improve from 27.69811
# Epoch 413/50000
#
# Epoch 00413: val_loss did not improve from 27.69811
# Epoch 414/50000
#
# Epoch 00414: val_loss did not improve from 27.69811
# Epoch 415/50000
#
# Epoch 00415: val_loss did not improve from 27.69811
# Epoch 416/50000
#
# Epoch 00416: val_loss did not improve from 27.69811
# Epoch 417/50000
#
# Epoch 00417: val_loss did not improve from 27.69811
# Epoch 418/50000
#
# Epoch 00418: val_loss did not improve from 27.69811
# Epoch 419/50000
#
# Epoch 00419: val_loss did not improve from 27.69811
# Epoch 420/50000
#
# Epoch 00420: val_loss did not improve from 27.69811
# Epoch 421/50000
#
# Epoch 00421: val_loss did not improve from 27.69811
# Epoch 422/50000
#
# Epoch 00422: val_loss did not improve from 27.69811
# Epoch 423/50000
#
# Epoch 00423: val_loss did not improve from 27.69811
# Epoch 424/50000
#
# Epoch 00424: val_loss did not improve from 27.69811
# Epoch 425/50000
#
# Epoch 00425: val_loss did not improve from 27.69811
# Epoch 426/50000
#
# Epoch 00426: val_loss did not improve from 27.69811
# Epoch 427/50000
#
# Epoch 00427: val_loss did not improve from 27.69811
# Epoch 428/50000
#
# Epoch 00428: val_loss did not improve from 27.69811
# Epoch 429/50000
#
# Epoch 00429: val_loss did not improve from 27.69811
# Epoch 430/50000
# Epoch 00430: val_loss did not improve from 27.69811
# Epoch 431/50000
#
# Epoch 00431: val_loss did not improve from 27.69811
# Epoch 432/50000
#
# Epoch 00432: val_loss did not improve from 27.69811
# Epoch 433/50000
#
# Epoch 00433: val_loss did not improve from 27.69811
# Epoch 434/50000
#
# Epoch 00434: val_loss did not improve from 27.69811
# Epoch 435/50000
#
# Epoch 00435: val_loss did not improve from 27.69811
# Epoch 436/50000
#
# Epoch 00436: val_loss did not improve from 27.69811
# Epoch 437/50000
#
# Epoch 00437: val_loss did not improve from 27.69811
# Epoch 438/50000
#
# Epoch 00438: val_loss did not improve from 27.69811
# Epoch 439/50000
#
# Epoch 00439: val_loss improved from 27.69811 to 27.63036, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 440/50000
#
# Epoch 00440: val_loss did not improve from 27.63036
# Epoch 441/50000
#
# Epoch 00441: val_loss did not improve from 27.63036
# Epoch 442/50000
#
# Epoch 00442: val_loss did not improve from 27.63036
# Epoch 443/50000
#
# Epoch 00443: val_loss improved from 27.63036 to 27.62320, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 444/50000
#
# Epoch 00444: val_loss did not improve from 27.62320
# Epoch 445/50000
#
# Epoch 00445: val_loss did not improve from 27.62320
# Epoch 446/50000
#
# Epoch 00446: val_loss did not improve from 27.62320
# Epoch 447/50000
#
# Epoch 00447: val_loss did not improve from 27.62320
# Epoch 448/50000
#
# Epoch 00448: val_loss did not improve from 27.62320
# Epoch 449/50000
#
# Epoch 00449: val_loss did not improve from 27.62320
# Epoch 450/50000
#
# Epoch 00450: val_loss did not improve from 27.62320
# Epoch 451/50000
#
# Epoch 00451: val_loss improved from 27.62320 to 27.58039, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 452/50000
#
# Epoch 00452: val_loss did not improve from 27.58039
# Epoch 453/50000
#
# Epoch 00453: val_loss did not improve from 27.58039
# Epoch 454/50000
#
# Epoch 00454: val_loss improved from 27.58039 to 27.44939, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 455/50000
#
# Epoch 00455: val_loss did not improve from 27.44939
# Epoch 456/50000
#
# Epoch 00456: val_loss did not improve from 27.44939
# Epoch 457/50000
#
# Epoch 00457: val_loss did not improve from 27.44939
# Epoch 458/50000
#
# Epoch 00458: val_loss did not improve from 27.44939
# Epoch 459/50000
#
# Epoch 00459: val_loss did not improve from 27.44939
# Epoch 460/50000
#
# Epoch 00460: val_loss did not improve from 27.44939
# Epoch 461/50000
#
# Epoch 00461: val_loss did not improve from 27.44939
# Epoch 462/50000
#
# Epoch 00462: val_loss did not improve from 27.44939
# Epoch 463/50000
#
# Epoch 00463: val_loss did not improve from 27.44939
# Epoch 464/50000
#
# Epoch 00464: val_loss did not improve from 27.44939
# Epoch 465/50000
#
# Epoch 00465: val_loss did not improve from 27.44939
# Epoch 466/50000
#
# Epoch 00466: val_loss did not improve from 27.44939
# Epoch 467/50000
#
# Epoch 00467: val_loss did not improve from 27.44939
# Epoch 468/50000
#
# Epoch 00468: val_loss did not improve from 27.44939
# Epoch 469/50000
#
# Epoch 00469: val_loss did not improve from 27.44939
# Epoch 470/50000
#
# Epoch 00470: val_loss did not improve from 27.44939
# Epoch 471/50000
#
# Epoch 00471: val_loss did not improve from 27.44939
# Epoch 472/50000
#
# Epoch 00472: val_loss did not improve from 27.44939
# Epoch 473/50000
#
# Epoch 00473: val_loss did not improve from 27.44939
# Epoch 474/50000
#
# Epoch 00474: val_loss improved from 27.44939 to 27.38691, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 475/50000
#
# Epoch 00475: val_loss did not improve from 27.38691
# Epoch 476/50000
#
# Epoch 00476: val_loss did not improve from 27.38691
# Epoch 477/50000
#
# Epoch 00477: val_loss did not improve from 27.38691
# Epoch 478/50000
#
# Epoch 00478: val_loss did not improve from 27.38691
# Epoch 479/50000
#
# Epoch 00479: val_loss did not improve from 27.38691
# Epoch 480/50000
#
# Epoch 00480: val_loss did not improve from 27.38691
# Epoch 481/50000
#
# Epoch 00481: val_loss did not improve from 27.38691
# Epoch 482/50000
#
# Epoch 00482: val_loss improved from 27.38691 to 27.09953, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 483/50000
#
# Epoch 00483: val_loss improved from 27.09953 to 27.03444, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 484/50000
#
# Epoch 00484: val_loss did not improve from 27.03444
# Epoch 485/50000
#
# Epoch 00485: val_loss did not improve from 27.03444
# Epoch 486/50000
#
# Epoch 00486: val_loss did not improve from 27.03444
# Epoch 487/50000
#
# Epoch 00487: val_loss did not improve from 27.03444
# Epoch 488/50000
#
# Epoch 00488: val_loss did not improve from 27.03444
# Epoch 489/50000
#
# Epoch 00489: val_loss did not improve from 27.03444
# Epoch 490/50000
#
# Epoch 00490: val_loss did not improve from 27.03444
# Epoch 491/50000
#
# Epoch 00491: val_loss did not improve from 27.03444
# Epoch 492/50000
#
# Epoch 00492: val_loss did not improve from 27.03444
# Epoch 493/50000
#
# Epoch 00493: val_loss improved from 27.03444 to 26.98614, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 494/50000
#
# Epoch 00494: val_loss did not improve from 26.98614
# Epoch 495/50000
#
# Epoch 00495: val_loss did not improve from 26.98614
# Epoch 496/50000
#
# Epoch 00496: val_loss did not improve from 26.98614
# Epoch 497/50000
#
# Epoch 00497: val_loss did not improve from 26.98614
# Epoch 498/50000
#
# Epoch 00498: val_loss did not improve from 26.98614
# Epoch 499/50000
#
# Epoch 00499: val_loss did not improve from 26.98614
# Epoch 500/50000
#
# Epoch 00500: val_loss did not improve from 26.98614
# Epoch 501/50000
#
# Epoch 00501: val_loss did not improve from 26.98614
# Epoch 502/50000
#
# Epoch 00502: val_loss did not improve from 26.98614
# Epoch 503/50000
#
# Epoch 00503: val_loss did not improve from 26.98614
# Epoch 504/50000
#
# Epoch 00504: val_loss did not improve from 26.98614
# Epoch 505/50000
#
# Epoch 00505: val_loss did not improve from 26.98614
# Epoch 506/50000
#
# Epoch 00506: val_loss did not improve from 26.98614
# Epoch 507/50000
#
# Epoch 00507: val_loss did not improve from 26.98614
# Epoch 508/50000
#
# Epoch 00508: val_loss did not improve from 26.98614
# Epoch 509/50000
#
# Epoch 00509: val_loss did not improve from 26.98614
# Epoch 510/50000
#
# Epoch 00510: val_loss did not improve from 26.98614
# Epoch 511/50000
#
# Epoch 00511: val_loss did not improve from 26.98614
# Epoch 512/50000
#
# Epoch 00512: val_loss did not improve from 26.98614
# Epoch 513/50000
#
# Epoch 00513: val_loss did not improve from 26.98614
# Epoch 514/50000
#
# Epoch 00514: val_loss did not improve from 26.98614
# Epoch 515/50000
#
# Epoch 00515: val_loss did not improve from 26.98614
# Epoch 516/50000
#
# Epoch 00516: val_loss did not improve from 26.98614
# Epoch 517/50000
#
# Epoch 00517: val_loss improved from 26.98614 to 26.72734, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 518/50000
#
# Epoch 00518: val_loss did not improve from 26.72734
# Epoch 519/50000
#
# Epoch 00519: val_loss did not improve from 26.72734
# Epoch 520/50000
#
# Epoch 00520: val_loss did not improve from 26.72734
# Epoch 521/50000
#
# Epoch 00521: val_loss did not improve from 26.72734
# Epoch 522/50000
#
# Epoch 00522: val_loss did not improve from 26.72734
# Epoch 523/50000
#
# Epoch 00523: val_loss did not improve from 26.72734
# Epoch 524/50000
#
# Epoch 00524: val_loss did not improve from 26.72734
# Epoch 525/50000
#
# Epoch 00525: val_loss did not improve from 26.72734
# Epoch 526/50000
#
# Epoch 00526: val_loss did not improve from 26.72734
# Epoch 527/50000
#
# Epoch 00527: val_loss did not improve from 26.72734
# Epoch 528/50000
#
# Epoch 00528: val_loss did not improve from 26.72734
# Epoch 529/50000
#
# Epoch 00529: val_loss did not improve from 26.72734
# Epoch 530/50000
#
# Epoch 00530: val_loss did not improve from 26.72734
# Epoch 531/50000
#
# Epoch 00531: val_loss did not improve from 26.72734
# Epoch 532/50000
#
# Epoch 00532: val_loss did not improve from 26.72734
# Epoch 533/50000
#
# Epoch 00533: val_loss did not improve from 26.72734
# Epoch 534/50000
#
# Epoch 00534: val_loss did not improve from 26.72734
# Epoch 535/50000
#
# Epoch 00535: val_loss did not improve from 26.72734
# Epoch 536/50000
#
# Epoch 00536: val_loss did not improve from 26.72734
# Epoch 537/50000
#
# Epoch 00537: val_loss did not improve from 26.72734
# Epoch 538/50000
# Epoch 00538: val_loss did not improve from 26.72734
# Epoch 539/50000
#
# Epoch 00539: val_loss did not improve from 26.72734
# Epoch 540/50000
#
# Epoch 00540: val_loss did not improve from 26.72734
# Epoch 541/50000
#
# Epoch 00541: val_loss did not improve from 26.72734
# Epoch 542/50000
#
# Epoch 00542: val_loss did not improve from 26.72734
# Epoch 543/50000
#
# Epoch 00543: val_loss did not improve from 26.72734
# Epoch 544/50000
#
# Epoch 00544: val_loss did not improve from 26.72734
# Epoch 545/50000
#
# Epoch 00545: val_loss did not improve from 26.72734
# Epoch 546/50000
#
# Epoch 00546: val_loss did not improve from 26.72734
# Epoch 547/50000
#
# Epoch 00547: val_loss did not improve from 26.72734
# Epoch 548/50000
#
# Epoch 00548: val_loss did not improve from 26.72734
# Epoch 549/50000
#
# Epoch 00549: val_loss improved from 26.72734 to 26.45395, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 550/50000
#
# Epoch 00550: val_loss did not improve from 26.45395
# Epoch 551/50000
#
# Epoch 00551: val_loss did not improve from 26.45395
# Epoch 552/50000
#
# Epoch 00552: val_loss did not improve from 26.45395
# Epoch 553/50000
#
# Epoch 00553: val_loss did not improve from 26.45395
# Epoch 554/50000
#
# Epoch 00554: val_loss did not improve from 26.45395
# Epoch 555/50000
#
# Epoch 00555: val_loss improved from 26.45395 to 26.43212, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 556/50000
#
# Epoch 00556: val_loss did not improve from 26.43212
# Epoch 557/50000
#
# Epoch 00557: val_loss did not improve from 26.43212
# Epoch 558/50000
#
# Epoch 00558: val_loss did not improve from 26.43212
# Epoch 559/50000
#
# Epoch 00559: val_loss did not improve from 26.43212
# Epoch 560/50000
#
# Epoch 00560: val_loss did not improve from 26.43212
# Epoch 561/50000
#
# Epoch 00561: val_loss did not improve from 26.43212
# Epoch 562/50000
#
# Epoch 00562: val_loss did not improve from 26.43212
# Epoch 563/50000
#
# Epoch 00563: val_loss did not improve from 26.43212
# Epoch 564/50000
#
# Epoch 00564: val_loss did not improve from 26.43212
# Epoch 565/50000
#
# Epoch 00565: val_loss did not improve from 26.43212
# Epoch 566/50000
#
# Epoch 00566: val_loss did not improve from 26.43212
# Epoch 567/50000
#
# Epoch 00567: val_loss did not improve from 26.43212
# Epoch 568/50000
#
# Epoch 00568: val_loss did not improve from 26.43212
# Epoch 569/50000
#
# Epoch 00569: val_loss did not improve from 26.43212
# Epoch 570/50000
#
# Epoch 00570: val_loss did not improve from 26.43212
# Epoch 571/50000
#
# Epoch 00571: val_loss did not improve from 26.43212
# Epoch 572/50000
#
# Epoch 00572: val_loss did not improve from 26.43212
# Epoch 573/50000
#
# Epoch 00573: val_loss did not improve from 26.43212
# Epoch 574/50000
#
# Epoch 00574: val_loss did not improve from 26.43212
# Epoch 575/50000
#
# Epoch 00575: val_loss did not improve from 26.43212
# Epoch 576/50000
#
# Epoch 00576: val_loss did not improve from 26.43212
# Epoch 577/50000
#
# Epoch 00577: val_loss did not improve from 26.43212
# Epoch 578/50000
#
# Epoch 00578: val_loss did not improve from 26.43212
# Epoch 579/50000
#
# Epoch 00579: val_loss did not improve from 26.43212
# Epoch 580/50000
#
# Epoch 00580: val_loss did not improve from 26.43212
# Epoch 581/50000
#
# Epoch 00581: val_loss did not improve from 26.43212
# Epoch 582/50000
#
# Epoch 00582: val_loss did not improve from 26.43212
# Epoch 583/50000
#
# Epoch 00583: val_loss did not improve from 26.43212
# Epoch 584/50000
#
# Epoch 00584: val_loss did not improve from 26.43212
# Epoch 585/50000
#
# Epoch 00585: val_loss did not improve from 26.43212
# Epoch 586/50000
#
# Epoch 00586: val_loss did not improve from 26.43212
# Epoch 587/50000
#
# Epoch 00587: val_loss did not improve from 26.43212
# Epoch 588/50000
#
# Epoch 00588: val_loss did not improve from 26.43212
# Epoch 589/50000
#
# Epoch 00589: val_loss did not improve from 26.43212
# Epoch 590/50000
#
# Epoch 00590: val_loss did not improve from 26.43212
# Epoch 591/50000
#
# Epoch 00591: val_loss did not improve from 26.43212
# Epoch 592/50000
#
# Epoch 00592: val_loss did not improve from 26.43212
# Epoch 593/50000
#
# Epoch 00593: val_loss did not improve from 26.43212
# Epoch 594/50000
#
# Epoch 00594: val_loss did not improve from 26.43212
# Epoch 595/50000
#
# Epoch 00595: val_loss did not improve from 26.43212
# Epoch 596/50000
#
# Epoch 00596: val_loss did not improve from 26.43212
# Epoch 597/50000
#
# Epoch 00597: val_loss improved from 26.43212 to 25.91349, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 598/50000
#
# Epoch 00598: val_loss did not improve from 25.91349
# Epoch 599/50000
#
# Epoch 00599: val_loss did not improve from 25.91349
# Epoch 600/50000
#
# Epoch 00600: val_loss did not improve from 25.91349
# Epoch 601/50000
#
# Epoch 00601: val_loss did not improve from 25.91349
# Epoch 602/50000
#
# Epoch 00602: val_loss did not improve from 25.91349
# Epoch 603/50000
#
# Epoch 00603: val_loss did not improve from 25.91349
# Epoch 604/50000
#
# Epoch 00604: val_loss did not improve from 25.91349
# Epoch 605/50000
#
# Epoch 00605: val_loss did not improve from 25.91349
# Epoch 606/50000
#
# Epoch 00606: val_loss did not improve from 25.91349
# Epoch 607/50000
#
# Epoch 00607: val_loss did not improve from 25.91349
# Epoch 608/50000
#
# Epoch 00608: val_loss did not improve from 25.91349
# Epoch 609/50000
#
# Epoch 00609: val_loss did not improve from 25.91349
# Epoch 610/50000
#
# Epoch 00610: val_loss did not improve from 25.91349
# Epoch 611/50000
#
# Epoch 00611: val_loss did not improve from 25.91349
# Epoch 612/50000
#
# Epoch 00612: val_loss did not improve from 25.91349
# Epoch 613/50000
#
# Epoch 00613: val_loss did not improve from 25.91349
# Epoch 614/50000
#
# Epoch 00614: val_loss did not improve from 25.91349
# Epoch 615/50000
#
# Epoch 00615: val_loss did not improve from 25.91349
# Epoch 616/50000
#
# Epoch 00616: val_loss did not improve from 25.91349
# Epoch 617/50000
#
# Epoch 00617: val_loss did not improve from 25.91349
# Epoch 618/50000
#
# Epoch 00618: val_loss did not improve from 25.91349
# Epoch 619/50000
#
# Epoch 00619: val_loss did not improve from 25.91349
# Epoch 620/50000
#
# Epoch 00620: val_loss did not improve from 25.91349
# Epoch 621/50000
#
# Epoch 00621: val_loss did not improve from 25.91349
# Epoch 622/50000
#
# Epoch 00622: val_loss did not improve from 25.91349
# Epoch 623/50000
#
# Epoch 00623: val_loss did not improve from 25.91349
# Epoch 624/50000
#
# Epoch 00624: val_loss did not improve from 25.91349
# Epoch 625/50000
#
# Epoch 00625: val_loss did not improve from 25.91349
# Epoch 626/50000
#
# Epoch 00626: val_loss did not improve from 25.91349
# Epoch 627/50000
#
# Epoch 00627: val_loss did not improve from 25.91349
# Epoch 628/50000
#
# Epoch 00628: val_loss did not improve from 25.91349
# Epoch 629/50000
#
# Epoch 00629: val_loss did not improve from 25.91349
# Epoch 630/50000
#
# Epoch 00630: val_loss did not improve from 25.91349
# Epoch 631/50000
#
# Epoch 00631: val_loss did not improve from 25.91349
# Epoch 632/50000
#
# Epoch 00632: val_loss did not improve from 25.91349
# Epoch 633/50000
#
# ...
# Epoch 1427/50000
#
# Epoch 01427: val_loss did not improve from 24.27579
# Epoch 1428/50000
#
# Epoch 01428: val_loss did not improve from 24.27579
# Epoch 1429/50000
#
# Epoch 01429: val_loss did not improve from 24.27579
# Epoch 1430/50000
#
# Epoch 01430: val_loss did not improve from 24.27579
# Epoch 1431/50000
#
# Epoch 01431: val_loss did not improve from 24.27579
# Epoch 1432/50000
#
# Epoch 01432: val_loss did not improve from 24.27579
# Epoch 1433/50000
#
# Epoch 01433: val_loss did not improve from 24.27579
# Epoch 1434/50000
#
# Epoch 01434: val_loss did not improve from 24.27579
# Epoch 1435/50000
#
# Epoch 01435: val_loss did not improve from 24.27579
# Epoch 1436/50000
#
# Epoch 01436: val_loss did not improve from 24.27579
# Epoch 1437/50000
#
# Epoch 01437: val_loss did not improve from 24.27579
# Epoch 1438/50000
#
# Epoch 01438: val_loss did not improve from 24.27579
# Epoch 1439/50000
#
# Epoch 01439: val_loss did not improve from 24.27579
# Epoch 1440/50000
#
# Epoch 01440: val_loss did not improve from 24.27579
# Epoch 1441/50000
#
# Epoch 01441: val_loss did not improve from 24.27579
# Epoch 1442/50000
#
# Epoch 01442: val_loss did not improve from 24.27579
# Epoch 1443/50000
#
# Epoch 01443: val_loss did not improve from 24.27579
# Epoch 1444/50000
#
# Epoch 01444: val_loss did not improve from 24.27579
# Epoch 1445/50000
#
# Epoch 01445: val_loss did not improve from 24.27579
# Epoch 1446/50000
#
# Epoch 01446: val_loss did not improve from 24.27579
# Epoch 1447/50000
#
# Epoch 01447: val_loss did not improve from 24.27579
# Epoch 1448/50000
#
# Epoch 01448: val_loss did not improve from 24.27579
# Epoch 1449/50000
#
# Epoch 01449: val_loss did not improve from 24.27579
# Epoch 1450/50000
#
# Epoch 01450: val_loss did not improve from 24.27579
# Epoch 1451/50000
#
# Epoch 01451: val_loss did not improve from 24.27579
# Epoch 1452/50000
#
# Epoch 01452: val_loss did not improve from 24.27579
# Epoch 1453/50000
#
# Epoch 01453: val_loss did not improve from 24.27579
# Epoch 1454/50000
# Epoch 01454: val_loss did not improve from 24.27579
# Epoch 1455/50000
#
# Epoch 01455: val_loss did not improve from 24.27579
# Epoch 1456/50000
#
# Epoch 01456: val_loss did not improve from 24.27579
# Epoch 1457/50000
#
# Epoch 01457: val_loss did not improve from 24.27579
# Epoch 1458/50000
#
# Epoch 01458: val_loss did not improve from 24.27579
# Epoch 1459/50000
#
# Epoch 01459: val_loss did not improve from 24.27579
# Epoch 1460/50000
#
# Epoch 01460: val_loss did not improve from 24.27579
# Epoch 1461/50000
#
# Epoch 01461: val_loss did not improve from 24.27579
# Epoch 1462/50000
#
# Epoch 01462: val_loss did not improve from 24.27579
# Epoch 1463/50000
#
# Epoch 01463: val_loss did not improve from 24.27579
# Epoch 1464/50000
#
# Epoch 01464: val_loss did not improve from 24.27579
# Epoch 1465/50000
#
# Epoch 01465: val_loss did not improve from 24.27579
# Epoch 1466/50000
#
# Epoch 01466: val_loss did not improve from 24.27579
# Epoch 1467/50000
#
# Epoch 01467: val_loss did not improve from 24.27579
# Epoch 1468/50000
#
# Epoch 01468: val_loss did not improve from 24.27579
# Epoch 1469/50000
#
# Epoch 01469: val_loss did not improve from 24.27579
# Epoch 1470/50000
#
# Epoch 01470: val_loss did not improve from 24.27579
# Epoch 1471/50000
#
# Epoch 01471: val_loss did not improve from 24.27579
# Epoch 1472/50000
#
# Epoch 01472: val_loss did not improve from 24.27579
# Epoch 1473/50000
#
# Epoch 01473: val_loss did not improve from 24.27579
# Epoch 1474/50000
#
# Epoch 01474: val_loss did not improve from 24.27579
# Epoch 1475/50000
#
# Epoch 01475: val_loss did not improve from 24.27579
# Epoch 1476/50000
#
# Epoch 01476: val_loss did not improve from 24.27579
# Epoch 1477/50000
#
# Epoch 01477: val_loss did not improve from 24.27579
# Epoch 1478/50000
#
# Epoch 01478: val_loss did not improve from 24.27579
# Epoch 1479/50000
#
# Epoch 01479: val_loss did not improve from 24.27579
# Epoch 1480/50000
#
# Epoch 01480: val_loss did not improve from 24.27579
# Epoch 1481/50000
#
# Epoch 01481: val_loss did not improve from 24.27579
# Epoch 1482/50000
#
# Epoch 01482: val_loss did not improve from 24.27579
# Epoch 1483/50000
#
# Epoch 01483: val_loss did not improve from 24.27579
# Epoch 1484/50000
#
# Epoch 01484: val_loss did not improve from 24.27579
# Epoch 1485/50000
#
# Epoch 01485: val_loss did not improve from 24.27579
# Epoch 1486/50000
#
# Epoch 01486: val_loss did not improve from 24.27579
# Epoch 1487/50000
#
# Epoch 01487: val_loss did not improve from 24.27579
# Epoch 1488/50000
#
# Epoch 01488: val_loss did not improve from 24.27579
# Epoch 1489/50000
#
# Epoch 01489: val_loss did not improve from 24.27579
# Epoch 1490/50000
#
# Epoch 01490: val_loss did not improve from 24.27579
# Epoch 1491/50000
#
# Epoch 01491: val_loss did not improve from 24.27579
# Epoch 1492/50000
#
# Epoch 01492: val_loss did not improve from 24.27579
# Epoch 1493/50000
#
# Epoch 01493: val_loss did not improve from 24.27579
# Epoch 1494/50000
#
# Epoch 01494: val_loss did not improve from 24.27579
# Epoch 1495/50000
#
# Epoch 01495: val_loss did not improve from 24.27579
# Epoch 1496/50000
#
# Epoch 01496: val_loss did not improve from 24.27579
# Epoch 1497/50000
#
# Epoch 01497: val_loss did not improve from 24.27579
# Epoch 1498/50000
#
# Epoch 01498: val_loss did not improve from 24.27579
# Epoch 1499/50000
#
# Epoch 01499: val_loss did not improve from 24.27579
# Epoch 1500/50000
#
# Epoch 01500: val_loss did not improve from 24.27579
# Epoch 1501/50000
#
# Epoch 01501: val_loss did not improve from 24.27579
# Epoch 1502/50000
#
# Epoch 01502: val_loss did not improve from 24.27579
# Epoch 1503/50000
#
# Epoch 01503: val_loss did not improve from 24.27579
# Epoch 1504/50000
#
# Epoch 01504: val_loss did not improve from 24.27579
# Epoch 1505/50000
#
# Epoch 01505: val_loss did not improve from 24.27579
# Epoch 1506/50000
#
# Epoch 01506: val_loss did not improve from 24.27579
# Epoch 1507/50000
#
# Epoch 01507: val_loss did not improve from 24.27579
# Epoch 1508/50000
#
# Epoch 01508: val_loss did not improve from 24.27579
# Epoch 1509/50000
#
# Epoch 01509: val_loss did not improve from 24.27579
# Epoch 1510/50000
#
# Epoch 01510: val_loss did not improve from 24.27579
# Epoch 1511/50000
#
# Epoch 01511: val_loss did not improve from 24.27579
# Epoch 1512/50000
#
# Epoch 01512: val_loss did not improve from 24.27579
# Epoch 1513/50000
#
# Epoch 01513: val_loss did not improve from 24.27579
# Epoch 1514/50000
#
# Epoch 01514: val_loss did not improve from 24.27579
# Epoch 1515/50000
#
# Epoch 01515: val_loss did not improve from 24.27579
# Epoch 1516/50000
#
# Epoch 01516: val_loss did not improve from 24.27579
# Epoch 1517/50000
#
# Epoch 01517: val_loss did not improve from 24.27579
# Epoch 1518/50000
#
# Epoch 01518: val_loss improved from 24.27579 to 24.16034, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 1519/50000
#
# Epoch 01519: val_loss did not improve from 24.16034
# Epoch 1520/50000
#
# Epoch 01520: val_loss did not improve from 24.16034
# Epoch 1521/50000
#
# Epoch 01521: val_loss did not improve from 24.16034
# Epoch 1522/50000
#
# Epoch 01522: val_loss did not improve from 24.16034
# Epoch 1523/50000
#
# Epoch 01523: val_loss did not improve from 24.16034
# Epoch 1524/50000
#
# Epoch 01524: val_loss did not improve from 24.16034
# Epoch 1525/50000
#
# Epoch 01525: val_loss did not improve from 24.16034
# Epoch 1526/50000
#
# Epoch 01526: val_loss did not improve from 24.16034
# Epoch 1527/50000
#
# Epoch 01527: val_loss did not improve from 24.16034
# Epoch 1528/50000
#
# Epoch 01528: val_loss did not improve from 24.16034
# Epoch 1529/50000
#
# Epoch 01529: val_loss did not improve from 24.16034
# Epoch 1530/50000
#
# Epoch 01530: val_loss did not improve from 24.16034
# Epoch 1531/50000
#
# Epoch 01531: val_loss did not improve from 24.16034
# Epoch 1532/50000
#
# Epoch 01532: val_loss did not improve from 24.16034
# Epoch 1533/50000
#
# Epoch 01533: val_loss did not improve from 24.16034
# Epoch 1534/50000
#
# Epoch 01534: val_loss did not improve from 24.16034
# Epoch 1535/50000
#
# Epoch 01535: val_loss did not improve from 24.16034
# Epoch 1536/50000
#
# Epoch 01536: val_loss did not improve from 24.16034
# Epoch 1537/50000
#
# Epoch 01537: val_loss did not improve from 24.16034
# Epoch 1538/50000
#
# Epoch 01538: val_loss did not improve from 24.16034
# Epoch 1539/50000
#
# Epoch 01539: val_loss did not improve from 24.16034
# Epoch 1540/50000
#
# Epoch 01540: val_loss did not improve from 24.16034
# Epoch 1541/50000
#
# Epoch 01541: val_loss did not improve from 24.16034
# Epoch 1542/50000
#
# Epoch 01542: val_loss did not improve from 24.16034
# Epoch 1543/50000
#
# Epoch 01543: val_loss did not improve from 24.16034
# Epoch 1544/50000
#
# Epoch 01544: val_loss did not improve from 24.16034
# Epoch 1545/50000
#
# Epoch 01545: val_loss did not improve from 24.16034
# Epoch 1546/50000
#
# Epoch 01546: val_loss did not improve from 24.16034
# Epoch 1547/50000
#
# Epoch 01547: val_loss did not improve from 24.16034
# Epoch 1548/50000
#
# Epoch 01548: val_loss did not improve from 24.16034
# Epoch 1549/50000
#
# Epoch 01549: val_loss did not improve from 24.16034
# Epoch 1550/50000
#
# Epoch 01550: val_loss did not improve from 24.16034
# Epoch 1551/50000
#
# Epoch 01551: val_loss did not improve from 24.16034
# Epoch 1552/50000
#
# Epoch 01552: val_loss did not improve from 24.16034
# Epoch 1553/50000
#
# Epoch 01553: val_loss did not improve from 24.16034
# Epoch 1554/50000
#
# Epoch 01554: val_loss did not improve from 24.16034
# Epoch 1555/50000
#
# Epoch 01555: val_loss did not improve from 24.16034
# Epoch 1556/50000
#
# Epoch 01556: val_loss did not improve from 24.16034
# Epoch 1557/50000
#
# Epoch 01557: val_loss did not improve from 24.16034
# Epoch 1558/50000
#
# Epoch 01558: val_loss improved from 24.16034 to 23.84509, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 1559/50000
#
# Epoch 01559: val_loss did not improve from 23.84509
# Epoch 1560/50000
#
# Epoch 01560: val_loss did not improve from 23.84509
# Epoch 1561/50000
#
# Epoch 01561: val_loss did not improve from 23.84509
# Epoch 1562/50000
#
# Epoch 01562: val_loss did not improve from 23.84509
# Epoch 1563/50000
#
# Epoch 01563: val_loss did not improve from 23.84509
# Epoch 1564/50000
#
# Epoch 01564: val_loss did not improve from 23.84509
# Epoch 1565/50000
#
# Epoch 01565: val_loss did not improve from 23.84509
# Epoch 1566/50000
#
# Epoch 01566: val_loss did not improve from 23.84509
# Epoch 1567/50000
#
# Epoch 01567: val_loss did not improve from 23.84509
# Epoch 1568/50000
#
# Epoch 01568: val_loss did not improve from 23.84509
# Epoch 1569/50000
# Epoch 01569: val_loss did not improve from 23.84509
# Epoch 1570/50000
#
# Epoch 01570: val_loss did not improve from 23.84509
# Epoch 1571/50000
#
# Epoch 01571: val_loss did not improve from 23.84509
# Epoch 1572/50000
#
# Epoch 01572: val_loss did not improve from 23.84509
# Epoch 1573/50000
#
# Epoch 01573: val_loss did not improve from 23.84509
# Epoch 1574/50000
#
# Epoch 01574: val_loss did not improve from 23.84509
# Epoch 1575/50000
#
# Epoch 01575: val_loss did not improve from 23.84509
# Epoch 1576/50000
#
# Epoch 01576: val_loss did not improve from 23.84509
# Epoch 1577/50000
#
# Epoch 01577: val_loss did not improve from 23.84509
# Epoch 1578/50000
#
# Epoch 01578: val_loss did not improve from 23.84509
# Epoch 1579/50000
#
# Epoch 01579: val_loss did not improve from 23.84509
# Epoch 1580/50000
#
# Epoch 01580: val_loss did not improve from 23.84509
# Epoch 1581/50000
#
# Epoch 01581: val_loss did not improve from 23.84509
# Epoch 1582/50000
#
# Epoch 01582: val_loss did not improve from 23.84509
# Epoch 1583/50000
#
# Epoch 01583: val_loss did not improve from 23.84509
# Epoch 1584/50000
#
# Epoch 01584: val_loss did not improve from 23.84509
# Epoch 1585/50000
#
# Epoch 01585: val_loss did not improve from 23.84509
# Epoch 1586/50000
#
# Epoch 01586: val_loss did not improve from 23.84509
# Epoch 1587/50000
#
# Epoch 01587: val_loss did not improve from 23.84509
# Epoch 1588/50000
#
# Epoch 01588: val_loss did not improve from 23.84509
# Epoch 1589/50000
#
# Epoch 01589: val_loss did not improve from 23.84509
# Epoch 1590/50000
#
# Epoch 01590: val_loss did not improve from 23.84509
# Epoch 1591/50000
#
# Epoch 01591: val_loss did not improve from 23.84509
# Epoch 1592/50000
#
# Epoch 01592: val_loss did not improve from 23.84509
# Epoch 1593/50000
#
# Epoch 01593: val_loss did not improve from 23.84509
# Epoch 1594/50000
#
# Epoch 01594: val_loss did not improve from 23.84509
# Epoch 1595/50000
#
# Epoch 01595: val_loss did not improve from 23.84509
# Epoch 1596/50000
#
# Epoch 01596: val_loss did not improve from 23.84509
# Epoch 1597/50000
#
# Epoch 01597: val_loss did not improve from 23.84509
# Epoch 1598/50000
#
# Epoch 01598: val_loss did not improve from 23.84509
# Epoch 1599/50000
#
# Epoch 01599: val_loss did not improve from 23.84509
# Epoch 1600/50000
#
# Epoch 01600: val_loss did not improve from 23.84509
# Epoch 1601/50000
#
# Epoch 01601: val_loss did not improve from 23.84509
# Epoch 1602/50000
#
# Epoch 01602: val_loss did not improve from 23.84509
# Epoch 1603/50000
#
# Epoch 01603: val_loss did not improve from 23.84509
# Epoch 1604/50000
#
# Epoch 01604: val_loss did not improve from 23.84509
# Epoch 1605/50000
#
# Epoch 01605: val_loss did not improve from 23.84509
# Epoch 1606/50000
#
# Epoch 01606: val_loss did not improve from 23.84509
# Epoch 1607/50000
#
# Epoch 01607: val_loss did not improve from 23.84509
# Epoch 1608/50000
#
# Epoch 01608: val_loss did not improve from 23.84509
# Epoch 1609/50000
#
# Epoch 01609: val_loss did not improve from 23.84509
# Epoch 1610/50000
#
# Epoch 01610: val_loss did not improve from 23.84509
# Epoch 1611/50000
#
# Epoch 01611: val_loss did not improve from 23.84509
# Epoch 1612/50000
#
# Epoch 01612: val_loss did not improve from 23.84509
# Epoch 1613/50000
#
# Epoch 01613: val_loss did not improve from 23.84509
# Epoch 1614/50000
#
# Epoch 01614: val_loss did not improve from 23.84509
# Epoch 1615/50000
#
# Epoch 01615: val_loss did not improve from 23.84509
# Epoch 1616/50000
#
# Epoch 01616: val_loss did not improve from 23.84509
# Epoch 1617/50000
#
# Epoch 01617: val_loss did not improve from 23.84509
# Epoch 1618/50000
#
# Epoch 01618: val_loss did not improve from 23.84509
# Epoch 1619/50000
#
# Epoch 01619: val_loss did not improve from 23.84509
# Epoch 1620/50000
#
# Epoch 01620: val_loss did not improve from 23.84509
# Epoch 1621/50000
#
# Epoch 01621: val_loss did not improve from 23.84509
# Epoch 1622/50000
#
# Epoch 01622: val_loss did not improve from 23.84509
# Epoch 1623/50000
#
# Epoch 01623: val_loss did not improve from 23.84509
# Epoch 1624/50000
#
# Epoch 01624: val_loss did not improve from 23.84509
# Epoch 1625/50000
#
# Epoch 01625: val_loss did not improve from 23.84509
# Epoch 1626/50000
#
# Epoch 01626: val_loss did not improve from 23.84509
# Epoch 1627/50000
#
# Epoch 01627: val_loss did not improve from 23.84509
# Epoch 1628/50000
#
# Epoch 01628: val_loss did not improve from 23.84509
# Epoch 1629/50000
#
# Epoch 01629: val_loss did not improve from 23.84509
# Epoch 1630/50000
#
# Epoch 01630: val_loss did not improve from 23.84509
# Epoch 1631/50000
#
# Epoch 01631: val_loss did not improve from 23.84509
# Epoch 1632/50000
#
# Epoch 01632: val_loss did not improve from 23.84509
# Epoch 1633/50000
#
# Epoch 01633: val_loss did not improve from 23.84509
# Epoch 1634/50000
#
# Epoch 01634: val_loss did not improve from 23.84509
# Epoch 1635/50000
#
# Epoch 01635: val_loss improved from 23.84509 to 23.73751, saving model to training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5
# Epoch 1636/50000
#
# Epoch 01636: val_loss did not improve from 23.73751
# Epoch 1637/50000
#
# Epoch 01637: val_loss did not improve from 23.73751
# Epoch 1638/50000
#
# Epoch 01638: val_loss did not improve from 23.73751
# Epoch 1639/50000
#
# Epoch 01639: val_loss did not improve from 23.73751
# Epoch 1640/50000
#
# Epoch 01640: val_loss did not improve from 23.73751
# Epoch 1641/50000
#
# Epoch 01641: val_loss did not improve from 23.73751
# Epoch 1642/50000
#
# Epoch 01642: val_loss did not improve from 23.73751
# Epoch 1643/50000
#
# Epoch 01643: val_loss did not improve from 23.73751
# Epoch 1644/50000
#
# Epoch 01644: val_loss did not improve from 23.73751
# Epoch 1645/50000
#
# Epoch 01645: val_loss did not improve from 23.73751
# Epoch 1646/50000
#
# Epoch 01646: val_loss did not improve from 23.73751
# Epoch 1647/50000
#
# Epoch 01647: val_loss did not improve from 23.73751
# Epoch 1648/50000
#
# Epoch 01648: val_loss did not improve from 23.73751
# Epoch 1649/50000
#
# Epoch 01649: val_loss did not improve from 23.73751
# Epoch 1650/50000
#
# Epoch 01650: val_loss did not improve from 23.73751
# Epoch 1651/50000

# %%
df = pd.DataFrame(hist.history)
df.plot(subplots=True, figsize=(12,15))

# %% [markdown]
# # Testing

# %%
model.load_weights('training/unseen_speakers/results/weights-lfw-crop-ctc-cls-v5.hdf5')
model.input[0]

# %%
from keras.models import Model, Sequential

# %%
prediction_model = Model(inputs = model.input[0], outputs = [model.get_layer('softmax').output,model.get_layer('classification').output])

# %%
SVG(model_to_dot(prediction_model, show_layer_names=True, show_shapes=True).create(prog='dot', format='svg'))

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import itertools


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=False):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(11, 11))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
g_test=datagen(data_partition='test',batch_size=16)
ctc_test = []
cls_test = []
true_data = []
for i in range(128):
    print(i/128, end='\r')
    x,y=next(g_test)
    for i in range(0,16):
        X = x['the_input'][i]
    #     print(X)
        y_true = x['source_str'][i]#words[np.argmax(y[0][i])]
#         print(y_true)
    #     print(Y)append(x['source_str'])
        ctc_preds, cls_preds = prediction_model.predict(np.expand_dims(X,0))
        cls = words[np.argmax(cls_preds)]
        decoded = K.ctc_decode(y_pred=ctc_preds, input_length=(30,) ,greedy=True, beam_width=50, top_paths=50)
        paths = [path.eval(session=K.get_session()) for path in decoded[0]]
        logprobs  = decoded[1].eval(session=K.get_session())
        preds = []
        for path in paths:
            preds.append(''.join([chr(65+v) for v in path[0] ]))
        preds = np.array(preds)[0]
        ctc_test.append(preds)
        cls_test.append(cls)
        true_data.append(y_true)

# %%
pd.DataFrame(np.transpose([ctc_test,cls_test,true_data]),columns=['ctc','cls','true'])

# %%
from sklearn.metrics import confusion_matrix
import pylab as pl

labels = words
true_data, ctc_test, cls_test = np.array(true_data), np.array(ctc_test), np.array(cls_test)
print(true_data.shape, ctc_test.shape, cls_test.shape)
cm = confusion_matrix(true_data, ctc_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix ctc')
cm = confusion_matrix(true_data, cls_test, labels)
plot_confusion_matrix(cm,words,title='Confusion Matrix cls')
